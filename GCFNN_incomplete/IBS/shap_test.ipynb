# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'H':0,'C':1,'D':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)

#随机缺失，生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
from sklearn.preprocessing import OneHotEncoder
from numpy.random import randint
import warnings
warnings.filterwarnings("ignore")
def get_sn(view_num, alldata_len, missing_rate):
    """Randomly generate incomplete data information, simulate partial view data with complete view data
    :param view_num:view number
    :param alldata_len:number of samples
    :param missing_rate:Defined in section 3.2 of the paper
    :return:Sn
    """
    one_rate = 1-missing_rate
    if one_rate <= (1 / view_num):
        #enc = OneHotEncoder(n_values=view_num)
        enc = OneHotEncoder()
        view_preserve = enc.fit_transform(randint(0, view_num, size=(alldata_len, 1))).toarray()
        return view_preserve
    error = 1
    if one_rate == 1:
        matrix = randint(1, 2, size=(alldata_len, view_num))
        return matrix
    while error >= 0.005:
        #enc = OneHotEncoder(n_values=view_num)
        enc = OneHotEncoder()
        view_preserve = enc.fit_transform(randint(0, view_num, size=(alldata_len, 1))).toarray()
        one_num = view_num * alldata_len * one_rate - alldata_len
        ratio = one_num / (view_num * alldata_len)
        matrix_iter = (randint(0, 100, size=(alldata_len, view_num)) < int(ratio * 100)).astype(np.int)
        a = np.sum(((matrix_iter + view_preserve) > 1).astype(np.int))
        one_num_iter = one_num / (1 - a / one_num)
        ratio = one_num_iter / (view_num * alldata_len)
        matrix_iter = (randint(0, 100, size=(alldata_len, view_num)) < int(ratio * 100)).astype(np.int)
        matrix = ((matrix_iter + view_preserve) > 0).astype(np.int)
        ratio = np.sum(matrix) / (view_num * alldata_len)
        error = abs(one_rate - ratio)
    return matrix
Mask     = np.ones([np.shape(X_set[0])[0], M])
print(sum(Mask))
missrate = 0.5
Mask     = get_sn(2,X_set[0].shape[0],missrate)
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
print(sum(Mask)) 
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (444, 1034) (444, 43) (444, 1)
# Index(['1.T.0', '1.T.1', '1.T.2', '1.T.3', '1.T.4', '1.T.5', '1.T.6', '10.T.0',
#        '10.T.1', '10.T.2',
#        ...
#        '8.T.4', '8.T.5', '8.T.6', '9.T.0', '9.T.1', '9.T.2', '9.T.3', '9.T.4',
#        '9.T.6', '9.T.Flare'],
#       dtype='object', name='Sample', length=444)
# 数据完整率missing_rate : 1.0
# 集合所有样本重构数据表： (444, 1034) (444, 43) (444, 1)
# 888.0
# 444.0
# 标签转换为one-hot编码： (444, 2) 139.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 4, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1',f1_cv)
print('average maxf1',sum(f1_cv)/5)
print('acc',acc_cv)
print('average maxacc',sum(acc_cv)/5)
print('auc',auc_cv)
print('average maxauc',sum(auc_cv)/5)
# Out:
# Train F1: 0.8325
# 00050: TRAIN| LT=1.617 LP=0.545 LKL=6.394 LPS=0.891 LKLS=11.658 |
# Test F1: 0.8414
# Test ACC: 0.7416
# Test AUC: 0.7904
# Train F1: 0.8767
# 00100: TRAIN| LT=1.217 LP=0.398 LKL=6.731 LPS=0.641 LKLS=11.163 |
# Test F1: 0.9008
# Test ACC: 0.8539
# Test AUC: 0.8706
# Train F1: 0.8588
# 00150: TRAIN| LT=1.271 LP=0.442 LKL=6.542 LPS=0.668 LKLS=9.549 |
# Test F1: 0.9008
# Test ACC: 0.8539
# Test AUC: 0.9028
# Train F1: 0.8657
# 00200: TRAIN| LT=1.174 LP=0.384 LKL=6.392 LPS=0.644 LKLS=8.202 |
# Test F1: 0.8939
# Test ACC: 0.8427
# Test AUC: 0.8958
# Train F1: 0.8711
# 00250: TRAIN| LT=1.198 LP=0.401 LKL=6.524 LPS=0.647 LKLS=8.439 |
# Test F1: 0.9091
# Test ACC: 0.8652
# Test AUC: 0.9192
# Train F1: 0.8667
# 00300: TRAIN| LT=1.179 LP=0.406 LKL=6.365 LPS=0.636 LKLS=7.309 |
# Test F1: 0.8955
# Test ACC: 0.8427
# Test AUC: 0.9186
# Train F1: 0.8755
# 00350: TRAIN| LT=1.152 LP=0.382 LKL=6.481 LPS=0.632 LKLS=7.313 |
# Test F1: 0.9091
# Test ACC: 0.8652
# Test AUC: 0.9052
# Train F1: 0.8543
# 00400: TRAIN| LT=1.106 LP=0.357 LKL=6.443 LPS=0.611 LKLS=7.415 |
# Test F1: 0.9023
# Test ACC: 0.8539
# Test AUC: 0.9063
# Train F1: 0.8792
# 00450: TRAIN| LT=1.103 LP=0.362 LKL=6.446 LPS=0.604 LKLS=7.263 |
# Test F1: 0.8955
# Test ACC: 0.8427
# Test AUC: 0.9192
# Train F1: 0.8794
# 00500: TRAIN| LT=1.119 LP=0.372 LKL=6.321 LPS=0.614 LKLS=7.026 |
# Test F1: 0.8824
# Test ACC: 0.8202
# Test AUC: 0.9198
# Train F1: 0.8867
# 00550: TRAIN| LT=1.137 LP=0.395 LKL=6.216 LPS=0.618 LKLS=6.272 |
# Test F1: 0.9023
# Test ACC: 0.8539
# Test AUC: 0.9075
# Train F1: 0.8846
# 00600: TRAIN| LT=1.103 LP=0.366 LKL=6.316 LPS=0.607 LKLS=6.611 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.9192
# Train F1: 0.8794
# 00650: TRAIN| LT=1.131 LP=0.383 LKL=6.388 LPS=0.616 LKLS=6.828 |
# Test F1: 0.8955
# Test ACC: 0.8427
# Test AUC: 0.9133
# Train F1: 0.8998
# 00700: TRAIN| LT=1.123 LP=0.375 LKL=6.219 LPS=0.624 LKLS=6.209 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.9116
# Train F1: 0.8855
# 00750: TRAIN| LT=1.105 LP=0.360 LKL=6.275 LPS=0.618 LKLS=6.434 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.9087
# Train F1: 0.8958
# 00800: TRAIN| LT=1.145 LP=0.388 LKL=6.329 LPS=0.630 LKLS=6.398 |
# Test F1: 0.8955
# Test ACC: 0.8427
# Test AUC: 0.9192
# Train F1: 0.8969
# 00850: TRAIN| LT=1.079 LP=0.346 LKL=6.332 LPS=0.608 LKLS=6.170 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.9186
# Train F1: 0.9101
# 00900: TRAIN| LT=1.147 LP=0.389 LKL=6.461 LPS=0.627 LKLS=6.637 |
# Test F1: 0.8955
# Test ACC: 0.8427
# Test AUC: 0.9145
# Train F1: 0.9036
# 00950: TRAIN| LT=1.086 LP=0.356 LKL=6.347 LPS=0.606 LKLS=6.152 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.9110
# Train F1: 0.8859
# 01000: TRAIN| LT=1.091 LP=0.362 LKL=6.418 LPS=0.603 LKLS=6.165 |
# Test F1: 0.8872
# Test ACC: 0.8315
# Test AUC: 0.9087
# Train F1: 0.8893
# 01050: TRAIN| LT=1.094 LP=0.363 LKL=6.365 LPS=0.608 LKLS=6.031 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.9133
# Train F1: 0.8906
# 01100: TRAIN| LT=1.119 LP=0.377 LKL=6.528 LPS=0.614 LKLS=6.282 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.9116
# Train F1: 0.8960
# 01150: TRAIN| LT=1.096 LP=0.352 LKL=6.392 LPS=0.622 LKLS=5.831 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.9110
# Train F1: 0.8922
# 01200: TRAIN| LT=1.101 LP=0.357 LKL=6.447 LPS=0.618 LKLS=6.108 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.9110
# Train F1: 0.8880
# 01250: TRAIN| LT=1.095 LP=0.371 LKL=6.424 LPS=0.601 LKLS=5.927 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.9186
# Train F1: 0.8893
# 01300: TRAIN| LT=1.084 LP=0.345 LKL=6.477 LPS=0.614 LKLS=6.084 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.9169
# Train F1: 0.9060
# 01350: TRAIN| LT=1.089 LP=0.353 LKL=6.290 LPS=0.618 LKLS=5.454 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.9139
# Train F1: 0.8981
# 01400: TRAIN| LT=1.092 LP=0.370 LKL=6.360 LPS=0.603 LKLS=5.541 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.9139
# Train F1: 0.8935
# 01450: TRAIN| LT=1.068 LP=0.332 LKL=6.412 LPS=0.615 LKLS=5.740 |
# Test F1: 0.8571
# Test ACC: 0.7753
# Test AUC: 0.8864
# Train F1: 0.8931
# 01500: TRAIN| LT=1.069 LP=0.345 LKL=6.305 LPS=0.607 LKLS=5.308 |
# Test F1: 0.8571
# Test ACC: 0.7753
# Test AUC: 0.8981
# Train F1: 0.8940
# 01550: TRAIN| LT=1.061 LP=0.331 LKL=6.337 LPS=0.612 LKLS=5.434 |
# Test F1: 0.8571
# Test ACC: 0.7753
# Test AUC: 0.8858
# Train F1: 0.8943
# 01600: TRAIN| LT=1.051 LP=0.315 LKL=6.395 LPS=0.618 LKLS=5.423 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.9098
# Train F1: 0.9040
# 01650: TRAIN| LT=1.087 LP=0.357 LKL=6.451 LPS=0.611 LKLS=5.433 |
# Test F1: 0.8571
# Test ACC: 0.7753
# Test AUC: 0.9069
# Train F1: 0.8902
# 01700: TRAIN| LT=1.053 LP=0.330 LKL=6.405 LPS=0.604 LKLS=5.481 |
# Test F1: 0.8511
# Test ACC: 0.7640
# Test AUC: 0.8794
# Train F1: 0.9040
# 01750: TRAIN| LT=1.055 LP=0.332 LKL=6.376 LPS=0.607 LKLS=5.244 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.9075
# Train F1: 0.8985
# 01800: TRAIN| LT=1.049 LP=0.326 LKL=6.362 LPS=0.608 LKLS=5.183 |
# Test F1: 0.8571
# Test ACC: 0.7753
# Test AUC: 0.8806
# Train F1: 0.9049
# 01850: TRAIN| LT=1.040 LP=0.323 LKL=6.340 LPS=0.603 LKLS=5.123 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.8835
# Train F1: 0.9067
# 01900: TRAIN| LT=1.057 LP=0.336 LKL=6.321 LPS=0.607 LKLS=5.129 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.8964
# Train F1: 0.8985
# 01950: TRAIN| LT=1.039 LP=0.317 LKL=6.261 LPS=0.610 LKLS=4.938 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.8817
# Train F1: 0.9023
# 02000: TRAIN| LT=1.030 LP=0.319 LKL=6.260 LPS=0.599 LKLS=4.884 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.8899
# f1: 0.9090909090909091
# acc: 0.8651685393258427
# auc: 0.9192037470725996
# Train F1: 0.8410
# 00050: TRAIN| LT=1.564 LP=0.516 LKL=6.474 LPS=0.862 LKLS=12.132 |
# Test F1: 0.8652
# Test ACC: 0.7865
# Test AUC: 0.8770
# Train F1: 0.8527
# 00100: TRAIN| LT=1.220 LP=0.395 LKL=6.625 LPS=0.648 LKLS=11.094 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8952
# Train F1: 0.8828
# 00150: TRAIN| LT=1.189 LP=0.404 LKL=6.411 LPS=0.631 LKLS=8.997 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8811
# Train F1: 0.8867
# 00200: TRAIN| LT=1.159 LP=0.399 LKL=6.388 LPS=0.611 LKLS=8.468 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8753
# Train F1: 0.8825
# 00250: TRAIN| LT=1.159 LP=0.384 LKL=6.308 LPS=0.635 LKLS=7.621 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8770
# Train F1: 0.8777
# 00300: TRAIN| LT=1.174 LP=0.395 LKL=6.451 LPS=0.631 LKLS=8.374 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8876
# Train F1: 0.8676
# 00350: TRAIN| LT=1.150 LP=0.392 LKL=6.420 LPS=0.618 LKLS=7.667 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8765
# Train F1: 0.8953
# 00400: TRAIN| LT=1.120 LP=0.378 LKL=6.311 LPS=0.608 LKLS=7.147 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8759
# Train F1: 0.8689
# 00450: TRAIN| LT=1.137 LP=0.396 LKL=6.265 LPS=0.608 LKLS=7.054 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8753
# Train F1: 0.8825
# 00500: TRAIN| LT=1.137 LP=0.398 LKL=6.217 LPS=0.609 LKLS=6.740 |
# Test F1: 0.8824
# Test ACC: 0.8202
# Test AUC: 0.8847
# Train F1: 0.8876
# 00550: TRAIN| LT=1.121 LP=0.374 LKL=6.335 LPS=0.614 LKLS=7.030 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8747
# Train F1: 0.8855
# 00600: TRAIN| LT=1.157 LP=0.418 LKL=6.243 LPS=0.612 LKLS=6.472 |
# Test F1: 0.8824
# Test ACC: 0.8202
# Test AUC: 0.8835
# Train F1: 0.8906
# 00650: TRAIN| LT=1.107 LP=0.376 LKL=6.229 LPS=0.604 LKLS=6.504 |
# Test F1: 0.8824
# Test ACC: 0.8202
# Test AUC: 0.8759
# Train F1: 0.8786
# 00700: TRAIN| LT=1.094 LP=0.346 LKL=6.303 LPS=0.620 LKLS=6.531 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8770
# Train F1: 0.8885
# 00750: TRAIN| LT=1.143 LP=0.400 LKL=6.247 LPS=0.616 LKLS=6.358 |
# Test F1: 0.8824
# Test ACC: 0.8202
# Test AUC: 0.8841
# Train F1: 0.8956
# 00800: TRAIN| LT=1.114 LP=0.387 LKL=6.143 LPS=0.608 LKLS=5.797 |
# Test F1: 0.8824
# Test ACC: 0.8202
# Test AUC: 0.8741
# Train F1: 0.8868
# 00850: TRAIN| LT=1.128 LP=0.403 LKL=6.249 LPS=0.600 LKLS=6.267 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.8823
# Train F1: 0.8902
# 00900: TRAIN| LT=1.121 LP=0.374 LKL=6.375 LPS=0.618 LKLS=6.523 |
# Test F1: 0.8824
# Test ACC: 0.8202
# Test AUC: 0.8448
# Train F1: 0.8716
# 00950: TRAIN| LT=1.091 LP=0.360 LKL=6.242 LPS=0.608 LKLS=6.108 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.8689
# Train F1: 0.9046
# 01000: TRAIN| LT=1.111 LP=0.379 LKL=6.286 LPS=0.608 LKLS=6.197 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.8718
# Train F1: 0.8812
# 01050: TRAIN| LT=1.118 LP=0.377 LKL=6.251 LPS=0.620 LKLS=5.863 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.8677
# Train F1: 0.9019
# 01100: TRAIN| LT=1.078 LP=0.345 LKL=6.268 LPS=0.613 LKLS=5.795 |
# Test F1: 0.8841
# Test ACC: 0.8202
# Test AUC: 0.8689
# Train F1: 0.8893
# 01150: TRAIN| LT=1.086 LP=0.355 LKL=6.428 LPS=0.605 LKLS=6.199 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.8507
# Train F1: 0.8918
# 01200: TRAIN| LT=1.104 LP=0.372 LKL=6.325 LPS=0.610 LKLS=5.904 |
# Test F1: 0.8824
# Test ACC: 0.8202
# Test AUC: 0.8595
# Train F1: 0.8893
# 01250: TRAIN| LT=1.069 LP=0.338 LKL=6.559 LPS=0.601 LKLS=6.496 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.8437
# Train F1: 0.8948
# 01300: TRAIN| LT=1.096 LP=0.367 LKL=6.337 LPS=0.608 LKLS=5.748 |
# Test F1: 0.8824
# Test ACC: 0.8202
# Test AUC: 0.8589
# Train F1: 0.8931
# 01350: TRAIN| LT=1.093 LP=0.361 LKL=6.453 LPS=0.608 LKLS=5.987 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8882
# Train F1: 0.9140
# 01400: TRAIN| LT=1.086 LP=0.349 LKL=6.350 LPS=0.618 LKLS=5.567 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8876
# Train F1: 0.8843
# 01450: TRAIN| LT=1.065 LP=0.337 LKL=6.399 LPS=0.606 LKLS=5.773 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8741
# Train F1: 0.8977
# 01500: TRAIN| LT=1.072 LP=0.344 LKL=6.429 LPS=0.606 LKLS=5.750 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8741
# Train F1: 0.8968
# 01550: TRAIN| LT=1.088 LP=0.355 LKL=6.440 LPS=0.610 LKLS=5.799 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.8683
# Train F1: 0.9077
# 01600: TRAIN| LT=1.056 LP=0.329 LKL=6.463 LPS=0.605 LKLS=5.711 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8571
# Train F1: 0.8931
# 01650: TRAIN| LT=1.073 LP=0.342 LKL=6.471 LPS=0.610 LKLS=5.654 |
# Test F1: 0.8824
# Test ACC: 0.8202
# Test AUC: 0.8794
# Train F1: 0.9026
# 01700: TRAIN| LT=1.063 LP=0.331 LKL=6.419 LPS=0.613 LKLS=5.476 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8448
# Train F1: 0.8985
# 01750: TRAIN| LT=1.045 LP=0.317 LKL=6.478 LPS=0.608 LKLS=5.626 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.8683
# Train F1: 0.8960
# 01800: TRAIN| LT=1.081 LP=0.350 LKL=6.480 LPS=0.611 LKLS=5.553 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8536
# Train F1: 0.8990
# 01850: TRAIN| LT=1.050 LP=0.339 LKL=6.415 LPS=0.594 LKLS=5.275 |
# Test F1: 0.8806
# Test ACC: 0.8202
# Test AUC: 0.8788
# Train F1: 0.8902
# 01900: TRAIN| LT=1.043 LP=0.322 LKL=6.358 LPS=0.606 LKLS=5.125 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8788
# Train F1: 0.8951
# 01950: TRAIN| LT=1.050 LP=0.330 LKL=6.361 LPS=0.605 LKLS=5.128 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8841
# Train F1: 0.8947
# 02000: TRAIN| LT=1.054 LP=0.328 LKL=6.375 LPS=0.611 LKLS=5.116 |
# Test F1: 0.8889
# Test ACC: 0.8315
# Test AUC: 0.8776
# f1: 0.888888888888889
# acc: 0.8314606741573034
# auc: 0.8951990632318501
# Train F1: 0.8201
# 00050: TRAIN| LT=1.539 LP=0.528 LKL=6.317 LPS=0.837 LKLS=11.087 |
# Test F1: 0.8188
# Test ACC: 0.6966
# Test AUC: 0.7131
# Train F1: 0.8713
# 00100: TRAIN| LT=1.213 LP=0.389 LKL=6.768 LPS=0.644 LKLS=11.267 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7652
# Train F1: 0.8867
# 00150: TRAIN| LT=1.143 LP=0.352 LKL=6.462 LPS=0.639 LKLS=8.782 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7613
# Train F1: 0.8786
# 00200: TRAIN| LT=1.188 LP=0.409 LKL=6.457 LPS=0.632 LKLS=8.294 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7681
# Train F1: 0.8718
# 00250: TRAIN| LT=1.130 LP=0.380 LKL=6.530 LPS=0.601 LKLS=8.322 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7693
# Train F1: 0.8862
# 00300: TRAIN| LT=1.131 LP=0.361 LKL=6.540 LPS=0.620 LKLS=8.457 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7875
# Train F1: 0.8932
# 00350: TRAIN| LT=1.130 LP=0.376 LKL=6.474 LPS=0.613 LKLS=7.616 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7652
# Train F1: 0.8794
# 00400: TRAIN| LT=1.155 LP=0.409 LKL=6.380 LPS=0.612 LKLS=7.049 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7810
# Train F1: 0.8983
# 00450: TRAIN| LT=1.124 LP=0.374 LKL=6.337 LPS=0.617 LKLS=7.025 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7793
# Train F1: 0.8867
# 00500: TRAIN| LT=1.102 LP=0.370 LKL=6.361 LPS=0.599 LKLS=6.918 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7711
# Train F1: 0.8902
# 00550: TRAIN| LT=1.101 LP=0.358 LKL=6.405 LPS=0.605 LKLS=7.354 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7840
# Train F1: 0.9006
# 00600: TRAIN| LT=1.122 LP=0.384 LKL=6.436 LPS=0.603 LKLS=7.019 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7711
# Train F1: 0.8971
# 00650: TRAIN| LT=1.138 LP=0.381 LKL=6.440 LPS=0.620 LKLS=7.277 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7963
# Train F1: 0.8772
# 00700: TRAIN| LT=1.078 LP=0.344 LKL=6.223 LPS=0.608 LKLS=6.330 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7968
# Train F1: 0.9017
# 00750: TRAIN| LT=1.096 LP=0.357 LKL=6.335 LPS=0.608 LKLS=6.795 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7898
# Train F1: 0.8897
# 00800: TRAIN| LT=1.103 LP=0.365 LKL=6.317 LPS=0.609 LKLS=6.607 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7875
# Train F1: 0.8940
# 00850: TRAIN| LT=1.083 LP=0.355 LKL=6.335 LPS=0.599 LKLS=6.589 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7875
# Train F1: 0.9046
# 00900: TRAIN| LT=1.112 LP=0.375 LKL=6.230 LPS=0.612 LKLS=6.222 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7916
# Train F1: 0.9031
# 00950: TRAIN| LT=1.080 LP=0.349 LKL=6.206 LPS=0.607 LKLS=6.139 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7769
# Train F1: 0.8915
# 01000: TRAIN| LT=1.087 LP=0.358 LKL=6.274 LPS=0.605 LKLS=6.126 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7588
# Train F1: 0.8927
# 01050: TRAIN| LT=1.106 LP=0.379 LKL=6.250 LPS=0.607 LKLS=5.793 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7699
# Train F1: 0.8975
# 01100: TRAIN| LT=1.091 LP=0.362 LKL=6.280 LPS=0.605 LKLS=6.137 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7845
# Train F1: 0.9087
# 01150: TRAIN| LT=1.084 LP=0.354 LKL=6.359 LPS=0.607 LKLS=5.992 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7635
# Train F1: 0.8889
# 01200: TRAIN| LT=1.082 LP=0.360 LKL=6.311 LPS=0.598 LKLS=6.027 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7834
# Train F1: 0.8932
# 01250: TRAIN| LT=1.071 LP=0.361 LKL=6.199 LPS=0.591 LKLS=5.600 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7758
# Train F1: 0.8973
# 01300: TRAIN| LT=1.060 LP=0.354 LKL=6.400 LPS=0.582 LKLS=6.075 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7775
# Train F1: 0.8944
# 01350: TRAIN| LT=1.071 LP=0.347 LKL=6.421 LPS=0.599 LKLS=6.113 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7769
# Train F1: 0.8910
# 01400: TRAIN| LT=1.085 LP=0.362 LKL=6.246 LPS=0.605 LKLS=5.470 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7658
# Train F1: 0.8919
# 01450: TRAIN| LT=1.069 LP=0.341 LKL=6.389 LPS=0.607 LKLS=5.725 |
# Test F1: 0.8551
# Test ACC: 0.7753
# Test AUC: 0.7746
# Train F1: 0.8973
# 01500: TRAIN| LT=1.082 LP=0.354 LKL=6.348 LPS=0.607 LKLS=5.818 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7752
# Train F1: 0.9032
# 01550: TRAIN| LT=1.047 LP=0.335 LKL=6.280 LPS=0.594 LKLS=5.515 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7828
# Train F1: 0.9087
# 01600: TRAIN| LT=1.070 LP=0.336 LKL=6.255 LPS=0.618 LKLS=5.336 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7898
# Train F1: 0.9122
# 01650: TRAIN| LT=1.048 LP=0.320 LKL=6.443 LPS=0.605 LKLS=5.889 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7910
# Train F1: 0.9019
# 01700: TRAIN| LT=1.045 LP=0.322 LKL=6.303 LPS=0.604 LKLS=5.522 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7799
# Train F1: 0.8952
# 01750: TRAIN| LT=1.084 LP=0.364 LKL=6.463 LPS=0.601 LKLS=5.485 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7857
# Train F1: 0.9040
# 01800: TRAIN| LT=1.053 LP=0.321 LKL=6.361 LPS=0.613 LKLS=5.473 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7816
# Train F1: 0.9042
# 01850: TRAIN| LT=1.032 LP=0.315 LKL=6.371 LPS=0.600 LKLS=5.387 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7834
# Train F1: 0.8987
# 01900: TRAIN| LT=1.028 LP=0.307 LKL=6.303 LPS=0.606 LKLS=5.228 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7763
# Train F1: 0.9077
# 01950: TRAIN| LT=1.024 LP=0.302 LKL=6.371 LPS=0.604 LKLS=5.382 |
# Test F1: 0.8633
# Test ACC: 0.7865
# Test AUC: 0.7746
# Train F1: 0.8987
# 02000: TRAIN| LT=1.039 LP=0.317 LKL=6.442 LPS=0.602 LKLS=5.544 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.7951
# f1: 0.8714285714285713
# acc: 0.797752808988764
# auc: 0.7968384074941453
# Train F1: 0.8227
# 00050: TRAIN| LT=1.650 LP=0.560 LKL=6.106 LPS=0.932 LKLS=9.749 |
# Test F1: 0.8243
# Test ACC: 0.7079
# Test AUC: 0.7616
# Train F1: 0.8849
# 00100: TRAIN| LT=1.233 LP=0.392 LKL=6.730 LPS=0.661 LKLS=11.223 |
# Test F1: 0.8571
# Test ACC: 0.7865
# Test AUC: 0.8460
# Train F1: 0.8661
# 00150: TRAIN| LT=1.198 LP=0.397 LKL=6.553 LPS=0.643 LKLS=9.319 |
# Test F1: 0.8741
# Test ACC: 0.8090
# Test AUC: 0.8244
# Train F1: 0.8704
# 00200: TRAIN| LT=1.145 LP=0.374 LKL=6.515 LPS=0.618 LKLS=8.800 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.8167
# Train F1: 0.8777
# 00250: TRAIN| LT=1.187 LP=0.401 LKL=6.499 LPS=0.640 LKLS=8.014 |
# Test F1: 0.8657
# Test ACC: 0.7978
# Test AUC: 0.8308
# Train F1: 0.8814
# 00300: TRAIN| LT=1.153 LP=0.390 LKL=6.413 LPS=0.622 LKLS=7.662 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.8302
# Train F1: 0.8701
# 00350: TRAIN| LT=1.121 LP=0.358 LKL=6.404 LPS=0.626 LKLS=7.238 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.8337
# Train F1: 0.8774
# 00400: TRAIN| LT=1.145 LP=0.385 LKL=6.356 LPS=0.627 LKLS=7.012 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.8296
# Train F1: 0.9014
# 00450: TRAIN| LT=1.129 LP=0.376 LKL=6.347 LPS=0.620 LKLS=6.959 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.8308
# Train F1: 0.8906
# 00500: TRAIN| LT=1.083 LP=0.353 LKL=6.307 LPS=0.603 LKLS=6.442 |
# Test F1: 0.8759
# Test ACC: 0.8090
# Test AUC: 0.8302
# Train F1: 0.8806
# 00550: TRAIN| LT=1.090 LP=0.350 LKL=6.268 LPS=0.612 LKLS=6.477 |
# Test F1: 0.8777
# Test ACC: 0.8090
# Test AUC: 0.8331
# Train F1: 0.8969
# 00600: TRAIN| LT=1.084 LP=0.354 LKL=6.353 LPS=0.600 LKLS=6.702 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8302
# Train F1: 0.8872
# 00650: TRAIN| LT=1.105 LP=0.352 LKL=6.507 LPS=0.619 LKLS=6.833 |
# Test F1: 0.8676
# Test ACC: 0.7978
# Test AUC: 0.8244
# Train F1: 0.9062
# 00700: TRAIN| LT=1.107 LP=0.375 LKL=6.281 LPS=0.607 LKLS=6.239 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8314
# Train F1: 0.8953
# 00750: TRAIN| LT=1.101 LP=0.374 LKL=6.294 LPS=0.602 LKLS=6.172 |
# Test F1: 0.8696
# Test ACC: 0.7978
# Test AUC: 0.8296
# Train F1: 0.8944
# 00800: TRAIN| LT=1.128 LP=0.379 LKL=6.282 LPS=0.624 LKLS=6.210 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8320
# Train F1: 0.9073
# 00850: TRAIN| LT=1.099 LP=0.359 LKL=6.313 LPS=0.614 LKLS=6.222 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8326
# Train F1: 0.8944
# 00900: TRAIN| LT=1.106 LP=0.368 LKL=6.295 LPS=0.614 LKLS=6.041 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8326
# Train F1: 0.8880
# 00950: TRAIN| LT=1.093 LP=0.367 LKL=6.308 LPS=0.602 LKLS=6.191 |
# Test F1: 0.8652
# Test ACC: 0.7865
# Test AUC: 0.8331
# Train F1: 0.8854
# 01000: TRAIN| LT=1.081 LP=0.344 LKL=6.338 LPS=0.610 LKLS=6.240 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8320
# Train F1: 0.8923
# 01050: TRAIN| LT=1.112 LP=0.346 LKL=6.247 LPS=0.647 LKLS=5.642 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8326
# Train F1: 0.9031
# 01100: TRAIN| LT=1.058 LP=0.324 LKL=6.410 LPS=0.608 LKLS=6.092 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8326
# Train F1: 0.9074
# 01150: TRAIN| LT=1.101 LP=0.357 LKL=6.275 LPS=0.625 LKLS=5.626 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8320
# Train F1: 0.9011
# 01200: TRAIN| LT=1.073 LP=0.341 LKL=6.424 LPS=0.609 LKLS=5.879 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8361
# Train F1: 0.8966
# 01250: TRAIN| LT=1.080 LP=0.337 LKL=6.436 LPS=0.619 LKLS=6.024 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8355
# Train F1: 0.8966
# 01300: TRAIN| LT=1.096 LP=0.366 LKL=6.304 LPS=0.611 LKLS=5.624 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8361
# Train F1: 0.9077
# 01350: TRAIN| LT=1.037 LP=0.316 LKL=6.276 LPS=0.606 LKLS=5.304 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8337
# Train F1: 0.9067
# 01400: TRAIN| LT=1.059 LP=0.326 LKL=6.324 LPS=0.614 LKLS=5.475 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8326
# Train F1: 0.9011
# 01450: TRAIN| LT=1.072 LP=0.340 LKL=6.531 LPS=0.608 LKLS=5.863 |
# Test F1: 0.8592
# Test ACC: 0.7753
# Test AUC: 0.8378
# Train F1: 0.8910
# 01500: TRAIN| LT=1.085 LP=0.353 LKL=6.482 LPS=0.611 LKLS=5.617 |
# Test F1: 0.8652
# Test ACC: 0.7865
# Test AUC: 0.8355
# Train F1: 0.9143
# 01550: TRAIN| LT=1.052 LP=0.321 LKL=6.421 LPS=0.610 LKLS=5.678 |
# Test F1: 0.8592
# Test ACC: 0.7753
# Test AUC: 0.8162
# Train F1: 0.8919
# 01600: TRAIN| LT=1.054 LP=0.332 LKL=6.346 LPS=0.605 LKLS=5.347 |
# Test F1: 0.8531
# Test ACC: 0.7640
# Test AUC: 0.8203
# Train F1: 0.9021
# 01650: TRAIN| LT=1.038 LP=0.319 LKL=6.347 LPS=0.603 LKLS=5.259 |
# Test F1: 0.8652
# Test ACC: 0.7865
# Test AUC: 0.8407
# Train F1: 0.8983
# 01700: TRAIN| LT=1.038 LP=0.320 LKL=6.339 LPS=0.601 LKLS=5.333 |
# Test F1: 0.8592
# Test ACC: 0.7753
# Test AUC: 0.8214
# Train F1: 0.9070
# 01750: TRAIN| LT=1.026 LP=0.304 LKL=6.499 LPS=0.602 LKLS=5.528 |
# Test F1: 0.8592
# Test ACC: 0.7753
# Test AUC: 0.8109
# Train F1: 0.9036
# 01800: TRAIN| LT=1.048 LP=0.322 LKL=6.318 LPS=0.612 LKLS=5.099 |
# Test F1: 0.8652
# Test ACC: 0.7865
# Test AUC: 0.8308
# Train F1: 0.9042
# 01850: TRAIN| LT=1.025 LP=0.303 LKL=6.264 LPS=0.610 LKLS=4.981 |
# Test F1: 0.8652
# Test ACC: 0.7865
# Test AUC: 0.8402
# Train F1: 0.9032
# 01900: TRAIN| LT=1.026 LP=0.309 LKL=6.325 LPS=0.601 LKLS=5.183 |
# Test F1: 0.8592
# Test ACC: 0.7753
# Test AUC: 0.8109
# Train F1: 0.8981
# 01950: TRAIN| LT=1.042 LP=0.318 LKL=6.286 LPS=0.611 LKLS=5.096 |
# Test F1: 0.8531
# Test ACC: 0.7640
# Test AUC: 0.8080
# Train F1: 0.8948
# 02000: TRAIN| LT=1.022 LP=0.313 LKL=6.367 LPS=0.595 LKLS=5.118 |
# Test F1: 0.8714
# Test ACC: 0.7978
# Test AUC: 0.8220
# f1: 0.8776978417266188
# acc: 0.8089887640449438
# auc: 0.8331381733021077
# Train F1: 0.8221
# 00050: TRAIN| LT=1.581 LP=0.556 LKL=6.151 LPS=0.857 LKLS=10.653 |
# Test F1: 0.8511
# Test ACC: 0.7614
# Test AUC: 0.7620
# Train F1: 0.8638
# 00100: TRAIN| LT=1.267 LP=0.408 LKL=6.613 LPS=0.683 LKLS=10.938 |
# Test F1: 0.8824
# Test ACC: 0.8182
# Test AUC: 0.8421
# Train F1: 0.8696
# 00150: TRAIN| LT=1.195 LP=0.396 LKL=6.458 LPS=0.643 LKLS=9.193 |
# Test F1: 0.8824
# Test ACC: 0.8182
# Test AUC: 0.8755
# Train F1: 0.8802
# 00200: TRAIN| LT=1.113 LP=0.336 LKL=6.462 LPS=0.625 LKLS=8.645 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8749
# Train F1: 0.8885
# 00250: TRAIN| LT=1.152 LP=0.391 LKL=6.582 LPS=0.606 LKLS=8.965 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8682
# Train F1: 0.8723
# 00300: TRAIN| LT=1.168 LP=0.397 LKL=6.340 LPS=0.635 LKLS=7.320 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8743
# Train F1: 0.8919
# 00350: TRAIN| LT=1.198 LP=0.432 LKL=6.396 LPS=0.627 LKLS=7.499 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8743
# Train F1: 0.9049
# 00400: TRAIN| LT=1.123 LP=0.363 LKL=6.339 LPS=0.625 LKLS=7.134 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8774
# Train F1: 0.8893
# 00450: TRAIN| LT=1.117 LP=0.353 LKL=6.284 LPS=0.631 LKLS=6.981 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8780
# Train F1: 0.8816
# 00500: TRAIN| LT=1.160 LP=0.402 LKL=6.274 LPS=0.627 LKLS=6.764 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8755
# Train F1: 0.8800
# 00550: TRAIN| LT=1.142 LP=0.387 LKL=6.243 LPS=0.626 LKLS=6.634 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8804
# Train F1: 0.8969
# 00600: TRAIN| LT=1.112 LP=0.351 LKL=6.255 LPS=0.631 LKLS=6.743 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8743
# Train F1: 0.8876
# 00650: TRAIN| LT=1.156 LP=0.380 LKL=6.284 LPS=0.647 LKLS=6.592 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8743
# Train F1: 0.8858
# 00700: TRAIN| LT=1.099 LP=0.346 LKL=6.280 LPS=0.623 LKLS=6.657 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8640
# Train F1: 0.8987
# 00750: TRAIN| LT=1.103 LP=0.361 LKL=6.243 LPS=0.617 LKLS=6.339 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8780
# Train F1: 0.8851
# 00800: TRAIN| LT=1.095 LP=0.353 LKL=6.291 LPS=0.617 LKLS=6.229 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8780
# Train F1: 0.8859
# 00850: TRAIN| LT=1.083 LP=0.349 LKL=6.269 LPS=0.609 LKLS=6.181 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8713
# Train F1: 0.8919
# 00900: TRAIN| LT=1.114 LP=0.367 LKL=6.278 LPS=0.617 LKLS=6.740 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8591
# Train F1: 0.8987
# 00950: TRAIN| LT=1.095 LP=0.357 LKL=6.278 LPS=0.615 LKLS=6.150 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8597
# Train F1: 0.8996
# 01000: TRAIN| LT=1.122 LP=0.386 LKL=6.299 LPS=0.612 LKLS=6.152 |
# Test F1: 0.8777
# Test ACC: 0.8068
# Test AUC: 0.8567
# Train F1: 0.8935
# 01050: TRAIN| LT=1.095 LP=0.365 LKL=6.448 LPS=0.602 LKLS=6.231 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8628
# Train F1: 0.8952
# 01100: TRAIN| LT=1.131 LP=0.391 LKL=6.370 LPS=0.616 LKLS=6.051 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8427
# Train F1: 0.8962
# 01150: TRAIN| LT=1.099 LP=0.352 LKL=6.484 LPS=0.618 LKLS=6.451 |
# Test F1: 0.8905
# Test ACC: 0.8295
# Test AUC: 0.8682
# Train F1: 0.8791
# 01200: TRAIN| LT=1.098 LP=0.357 LKL=6.386 LPS=0.616 LKLS=6.092 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8397
# Train F1: 0.8960
# 01250: TRAIN| LT=1.093 LP=0.348 LKL=6.439 LPS=0.620 LKLS=6.001 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8561
# Train F1: 0.9081
# 01300: TRAIN| LT=1.070 LP=0.329 LKL=6.385 LPS=0.619 LKLS=5.868 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8440
# Train F1: 0.9008
# 01350: TRAIN| LT=1.067 LP=0.319 LKL=6.388 LPS=0.627 LKLS=5.762 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8458
# Train F1: 0.8923
# 01400: TRAIN| LT=1.098 LP=0.361 LKL=6.403 LPS=0.615 LKLS=5.779 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8397
# Train F1: 0.8889
# 01450: TRAIN| LT=1.075 LP=0.335 LKL=6.267 LPS=0.622 LKLS=5.513 |
# Test F1: 0.8777
# Test ACC: 0.8068
# Test AUC: 0.8379
# Train F1: 0.8906
# 01500: TRAIN| LT=1.081 LP=0.355 LKL=6.358 LPS=0.606 LKLS=5.685 |
# Test F1: 0.8777
# Test ACC: 0.8068
# Test AUC: 0.8379
# Train F1: 0.8994
# 01550: TRAIN| LT=1.076 LP=0.353 LKL=6.333 LPS=0.605 LKLS=5.438 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8379
# Train F1: 0.9008
# 01600: TRAIN| LT=1.067 LP=0.336 LKL=6.316 LPS=0.615 LKLS=5.284 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8379
# Train F1: 0.9067
# 01650: TRAIN| LT=1.061 LP=0.324 LKL=6.450 LPS=0.617 LKLS=5.543 |
# Test F1: 0.8841
# Test ACC: 0.8182
# Test AUC: 0.8367
# Train F1: 0.9036
# 01700: TRAIN| LT=1.049 LP=0.316 LKL=6.305 LPS=0.619 LKLS=5.146 |
# Test F1: 0.8777
# Test ACC: 0.8068
# Test AUC: 0.8185
# Train F1: 0.8969
# 01750: TRAIN| LT=1.038 LP=0.313 LKL=6.345 LPS=0.611 LKLS=4.985 |
# Test F1: 0.8777
# Test ACC: 0.8068
# Test AUC: 0.8282
# Train F1: 0.9063
# 01800: TRAIN| LT=1.044 LP=0.323 LKL=6.238 LPS=0.610 LKLS=4.881 |
# Test F1: 0.8777
# Test ACC: 0.8068
# Test AUC: 0.8209
# Train F1: 0.9040
# 01850: TRAIN| LT=1.028 LP=0.302 LKL=6.400 LPS=0.611 LKLS=5.071 |
# Test F1: 0.8714
# Test ACC: 0.7955
# Test AUC: 0.8361
# Train F1: 0.9036
# 01900: TRAIN| LT=1.045 LP=0.316 LKL=6.350 LPS=0.616 LKLS=4.929 |
# Test F1: 0.8777
# Test ACC: 0.8068
# Test AUC: 0.8336
# Train F1: 0.8902
# 01950: TRAIN| LT=1.023 LP=0.302 LKL=6.190 LPS=0.613 LKLS=4.570 |
# Test F1: 0.8777
# Test ACC: 0.8068
# Test AUC: 0.8233
# Train F1: 0.9032
# 02000: TRAIN| LT=1.024 LP=0.304 LKL=6.250 LPS=0.612 LKLS=4.574 |
# Test F1: 0.8777
# Test ACC: 0.8068
# Test AUC: 0.8227
# f1: 0.8905109489051095
# acc: 0.8295454545454546
# auc: 0.877959927140255
# f1 [0.9090909090909091, 0.888888888888889, 0.8714285714285713, 0.8776978417266188, 0.8905109489051095]
# average maxf1 0.8875234320080196
# acc [0.8651685393258427, 0.8314606741573034, 0.797752808988764, 0.8089887640449438, 0.8295454545454546]
# average maxacc 0.8265832482124615
# auc [0.9192037470725996, 0.8951990632318501, 0.7968384074941453, 0.8331381733021077, 0.877959927140255]
# average maxauc 0.8644678636481915
