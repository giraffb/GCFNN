# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'Healthy':0,'Stage_0':1, 'Stage_I_II':1, 'Stage_III_IV':1, 'HS':1, 'MP':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)

#随机缺失，生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
from sklearn.preprocessing import OneHotEncoder
from numpy.random import randint
import warnings
warnings.filterwarnings("ignore")
def get_sn(view_num, alldata_len, missing_rate):
    """Randomly generate incomplete data information, simulate partial view data with complete view data
    :param view_num:view number
    :param alldata_len:number of samples
    :param missing_rate:Defined in section 3.2 of the paper
    :return:Sn
    """
    one_rate = 1-missing_rate
    if one_rate <= (1 / view_num):
        #enc = OneHotEncoder(n_values=view_num)
        enc = OneHotEncoder()
        view_preserve = enc.fit_transform(randint(0, view_num, size=(alldata_len, 1))).toarray()
        return view_preserve
    error = 1
    if one_rate == 1:
        matrix = randint(1, 2, size=(alldata_len, view_num))
        return matrix
    while error >= 0.005:
        #enc = OneHotEncoder(n_values=view_num)
        enc = OneHotEncoder()
        view_preserve = enc.fit_transform(randint(0, view_num, size=(alldata_len, 1))).toarray()
        one_num = view_num * alldata_len * one_rate - alldata_len
        ratio = one_num / (view_num * alldata_len)
        matrix_iter = (randint(0, 100, size=(alldata_len, view_num)) < int(ratio * 100)).astype(np.int)
        a = np.sum(((matrix_iter + view_preserve) > 1).astype(np.int))
        one_num_iter = one_num / (1 - a / one_num)
        ratio = one_num_iter / (view_num * alldata_len)
        matrix_iter = (randint(0, 100, size=(alldata_len, view_num)) < int(ratio * 100)).astype(np.int)
        matrix = ((matrix_iter + view_preserve) > 0).astype(np.int)
        ratio = np.sum(matrix) / (view_num * alldata_len)
        error = abs(one_rate - ratio)
    return matrix
Mask     = np.ones([np.shape(X_set[0])[0], M])
print(sum(Mask))
missrate = 0.5
Mask     = get_sn(2,X_set[0].shape[0],missrate)
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
print(sum(Mask)) 
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (347, 851) (347, 450) (347, 1)
# Int64Index([10021, 10023, 10025, 10029, 10031, 10033, 10034, 10036, 10037,
#             10038,
#             ...
#             10818, 10825, 10827, 10829, 10835, 10838, 10839, 10847, 10850,
#             10853],
#            dtype='int64', name='Sample', length=347)
# 数据完整率missing_rate : 1.0
# 集合所有样本重构数据表： (347, 851) (347, 450) (347, 1)
# 694.0
# 347.0
# 标签转换为one-hot编码： (347, 2) 127.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 4, 
        'ITERATION': 1000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1',f1_cv)
print('average maxf1',sum(f1_cv)/5)
print('acc',acc_cv)
print('average maxacc',sum(acc_cv)/5)
print('auc',auc_cv)
print('average maxauc',sum(auc_cv)/5)
# Out:
# Train F1: 0.7393
# 00050: TRAIN| LT=1.902 LP=0.641 LKL=5.305 LPS=1.161 LKLS=4.722 |
# Test F1: 0.7890
# Test ACC: 0.6714
# Test AUC: 0.6233
# Train F1: 0.8316
# 00100: TRAIN| LT=1.398 LP=0.466 LKL=6.714 LPS=0.739 LKLS=12.569 |
# Test F1: 0.7921
# Test ACC: 0.7000
# Test AUC: 0.6976
# Train F1: 0.8204
# 00150: TRAIN| LT=1.338 LP=0.444 LKL=6.380 LPS=0.735 LKLS=9.482 |
# Test F1: 0.6410
# Test ACC: 0.6000
# Test AUC: 0.6906
# Train F1: 0.8764
# 00200: TRAIN| LT=1.296 LP=0.445 LKL=6.420 LPS=0.695 LKLS=9.149 |
# Test F1: 0.6988
# Test ACC: 0.6429
# Test AUC: 0.6984
# Train F1: 0.8689
# 00250: TRAIN| LT=1.216 LP=0.395 LKL=6.475 LPS=0.663 LKLS=9.329 |
# Test F1: 0.7209
# Test ACC: 0.6571
# Test AUC: 0.7124
# Train F1: 0.8796
# 00300: TRAIN| LT=1.172 LP=0.402 LKL=6.591 LPS=0.608 LKLS=9.609 |
# Test F1: 0.7059
# Test ACC: 0.6429
# Test AUC: 0.7089
# Train F1: 0.9183
# 00350: TRAIN| LT=0.992 LP=0.339 LKL=6.863 LPS=0.475 LKLS=10.937 |
# Test F1: 0.7356
# Test ACC: 0.6714
# Test AUC: 0.7098
# Train F1: 0.9200
# 00400: TRAIN| LT=0.895 LP=0.279 LKL=7.075 LPS=0.425 LKLS=11.961 |
# Test F1: 0.7640
# Test ACC: 0.7000
# Test AUC: 0.7142
# Train F1: 0.9341
# 00450: TRAIN| LT=0.751 LP=0.209 LKL=7.262 LPS=0.342 LKLS=12.636 |
# Test F1: 0.7416
# Test ACC: 0.6714
# Test AUC: 0.7080
# Train F1: 0.9456
# 00500: TRAIN| LT=0.776 LP=0.197 LKL=7.328 LPS=0.378 LKLS=12.809 |
# Test F1: 0.7209
# Test ACC: 0.6571
# Test AUC: 0.7028
# Train F1: 0.9625
# 00550: TRAIN| LT=0.589 LP=0.174 LKL=7.365 LPS=0.214 LKLS=12.746 |
# Test F1: 0.7556
# Test ACC: 0.6857
# Test AUC: 0.6906
# Train F1: 0.9486
# 00600: TRAIN| LT=0.606 LP=0.166 LKL=7.461 LPS=0.235 LKLS=13.067 |
# Test F1: 0.7556
# Test ACC: 0.6857
# Test AUC: 0.6853
# Train F1: 0.9602
# 00650: TRAIN| LT=0.511 LP=0.128 LKL=7.430 LPS=0.178 LKLS=13.110 |
# Test F1: 0.7742
# Test ACC: 0.7000
# Test AUC: 0.6827
# Train F1: 0.9745
# 00700: TRAIN| LT=0.408 LP=0.099 LKL=7.592 LPS=0.097 LKLS=13.539 |
# Test F1: 0.7609
# Test ACC: 0.6857
# Test AUC: 0.6984
# Train F1: 0.9573
# 00750: TRAIN| LT=0.442 LP=0.071 LKL=7.676 LPS=0.156 LKLS=13.814 |
# Test F1: 0.7957
# Test ACC: 0.7286
# Test AUC: 0.6949
# Train F1: 0.9718
# 00800: TRAIN| LT=0.453 LP=0.107 LKL=7.447 LPS=0.143 LKLS=12.820 |
# Test F1: 0.7872
# Test ACC: 0.7143
# Test AUC: 0.6932
# Train F1: 0.9801
# 00850: TRAIN| LT=0.390 LP=0.084 LKL=7.697 LPS=0.090 LKLS=13.916 |
# Test F1: 0.7957
# Test ACC: 0.7286
# Test AUC: 0.6949
# Train F1: 0.9802
# 00900: TRAIN| LT=0.387 LP=0.086 LKL=7.596 LPS=0.090 LKLS=13.404 |
# Test F1: 0.7957
# Test ACC: 0.7286
# Test AUC: 0.6897
# Train F1: 0.9801
# 00950: TRAIN| LT=0.357 LP=0.073 LKL=7.564 LPS=0.080 LKLS=12.887 |
# Test F1: 0.7957
# Test ACC: 0.7286
# Test AUC: 0.6801
# Train F1: 0.9801
# 01000: TRAIN| LT=0.351 LP=0.069 LKL=7.735 LPS=0.065 LKLS=13.902 |
# Test F1: 0.7872
# Test ACC: 0.7143
# Test AUC: 0.6783
# f1: 0.7956989247311828
# acc: 0.7285714285714285
# auc: 0.6949300699300699
# Train F1: 0.7512
# 00050: TRAIN| LT=1.939 LP=0.640 LKL=5.432 LPS=1.188 LKLS=5.624 |
# Test F1: 0.7664
# Test ACC: 0.6429
# Test AUC: 0.6748
# Train F1: 0.8533
# 00100: TRAIN| LT=1.379 LP=0.443 LKL=6.860 LPS=0.744 LKLS=12.402 |
# Test F1: 0.7379
# Test ACC: 0.6143
# Test AUC: 0.5760
# Train F1: 0.8293
# 00150: TRAIN| LT=1.287 LP=0.414 LKL=6.776 LPS=0.700 LKLS=10.556 |
# Test F1: 0.7255
# Test ACC: 0.6000
# Test AUC: 0.5726
# Train F1: 0.8633
# 00200: TRAIN| LT=1.194 LP=0.390 LKL=6.573 LPS=0.649 LKLS=9.006 |
# Test F1: 0.7143
# Test ACC: 0.6000
# Test AUC: 0.5839
# Train F1: 0.8802
# 00250: TRAIN| LT=1.134 LP=0.343 LKL=6.690 LPS=0.630 LKLS=9.413 |
# Test F1: 0.6966
# Test ACC: 0.6143
# Test AUC: 0.5892
# Train F1: 0.8986
# 00300: TRAIN| LT=0.988 LP=0.294 LKL=6.894 LPS=0.519 LKLS=10.700 |
# Test F1: 0.7045
# Test ACC: 0.6286
# Test AUC: 0.6189
# Train F1: 0.9127
# 00350: TRAIN| LT=0.853 LP=0.221 LKL=7.096 LPS=0.443 LKLS=11.772 |
# Test F1: 0.7111
# Test ACC: 0.6286
# Test AUC: 0.6276
# Train F1: 0.9330
# 00400: TRAIN| LT=0.790 LP=0.223 LKL=7.265 LPS=0.371 LKLS=12.396 |
# Test F1: 0.6742
# Test ACC: 0.5857
# Test AUC: 0.6337
# Train F1: 0.9462
# 00450: TRAIN| LT=0.744 LP=0.202 LKL=7.400 LPS=0.339 LKLS=12.946 |
# Test F1: 0.7097
# Test ACC: 0.6143
# Test AUC: 0.6407
# Train F1: 0.9568
# 00500: TRAIN| LT=0.721 LP=0.218 LKL=7.423 LPS=0.301 LKLS=12.751 |
# Test F1: 0.7191
# Test ACC: 0.6429
# Test AUC: 0.6425
# Train F1: 0.9459
# 00550: TRAIN| LT=0.590 LP=0.149 LKL=7.487 LPS=0.232 LKLS=13.397 |
# Test F1: 0.7174
# Test ACC: 0.6286
# Test AUC: 0.6381
# Train F1: 0.9526
# 00600: TRAIN| LT=0.478 LP=0.099 LKL=7.628 LPS=0.165 LKLS=13.807 |
# Test F1: 0.7174
# Test ACC: 0.6286
# Test AUC: 0.6302
# Train F1: 0.9489
# 00650: TRAIN| LT=0.466 LP=0.113 LKL=7.563 LPS=0.143 LKLS=13.445 |
# Test F1: 0.7234
# Test ACC: 0.6286
# Test AUC: 0.6233
# Train F1: 0.9774
# 00700: TRAIN| LT=0.479 LP=0.110 LKL=7.709 LPS=0.154 LKLS=13.692 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.6294
# Train F1: 0.9687
# 00750: TRAIN| LT=0.449 LP=0.094 LKL=7.754 LPS=0.137 LKLS=14.116 |
# Test F1: 0.7097
# Test ACC: 0.6143
# Test AUC: 0.6337
# Train F1: 0.9687
# 00800: TRAIN| LT=0.402 LP=0.082 LKL=7.689 LPS=0.109 LKLS=13.413 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.6285
# Train F1: 0.9540
# 00850: TRAIN| LT=0.407 LP=0.073 LKL=7.538 LPS=0.130 LKLS=12.820 |
# Test F1: 0.7174
# Test ACC: 0.6286
# Test AUC: 0.6224
# Train F1: 0.9830
# 00900: TRAIN| LT=0.408 LP=0.073 LKL=7.711 LPS=0.124 LKLS=13.409 |
# Test F1: 0.6957
# Test ACC: 0.6000
# Test AUC: 0.6285
# Train F1: 0.9687
# 00950: TRAIN| LT=0.339 LP=0.069 LKL=7.647 LPS=0.065 LKLS=12.831 |
# Test F1: 0.7234
# Test ACC: 0.6286
# Test AUC: 0.6276
# Train F1: 0.9886
# 01000: TRAIN| LT=0.332 LP=0.046 LKL=7.676 LPS=0.079 LKLS=12.982 |
# Test F1: 0.7097
# Test ACC: 0.6143
# Test AUC: 0.6346
# f1: 0.7663551401869159
# acc: 0.6428571428571429
# auc: 0.6748251748251748
# Train F1: 0.7793
# 00050: TRAIN| LT=1.901 LP=0.636 LKL=5.460 LPS=1.161 LKLS=4.959 |
# Test F1: 0.7788
# Test ACC: 0.6377
# Test AUC: 0.6127
# Train F1: 0.8482
# 00100: TRAIN| LT=1.339 LP=0.415 LKL=6.996 LPS=0.735 LKLS=11.900 |
# Test F1: 0.7677
# Test ACC: 0.6667
# Test AUC: 0.6200
# Train F1: 0.8283
# 00150: TRAIN| LT=1.263 LP=0.391 LKL=6.703 LPS=0.709 LKLS=9.546 |
# Test F1: 0.7579
# Test ACC: 0.6667
# Test AUC: 0.6364
# Train F1: 0.8274
# 00200: TRAIN| LT=1.239 LP=0.378 LKL=6.748 LPS=0.698 LKLS=9.536 |
# Test F1: 0.7423
# Test ACC: 0.6377
# Test AUC: 0.6309
# Train F1: 0.8852
# 00250: TRAIN| LT=1.191 LP=0.396 LKL=6.815 LPS=0.630 LKLS=9.697 |
# Test F1: 0.6585
# Test ACC: 0.5942
# Test AUC: 0.6200
# Train F1: 0.9045
# 00300: TRAIN| LT=1.083 LP=0.308 LKL=6.988 LPS=0.597 LKLS=10.826 |
# Test F1: 0.6250
# Test ACC: 0.5652
# Test AUC: 0.6227
# Train F1: 0.9065
# 00350: TRAIN| LT=0.896 LP=0.282 LKL=7.355 LPS=0.412 LKLS=12.879 |
# Test F1: 0.6000
# Test ACC: 0.5362
# Test AUC: 0.6264
# Train F1: 0.9080
# 00400: TRAIN| LT=0.804 LP=0.227 LKL=7.233 LPS=0.384 LKLS=12.103 |
# Test F1: 0.5897
# Test ACC: 0.5362
# Test AUC: 0.6273
# Train F1: 0.9389
# 00450: TRAIN| LT=0.735 LP=0.236 LKL=7.293 LPS=0.301 LKLS=12.385 |
# Test F1: 0.7143
# Test ACC: 0.6522
# Test AUC: 0.6791
# Train F1: 0.9405
# 00500: TRAIN| LT=0.706 LP=0.194 LKL=7.488 LPS=0.306 LKLS=13.049 |
# Test F1: 0.6667
# Test ACC: 0.6087
# Test AUC: 0.6782
# Train F1: 0.9435
# 00550: TRAIN| LT=0.558 LP=0.133 LKL=7.396 LPS=0.224 LKLS=12.773 |
# Test F1: 0.7059
# Test ACC: 0.6377
# Test AUC: 0.6764
# Train F1: 0.9532
# 00600: TRAIN| LT=0.547 LP=0.098 LKL=7.524 LPS=0.239 LKLS=13.431 |
# Test F1: 0.6585
# Test ACC: 0.5942
# Test AUC: 0.6727
# Train F1: 0.9746
# 00650: TRAIN| LT=0.526 LP=0.133 LKL=7.489 LPS=0.188 LKLS=13.014 |
# Test F1: 0.6977
# Test ACC: 0.6232
# Test AUC: 0.6827
# Train F1: 0.9551
# 00700: TRAIN| LT=0.500 LP=0.119 LKL=7.727 LPS=0.162 LKLS=14.079 |
# Test F1: 0.6747
# Test ACC: 0.6087
# Test AUC: 0.6718
# Train F1: 0.9746
# 00750: TRAIN| LT=0.434 LP=0.096 LKL=7.624 LPS=0.129 LKLS=13.261 |
# Test F1: 0.6905
# Test ACC: 0.6232
# Test AUC: 0.6864
# Train F1: 0.9538
# 00800: TRAIN| LT=0.457 LP=0.144 LKL=7.561 LPS=0.107 LKLS=13.081 |
# Test F1: 0.6667
# Test ACC: 0.6087
# Test AUC: 0.6800
# Train F1: 0.9773
# 00850: TRAIN| LT=0.402 LP=0.085 LKL=7.787 LPS=0.097 LKLS=14.169 |
# Test F1: 0.7356
# Test ACC: 0.6667
# Test AUC: 0.7073
# Train F1: 0.9687
# 00900: TRAIN| LT=0.308 LP=0.043 LKL=7.613 LPS=0.055 LKLS=13.393 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6927
# Train F1: 0.9799
# 00950: TRAIN| LT=0.351 LP=0.075 LKL=7.648 LPS=0.063 LKLS=13.643 |
# Test F1: 0.7191
# Test ACC: 0.6377
# Test AUC: 0.6882
# Train F1: 0.9798
# 01000: TRAIN| LT=0.316 LP=0.057 LKL=7.687 LPS=0.049 LKLS=13.315 |
# Test F1: 0.7356
# Test ACC: 0.6667
# Test AUC: 0.6873
# f1: 0.7787610619469026
# acc: 0.6376811594202898
# auc: 0.6127272727272727
# Train F1: 0.7685
# 00050: TRAIN| LT=1.926 LP=0.650 LKL=5.396 LPS=1.170 LKLS=5.113 |
# Test F1: 0.7788
# Test ACC: 0.6377
# Test AUC: 0.6273
# Train F1: 0.8830
# 00100: TRAIN| LT=1.364 LP=0.418 LKL=7.060 LPS=0.746 LKLS=12.907 |
# Test F1: 0.7573
# Test ACC: 0.6377
# Test AUC: 0.5609
# Train F1: 0.8470
# 00150: TRAIN| LT=1.264 LP=0.415 LKL=6.753 LPS=0.678 LKLS=10.396 |
# Test F1: 0.7184
# Test ACC: 0.5797
# Test AUC: 0.5664
# Train F1: 0.8835
# 00200: TRAIN| LT=1.157 LP=0.349 LKL=6.659 LPS=0.646 LKLS=9.641 |
# Test F1: 0.6947
# Test ACC: 0.5797
# Test AUC: 0.5773
# Train F1: 0.8840
# 00250: TRAIN| LT=1.131 LP=0.328 LKL=7.001 LPS=0.621 LKLS=11.215 |
# Test F1: 0.7447
# Test ACC: 0.6522
# Test AUC: 0.6118
# Train F1: 0.9200
# 00300: TRAIN| LT=0.859 LP=0.239 LKL=7.259 LPS=0.418 LKLS=13.016 |
# Test F1: 0.7527
# Test ACC: 0.6667
# Test AUC: 0.6536
# Train F1: 0.9408
# 00350: TRAIN| LT=0.838 LP=0.249 LKL=7.344 LPS=0.383 LKLS=13.304 |
# Test F1: 0.7391
# Test ACC: 0.6522
# Test AUC: 0.6682
# Train F1: 0.9575
# 00400: TRAIN| LT=0.706 LP=0.163 LKL=7.443 LPS=0.329 LKLS=13.972 |
# Test F1: 0.7527
# Test ACC: 0.6667
# Test AUC: 0.6582
# Train F1: 0.9718
# 00450: TRAIN| LT=0.525 LP=0.125 LKL=7.424 LPS=0.190 LKLS=13.514 |
# Test F1: 0.7579
# Test ACC: 0.6667
# Test AUC: 0.6600
# Train F1: 0.9688
# 00500: TRAIN| LT=0.570 LP=0.095 LKL=7.679 LPS=0.248 LKLS=15.051 |
# Test F1: 0.7447
# Test ACC: 0.6522
# Test AUC: 0.6573
# Train F1: 0.9771
# 00550: TRAIN| LT=0.482 LP=0.099 LKL=7.517 LPS=0.166 LKLS=14.184 |
# Test F1: 0.7312
# Test ACC: 0.6377
# Test AUC: 0.6645
# Train F1: 0.9719
# 00600: TRAIN| LT=0.461 LP=0.101 LKL=7.455 LPS=0.150 LKLS=13.524 |
# Test F1: 0.7579
# Test ACC: 0.6667
# Test AUC: 0.6600
# Train F1: 0.9659
# 00650: TRAIN| LT=0.466 LP=0.117 LKL=7.664 LPS=0.127 LKLS=14.488 |
# Test F1: 0.7708
# Test ACC: 0.6812
# Test AUC: 0.6652
# Train F1: 0.9771
# 00700: TRAIN| LT=0.425 LP=0.087 LKL=7.625 LPS=0.120 LKLS=14.208 |
# Test F1: 0.7579
# Test ACC: 0.6667
# Test AUC: 0.6702
# Train F1: 0.9801
# 00750: TRAIN| LT=0.323 LP=0.046 LKL=7.550 LPS=0.069 LKLS=13.308 |
# Test F1: 0.7579
# Test ACC: 0.6667
# Test AUC: 0.6675
# Train F1: 0.9802
# 00800: TRAIN| LT=0.316 LP=0.069 LKL=7.654 LPS=0.032 LKLS=13.833 |
# Test F1: 0.7660
# Test ACC: 0.6812
# Test AUC: 0.6739
# Train F1: 0.9716
# 00850: TRAIN| LT=0.396 LP=0.077 LKL=7.672 LPS=0.107 LKLS=13.591 |
# Test F1: 0.7708
# Test ACC: 0.6812
# Test AUC: 0.6820
# Train F1: 0.9858
# 00900: TRAIN| LT=0.332 LP=0.039 LKL=7.567 LPS=0.084 LKLS=13.225 |
# Test F1: 0.7708
# Test ACC: 0.6812
# Test AUC: 0.6739
# Train F1: 0.9858
# 00950: TRAIN| LT=0.313 LP=0.037 LKL=7.676 LPS=0.062 LKLS=13.674 |
# Test F1: 0.7579
# Test ACC: 0.6667
# Test AUC: 0.6757
# Train F1: 0.9858
# 01000: TRAIN| LT=0.274 LP=0.051 LKL=7.550 LPS=0.022 LKLS=12.603 |
# Test F1: 0.7579
# Test ACC: 0.6667
# Test AUC: 0.6818
# f1: 0.7787610619469026
# acc: 0.6376811594202898
# auc: 0.6272727272727273
# Train F1: 0.7767
# 00050: TRAIN| LT=1.822 LP=0.613 LKL=5.579 LPS=1.095 LKLS=5.885 |
# Test F1: 0.7748
# Test ACC: 0.6377
# Test AUC: 0.5318
# Train F1: 0.8338
# 00100: TRAIN| LT=1.345 LP=0.442 LKL=6.887 LPS=0.710 LKLS=12.425 |
# Test F1: 0.7358
# Test ACC: 0.5942
# Test AUC: 0.5318
# Train F1: 0.8306
# 00150: TRAIN| LT=1.225 LP=0.357 LKL=6.706 LPS=0.697 LKLS=10.400 |
# Test F1: 0.7429
# Test ACC: 0.6087
# Test AUC: 0.5936
# Train F1: 0.8501
# 00200: TRAIN| LT=1.267 LP=0.428 LKL=6.523 LPS=0.685 LKLS=8.877 |
# Test F1: 0.7429
# Test ACC: 0.6087
# Test AUC: 0.5700
# Train F1: 0.8771
# 00250: TRAIN| LT=1.163 LP=0.331 LKL=6.650 LPS=0.673 LKLS=9.280 |
# Test F1: 0.7429
# Test ACC: 0.6087
# Test AUC: 0.5773
# Train F1: 0.8661
# 00300: TRAIN| LT=1.061 LP=0.311 LKL=6.724 LPS=0.585 LKLS=9.820 |
# Test F1: 0.6804
# Test ACC: 0.5507
# Test AUC: 0.5927
# Train F1: 0.9106
# 00350: TRAIN| LT=0.872 LP=0.257 LKL=6.986 LPS=0.431 LKLS=11.322 |
# Test F1: 0.7255
# Test ACC: 0.5942
# Test AUC: 0.6309
# Train F1: 0.9379
# 00400: TRAIN| LT=0.843 LP=0.276 LKL=7.025 LPS=0.383 LKLS=11.397 |
# Test F1: 0.7500
# Test ACC: 0.6232
# Test AUC: 0.6473
# Train F1: 0.9465
# 00450: TRAIN| LT=0.805 LP=0.276 LKL=7.205 LPS=0.338 LKLS=11.926 |
# Test F1: 0.7475
# Test ACC: 0.6377
# Test AUC: 0.6545
# Train F1: 0.9405
# 00500: TRAIN| LT=0.654 LP=0.215 LKL=7.332 LPS=0.237 LKLS=12.899 |
# Test F1: 0.7379
# Test ACC: 0.6087
# Test AUC: 0.6709
# Train F1: 0.9364
# 00550: TRAIN| LT=0.638 LP=0.159 LKL=7.218 LPS=0.287 LKLS=11.960 |
# Test F1: 0.7551
# Test ACC: 0.6522
# Test AUC: 0.6655
# Train F1: 0.9471
# 00600: TRAIN| LT=0.590 LP=0.155 LKL=7.441 LPS=0.230 LKLS=13.130 |
# Test F1: 0.7573
# Test ACC: 0.6377
# Test AUC: 0.6691
# Train F1: 0.9657
# 00650: TRAIN| LT=0.497 LP=0.126 LKL=7.443 LPS=0.167 LKLS=12.922 |
# Test F1: 0.7647
# Test ACC: 0.6522
# Test AUC: 0.6791
# Train F1: 0.9773
# 00700: TRAIN| LT=0.490 LP=0.133 LKL=7.410 LPS=0.156 LKLS=12.786 |
# Test F1: 0.7647
# Test ACC: 0.6522
# Test AUC: 0.6718
# Train F1: 0.9858
# 00750: TRAIN| LT=0.472 LP=0.119 LKL=7.445 LPS=0.151 LKLS=12.747 |
# Test F1: 0.7723
# Test ACC: 0.6667
# Test AUC: 0.6645
# Train F1: 0.9716
# 00800: TRAIN| LT=0.441 LP=0.085 LKL=7.470 LPS=0.153 LKLS=12.804 |
# Test F1: 0.7525
# Test ACC: 0.6377
# Test AUC: 0.6645
# Train F1: 0.9688
# 00850: TRAIN| LT=0.463 LP=0.076 LKL=7.452 LPS=0.186 LKLS=12.708 |
# Test F1: 0.7451
# Test ACC: 0.6232
# Test AUC: 0.6609
# Train F1: 0.9716
# 00900: TRAIN| LT=0.358 LP=0.063 LKL=7.626 LPS=0.090 LKLS=12.865 |
# Test F1: 0.7400
# Test ACC: 0.6232
# Test AUC: 0.6764
# Train F1: 0.9915
# 00950: TRAIN| LT=0.389 LP=0.086 LKL=7.545 LPS=0.099 LKLS=12.796 |
# Test F1: 0.7573
# Test ACC: 0.6377
# Test AUC: 0.6720
# Train F1: 0.9745
# 01000: TRAIN| LT=0.390 LP=0.092 LKL=7.561 LPS=0.092 LKLS=12.983 |
# Test F1: 0.7525
# Test ACC: 0.6377
# Test AUC: 0.6627
# f1: 0.7747747747747746
# acc: 0.6376811594202898
# auc: 0.5318181818181817
# f1 [0.7956989247311828, 0.7663551401869159, 0.7787610619469026, 0.7787610619469026, 0.7747747747747746]
# average maxf1 0.7788701927173356
# acc [0.7285714285714285, 0.6428571428571429, 0.6376811594202898, 0.6376811594202898, 0.6376811594202898]
# average maxacc 0.6568944099378882
# auc [0.6949300699300699, 0.6748251748251748, 0.6127272727272727, 0.6272727272727273, 0.5318181818181817]
# average maxauc 0.6283146853146853
