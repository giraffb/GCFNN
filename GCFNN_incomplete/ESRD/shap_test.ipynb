# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'Control':0,'ESRD':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)

#随机缺失，生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
from sklearn.preprocessing import OneHotEncoder
from numpy.random import randint
import warnings
warnings.filterwarnings("ignore")
def get_sn(view_num, alldata_len, missing_rate):
    """Randomly generate incomplete data information, simulate partial view data with complete view data
    :param view_num:view number
    :param alldata_len:number of samples
    :param missing_rate:Defined in section 3.2 of the paper
    :return:Sn
    """
    one_rate = 1-missing_rate
    if one_rate <= (1 / view_num):
        #enc = OneHotEncoder(n_values=view_num)
        enc = OneHotEncoder()
        view_preserve = enc.fit_transform(randint(0, view_num, size=(alldata_len, 1))).toarray()
        return view_preserve
    error = 1
    if one_rate == 1:
        matrix = randint(1, 2, size=(alldata_len, view_num))
        return matrix
    while error >= 0.005:
        #enc = OneHotEncoder(n_values=view_num)
        enc = OneHotEncoder()
        view_preserve = enc.fit_transform(randint(0, view_num, size=(alldata_len, 1))).toarray()
        one_num = view_num * alldata_len * one_rate - alldata_len
        ratio = one_num / (view_num * alldata_len)
        matrix_iter = (randint(0, 100, size=(alldata_len, view_num)) < int(ratio * 100)).astype(np.int)
        a = np.sum(((matrix_iter + view_preserve) > 1).astype(np.int))
        one_num_iter = one_num / (1 - a / one_num)
        ratio = one_num_iter / (view_num * alldata_len)
        matrix_iter = (randint(0, 100, size=(alldata_len, view_num)) < int(ratio * 100)).astype(np.int)
        matrix = ((matrix_iter + view_preserve) > 0).astype(np.int)
        ratio = np.sum(matrix) / (view_num * alldata_len)
        error = abs(one_rate - ratio)
    return matrix
Mask     = np.ones([np.shape(X_set[0])[0], M])
print(sum(Mask))
missrate = 0.5
Mask     = get_sn(2,X_set[0].shape[0],missrate)
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
print(sum(Mask)) 
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (287, 780) (287, 276) (287, 1)
# Index(['CON-001', 'CON-002', 'CON-003', 'CON-004', 'CON-005', 'CON-006',
#        'CON-007', 'CON-008', 'CON-009', 'CON-010',
#        ...
#        'KD-214', 'KD-215', 'KD-216', 'KD-217', 'KD-218', 'KD-219', 'KD-220',
#        'KD-221', 'KD-222', 'KD-223'],
#       dtype='object', name='Sample', length=287)
# 数据完整率missing_rate : 1.0
# 集合所有样本重构数据表： (287, 780) (287, 276) (287, 1)
# 574.0
# 287.0
# 标签转换为one-hot编码： (287, 2) 67.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 20)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 1, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1',f1_cv)
print('average maxf1',sum(f1_cv)/5)
print('acc',acc_cv)
print('average maxacc',sum(acc_cv)/5)
print('auc',auc_cv)
print('average maxauc',sum(auc_cv)/5)
# Out:
# Train F1: 0.8601
# 00050: TRAIN| LT=1.553 LP=0.501 LKL=6.122 LPS=0.883 LKLS=10.761 |
# Test F1: 0.8889
# Test ACC: 0.8103
# Test AUC: 0.8231
# Train F1: 0.8960
# 00100: TRAIN| LT=1.245 LP=0.403 LKL=6.371 LPS=0.670 LKLS=10.850 |
# Test F1: 0.8842
# Test ACC: 0.8103
# Test AUC: 0.9075
# Train F1: 0.8936
# 00150: TRAIN| LT=1.072 LP=0.367 LKL=6.190 LPS=0.546 LKLS=9.654 |
# Test F1: 0.8632
# Test ACC: 0.7759
# Test AUC: 0.9075
# Train F1: 0.9030
# 00200: TRAIN| LT=0.973 LP=0.308 LKL=6.314 LPS=0.499 LKLS=10.347 |
# Test F1: 0.8723
# Test ACC: 0.7931
# Test AUC: 0.8929
# Train F1: 0.9222
# 00250: TRAIN| LT=0.816 LP=0.246 LKL=6.543 LPS=0.392 LKLS=11.265 |
# Test F1: 0.8913
# Test ACC: 0.8276
# Test AUC: 0.9042
# Train F1: 0.9366
# 00300: TRAIN| LT=0.768 LP=0.254 LKL=6.662 LPS=0.333 LKLS=11.477 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.9156
# Train F1: 0.9412
# 00350: TRAIN| LT=0.637 LP=0.165 LKL=6.841 LPS=0.281 LKLS=12.201 |
# Test F1: 0.8989
# Test ACC: 0.8448
# Test AUC: 0.8864
# Train F1: 0.9687
# 00400: TRAIN| LT=0.555 LP=0.158 LKL=6.910 LPS=0.206 LKLS=12.223 |
# Test F1: 0.8736
# Test ACC: 0.8103
# Test AUC: 0.8701
# Train F1: 0.9636
# 00450: TRAIN| LT=0.405 LP=0.100 LKL=7.081 LPS=0.105 LKLS=12.958 |
# Test F1: 0.8736
# Test ACC: 0.8103
# Test AUC: 0.8636
# Train F1: 0.9858
# 00500: TRAIN| LT=0.379 LP=0.089 LKL=7.136 LPS=0.085 LKLS=13.402 |
# Test F1: 0.8864
# Test ACC: 0.8276
# Test AUC: 0.8425
# Train F1: 0.9859
# 00550: TRAIN| LT=0.339 LP=0.062 LKL=7.229 LPS=0.068 LKLS=13.672 |
# Test F1: 0.8989
# Test ACC: 0.8448
# Test AUC: 0.8539
# Train F1: 0.9829
# 00600: TRAIN| LT=0.294 LP=0.056 LKL=7.206 LPS=0.033 LKLS=13.255 |
# Test F1: 0.8736
# Test ACC: 0.8103
# Test AUC: 0.8799
# Train F1: 0.9858
# 00650: TRAIN| LT=0.318 LP=0.078 LKL=7.129 LPS=0.043 LKLS=12.595 |
# Test F1: 0.8989
# Test ACC: 0.8448
# Test AUC: 0.8571
# Train F1: 0.9915
# 00700: TRAIN| LT=0.300 LP=0.032 LKL=7.180 LPS=0.069 LKLS=12.704 |
# Test F1: 0.8989
# Test ACC: 0.8448
# Test AUC: 0.8588
# Train F1: 0.9915
# 00750: TRAIN| LT=0.264 LP=0.026 LKL=7.256 LPS=0.034 LKLS=13.066 |
# Test F1: 0.9130
# Test ACC: 0.8621
# Test AUC: 0.8685
# Train F1: 0.9887
# 00800: TRAIN| LT=0.298 LP=0.045 LKL=7.052 LPS=0.064 LKLS=11.850 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.8669
# Train F1: 0.9943
# 00850: TRAIN| LT=0.283 LP=0.034 LKL=7.177 LPS=0.053 LKLS=12.488 |
# Test F1: 0.8889
# Test ACC: 0.8276
# Test AUC: 0.8506
# Train F1: 0.9943
# 00900: TRAIN| LT=0.269 LP=0.042 LKL=7.122 LPS=0.036 LKLS=12.066 |
# Test F1: 0.9111
# Test ACC: 0.8621
# Test AUC: 0.8782
# Train F1: 0.9943
# 00950: TRAIN| LT=0.248 LP=0.030 LKL=7.057 LPS=0.033 LKLS=11.458 |
# Test F1: 0.9111
# Test ACC: 0.8621
# Test AUC: 0.8685
# Train F1: 0.9972
# 01000: TRAIN| LT=0.280 LP=0.053 LKL=7.007 LPS=0.046 LKLS=11.119 |
# Test F1: 0.9032
# Test ACC: 0.8448
# Test AUC: 0.8588
# Train F1: 0.9972
# 01050: TRAIN| LT=0.209 LP=0.017 LKL=7.072 LPS=0.005 LKLS=11.553 |
# Test F1: 0.9130
# Test ACC: 0.8621
# Test AUC: 0.8730
# Train F1: 0.9885
# 01100: TRAIN| LT=0.215 LP=0.013 LKL=7.091 LPS=0.016 LKLS=11.486 |
# Test F1: 0.8889
# Test ACC: 0.8276
# Test AUC: 0.8799
# Train F1: 0.9915
# 01150: TRAIN| LT=0.222 LP=0.027 LKL=7.028 LPS=0.013 LKLS=11.128 |
# Test F1: 0.9247
# Test ACC: 0.8793
# Test AUC: 0.8718
# Train F1: 0.9943
# 01200: TRAIN| LT=0.242 LP=0.047 LKL=7.119 LPS=0.010 LKLS=11.425 |
# Test F1: 0.9247
# Test ACC: 0.8793
# Test AUC: 0.8766
# Train F1: 0.9801
# 01250: TRAIN| LT=0.217 LP=0.029 LKL=6.971 LPS=0.013 LKLS=10.547 |
# Test F1: 0.8864
# Test ACC: 0.8276
# Test AUC: 0.8847
# Train F1: 0.9886
# 01300: TRAIN| LT=0.223 LP=0.042 LKL=7.015 LPS=0.005 LKLS=10.605 |
# Test F1: 0.8913
# Test ACC: 0.8276
# Test AUC: 0.8669
# Train F1: 0.9972
# 01350: TRAIN| LT=0.238 LP=0.044 LKL=6.905 LPS=0.022 LKLS=10.364 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.8734
# Train F1: 0.9886
# 01400: TRAIN| LT=0.257 LP=0.050 LKL=6.928 LPS=0.036 LKLS=10.145 |
# Test F1: 0.8989
# Test ACC: 0.8448
# Test AUC: 0.8636
# Train F1: 0.9915
# 01450: TRAIN| LT=0.200 LP=0.013 LKL=6.889 LPS=0.016 LKLS=10.213 |
# Test F1: 0.9247
# Test ACC: 0.8793
# Test AUC: 0.8734
# Train F1: 0.9972
# 01500: TRAIN| LT=0.216 LP=0.039 LKL=6.984 LPS=0.003 LKLS=10.403 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.8799
# Train F1: 0.9915
# 01550: TRAIN| LT=0.243 LP=0.061 LKL=6.844 LPS=0.016 LKLS=9.817 |
# Test F1: 0.9149
# Test ACC: 0.8621
# Test AUC: 0.8592
# Train F1: 0.9943
# 01600: TRAIN| LT=0.188 LP=0.016 LKL=6.844 LPS=0.005 LKLS=9.828 |
# Test F1: 0.9130
# Test ACC: 0.8621
# Test AUC: 0.8815
# Train F1: 0.9943
# 01650: TRAIN| LT=0.243 LP=0.028 LKL=6.949 LPS=0.043 LKLS=10.183 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.8782
# Train F1: 0.9972
# 01700: TRAIN| LT=0.208 LP=0.036 LKL=6.954 LPS=0.001 LKLS=10.112 |
# Test F1: 0.9149
# Test ACC: 0.8621
# Test AUC: 0.8782
# Train F1: 0.9915
# 01750: TRAIN| LT=0.214 LP=0.036 LKL=6.910 LPS=0.009 LKLS=9.913 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.8782
# Train F1: 1.0000
# 01800: TRAIN| LT=0.180 LP=0.007 LKL=6.909 LPS=0.009 LKLS=9.528 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.8815
# Train F1: 0.9943
# 01850: TRAIN| LT=0.191 LP=0.021 LKL=6.806 LPS=0.009 LKLS=9.299 |
# Test F1: 0.9247
# Test ACC: 0.8793
# Test AUC: 0.8815
# Train F1: 0.9972
# 01900: TRAIN| LT=0.190 LP=0.019 LKL=6.859 LPS=0.009 LKLS=9.362 |
# Test F1: 0.9247
# Test ACC: 0.8793
# Test AUC: 0.8851
# Train F1: 0.9972
# 01950: TRAIN| LT=0.172 LP=0.008 LKL=6.672 LPS=0.008 LKLS=8.818 |
# Test F1: 0.9149
# Test ACC: 0.8621
# Test AUC: 0.8770
# Train F1: 0.9887
# 02000: TRAIN| LT=0.194 LP=0.024 LKL=6.728 LPS=0.011 LKLS=9.192 |
# Test F1: 0.9247
# Test ACC: 0.8793
# Test AUC: 0.8799
# f1: 0.9247311827956989
# acc: 0.8793103448275862
# auc: 0.8851461038961039
# Train F1: 0.8702
# 00050: TRAIN| LT=1.476 LP=0.483 LKL=6.001 LPS=0.834 LKLS=9.959 |
# Test F1: 0.8800
# Test ACC: 0.7931
# Test AUC: 0.8295
# Train F1: 0.9072
# 00100: TRAIN| LT=1.236 LP=0.427 LKL=6.404 LPS=0.636 LKLS=10.987 |
# Test F1: 0.8800
# Test ACC: 0.7931
# Test AUC: 0.9140
# Train F1: 0.8997
# 00150: TRAIN| LT=1.081 LP=0.380 LKL=6.144 LPS=0.548 LKLS=9.104 |
# Test F1: 0.8800
# Test ACC: 0.7931
# Test AUC: 0.9416
# Train F1: 0.9096
# 00200: TRAIN| LT=0.926 LP=0.305 LKL=6.341 LPS=0.452 LKLS=10.588 |
# Test F1: 0.8889
# Test ACC: 0.8103
# Test AUC: 0.9529
# Train F1: 0.9421
# 00250: TRAIN| LT=0.835 LP=0.256 LKL=6.596 LPS=0.401 LKLS=11.233 |
# Test F1: 0.9362
# Test ACC: 0.8966
# Test AUC: 0.9675
# Train F1: 0.9751
# 00300: TRAIN| LT=0.565 LP=0.131 LKL=7.037 LPS=0.228 LKLS=13.618 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9870
# Train F1: 0.9548
# 00350: TRAIN| LT=0.571 LP=0.161 LKL=7.138 LPS=0.201 LKLS=13.784 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9886
# Train F1: 0.9746
# 00400: TRAIN| LT=0.507 LP=0.136 LKL=7.061 LPS=0.170 LKLS=13.101 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9903
# Train F1: 0.9858
# 00450: TRAIN| LT=0.393 LP=0.097 LKL=7.340 LPS=0.078 LKLS=14.441 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9838
# Train F1: 0.9830
# 00500: TRAIN| LT=0.334 LP=0.071 LKL=7.198 LPS=0.061 LKLS=13.052 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9805
# Train F1: 0.9915
# 00550: TRAIN| LT=0.291 LP=0.041 LKL=7.104 LPS=0.055 LKLS=12.416 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9708
# Train F1: 0.9915
# 00600: TRAIN| LT=0.354 LP=0.067 LKL=7.210 LPS=0.088 LKLS=12.744 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9740
# Train F1: 0.9773
# 00650: TRAIN| LT=0.328 LP=0.075 LKL=7.130 LPS=0.059 LKLS=12.220 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9708
# Train F1: 0.9914
# 00700: TRAIN| LT=0.256 LP=0.030 LKL=7.214 LPS=0.027 LKLS=12.706 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9724
# Train F1: 0.9944
# 00750: TRAIN| LT=0.269 LP=0.044 LKL=7.382 LPS=0.019 LKLS=13.179 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9789
# Train F1: 0.9829
# 00800: TRAIN| LT=0.262 LP=0.043 LKL=7.257 LPS=0.022 LKLS=12.363 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9740
# Train F1: 0.9915
# 00850: TRAIN| LT=0.306 LP=0.080 LKL=7.224 LPS=0.029 LKLS=12.507 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9627
# Train F1: 0.9972
# 00900: TRAIN| LT=0.233 LP=0.024 LKL=7.159 LPS=0.018 LKLS=11.951 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9789
# Train F1: 0.9943
# 00950: TRAIN| LT=0.239 LP=0.033 LKL=7.141 LPS=0.016 LKLS=11.832 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9659
# Train F1: 0.9830
# 01000: TRAIN| LT=0.238 LP=0.017 LKL=7.054 LPS=0.039 LKLS=11.170 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9789
# Train F1: 0.9915
# 01050: TRAIN| LT=0.238 LP=0.012 LKL=7.187 LPS=0.036 LKLS=11.813 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9627
# Train F1: 0.9887
# 01100: TRAIN| LT=0.236 LP=0.052 LKL=7.054 LPS=0.005 LKLS=10.877 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9675
# Train F1: 0.9915
# 01150: TRAIN| LT=0.249 LP=0.038 LKL=7.047 LPS=0.033 LKLS=10.827 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9708
# Train F1: 0.9859
# 01200: TRAIN| LT=0.230 LP=0.032 LKL=6.912 LPS=0.027 LKLS=10.210 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9756
# Train F1: 0.9972
# 01250: TRAIN| LT=0.240 LP=0.039 LKL=7.010 LPS=0.027 LKLS=10.428 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9675
# Train F1: 0.9944
# 01300: TRAIN| LT=0.217 LP=0.021 LKL=6.957 LPS=0.024 LKLS=10.194 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9692
# Train F1: 0.9915
# 01350: TRAIN| LT=0.229 LP=0.032 LKL=7.105 LPS=0.021 LKLS=10.522 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9659
# Train F1: 0.9943
# 01400: TRAIN| LT=0.212 LP=0.020 LKL=7.070 LPS=0.013 LKLS=10.862 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9692
# Train F1: 0.9972
# 01450: TRAIN| LT=0.252 LP=0.033 LKL=7.032 LPS=0.047 LKLS=10.185 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9627
# Train F1: 0.9886
# 01500: TRAIN| LT=0.219 LP=0.046 LKL=6.969 LPS=0.005 LKLS=9.805 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9643
# Train F1: 0.9915
# 01550: TRAIN| LT=0.198 LP=0.023 LKL=7.051 LPS=0.003 LKLS=10.147 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9627
# Train F1: 0.9943
# 01600: TRAIN| LT=0.286 LP=0.062 LKL=7.092 LPS=0.049 LKLS=10.300 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9708
# Train F1: 0.9972
# 01650: TRAIN| LT=0.252 LP=0.046 LKL=7.007 LPS=0.039 LKLS=9.694 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9562
# Train F1: 0.9972
# 01700: TRAIN| LT=0.199 LP=0.016 LKL=6.916 LPS=0.016 LKLS=9.807 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9692
# Train F1: 0.9972
# 01750: TRAIN| LT=0.183 LP=0.017 LKL=6.903 LPS=0.002 LKLS=9.534 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9610
# Train F1: 0.9972
# 01800: TRAIN| LT=0.177 LP=0.009 LKL=6.769 LPS=0.014 LKLS=8.646 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9643
# Train F1: 0.9972
# 01850: TRAIN| LT=0.215 LP=0.022 LKL=6.745 LPS=0.035 LKLS=9.022 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9692
# Train F1: 1.0000
# 01900: TRAIN| LT=0.172 LP=0.007 LKL=6.886 LPS=0.003 LKLS=9.287 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9692
# Train F1: 0.9972
# 01950: TRAIN| LT=0.170 LP=0.007 LKL=6.816 LPS=0.006 LKLS=8.797 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9594
# Train F1: 0.9972
# 02000: TRAIN| LT=0.194 LP=0.013 LKL=6.779 LPS=0.026 LKLS=8.654 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9643
# f1: 0.9565217391304348
# acc: 0.9310344827586207
# auc: 0.9902597402597403
# Train F1: 0.8728
# 00050: TRAIN| LT=1.464 LP=0.507 LKL=5.794 LPS=0.808 LKLS=9.074 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.7343
# Train F1: 0.8964
# 00100: TRAIN| LT=1.219 LP=0.404 LKL=6.028 LPS=0.658 LKLS=9.684 |
# Test F1: 0.9072
# Test ACC: 0.8421
# Test AUC: 0.7920
# Train F1: 0.8989
# 00150: TRAIN| LT=1.167 LP=0.423 LKL=6.070 LPS=0.586 LKLS=9.771 |
# Test F1: 0.9072
# Test ACC: 0.8421
# Test AUC: 0.8077
# Train F1: 0.9115
# 00200: TRAIN| LT=1.024 LP=0.350 LKL=6.089 LPS=0.521 LKLS=9.214 |
# Test F1: 0.9167
# Test ACC: 0.8596
# Test AUC: 0.8776
# Train F1: 0.9176
# 00250: TRAIN| LT=0.923 LP=0.294 LKL=6.374 LPS=0.463 LKLS=10.305 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.9196
# Train F1: 0.9330
# 00300: TRAIN| LT=0.841 LP=0.260 LKL=6.673 LPS=0.397 LKLS=11.718 |
# Test F1: 0.9213
# Test ACC: 0.8772
# Test AUC: 0.9406
# Train F1: 0.9418
# 00350: TRAIN| LT=0.700 LP=0.222 LKL=6.788 LPS=0.291 LKLS=11.869 |
# Test F1: 0.9318
# Test ACC: 0.8947
# Test AUC: 0.9580
# Train F1: 0.9634
# 00400: TRAIN| LT=0.609 LP=0.196 LKL=7.036 LPS=0.213 LKLS=13.016 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9615
# Train F1: 0.9570
# 00450: TRAIN| LT=0.467 LP=0.124 LKL=7.223 LPS=0.134 LKLS=13.624 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9633
# Train F1: 0.9598
# 00500: TRAIN| LT=0.418 LP=0.118 LKL=7.123 LPS=0.104 LKLS=12.517 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9633
# Train F1: 0.9746
# 00550: TRAIN| LT=0.426 LP=0.141 LKL=7.276 LPS=0.078 LKLS=13.489 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9668
# Train F1: 0.9859
# 00600: TRAIN| LT=0.377 LP=0.070 LKL=7.261 LPS=0.103 LKLS=13.096 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9685
# Train F1: 0.9802
# 00650: TRAIN| LT=0.292 LP=0.048 LKL=7.353 LPS=0.040 LKLS=13.070 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9685
# Train F1: 0.9687
# 00700: TRAIN| LT=0.322 LP=0.080 LKL=7.352 LPS=0.041 LKLS=12.817 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9668
# Train F1: 0.9857
# 00750: TRAIN| LT=0.298 LP=0.051 LKL=7.399 LPS=0.041 LKLS=13.228 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9650
# Train F1: 0.9886
# 00800: TRAIN| LT=0.283 LP=0.040 LKL=7.370 LPS=0.040 LKLS=12.950 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9650
# Train F1: 0.9888
# 00850: TRAIN| LT=0.300 LP=0.053 LKL=7.352 LPS=0.047 LKLS=12.571 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9668
# Train F1: 0.9915
# 00900: TRAIN| LT=0.308 LP=0.065 LKL=7.279 LPS=0.047 LKLS=12.302 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9633
# Train F1: 0.9858
# 00950: TRAIN| LT=0.235 LP=0.020 LKL=7.137 LPS=0.031 LKLS=11.295 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9668
# Train F1: 0.9857
# 01000: TRAIN| LT=0.315 LP=0.051 LKL=7.182 LPS=0.077 LKLS=11.524 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9650
# Train F1: 0.9943
# 01050: TRAIN| LT=0.245 LP=0.023 LKL=7.359 LPS=0.028 LKLS=12.066 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9650
# Train F1: 0.9943
# 01100: TRAIN| LT=0.289 LP=0.027 LKL=7.329 LPS=0.070 LKLS=11.853 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9615
# Train F1: 0.9943
# 01150: TRAIN| LT=0.294 LP=0.067 LKL=7.229 LPS=0.041 LKLS=11.382 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9598
# Train F1: 1.0000
# 01200: TRAIN| LT=0.281 LP=0.053 LKL=7.245 LPS=0.047 LKLS=10.793 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9598
# Train F1: 0.9944
# 01250: TRAIN| LT=0.228 LP=0.022 LKL=7.391 LPS=0.013 LKLS=11.872 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9650
# Train F1: 0.9972
# 01300: TRAIN| LT=0.278 LP=0.035 LKL=7.332 LPS=0.057 LKLS=11.313 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9615
# Train F1: 0.9972
# 01350: TRAIN| LT=0.261 LP=0.026 LKL=7.311 LPS=0.050 LKLS=11.198 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9633
# Train F1: 1.0000
# 01400: TRAIN| LT=0.253 LP=0.043 LKL=7.235 LPS=0.029 LKLS=10.944 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9633
# Train F1: 0.9856
# 01450: TRAIN| LT=0.237 LP=0.038 LKL=7.061 LPS=0.024 LKLS=10.334 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9650
# Train F1: 0.9972
# 01500: TRAIN| LT=0.227 LP=0.037 LKL=7.025 LPS=0.022 LKLS=9.815 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9615
# Train F1: 0.9943
# 01550: TRAIN| LT=0.223 LP=0.022 LKL=7.375 LPS=0.017 LKLS=11.112 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9615
# Train F1: 0.9915
# 01600: TRAIN| LT=0.248 LP=0.058 LKL=7.081 LPS=0.019 LKLS=10.068 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9633
# Train F1: 0.9857
# 01650: TRAIN| LT=0.216 LP=0.024 LKL=7.105 LPS=0.020 LKLS=10.066 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9668
# Train F1: 0.9885
# 01700: TRAIN| LT=0.285 LP=0.066 LKL=6.996 LPS=0.056 LKLS=9.352 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9650
# Train F1: 1.0000
# 01750: TRAIN| LT=0.193 LP=0.027 LKL=6.878 LPS=0.008 LKLS=8.960 |
# Test F1: 0.9149
# Test ACC: 0.8596
# Test AUC: 0.9650
# Train F1: 0.9943
# 01800: TRAIN| LT=0.181 LP=0.017 LKL=6.832 LPS=0.006 LKLS=8.911 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9668
# Train F1: 0.9915
# 01850: TRAIN| LT=0.253 LP=0.050 LKL=7.101 LPS=0.036 LKLS=9.668 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9720
# Train F1: 0.9972
# 01900: TRAIN| LT=0.187 LP=0.016 LKL=7.069 LPS=0.005 LKLS=9.540 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9685
# Train F1: 0.9972
# 01950: TRAIN| LT=0.198 LP=0.014 LKL=7.045 LPS=0.021 LKLS=9.182 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9615
# Train F1: 0.9972
# 02000: TRAIN| LT=0.197 LP=0.024 LKL=7.005 LPS=0.013 LKLS=9.032 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9615
# f1: 0.9555555555555557
# acc: 0.9298245614035088
# auc: 0.9667832167832168
# Train F1: 0.8804
# 00050: TRAIN| LT=1.454 LP=0.515 LKL=5.980 LPS=0.772 LKLS=10.797 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.7203
# Train F1: 0.8918
# 00100: TRAIN| LT=1.180 LP=0.426 LKL=6.203 LPS=0.584 LKLS=10.779 |
# Test F1: 0.8776
# Test ACC: 0.7895
# Test AUC: 0.7098
# Train F1: 0.9169
# 00150: TRAIN| LT=1.158 LP=0.411 LKL=5.972 LPS=0.600 LKLS=8.701 |
# Test F1: 0.8660
# Test ACC: 0.7719
# Test AUC: 0.7535
# Train F1: 0.9194
# 00200: TRAIN| LT=0.969 LP=0.286 LKL=6.373 LPS=0.508 LKLS=11.039 |
# Test F1: 0.8750
# Test ACC: 0.7895
# Test AUC: 0.8042
# Train F1: 0.9185
# 00250: TRAIN| LT=0.807 LP=0.276 LKL=6.536 LPS=0.355 LKLS=11.085 |
# Test F1: 0.8315
# Test ACC: 0.7368
# Test AUC: 0.8409
# Train F1: 0.9526
# 00300: TRAIN| LT=0.720 LP=0.233 LKL=6.719 LPS=0.303 LKLS=11.695 |
# Test F1: 0.8372
# Test ACC: 0.7544
# Test AUC: 0.8566
# Train F1: 0.9716
# 00350: TRAIN| LT=0.627 LP=0.172 LKL=6.912 LPS=0.260 LKLS=12.583 |
# Test F1: 0.8471
# Test ACC: 0.7719
# Test AUC: 0.8654
# Train F1: 0.9632
# 00400: TRAIN| LT=0.468 LP=0.113 LKL=7.156 LPS=0.148 LKLS=13.590 |
# Test F1: 0.8636
# Test ACC: 0.7895
# Test AUC: 0.8619
# Train F1: 0.9657
# 00450: TRAIN| LT=0.425 LP=0.099 LKL=7.249 LPS=0.116 LKLS=13.767 |
# Test F1: 0.8736
# Test ACC: 0.8070
# Test AUC: 0.8724
# Train F1: 0.9636
# 00500: TRAIN| LT=0.467 LP=0.112 LKL=7.315 LPS=0.143 LKLS=13.880 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.8636
# Train F1: 0.9803
# 00550: TRAIN| LT=0.379 LP=0.088 LKL=7.258 LPS=0.084 LKLS=13.441 |
# Test F1: 0.8667
# Test ACC: 0.7895
# Test AUC: 0.8724
# Train F1: 0.9831
# 00600: TRAIN| LT=0.347 LP=0.091 LKL=7.373 LPS=0.045 LKLS=13.637 |
# Test F1: 0.8791
# Test ACC: 0.8070
# Test AUC: 0.8811
# Train F1: 0.9775
# 00650: TRAIN| LT=0.365 LP=0.062 LKL=7.333 LPS=0.097 LKLS=13.238 |
# Test F1: 0.8764
# Test ACC: 0.8070
# Test AUC: 0.8811
# Train F1: 0.9886
# 00700: TRAIN| LT=0.322 LP=0.095 LKL=7.184 LPS=0.031 LKLS=12.357 |
# Test F1: 0.8636
# Test ACC: 0.7895
# Test AUC: 0.8916
# Train F1: 0.9859
# 00750: TRAIN| LT=0.335 LP=0.046 LKL=7.351 LPS=0.084 LKLS=13.152 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.9003
# Train F1: 0.9858
# 00800: TRAIN| LT=0.297 LP=0.074 LKL=7.303 LPS=0.022 LKLS=12.807 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.8881
# Train F1: 0.9886
# 00850: TRAIN| LT=0.260 LP=0.038 LKL=7.215 LPS=0.029 LKLS=12.075 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.8864
# Train F1: 0.9830
# 00900: TRAIN| LT=0.270 LP=0.033 LKL=7.446 LPS=0.029 LKLS=13.296 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9073
# Train F1: 0.9915
# 00950: TRAIN| LT=0.255 LP=0.028 LKL=7.255 LPS=0.032 LKLS=12.238 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.8864
# Train F1: 0.9886
# 01000: TRAIN| LT=0.275 LP=0.040 LKL=7.457 LPS=0.035 LKLS=12.500 |
# Test F1: 0.9111
# Test ACC: 0.8596
# Test AUC: 0.9161
# Train F1: 0.9915
# 01050: TRAIN| LT=0.268 LP=0.043 LKL=7.164 LPS=0.035 LKLS=11.831 |
# Test F1: 0.8936
# Test ACC: 0.8246
# Test AUC: 0.8916
# Train F1: 0.9944
# 01100: TRAIN| LT=0.251 LP=0.039 LKL=7.177 LPS=0.026 LKLS=11.427 |
# Test F1: 0.9231
# Test ACC: 0.8772
# Test AUC: 0.9108
# Train F1: 0.9886
# 01150: TRAIN| LT=0.265 LP=0.058 LKL=7.206 LPS=0.018 LKLS=11.740 |
# Test F1: 0.8936
# Test ACC: 0.8246
# Test AUC: 0.8916
# Train F1: 0.9972
# 01200: TRAIN| LT=0.307 LP=0.071 LKL=7.046 LPS=0.058 LKLS=10.698 |
# Test F1: 0.8936
# Test ACC: 0.8246
# Test AUC: 0.9003
# Train F1: 0.9774
# 01250: TRAIN| LT=0.242 LP=0.042 LKL=7.266 LPS=0.011 LKLS=11.678 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.8969
# Train F1: 0.9830
# 01300: TRAIN| LT=0.254 LP=0.027 LKL=7.317 LPS=0.038 LKLS=11.650 |
# Test F1: 0.9011
# Test ACC: 0.8421
# Test AUC: 0.9248
# Train F1: 0.9943
# 01350: TRAIN| LT=0.227 LP=0.032 LKL=7.032 LPS=0.017 LKLS=10.812 |
# Test F1: 0.8936
# Test ACC: 0.8246
# Test AUC: 0.9056
# Train F1: 0.9915
# 01400: TRAIN| LT=0.261 LP=0.054 LKL=7.108 LPS=0.027 LKLS=10.758 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9108
# Train F1: 0.9943
# 01450: TRAIN| LT=0.237 LP=0.025 LKL=7.075 LPS=0.037 LKLS=10.531 |
# Test F1: 0.8936
# Test ACC: 0.8246
# Test AUC: 0.9021
# Train F1: 0.9830
# 01500: TRAIN| LT=0.214 LP=0.030 LKL=7.073 LPS=0.005 LKLS=10.781 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.9213
# Train F1: 0.9943
# 01550: TRAIN| LT=0.215 LP=0.025 LKL=7.025 LPS=0.017 LKLS=10.248 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9108
# Train F1: 0.9972
# 01600: TRAIN| LT=0.236 LP=0.043 LKL=7.202 LPS=0.011 LKLS=10.978 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9161
# Train F1: 0.9858
# 01650: TRAIN| LT=0.218 LP=0.027 LKL=7.001 LPS=0.023 LKLS=9.891 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9196
# Train F1: 0.9943
# 01700: TRAIN| LT=0.227 LP=0.050 LKL=7.093 LPS=0.004 LKLS=10.230 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9091
# Train F1: 0.9803
# 01750: TRAIN| LT=0.220 LP=0.024 LKL=7.219 LPS=0.016 LKLS=10.760 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9283
# Train F1: 0.9915
# 01800: TRAIN| LT=0.198 LP=0.021 LKL=6.932 LPS=0.010 LKLS=9.778 |
# Test F1: 0.8936
# Test ACC: 0.8246
# Test AUC: 0.9108
# Train F1: 0.9857
# 01850: TRAIN| LT=0.226 LP=0.019 LKL=6.931 LPS=0.040 LKLS=9.819 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.9248
# Train F1: 0.9915
# 01900: TRAIN| LT=0.272 LP=0.047 LKL=7.025 LPS=0.054 LKLS=10.038 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9371
# Train F1: 1.0000
# 01950: TRAIN| LT=0.225 LP=0.047 LKL=6.926 LPS=0.015 LKLS=9.300 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9108
# Train F1: 0.9914
# 02000: TRAIN| LT=0.222 LP=0.042 LKL=6.971 LPS=0.015 LKLS=9.468 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9213
# f1: 0.9230769230769231
# acc: 0.8771929824561403
# auc: 0.9108391608391608
# Train F1: 0.8696
# 00050: TRAIN| LT=1.476 LP=0.504 LKL=6.052 LPS=0.809 LKLS=10.308 |
# Test F1: 0.8687
# Test ACC: 0.7719
# Test AUC: 0.7587
# Train F1: 0.8828
# 00100: TRAIN| LT=1.200 LP=0.415 LKL=6.255 LPS=0.618 LKLS=10.479 |
# Test F1: 0.8866
# Test ACC: 0.8070
# Test AUC: 0.8322
# Train F1: 0.8889
# 00150: TRAIN| LT=1.027 LP=0.323 LKL=6.191 LPS=0.542 LKLS=10.033 |
# Test F1: 0.8660
# Test ACC: 0.7719
# Test AUC: 0.8164
# Train F1: 0.9256
# 00200: TRAIN| LT=0.963 LP=0.301 LKL=6.382 LPS=0.493 LKLS=10.562 |
# Test F1: 0.8966
# Test ACC: 0.8421
# Test AUC: 0.8409
# Train F1: 0.9497
# 00250: TRAIN| LT=0.800 LP=0.250 LKL=6.744 LPS=0.362 LKLS=12.053 |
# Test F1: 0.8889
# Test ACC: 0.8246
# Test AUC: 0.8601
# Train F1: 0.9441
# 00300: TRAIN| LT=0.724 LP=0.227 LKL=6.808 LPS=0.312 LKLS=11.712 |
# Test F1: 0.9091
# Test ACC: 0.8596
# Test AUC: 0.8846
# Train F1: 0.9471
# 00350: TRAIN| LT=0.673 LP=0.211 LKL=6.857 LPS=0.278 LKLS=11.556 |
# Test F1: 0.9318
# Test ACC: 0.8947
# Test AUC: 0.9161
# Train F1: 0.9521
# 00400: TRAIN| LT=0.470 LP=0.129 LKL=6.909 LPS=0.151 LKLS=12.041 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9196
# Train F1: 0.9607
# 00450: TRAIN| LT=0.436 LP=0.102 LKL=7.063 LPS=0.136 LKLS=12.680 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9283
# Train F1: 0.9774
# 00500: TRAIN| LT=0.427 LP=0.095 LKL=7.138 LPS=0.134 LKLS=12.645 |
# Test F1: 0.9318
# Test ACC: 0.8947
# Test AUC: 0.9406
# Train F1: 0.9746
# 00550: TRAIN| LT=0.331 LP=0.088 LKL=7.165 LPS=0.046 LKLS=12.656 |
# Test F1: 0.9438
# Test ACC: 0.9123
# Test AUC: 0.9406
# Train F1: 0.9801
# 00600: TRAIN| LT=0.318 LP=0.076 LKL=7.198 LPS=0.045 LKLS=12.457 |
# Test F1: 0.9425
# Test ACC: 0.9123
# Test AUC: 0.9423
# Train F1: 0.9888
# 00650: TRAIN| LT=0.298 LP=0.052 LKL=7.262 LPS=0.048 LKLS=12.632 |
# Test F1: 0.9425
# Test ACC: 0.9123
# Test AUC: 0.9441
# Train F1: 0.9829
# 00700: TRAIN| LT=0.286 LP=0.039 LKL=7.139 LPS=0.054 LKLS=12.237 |
# Test F1: 0.9318
# Test ACC: 0.8947
# Test AUC: 0.9441
# Train F1: 0.9801
# 00750: TRAIN| LT=0.319 LP=0.048 LKL=7.254 LPS=0.072 LKLS=12.652 |
# Test F1: 0.9318
# Test ACC: 0.8947
# Test AUC: 0.9441
# Train F1: 0.9858
# 00800: TRAIN| LT=0.280 LP=0.053 LKL=7.196 LPS=0.033 LKLS=12.228 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9441
# Train F1: 0.9972
# 00850: TRAIN| LT=0.237 LP=0.028 LKL=7.193 LPS=0.016 LKLS=12.174 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9423
# Train F1: 0.9915
# 00900: TRAIN| LT=0.249 LP=0.040 LKL=7.208 LPS=0.015 LKLS=12.202 |
# Test F1: 0.9438
# Test ACC: 0.9123
# Test AUC: 0.9458
# Train F1: 0.9744
# 00950: TRAIN| LT=0.236 LP=0.020 LKL=7.148 LPS=0.026 LKLS=11.852 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9423
# Train F1: 0.9858
# 01000: TRAIN| LT=0.298 LP=0.055 LKL=7.072 LPS=0.060 LKLS=11.203 |
# Test F1: 0.9438
# Test ACC: 0.9123
# Test AUC: 0.9441
# Train F1: 0.9858
# 01050: TRAIN| LT=0.358 LP=0.097 LKL=7.013 LPS=0.081 LKLS=11.029 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9441
# Train F1: 0.9944
# 01100: TRAIN| LT=0.231 LP=0.017 LKL=7.235 LPS=0.023 LKLS=11.909 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9353
# Train F1: 0.9801
# 01150: TRAIN| LT=0.290 LP=0.065 LKL=7.177 LPS=0.040 LKLS=11.262 |
# Test F1: 0.9318
# Test ACC: 0.8947
# Test AUC: 0.9388
# Train F1: 0.9944
# 01200: TRAIN| LT=0.231 LP=0.019 LKL=6.994 LPS=0.036 LKLS=10.636 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9458
# Train F1: 0.9886
# 01250: TRAIN| LT=0.286 LP=0.061 LKL=7.195 LPS=0.040 LKLS=11.279 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9458
# Train F1: 0.9915
# 01300: TRAIN| LT=0.208 LP=0.023 LKL=7.024 LPS=0.010 LKLS=10.554 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9458
# Train F1: 0.9858
# 01350: TRAIN| LT=0.210 LP=0.027 LKL=6.880 LPS=0.015 LKLS=9.819 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9423
# Train F1: 0.9915
# 01400: TRAIN| LT=0.207 LP=0.018 LKL=7.081 LPS=0.014 LKLS=10.341 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9423
# Train F1: 0.9943
# 01450: TRAIN| LT=0.210 LP=0.023 LKL=6.929 LPS=0.018 LKLS=9.969 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9441
# Train F1: 0.9915
# 01500: TRAIN| LT=0.231 LP=0.035 LKL=6.968 LPS=0.028 LKLS=9.905 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9458
# Train F1: 0.9943
# 01550: TRAIN| LT=0.222 LP=0.033 LKL=6.945 LPS=0.020 LKLS=9.960 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9388
# Train F1: 0.9943
# 01600: TRAIN| LT=0.230 LP=0.011 LKL=6.877 LPS=0.055 LKLS=9.451 |
# Test F1: 0.9438
# Test ACC: 0.9123
# Test AUC: 0.9510
# Train F1: 0.9972
# 01650: TRAIN| LT=0.221 LP=0.013 LKL=6.991 LPS=0.038 LKLS=9.965 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9458
# Train F1: 0.9915
# 01700: TRAIN| LT=0.213 LP=0.038 LKL=6.890 LPS=0.010 LKLS=9.496 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9476
# Train F1: 0.9972
# 01750: TRAIN| LT=0.202 LP=0.031 LKL=6.903 LPS=0.009 LKLS=9.319 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9388
# Train F1: 0.9972
# 01800: TRAIN| LT=0.209 LP=0.024 LKL=6.932 LPS=0.022 LKLS=9.399 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9423
# Train F1: 0.9943
# 01850: TRAIN| LT=0.227 LP=0.040 LKL=6.973 LPS=0.023 LKLS=9.413 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9353
# Train F1: 1.0000
# 01900: TRAIN| LT=0.189 LP=0.022 LKL=6.918 LPS=0.005 LKLS=9.340 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9476
# Train F1: 0.9972
# 01950: TRAIN| LT=0.222 LP=0.028 LKL=6.788 LPS=0.038 LKLS=8.808 |
# Test F1: 0.9231
# Test ACC: 0.8772
# Test AUC: 0.9406
# Train F1: 0.9944
# 02000: TRAIN| LT=0.234 LP=0.064 LKL=6.604 LPS=0.024 LKLS=7.950 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9493
# f1: 0.9555555555555557
# acc: 0.9298245614035088
# auc: 0.9458041958041958
# f1 [0.9247311827956989, 0.9565217391304348, 0.9555555555555557, 0.9230769230769231, 0.9555555555555557]
# average maxf1 0.9430881912228337
# acc [0.8793103448275862, 0.9310344827586207, 0.9298245614035088, 0.8771929824561403, 0.9298245614035088]
# average maxacc 0.9094373865698729
# auc [0.8851461038961039, 0.9902597402597403, 0.9667832167832168, 0.9108391608391608, 0.9458041958041958]
# average maxauc 0.9397664835164836
