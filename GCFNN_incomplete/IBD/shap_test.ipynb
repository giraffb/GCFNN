# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics.csv',index_col=0)
data_class={'nonIBD':0,'CD':1,'UC':1}
meta_data['diagnosis']=meta_data['diagnosis'].map(data_class)

X1=metagenomics
X2=metabolomics
print('输入各组学数据表：',X1.shape,X2.shape,meta_data.shape)

#重构数据表和标签表
index_new = X1.index&X2.index
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)

#随机缺失，生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
from sklearn.preprocessing import OneHotEncoder
from numpy.random import randint
import warnings
warnings.filterwarnings("ignore")
def get_sn(view_num, alldata_len, missing_rate):
    """Randomly generate incomplete data information, simulate partial view data with complete view data
    :param view_num:view number
    :param alldata_len:number of samples
    :param missing_rate:Defined in section 3.2 of the paper
    :return:Sn
    """
    one_rate = 1-missing_rate
    if one_rate <= (1 / view_num):
        #enc = OneHotEncoder(n_values=view_num)
        enc = OneHotEncoder()
        view_preserve = enc.fit_transform(randint(0, view_num, size=(alldata_len, 1))).toarray()
        return view_preserve
    error = 1
    if one_rate == 1:
        matrix = randint(1, 2, size=(alldata_len, view_num))
        return matrix
    while error >= 0.005:
        #enc = OneHotEncoder(n_values=view_num)
        enc = OneHotEncoder()
        view_preserve = enc.fit_transform(randint(0, view_num, size=(alldata_len, 1))).toarray()
        one_num = view_num * alldata_len * one_rate - alldata_len
        ratio = one_num / (view_num * alldata_len)
        matrix_iter = (randint(0, 100, size=(alldata_len, view_num)) < int(ratio * 100)).astype(np.int)
        a = np.sum(((matrix_iter + view_preserve) > 1).astype(np.int))
        one_num_iter = one_num / (1 - a / one_num)
        ratio = one_num_iter / (view_num * alldata_len)
        matrix_iter = (randint(0, 100, size=(alldata_len, view_num)) < int(ratio * 100)).astype(np.int)
        matrix = ((matrix_iter + view_preserve) > 0).astype(np.int)
        ratio = np.sum(matrix) / (view_num * alldata_len)
        error = abs(one_rate - ratio)
    return matrix
Mask     = np.ones([np.shape(X_set[0])[0], M])
print(sum(Mask))
missrate = 0.5
Mask     = get_sn(2,X_set[0].shape[0],missrate)
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
print(sum(Mask)) 
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['diagnosis'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (1638, 578) (546, 596) (2891, 1)
# 集合所有样本重构数据表： (388, 578) (388, 596) (388, 1)
# 776.0
# 388.0
# 标签转换为one-hot编码： (388, 2) 105.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 8, 
        'ITERATION': 1000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1',f1_cv)
print('average maxf1',sum(f1_cv)/5)
print('acc',acc_cv)
print('average maxacc',sum(acc_cv)/5)
print('auc',auc_cv)
print('average maxauc',sum(auc_cv)/5)
# Out:
# Train F1: 0.8399
# 00050: TRAIN| LT=1.734 LP=0.577 LKL=5.136 LPS=1.066 LKLS=3.987 |
# Test F1: 0.8444
# Test ACC: 0.7308
# Test AUC: 0.7360
# Train F1: 0.8816
# 00100: TRAIN| LT=1.230 LP=0.416 LKL=6.687 LPS=0.610 LKLS=13.710 |
# Test F1: 0.8760
# Test ACC: 0.8077
# Test AUC: 0.8404
# Train F1: 0.9087
# 00150: TRAIN| LT=0.986 LP=0.310 LKL=6.681 LPS=0.483 LKLS=12.626 |
# Test F1: 0.8440
# Test ACC: 0.7821
# Test AUC: 0.8488
# Train F1: 0.9034
# 00200: TRAIN| LT=1.001 LP=0.331 LKL=6.793 LPS=0.479 LKLS=12.305 |
# Test F1: 0.8649
# Test ACC: 0.8077
# Test AUC: 0.8521
# Train F1: 0.9111
# 00250: TRAIN| LT=0.868 LP=0.265 LKL=6.768 LPS=0.421 LKLS=11.369 |
# Test F1: 0.8468
# Test ACC: 0.7821
# Test AUC: 0.8571
# Train F1: 0.9099
# 00300: TRAIN| LT=0.828 LP=0.246 LKL=6.714 LPS=0.405 LKLS=10.881 |
# Test F1: 0.8440
# Test ACC: 0.7821
# Test AUC: 0.8563
# Train F1: 0.9211
# 00350: TRAIN| LT=0.816 LP=0.266 LKL=6.797 LPS=0.375 LKLS=10.804 |
# Test F1: 0.8364
# Test ACC: 0.7692
# Test AUC: 0.8563
# Train F1: 0.9368
# 00400: TRAIN| LT=0.804 LP=0.263 LKL=6.799 LPS=0.364 LKLS=10.839 |
# Test F1: 0.8257
# Test ACC: 0.7564
# Test AUC: 0.8555
# Train F1: 0.9258
# 00450: TRAIN| LT=0.689 LP=0.206 LKL=6.956 LPS=0.299 LKLS=11.360 |
# Test F1: 0.8148
# Test ACC: 0.7436
# Test AUC: 0.8571
# Train F1: 0.9536
# 00500: TRAIN| LT=0.674 LP=0.200 LKL=7.017 LPS=0.288 LKLS=11.605 |
# Test F1: 0.8257
# Test ACC: 0.7564
# Test AUC: 0.8530
# Train F1: 0.9502
# 00550: TRAIN| LT=0.707 LP=0.232 LKL=6.966 LPS=0.296 LKLS=10.920 |
# Test F1: 0.8148
# Test ACC: 0.7436
# Test AUC: 0.8496
# Train F1: 0.9646
# 00600: TRAIN| LT=0.635 LP=0.169 LKL=7.195 LPS=0.271 LKLS=12.293 |
# Test F1: 0.8257
# Test ACC: 0.7564
# Test AUC: 0.8480
# Train F1: 0.9646
# 00650: TRAIN| LT=0.499 LP=0.132 LKL=7.014 LPS=0.184 LKLS=11.246 |
# Test F1: 0.8257
# Test ACC: 0.7564
# Test AUC: 0.8388
# Train F1: 0.9534
# 00700: TRAIN| LT=0.522 LP=0.140 LKL=7.042 LPS=0.200 LKLS=11.122 |
# Test F1: 0.8364
# Test ACC: 0.7692
# Test AUC: 0.8471
# Train F1: 0.9737
# 00750: TRAIN| LT=0.494 LP=0.156 LKL=7.024 LPS=0.157 LKLS=11.144 |
# Test F1: 0.8364
# Test ACC: 0.7692
# Test AUC: 0.8404
# Train F1: 0.9643
# 00800: TRAIN| LT=0.445 LP=0.106 LKL=7.122 LPS=0.154 LKLS=11.361 |
# Test F1: 0.8148
# Test ACC: 0.7436
# Test AUC: 0.8413
# Train F1: 0.9822
# 00850: TRAIN| LT=0.386 LP=0.086 LKL=7.183 LPS=0.114 LKLS=11.416 |
# Test F1: 0.8257
# Test ACC: 0.7564
# Test AUC: 0.8421
# Train F1: 0.9736
# 00900: TRAIN| LT=0.360 LP=0.089 LKL=7.134 LPS=0.088 LKLS=11.136 |
# Test F1: 0.8468
# Test ACC: 0.7821
# Test AUC: 0.8379
# Train F1: 0.9779
# 00950: TRAIN| LT=0.389 LP=0.101 LKL=7.115 LPS=0.105 LKLS=11.184 |
# Test F1: 0.8468
# Test ACC: 0.7821
# Test AUC: 0.8371
# Train F1: 0.9760
# 01000: TRAIN| LT=0.312 LP=0.064 LKL=7.039 LPS=0.070 LKLS=10.808 |
# Test F1: 0.8571
# Test ACC: 0.7949
# Test AUC: 0.8446
# f1: 0.8760330578512396
# acc: 0.8076923076923077
# auc: 0.8404344193817879
# Train F1: 0.8385
# 00050: TRAIN| LT=1.632 LP=0.575 LKL=5.229 LPS=0.953 LKLS=5.241 |
# Test F1: 0.8444
# Test ACC: 0.7308
# Test AUC: 0.8730
# Train F1: 0.8966
# 00100: TRAIN| LT=1.214 LP=0.381 LKL=6.636 LPS=0.636 LKLS=13.025 |
# Test F1: 0.8889
# Test ACC: 0.8205
# Test AUC: 0.8864
# Train F1: 0.9011
# 00150: TRAIN| LT=1.055 LP=0.324 LKL=7.036 LPS=0.521 LKLS=13.936 |
# Test F1: 0.8908
# Test ACC: 0.8333
# Test AUC: 0.8672
# Train F1: 0.9330
# 00200: TRAIN| LT=0.880 LP=0.256 LKL=6.926 LPS=0.427 LKLS=12.687 |
# Test F1: 0.8983
# Test ACC: 0.8462
# Test AUC: 0.8530
# Train F1: 0.9275
# 00250: TRAIN| LT=0.843 LP=0.258 LKL=7.048 LPS=0.385 LKLS=12.986 |
# Test F1: 0.8870
# Test ACC: 0.8333
# Test AUC: 0.8204
# Train F1: 0.9275
# 00300: TRAIN| LT=0.836 LP=0.229 LKL=6.925 LPS=0.419 LKLS=11.795 |
# Test F1: 0.8772
# Test ACC: 0.8205
# Test AUC: 0.8112
# Train F1: 0.9357
# 00350: TRAIN| LT=0.697 LP=0.193 LKL=6.900 LPS=0.320 LKLS=11.476 |
# Test F1: 0.8870
# Test ACC: 0.8333
# Test AUC: 0.8070
# Train F1: 0.9446
# 00400: TRAIN| LT=0.779 LP=0.227 LKL=7.198 LPS=0.353 LKLS=12.826 |
# Test F1: 0.8850
# Test ACC: 0.8333
# Test AUC: 0.8062
# Train F1: 0.9558
# 00450: TRAIN| LT=0.701 LP=0.187 LKL=7.070 LPS=0.323 LKLS=11.978 |
# Test F1: 0.8850
# Test ACC: 0.8333
# Test AUC: 0.8062
# Train F1: 0.9476
# 00500: TRAIN| LT=0.657 LP=0.189 LKL=7.011 LPS=0.287 LKLS=11.086 |
# Test F1: 0.8850
# Test ACC: 0.8333
# Test AUC: 0.8112
# Train F1: 0.9365
# 00550: TRAIN| LT=0.556 LP=0.143 LKL=7.031 LPS=0.229 LKLS=11.292 |
# Test F1: 0.9043
# Test ACC: 0.8590
# Test AUC: 0.8104
# Train F1: 0.9692
# 00600: TRAIN| LT=0.572 LP=0.131 LKL=7.254 LPS=0.248 LKLS=12.068 |
# Test F1: 0.8947
# Test ACC: 0.8462
# Test AUC: 0.8154
# Train F1: 0.9644
# 00650: TRAIN| LT=0.502 LP=0.112 LKL=7.089 LPS=0.206 LKLS=11.306 |
# Test F1: 0.8850
# Test ACC: 0.8333
# Test AUC: 0.8195
# Train F1: 0.9800
# 00700: TRAIN| LT=0.503 LP=0.119 LKL=7.235 LPS=0.198 LKLS=11.458 |
# Test F1: 0.8850
# Test ACC: 0.8333
# Test AUC: 0.8195
# Train F1: 0.9735
# 00750: TRAIN| LT=0.449 LP=0.110 LKL=7.348 LPS=0.145 LKLS=12.057 |
# Test F1: 0.8966
# Test ACC: 0.8462
# Test AUC: 0.8170
# Train F1: 0.9825
# 00800: TRAIN| LT=0.382 LP=0.078 LKL=7.263 LPS=0.116 LKLS=11.501 |
# Test F1: 0.9043
# Test ACC: 0.8590
# Test AUC: 0.8137
# Train F1: 0.9912
# 00850: TRAIN| LT=0.481 LP=0.148 LKL=7.122 LPS=0.155 LKLS=10.706 |
# Test F1: 0.9138
# Test ACC: 0.8718
# Test AUC: 0.8120
# Train F1: 0.9733
# 00900: TRAIN| LT=0.345 LP=0.044 LKL=7.379 LPS=0.111 LKLS=11.670 |
# Test F1: 0.8983
# Test ACC: 0.8462
# Test AUC: 0.8193
# Train F1: 0.9844
# 00950: TRAIN| LT=0.415 LP=0.096 LKL=7.240 LPS=0.134 LKLS=11.202 |
# Test F1: 0.8983
# Test ACC: 0.8462
# Test AUC: 0.8166
# Train F1: 0.9867
# 01000: TRAIN| LT=0.312 LP=0.052 LKL=7.297 LPS=0.074 LKLS=11.313 |
# Test F1: 0.8983
# Test ACC: 0.8462
# Test AUC: 0.8147
# f1: 0.9137931034482759
# acc: 0.8717948717948718
# auc: 0.8120300751879699
# Train F1: 0.8421
# 00050: TRAIN| LT=1.734 LP=0.567 LKL=5.200 LPS=1.070 LKLS=4.453 |
# Test F1: 0.8444
# Test ACC: 0.7308
# Test AUC: 0.7251
# Train F1: 0.8884
# 00100: TRAIN| LT=1.260 LP=0.412 LKL=6.710 LPS=0.650 LKLS=13.032 |
# Test F1: 0.8682
# Test ACC: 0.7821
# Test AUC: 0.8571
# Train F1: 0.8974
# 00150: TRAIN| LT=1.059 LP=0.321 LKL=6.840 LPS=0.540 LKLS=12.939 |
# Test F1: 0.8780
# Test ACC: 0.8077
# Test AUC: 0.8546
# Train F1: 0.9138
# 00200: TRAIN| LT=0.919 LP=0.266 LKL=6.913 LPS=0.459 LKLS=12.491 |
# Test F1: 0.8833
# Test ACC: 0.8205
# Test AUC: 0.8279
# Train F1: 0.9348
# 00250: TRAIN| LT=0.905 LP=0.283 LKL=6.976 LPS=0.429 LKLS=12.336 |
# Test F1: 0.8833
# Test ACC: 0.8205
# Test AUC: 0.8179
# Train F1: 0.9142
# 00300: TRAIN| LT=0.866 LP=0.246 LKL=6.974 LPS=0.430 LKLS=12.099 |
# Test F1: 0.8689
# Test ACC: 0.7949
# Test AUC: 0.8087
# Train F1: 0.9254
# 00350: TRAIN| LT=0.792 LP=0.256 LKL=7.140 LPS=0.341 LKLS=12.352 |
# Test F1: 0.8667
# Test ACC: 0.7949
# Test AUC: 0.8104
# Train F1: 0.9322
# 00400: TRAIN| LT=0.784 LP=0.217 LKL=7.024 LPS=0.379 LKLS=11.710 |
# Test F1: 0.8595
# Test ACC: 0.7821
# Test AUC: 0.8037
# Train F1: 0.9513
# 00450: TRAIN| LT=0.757 LP=0.210 LKL=7.037 LPS=0.364 LKLS=11.258 |
# Test F1: 0.8667
# Test ACC: 0.7949
# Test AUC: 0.8079
# Train F1: 0.9295
# 00500: TRAIN| LT=0.776 LP=0.236 LKL=6.986 LPS=0.362 LKLS=10.820 |
# Test F1: 0.8500
# Test ACC: 0.7692
# Test AUC: 0.8079
# Train F1: 0.9386
# 00550: TRAIN| LT=0.672 LP=0.176 LKL=7.018 LPS=0.315 LKLS=11.066 |
# Test F1: 0.8571
# Test ACC: 0.7821
# Test AUC: 0.8053
# Train F1: 0.9582
# 00600: TRAIN| LT=0.514 LP=0.143 LKL=7.147 LPS=0.183 LKLS=11.652 |
# Test F1: 0.8500
# Test ACC: 0.7692
# Test AUC: 0.8053
# Train F1: 0.9644
# 00650: TRAIN| LT=0.567 LP=0.156 LKL=7.216 LPS=0.224 LKLS=11.515 |
# Test F1: 0.8689
# Test ACC: 0.7949
# Test AUC: 0.8095
# Train F1: 0.9672
# 00700: TRAIN| LT=0.433 LP=0.090 LKL=7.297 LPS=0.150 LKLS=11.887 |
# Test F1: 0.8760
# Test ACC: 0.8077
# Test AUC: 0.7987
# Train F1: 0.9754
# 00750: TRAIN| LT=0.460 LP=0.123 LKL=7.108 LPS=0.157 LKLS=10.857 |
# Test F1: 0.8667
# Test ACC: 0.7949
# Test AUC: 0.8187
# Train F1: 0.9712
# 00800: TRAIN| LT=0.379 LP=0.088 LKL=7.352 LPS=0.097 LKLS=12.009 |
# Test F1: 0.8689
# Test ACC: 0.7949
# Test AUC: 0.8087
# Train F1: 0.9710
# 00850: TRAIN| LT=0.341 LP=0.093 LKL=7.327 LPS=0.059 LKLS=11.598 |
# Test F1: 0.8595
# Test ACC: 0.7821
# Test AUC: 0.8079
# Train F1: 0.9867
# 00900: TRAIN| LT=0.410 LP=0.114 LKL=7.246 LPS=0.113 LKLS=11.113 |
# Test F1: 0.8739
# Test ACC: 0.8077
# Test AUC: 0.8170
# Train F1: 0.9779
# 00950: TRAIN| LT=0.315 LP=0.054 LKL=7.266 LPS=0.073 LKLS=11.490 |
# Test F1: 0.8667
# Test ACC: 0.7949
# Test AUC: 0.8204
# Train F1: 0.9823
# 01000: TRAIN| LT=0.328 LP=0.056 LKL=7.224 LPS=0.089 LKLS=11.091 |
# Test F1: 0.8760
# Test ACC: 0.8077
# Test AUC: 0.8170
# f1: 0.8833333333333334
# acc: 0.8205128205128205
# auc: 0.8279030910609858
# Train F1: 0.8475
# 00050: TRAIN| LT=1.770 LP=0.580 LKL=5.173 LPS=1.095 LKLS=4.357 |
# Test F1: 0.8421
# Test ACC: 0.7273
# Test AUC: 0.7287
# Train F1: 0.8898
# 00100: TRAIN| LT=1.216 LP=0.445 LKL=6.564 LPS=0.575 LKLS=13.109 |
# Test F1: 0.8595
# Test ACC: 0.7792
# Test AUC: 0.7917
# Train F1: 0.8903
# 00150: TRAIN| LT=1.039 LP=0.324 LKL=6.579 LPS=0.528 LKLS=12.128 |
# Test F1: 0.8522
# Test ACC: 0.7792
# Test AUC: 0.8325
# Train F1: 0.9123
# 00200: TRAIN| LT=1.009 LP=0.331 LKL=6.737 LPS=0.489 LKLS=12.113 |
# Test F1: 0.8496
# Test ACC: 0.7792
# Test AUC: 0.8299
# Train F1: 0.9111
# 00250: TRAIN| LT=0.945 LP=0.321 LKL=6.629 LPS=0.449 LKLS=10.866 |
# Test F1: 0.8496
# Test ACC: 0.7792
# Test AUC: 0.8393
# Train F1: 0.9067
# 00300: TRAIN| LT=0.917 LP=0.289 LKL=6.754 LPS=0.447 LKLS=11.275 |
# Test F1: 0.8421
# Test ACC: 0.7662
# Test AUC: 0.8316
# Train F1: 0.9231
# 00350: TRAIN| LT=0.869 LP=0.307 LKL=6.773 LPS=0.383 LKLS=11.119 |
# Test F1: 0.8319
# Test ACC: 0.7532
# Test AUC: 0.8410
# Train F1: 0.9254
# 00400: TRAIN| LT=0.815 LP=0.276 LKL=6.703 LPS=0.367 LKLS=10.473 |
# Test F1: 0.8288
# Test ACC: 0.7532
# Test AUC: 0.8299
# Train F1: 0.9342
# 00450: TRAIN| LT=0.746 LP=0.235 LKL=6.902 LPS=0.328 LKLS=11.390 |
# Test F1: 0.8364
# Test ACC: 0.7662
# Test AUC: 0.8257
# Train F1: 0.9264
# 00500: TRAIN| LT=0.765 LP=0.257 LKL=6.764 LPS=0.335 LKLS=10.524 |
# Test F1: 0.8364
# Test ACC: 0.7662
# Test AUC: 0.8248
# Train F1: 0.9561
# 00550: TRAIN| LT=0.674 LP=0.202 LKL=7.002 LPS=0.288 LKLS=11.477 |
# Test F1: 0.8257
# Test ACC: 0.7532
# Test AUC: 0.8129
# Train F1: 0.9497
# 00600: TRAIN| LT=0.647 LP=0.175 LKL=6.821 LPS=0.300 LKLS=10.307 |
# Test F1: 0.8182
# Test ACC: 0.7403
# Test AUC: 0.8197
# Train F1: 0.9464
# 00650: TRAIN| LT=0.563 LP=0.157 LKL=7.075 LPS=0.218 LKLS=11.694 |
# Test F1: 0.8257
# Test ACC: 0.7532
# Test AUC: 0.8121
# Train F1: 0.9499
# 00700: TRAIN| LT=0.548 LP=0.144 LKL=6.974 LPS=0.223 LKLS=11.128 |
# Test F1: 0.8214
# Test ACC: 0.7403
# Test AUC: 0.8146
# Train F1: 0.9778
# 00750: TRAIN| LT=0.464 LP=0.138 LKL=7.135 LPS=0.138 LKLS=11.618 |
# Test F1: 0.8257
# Test ACC: 0.7532
# Test AUC: 0.8104
# Train F1: 0.9759
# 00800: TRAIN| LT=0.501 LP=0.143 LKL=7.158 LPS=0.169 LKLS=11.748 |
# Test F1: 0.8214
# Test ACC: 0.7403
# Test AUC: 0.8138
# Train F1: 0.9778
# 00850: TRAIN| LT=0.515 LP=0.141 LKL=7.066 LPS=0.192 LKLS=11.103 |
# Test F1: 0.8214
# Test ACC: 0.7403
# Test AUC: 0.8138
# Train F1: 0.9825
# 00900: TRAIN| LT=0.461 LP=0.095 LKL=7.200 LPS=0.175 LKLS=11.866 |
# Test F1: 0.8214
# Test ACC: 0.7403
# Test AUC: 0.8248
# Train F1: 0.9759
# 00950: TRAIN| LT=0.379 LP=0.083 LKL=7.294 LPS=0.103 LKLS=11.977 |
# Test F1: 0.8421
# Test ACC: 0.7662
# Test AUC: 0.8231
# Train F1: 0.9823
# 01000: TRAIN| LT=0.351 LP=0.088 LKL=7.098 LPS=0.084 LKLS=10.867 |
# Test F1: 0.8393
# Test ACC: 0.7662
# Test AUC: 0.8325
# f1: 0.859504132231405
# acc: 0.7792207792207793
# auc: 0.7916666666666666
# Train F1: 0.8304
# 00050: TRAIN| LT=1.809 LP=0.597 LKL=5.144 LPS=1.120 LKLS=4.157 |
# Test F1: 0.8485
# Test ACC: 0.7403
# Test AUC: 0.7474
# Train F1: 0.8857
# 00100: TRAIN| LT=1.305 LP=0.458 LKL=6.388 LPS=0.671 LKLS=11.237 |
# Test F1: 0.9167
# Test ACC: 0.8701
# Test AUC: 0.9609
# Train F1: 0.8966
# 00150: TRAIN| LT=1.144 LP=0.386 LKL=6.736 LPS=0.565 LKLS=12.624 |
# Test F1: 0.9057
# Test ACC: 0.8701
# Test AUC: 0.9566
# Train F1: 0.9142
# 00200: TRAIN| LT=1.031 LP=0.370 LKL=6.792 LPS=0.473 LKLS=11.932 |
# Test F1: 0.9259
# Test ACC: 0.8961
# Test AUC: 0.9575
# Train F1: 0.9258
# 00250: TRAIN| LT=0.919 LP=0.297 LKL=6.803 LPS=0.442 LKLS=11.211 |
# Test F1: 0.9273
# Test ACC: 0.8961
# Test AUC: 0.9609
# Train F1: 0.9159
# 00300: TRAIN| LT=0.949 LP=0.305 LKL=6.756 LPS=0.470 LKLS=10.655 |
# Test F1: 0.9273
# Test ACC: 0.8961
# Test AUC: 0.9549
# Train F1: 0.9234
# 00350: TRAIN| LT=0.839 LP=0.236 LKL=6.748 LPS=0.432 LKLS=10.240 |
# Test F1: 0.9189
# Test ACC: 0.8831
# Test AUC: 0.9524
# Train F1: 0.9180
# 00400: TRAIN| LT=0.769 LP=0.227 LKL=6.812 LPS=0.368 LKLS=10.512 |
# Test F1: 0.9027
# Test ACC: 0.8571
# Test AUC: 0.9337
# Train F1: 0.9224
# 00450: TRAIN| LT=0.673 LP=0.179 LKL=7.013 LPS=0.311 LKLS=11.292 |
# Test F1: 0.9009
# Test ACC: 0.8571
# Test AUC: 0.9141
# Train F1: 0.9538
# 00500: TRAIN| LT=0.720 LP=0.238 LKL=6.918 LPS=0.307 LKLS=10.625 |
# Test F1: 0.8909
# Test ACC: 0.8442
# Test AUC: 0.8988
# Train F1: 0.9492
# 00550: TRAIN| LT=0.552 LP=0.138 LKL=7.178 LPS=0.223 LKLS=11.815 |
# Test F1: 0.8727
# Test ACC: 0.8182
# Test AUC: 0.8954
# Train F1: 0.9558
# 00600: TRAIN| LT=0.566 LP=0.176 LKL=6.990 LPS=0.210 LKLS=10.975 |
# Test F1: 0.8727
# Test ACC: 0.8182
# Test AUC: 0.8920
# Train F1: 0.9600
# 00650: TRAIN| LT=0.487 LP=0.125 LKL=7.163 LPS=0.176 LKLS=11.507 |
# Test F1: 0.8909
# Test ACC: 0.8442
# Test AUC: 0.8929
# Train F1: 0.9644
# 00700: TRAIN| LT=0.464 LP=0.126 LKL=7.052 LPS=0.158 LKLS=11.006 |
# Test F1: 0.8829
# Test ACC: 0.8312
# Test AUC: 0.8852
# Train F1: 0.9740
# 00750: TRAIN| LT=0.464 LP=0.140 LKL=7.159 LPS=0.136 LKLS=11.676 |
# Test F1: 0.8829
# Test ACC: 0.8312
# Test AUC: 0.8878
# Train F1: 0.9845
# 00800: TRAIN| LT=0.426 LP=0.107 LKL=7.235 LPS=0.129 LKLS=11.780 |
# Test F1: 0.8829
# Test ACC: 0.8312
# Test AUC: 0.8878
# Train F1: 0.9912
# 00850: TRAIN| LT=0.405 LP=0.091 LKL=7.129 LPS=0.131 LKLS=11.139 |
# Test F1: 0.8829
# Test ACC: 0.8312
# Test AUC: 0.8810
# Train F1: 0.9869
# 00900: TRAIN| LT=0.367 LP=0.111 LKL=7.278 LPS=0.064 LKLS=11.849 |
# Test F1: 0.8829
# Test ACC: 0.8312
# Test AUC: 0.8878
# Train F1: 0.9802
# 00950: TRAIN| LT=0.392 LP=0.086 LKL=7.191 LPS=0.122 LKLS=11.218 |
# Test F1: 0.8909
# Test ACC: 0.8442
# Test AUC: 0.8844
# Train F1: 0.9712
# 01000: TRAIN| LT=0.346 LP=0.072 LKL=7.188 LPS=0.091 LKLS=11.173 |
# Test F1: 0.8829
# Test ACC: 0.8312
# Test AUC: 0.8784
# f1: 0.9272727272727271
# acc: 0.8961038961038961
# auc: 0.9608843537414966
# f1 [0.8760330578512396, 0.9137931034482759, 0.8833333333333334, 0.859504132231405, 0.9272727272727271]
# average maxf1 0.8919872708273962
# acc [0.8076923076923077, 0.8717948717948718, 0.8205128205128205, 0.7792207792207793, 0.8961038961038961]
# average maxacc 0.8350649350649351
# auc [0.8404344193817879, 0.8120300751879699, 0.8279030910609858, 0.7916666666666666, 0.9608843537414966]
# average maxauc 0.8465837212077814
