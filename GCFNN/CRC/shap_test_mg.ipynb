# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'Healthy':0,'Stage_0':1, 'Stage_I_II':1, 'Stage_III_IV':1, 'HS':1, 'MP':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
print('输入各组学数据表：',x1.shape,meta_data.shape)

#重构数据表和标签表
X1 = x1
index_new=X1.index
print(index_new)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,meta_data.shape)
X_set=[X1]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (347, 851) (347, 1)
# Int64Index([10021, 10023, 10025, 10029, 10031, 10033, 10034, 10036, 10037,
#             10038,
#             ...
#             10818, 10825, 10827, 10829, 10835, 10838, 10839, 10847, 10850,
#             10853],
#            dtype='int64', name='Sample', length=347)
# 集合所有样本重构数据表： (347, 851) (347, 1)
# 标签转换为one-hot编码： (347, 2) 127.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap_mg'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 4, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1', f1_cv)
print('average f1: {}±{}'.format(np.mean(f1_cv), np.std(f1_cv)))
print('acc', acc_cv)
print('average acc: {}±{}'.format(np.mean(acc_cv), np.std(acc_cv)))
print('auc', auc_cv)
print('average auc: {}±{}'.format(np.mean(auc_cv), np.std(auc_cv)))
# Out:
# Train F1: 0.7728
# 00050: TRAIN| LT=1.290 LP=0.636 LKL=5.469 LPS=0.567 LKLS=3.247 |
# Test F1: 0.7719
# Test ACC: 0.6286
# Test AUC: 0.6766
# Train F1: 0.8696
# 00100: TRAIN| LT=0.950 LP=0.413 LKL=7.552 LPS=0.374 LKLS=8.729 |
# Test F1: 0.7447
# Test ACC: 0.6571
# Test AUC: 0.7115
# Train F1: 0.9008
# 00150: TRAIN| LT=0.757 LP=0.331 LKL=7.967 LPS=0.250 LKLS=9.627 |
# Test F1: 0.7253
# Test ACC: 0.6429
# Test AUC: 0.7893
# Train F1: 0.9231
# 00200: TRAIN| LT=0.681 LP=0.278 LKL=8.031 LPS=0.231 LKLS=9.137 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7771
# Train F1: 0.9050
# 00250: TRAIN| LT=0.626 LP=0.260 LKL=7.989 LPS=0.196 LKLS=8.963 |
# Test F1: 0.7872
# Test ACC: 0.7143
# Test AUC: 0.7955
# Train F1: 0.9435
# 00300: TRAIN| LT=0.537 LP=0.215 LKL=8.072 LPS=0.154 LKLS=8.720 |
# Test F1: 0.7692
# Test ACC: 0.7000
# Test AUC: 0.7972
# Train F1: 0.9322
# 00350: TRAIN| LT=0.556 LP=0.197 LKL=8.032 LPS=0.195 LKLS=8.392 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7972
# Train F1: 0.9412
# 00400: TRAIN| LT=0.510 LP=0.209 LKL=8.110 LPS=0.138 LKLS=8.275 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7902
# Train F1: 0.9326
# 00450: TRAIN| LT=0.461 LP=0.128 LKL=8.298 LPS=0.162 LKLS=8.775 |
# Test F1: 0.8043
# Test ACC: 0.7429
# Test AUC: 0.7788
# Train F1: 0.9632
# 00500: TRAIN| LT=0.469 LP=0.173 LKL=8.435 LPS=0.127 LKLS=8.518 |
# Test F1: 0.7957
# Test ACC: 0.7286
# Test AUC: 0.7823
# Train F1: 0.9432
# 00550: TRAIN| LT=0.436 LP=0.147 LKL=8.306 LPS=0.124 LKLS=8.238 |
# Test F1: 0.7692
# Test ACC: 0.7000
# Test AUC: 0.7841
# Train F1: 0.9521
# 00600: TRAIN| LT=0.491 LP=0.179 LKL=8.214 LPS=0.152 LKLS=7.747 |
# Test F1: 0.7556
# Test ACC: 0.6857
# Test AUC: 0.7893
# Train F1: 0.9521
# 00650: TRAIN| LT=0.408 LP=0.140 LKL=8.280 LPS=0.103 LKLS=8.137 |
# Test F1: 0.7826
# Test ACC: 0.7143
# Test AUC: 0.7832
# Train F1: 0.9580
# 00700: TRAIN| LT=0.449 LP=0.152 LKL=8.380 LPS=0.132 LKLS=8.133 |
# Test F1: 0.7556
# Test ACC: 0.6857
# Test AUC: 0.7771
# Train F1: 0.9580
# 00750: TRAIN| LT=0.402 LP=0.128 LKL=8.320 LPS=0.114 LKLS=7.719 |
# Test F1: 0.7692
# Test ACC: 0.7000
# Test AUC: 0.7736
# Train F1: 0.9448
# 00800: TRAIN| LT=0.374 LP=0.122 LKL=8.204 LPS=0.095 LKLS=7.510 |
# Test F1: 0.7692
# Test ACC: 0.7000
# Test AUC: 0.7727
# Train F1: 0.9688
# 00850: TRAIN| LT=0.371 LP=0.108 LKL=8.095 LPS=0.112 LKLS=7.059 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7666
# Train F1: 0.9665
# 00900: TRAIN| LT=0.366 LP=0.100 LKL=8.589 LPS=0.100 LKLS=8.017 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7509
# Train F1: 0.9524
# 00950: TRAIN| LT=0.413 LP=0.139 LKL=8.220 LPS=0.122 LKLS=7.062 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7622
# Train F1: 0.9628
# 01000: TRAIN| LT=0.365 LP=0.119 LKL=8.659 LPS=0.081 LKLS=7.859 |
# Test F1: 0.7727
# Test ACC: 0.7143
# Test AUC: 0.7771
# Train F1: 0.9690
# 01050: TRAIN| LT=0.385 LP=0.131 LKL=8.298 LPS=0.100 LKLS=7.004 |
# Test F1: 0.7556
# Test ACC: 0.6857
# Test AUC: 0.7675
# Train F1: 0.9518
# 01100: TRAIN| LT=0.345 LP=0.108 LKL=8.320 LPS=0.084 LKLS=7.020 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7605
# Train F1: 0.9526
# 01150: TRAIN| LT=0.434 LP=0.145 LKL=8.530 LPS=0.132 LKLS=7.157 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7544
# Train F1: 0.9638
# 01200: TRAIN| LT=0.348 LP=0.098 LKL=8.408 LPS=0.097 LKLS=7.004 |
# Test F1: 0.7527
# Test ACC: 0.6714
# Test AUC: 0.7413
# Train F1: 0.9545
# 01250: TRAIN| LT=0.369 LP=0.123 LKL=8.178 LPS=0.098 LKLS=6.639 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7456
# Train F1: 0.9540
# 01300: TRAIN| LT=0.364 LP=0.111 LKL=8.373 LPS=0.102 LKLS=6.688 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7378
# Train F1: 0.9663
# 01350: TRAIN| LT=0.369 LP=0.115 LKL=8.433 LPS=0.103 LKLS=6.653 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7386
# Train F1: 0.9630
# 01400: TRAIN| LT=0.331 LP=0.097 LKL=8.330 LPS=0.084 LKLS=6.647 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7483
# Train F1: 0.9721
# 01450: TRAIN| LT=0.334 LP=0.086 LKL=8.330 LPS=0.099 LKLS=6.595 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7430
# Train F1: 0.9659
# 01500: TRAIN| LT=0.361 LP=0.118 LKL=8.279 LPS=0.097 LKLS=6.291 |
# Test F1: 0.7609
# Test ACC: 0.6857
# Test AUC: 0.7369
# Train F1: 0.9513
# 01550: TRAIN| LT=0.322 LP=0.087 LKL=8.464 LPS=0.087 LKLS=6.311 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7491
# Train F1: 0.9584
# 01600: TRAIN| LT=0.302 LP=0.081 LKL=8.418 LPS=0.075 LKLS=6.243 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7336
# Train F1: 0.9609
# 01650: TRAIN| LT=0.310 LP=0.095 LKL=8.305 LPS=0.071 LKLS=6.058 |
# Test F1: 0.7609
# Test ACC: 0.6857
# Test AUC: 0.7354
# Train F1: 0.9602
# 01700: TRAIN| LT=0.294 LP=0.081 LKL=8.470 LPS=0.067 LKLS=6.208 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7493
# Train F1: 0.9632
# 01750: TRAIN| LT=0.305 LP=0.080 LKL=8.401 LPS=0.081 LKLS=6.090 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7375
# Train F1: 0.9636
# 01800: TRAIN| LT=0.296 LP=0.065 LKL=8.480 LPS=0.084 LKLS=6.260 |
# Test F1: 0.7609
# Test ACC: 0.6857
# Test AUC: 0.7275
# Train F1: 0.9718
# 01850: TRAIN| LT=0.306 LP=0.089 LKL=8.273 LPS=0.077 LKLS=5.734 |
# Test F1: 0.7527
# Test ACC: 0.6714
# Test AUC: 0.7279
# Train F1: 0.9690
# 01900: TRAIN| LT=0.338 LP=0.094 LKL=8.235 LPS=0.106 LKLS=5.533 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7354
# Train F1: 0.9663
# 01950: TRAIN| LT=0.289 LP=0.078 LKL=8.021 LPS=0.076 LKLS=5.468 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7445
# Train F1: 0.9690
# 02000: TRAIN| LT=0.284 LP=0.065 LKL=8.022 LPS=0.085 LKLS=5.396 |
# Test F1: 0.7473
# Test ACC: 0.6714
# Test AUC: 0.7233
# f1: 0.8043478260869567
# acc: 0.7428571428571429
# auc: 0.7788461538461539
# Train F1: 0.7575
# 00050: TRAIN| LT=1.292 LP=0.629 LKL=5.504 LPS=0.568 LKLS=3.931 |
# Test F1: 0.7719
# Test ACC: 0.6286
# Test AUC: 0.6372
# Train F1: 0.8302
# 00100: TRAIN| LT=0.972 LP=0.426 LKL=7.239 LPS=0.394 LKLS=7.901 |
# Test F1: 0.7500
# Test ACC: 0.6571
# Test AUC: 0.6136
# Train F1: 0.8712
# 00150: TRAIN| LT=0.774 LP=0.324 LKL=7.851 LPS=0.280 LKLS=9.188 |
# Test F1: 0.7234
# Test ACC: 0.6286
# Test AUC: 0.6556
# Train F1: 0.8952
# 00200: TRAIN| LT=0.741 LP=0.310 LKL=8.185 LPS=0.254 LKLS=9.522 |
# Test F1: 0.7097
# Test ACC: 0.6143
# Test AUC: 0.6337
# Train F1: 0.8955
# 00250: TRAIN| LT=0.643 LP=0.247 LKL=8.399 LPS=0.216 LKLS=9.622 |
# Test F1: 0.6744
# Test ACC: 0.6000
# Test AUC: 0.6302
# Train F1: 0.9352
# 00300: TRAIN| LT=0.628 LP=0.254 LKL=8.226 LPS=0.199 LKLS=9.223 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.6206
# Train F1: 0.9326
# 00350: TRAIN| LT=0.587 LP=0.194 LKL=8.353 LPS=0.220 LKLS=8.992 |
# Test F1: 0.7174
# Test ACC: 0.6286
# Test AUC: 0.6031
# Train F1: 0.9209
# 00400: TRAIN| LT=0.565 LP=0.204 LKL=8.214 LPS=0.197 LKLS=8.298 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.6110
# Train F1: 0.9257
# 00450: TRAIN| LT=0.530 LP=0.207 LKL=8.268 LPS=0.157 LKLS=8.382 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.5909
# Train F1: 0.9459
# 00500: TRAIN| LT=0.566 LP=0.216 LKL=8.376 LPS=0.181 LKLS=8.473 |
# Test F1: 0.6742
# Test ACC: 0.5857
# Test AUC: 0.5909
# Train F1: 0.9462
# 00550: TRAIN| LT=0.524 LP=0.222 LKL=7.973 LPS=0.147 LKLS=7.447 |
# Test F1: 0.7158
# Test ACC: 0.6143
# Test AUC: 0.5804
# Train F1: 0.9364
# 00600: TRAIN| LT=0.518 LP=0.218 LKL=8.306 LPS=0.139 LKLS=7.857 |
# Test F1: 0.6818
# Test ACC: 0.6000
# Test AUC: 0.5865
# Train F1: 0.9348
# 00650: TRAIN| LT=0.542 LP=0.184 LKL=8.413 LPS=0.193 LKLS=8.095 |
# Test F1: 0.6818
# Test ACC: 0.6000
# Test AUC: 0.5865
# Train F1: 0.9605
# 00700: TRAIN| LT=0.494 LP=0.179 LKL=8.270 LPS=0.157 LKLS=7.650 |
# Test F1: 0.6966
# Test ACC: 0.6143
# Test AUC: 0.6031
# Train F1: 0.9345
# 00750: TRAIN| LT=0.500 LP=0.167 LKL=8.543 LPS=0.169 LKLS=7.780 |
# Test F1: 0.6744
# Test ACC: 0.6000
# Test AUC: 0.5892
# Train F1: 0.9345
# 00800: TRAIN| LT=0.468 LP=0.170 LKL=8.576 LPS=0.137 LKLS=7.505 |
# Test F1: 0.6818
# Test ACC: 0.6000
# Test AUC: 0.5865
# Train F1: 0.9483
# 00850: TRAIN| LT=0.475 LP=0.172 LKL=8.494 LPS=0.145 LKLS=7.324 |
# Test F1: 0.6512
# Test ACC: 0.5714
# Test AUC: 0.5900
# Train F1: 0.9655
# 00900: TRAIN| LT=0.430 LP=0.153 LKL=8.451 LPS=0.119 LKLS=7.370 |
# Test F1: 0.6279
# Test ACC: 0.5429
# Test AUC: 0.5970
# Train F1: 0.9540
# 00950: TRAIN| LT=0.436 LP=0.143 LKL=8.583 LPS=0.134 LKLS=7.387 |
# Test F1: 0.6279
# Test ACC: 0.5429
# Test AUC: 0.5760
# Train F1: 0.9494
# 01000: TRAIN| LT=0.449 LP=0.171 LKL=8.467 LPS=0.121 LKLS=7.279 |
# Test F1: 0.7021
# Test ACC: 0.6000
# Test AUC: 0.5892
# Train F1: 0.9570
# 01050: TRAIN| LT=0.434 LP=0.137 LKL=8.530 LPS=0.139 LKLS=7.318 |
# Test F1: 0.6279
# Test ACC: 0.5429
# Test AUC: 0.5673
# Train F1: 0.9438
# 01100: TRAIN| LT=0.451 LP=0.161 LKL=8.652 LPS=0.131 LKLS=7.194 |
# Test F1: 0.6591
# Test ACC: 0.5714
# Test AUC: 0.5691
# Train F1: 0.9621
# 01150: TRAIN| LT=0.477 LP=0.179 LKL=8.428 LPS=0.144 LKLS=7.020 |
# Test F1: 0.6437
# Test ACC: 0.5571
# Test AUC: 0.5699
# Train F1: 0.9513
# 01200: TRAIN| LT=0.386 LP=0.102 LKL=8.797 LPS=0.123 LKLS=7.327 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.5804
# Train F1: 0.9504
# 01250: TRAIN| LT=0.390 LP=0.119 LKL=8.528 LPS=0.117 LKLS=6.895 |
# Test F1: 0.6889
# Test ACC: 0.6000
# Test AUC: 0.5734
# Train F1: 0.9459
# 01300: TRAIN| LT=0.390 LP=0.122 LKL=8.623 LPS=0.111 LKLS=7.014 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.5813
# Train F1: 0.9600
# 01350: TRAIN| LT=0.423 LP=0.156 LKL=8.549 LPS=0.112 LKLS=6.880 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.5699
# Train F1: 0.9628
# 01400: TRAIN| LT=0.411 LP=0.137 LKL=8.385 LPS=0.123 LKLS=6.793 |
# Test F1: 0.6742
# Test ACC: 0.5857
# Test AUC: 0.5822
# Train F1: 0.9659
# 01450: TRAIN| LT=0.405 LP=0.124 LKL=8.558 LPS=0.127 LKLS=6.848 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.5699
# Train F1: 0.9456
# 01500: TRAIN| LT=0.376 LP=0.121 LKL=8.520 LPS=0.103 LKLS=6.654 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.5743
# Train F1: 0.9716
# 01550: TRAIN| LT=0.395 LP=0.120 LKL=8.429 LPS=0.125 LKLS=6.578 |
# Test F1: 0.7097
# Test ACC: 0.6143
# Test AUC: 0.5682
# Train F1: 0.9538
# 01600: TRAIN| LT=0.392 LP=0.107 LKL=8.714 LPS=0.130 LKLS=6.748 |
# Test F1: 0.6517
# Test ACC: 0.5571
# Test AUC: 0.5708
# Train F1: 0.9602
# 01650: TRAIN| LT=0.376 LP=0.126 LKL=8.502 LPS=0.099 LKLS=6.582 |
# Test F1: 0.6882
# Test ACC: 0.5857
# Test AUC: 0.5575
# Train F1: 0.9492
# 01700: TRAIN| LT=0.345 LP=0.115 LKL=8.484 LPS=0.081 LKLS=6.408 |
# Test F1: 0.6957
# Test ACC: 0.6000
# Test AUC: 0.5647
# Train F1: 0.9518
# 01750: TRAIN| LT=0.338 LP=0.101 LKL=8.112 LPS=0.096 LKLS=6.033 |
# Test F1: 0.7097
# Test ACC: 0.6143
# Test AUC: 0.5830
# Train F1: 0.9540
# 01800: TRAIN| LT=0.341 LP=0.105 LKL=8.352 LPS=0.091 LKLS=6.159 |
# Test F1: 0.7097
# Test ACC: 0.6143
# Test AUC: 0.5988
# Train F1: 0.9543
# 01850: TRAIN| LT=0.320 LP=0.090 LKL=8.238 LPS=0.088 LKLS=5.994 |
# Test F1: 0.6957
# Test ACC: 0.6000
# Test AUC: 0.5830
# Train F1: 0.9535
# 01900: TRAIN| LT=0.354 LP=0.111 LKL=8.220 LPS=0.102 LKLS=5.937 |
# Test F1: 0.7158
# Test ACC: 0.6143
# Test AUC: 0.5848
# Train F1: 0.9688
# 01950: TRAIN| LT=0.383 LP=0.125 LKL=8.021 LPS=0.119 LKLS=5.923 |
# Test F1: 0.6947
# Test ACC: 0.5857
# Test AUC: 0.5795
# Train F1: 0.9548
# 02000: TRAIN| LT=0.348 LP=0.117 LKL=8.182 LPS=0.089 LKLS=5.949 |
# Test F1: 0.7083
# Test ACC: 0.6000
# Test AUC: 0.5752
# f1: 0.7719298245614035
# acc: 0.6285714285714286
# auc: 0.6372377622377623
# Train F1: 0.7880
# 00050: TRAIN| LT=1.315 LP=0.632 LKL=5.360 LPS=0.597 LKLS=3.259 |
# Test F1: 0.7706
# Test ACC: 0.6377
# Test AUC: 0.5555
# Train F1: 0.8472
# 00100: TRAIN| LT=0.970 LP=0.428 LKL=7.682 LPS=0.377 LKLS=8.882 |
# Test F1: 0.5714
# Test ACC: 0.4783
# Test AUC: 0.5264
# Train F1: 0.8579
# 00150: TRAIN| LT=0.776 LP=0.322 LKL=8.020 LPS=0.280 LKLS=9.321 |
# Test F1: 0.6420
# Test ACC: 0.5797
# Test AUC: 0.5100
# Train F1: 0.9188
# 00200: TRAIN| LT=0.627 LP=0.227 LKL=8.086 LPS=0.229 LKLS=9.109 |
# Test F1: 0.5641
# Test ACC: 0.5072
# Test AUC: 0.4936
# Train F1: 0.9222
# 00250: TRAIN| LT=0.565 LP=0.224 LKL=8.078 LPS=0.174 LKLS=8.688 |
# Test F1: 0.6429
# Test ACC: 0.5652
# Test AUC: 0.4855
# Train F1: 0.9151
# 00300: TRAIN| LT=0.599 LP=0.239 LKL=8.052 LPS=0.195 LKLS=8.450 |
# Test F1: 0.6098
# Test ACC: 0.5362
# Test AUC: 0.4845
# Train F1: 0.9322
# 00350: TRAIN| LT=0.526 LP=0.200 LKL=8.479 LPS=0.153 LKLS=8.877 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.4836
# Train F1: 0.9363
# 00400: TRAIN| LT=0.479 LP=0.172 LKL=8.412 LPS=0.138 LKLS=8.586 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.4827
# Train F1: 0.9548
# 00450: TRAIN| LT=0.565 LP=0.237 LKL=8.389 LPS=0.160 LKLS=8.305 |
# Test F1: 0.6667
# Test ACC: 0.5797
# Test AUC: 0.4700
# Train F1: 0.9462
# 00500: TRAIN| LT=0.518 LP=0.183 LKL=8.580 LPS=0.163 LKLS=8.618 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.4836
# Train F1: 0.9497
# 00550: TRAIN| LT=0.473 LP=0.162 LKL=8.444 LPS=0.147 LKLS=7.942 |
# Test F1: 0.6667
# Test ACC: 0.5797
# Test AUC: 0.4773
# Train F1: 0.9607
# 00600: TRAIN| LT=0.374 LP=0.119 LKL=8.374 LPS=0.092 LKLS=7.864 |
# Test F1: 0.6667
# Test ACC: 0.5797
# Test AUC: 0.4718
# Train F1: 0.9577
# 00650: TRAIN| LT=0.422 LP=0.158 LKL=8.569 LPS=0.099 LKLS=7.911 |
# Test F1: 0.6437
# Test ACC: 0.5507
# Test AUC: 0.4882
# Train F1: 0.9345
# 00700: TRAIN| LT=0.395 LP=0.135 LKL=8.233 LPS=0.106 LKLS=7.199 |
# Test F1: 0.6437
# Test ACC: 0.5507
# Test AUC: 0.4800
# Train F1: 0.9632
# 00750: TRAIN| LT=0.401 LP=0.156 LKL=8.410 LPS=0.088 LKLS=7.232 |
# Test F1: 0.6444
# Test ACC: 0.5362
# Test AUC: 0.4745
# Train F1: 0.9494
# 00800: TRAIN| LT=0.361 LP=0.097 LKL=8.568 LPS=0.105 LKLS=7.314 |
# Test F1: 0.6364
# Test ACC: 0.5362
# Test AUC: 0.4818
# Train F1: 0.9607
# 00850: TRAIN| LT=0.373 LP=0.113 LKL=8.391 LPS=0.107 LKLS=6.870 |
# Test F1: 0.6444
# Test ACC: 0.5362
# Test AUC: 0.4682
# Train F1: 0.9607
# 00900: TRAIN| LT=0.362 LP=0.113 LKL=8.253 LPS=0.101 LKLS=6.555 |
# Test F1: 0.6364
# Test ACC: 0.5362
# Test AUC: 0.4755
# Train F1: 0.9602
# 00950: TRAIN| LT=0.373 LP=0.106 LKL=8.520 LPS=0.111 LKLS=7.049 |
# Test F1: 0.6364
# Test ACC: 0.5362
# Test AUC: 0.4836
# Train F1: 0.9628
# 01000: TRAIN| LT=0.350 LP=0.100 LKL=8.576 LPS=0.094 LKLS=7.101 |
# Test F1: 0.6429
# Test ACC: 0.5652
# Test AUC: 0.4882
# Train F1: 0.9774
# 01050: TRAIN| LT=0.376 LP=0.115 LKL=8.303 LPS=0.115 LKLS=6.372 |
# Test F1: 0.6429
# Test ACC: 0.5652
# Test AUC: 0.4982
# Train F1: 0.9494
# 01100: TRAIN| LT=0.339 LP=0.122 LKL=8.495 LPS=0.065 LKLS=6.682 |
# Test F1: 0.6437
# Test ACC: 0.5507
# Test AUC: 0.4791
# Train F1: 0.9513
# 01150: TRAIN| LT=0.339 LP=0.113 LKL=8.386 LPS=0.078 LKLS=6.457 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.4736
# Train F1: 0.9714
# 01200: TRAIN| LT=0.377 LP=0.117 LKL=8.197 LPS=0.116 LKLS=6.251 |
# Test F1: 0.6047
# Test ACC: 0.5072
# Test AUC: 0.4818
# Train F1: 0.9600
# 01250: TRAIN| LT=0.386 LP=0.103 LKL=8.276 LPS=0.138 LKLS=6.256 |
# Test F1: 0.6098
# Test ACC: 0.5362
# Test AUC: 0.4945
# Train F1: 0.9716
# 01300: TRAIN| LT=0.334 LP=0.105 LKL=8.698 LPS=0.072 LKLS=7.075 |
# Test F1: 0.5814
# Test ACC: 0.4783
# Test AUC: 0.4673
# Train F1: 0.9575
# 01350: TRAIN| LT=0.360 LP=0.111 LKL=8.400 LPS=0.102 LKLS=6.283 |
# Test F1: 0.6279
# Test ACC: 0.5362
# Test AUC: 0.4745
# Train F1: 0.9688
# 01400: TRAIN| LT=0.331 LP=0.093 LKL=8.304 LPS=0.094 LKLS=6.040 |
# Test F1: 0.5952
# Test ACC: 0.5072
# Test AUC: 0.4945
# Train F1: 0.9746
# 01450: TRAIN| LT=0.300 LP=0.087 LKL=8.397 LPS=0.069 LKLS=6.040 |
# Test F1: 0.5882
# Test ACC: 0.4928
# Test AUC: 0.4745
# Train F1: 0.9718
# 01500: TRAIN| LT=0.300 LP=0.077 LKL=8.155 LPS=0.081 LKLS=5.961 |
# Test F1: 0.5783
# Test ACC: 0.4928
# Test AUC: 0.4877
# Train F1: 0.9634
# 01550: TRAIN| LT=0.291 LP=0.087 LKL=8.128 LPS=0.066 LKLS=5.683 |
# Test F1: 0.6067
# Test ACC: 0.4928
# Test AUC: 0.4845
# Train F1: 0.9486
# 01600: TRAIN| LT=0.320 LP=0.082 LKL=8.421 LPS=0.090 LKLS=6.345 |
# Test F1: 0.5952
# Test ACC: 0.5072
# Test AUC: 0.4936
# Train F1: 0.9775
# 01650: TRAIN| LT=0.257 LP=0.058 LKL=8.318 LPS=0.055 LKLS=6.088 |
# Test F1: 0.5952
# Test ACC: 0.5072
# Test AUC: 0.4889
# Train F1: 0.9690
# 01700: TRAIN| LT=0.300 LP=0.086 LKL=8.151 LPS=0.075 LKLS=5.740 |
# Test F1: 0.5714
# Test ACC: 0.4783
# Test AUC: 0.4743
# Train F1: 0.9773
# 01750: TRAIN| LT=0.260 LP=0.064 LKL=7.830 LPS=0.066 LKLS=5.213 |
# Test F1: 0.6000
# Test ACC: 0.5362
# Test AUC: 0.5036
# Train F1: 0.9625
# 01800: TRAIN| LT=0.257 LP=0.069 LKL=8.139 LPS=0.051 LKLS=5.498 |
# Test F1: 0.5823
# Test ACC: 0.5217
# Test AUC: 0.4945
# Train F1: 0.9746
# 01850: TRAIN| LT=0.274 LP=0.070 LKL=8.050 LPS=0.070 LKLS=5.300 |
# Test F1: 0.5854
# Test ACC: 0.5072
# Test AUC: 0.4818
# Train F1: 0.9716
# 01900: TRAIN| LT=0.272 LP=0.074 LKL=7.856 LPS=0.068 LKLS=5.136 |
# Test F1: 0.6024
# Test ACC: 0.5217
# Test AUC: 0.4982
# Train F1: 0.9745
# 01950: TRAIN| LT=0.310 LP=0.100 LKL=8.001 LPS=0.077 LKLS=5.305 |
# Test F1: 0.5610
# Test ACC: 0.4783
# Test AUC: 0.4755
# Train F1: 0.9745
# 02000: TRAIN| LT=0.264 LP=0.061 LKL=8.107 LPS=0.068 LKLS=5.289 |
# Test F1: 0.5823
# Test ACC: 0.5217
# Test AUC: 0.4998
# f1: 0.7706422018348624
# acc: 0.6376811594202898
# auc: 0.5554545454545454
# Train F1: 0.7856
# 00050: TRAIN| LT=1.287 LP=0.629 LKL=5.320 LPS=0.575 LKLS=2.979 |
# Test F1: 0.7788
# Test ACC: 0.6377
# Test AUC: 0.6773
# Train F1: 0.8430
# 00100: TRAIN| LT=0.949 LP=0.430 LKL=7.552 LPS=0.352 LKLS=9.079 |
# Test F1: 0.7111
# Test ACC: 0.6232
# Test AUC: 0.5718
# Train F1: 0.9101
# 00150: TRAIN| LT=0.808 LP=0.312 LKL=7.852 LPS=0.329 LKLS=8.842 |
# Test F1: 0.6744
# Test ACC: 0.5942
# Test AUC: 0.5627
# Train F1: 0.8815
# 00200: TRAIN| LT=0.752 LP=0.300 LKL=8.141 LPS=0.280 LKLS=9.098 |
# Test F1: 0.6977
# Test ACC: 0.6232
# Test AUC: 0.5482
# Train F1: 0.9213
# 00250: TRAIN| LT=0.642 LP=0.249 LKL=8.231 LPS=0.222 LKLS=8.725 |
# Test F1: 0.7045
# Test ACC: 0.6232
# Test AUC: 0.5609
# Train F1: 0.9257
# 00300: TRAIN| LT=0.629 LP=0.232 LKL=8.287 LPS=0.227 LKLS=8.649 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.5464
# Train F1: 0.9449
# 00350: TRAIN| LT=0.573 LP=0.223 LKL=8.337 LPS=0.187 LKLS=7.933 |
# Test F1: 0.6585
# Test ACC: 0.5942
# Test AUC: 0.5509
# Train F1: 0.9292
# 00400: TRAIN| LT=0.497 LP=0.164 LKL=8.645 LPS=0.160 LKLS=8.577 |
# Test F1: 0.6585
# Test ACC: 0.5942
# Test AUC: 0.5618
# Train F1: 0.9425
# 00450: TRAIN| LT=0.476 LP=0.158 LKL=8.739 LPS=0.151 LKLS=8.051 |
# Test F1: 0.6420
# Test ACC: 0.5797
# Test AUC: 0.5645
# Train F1: 0.9329
# 00500: TRAIN| LT=0.591 LP=0.239 LKL=8.581 LPS=0.187 LKLS=7.979 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.5618
# Train F1: 0.9292
# 00550: TRAIN| LT=0.480 LP=0.179 LKL=8.374 LPS=0.145 LKLS=7.224 |
# Test F1: 0.6744
# Test ACC: 0.5942
# Test AUC: 0.5782
# Train F1: 0.9425
# 00600: TRAIN| LT=0.451 LP=0.138 LKL=8.595 LPS=0.153 LKLS=7.482 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.5764
# Train F1: 0.9595
# 00650: TRAIN| LT=0.421 LP=0.139 LKL=8.770 LPS=0.121 LKLS=7.371 |
# Test F1: 0.6824
# Test ACC: 0.6087
# Test AUC: 0.5655
# Train F1: 0.9598
# 00700: TRAIN| LT=0.480 LP=0.162 LKL=8.522 LPS=0.165 LKLS=6.806 |
# Test F1: 0.6744
# Test ACC: 0.5942
# Test AUC: 0.5736
# Train F1: 0.9573
# 00750: TRAIN| LT=0.415 LP=0.137 LKL=8.742 LPS=0.122 LKLS=6.901 |
# Test F1: 0.6897
# Test ACC: 0.6087
# Test AUC: 0.5700
# Train F1: 0.9687
# 00800: TRAIN| LT=0.401 LP=0.134 LKL=8.617 LPS=0.114 LKLS=6.750 |
# Test F1: 0.7191
# Test ACC: 0.6377
# Test AUC: 0.5809
# Train F1: 0.9609
# 00850: TRAIN| LT=0.407 LP=0.132 LKL=8.772 LPS=0.118 LKLS=6.882 |
# Test F1: 0.7273
# Test ACC: 0.6522
# Test AUC: 0.5827
# Train F1: 0.9577
# 00900: TRAIN| LT=0.324 LP=0.077 LKL=8.719 LPS=0.092 LKLS=6.750 |
# Test F1: 0.7126
# Test ACC: 0.6377
# Test AUC: 0.5845
# Train F1: 0.9661
# 00950: TRAIN| LT=0.435 LP=0.150 LKL=8.278 LPS=0.143 LKLS=5.931 |
# Test F1: 0.7111
# Test ACC: 0.6232
# Test AUC: 0.5836
# Train F1: 0.9524
# 01000: TRAIN| LT=0.354 LP=0.100 LKL=8.765 LPS=0.103 LKLS=6.271 |
# Test F1: 0.6897
# Test ACC: 0.6087
# Test AUC: 0.5836
# Train F1: 0.9659
# 01050: TRAIN| LT=0.373 LP=0.117 LKL=8.665 LPS=0.108 LKLS=6.103 |
# Test F1: 0.7253
# Test ACC: 0.6377
# Test AUC: 0.5918
# Train F1: 0.9580
# 01100: TRAIN| LT=0.358 LP=0.127 LKL=8.713 LPS=0.082 LKLS=6.133 |
# Test F1: 0.6977
# Test ACC: 0.6232
# Test AUC: 0.5845
# Train F1: 0.9742
# 01150: TRAIN| LT=0.352 LP=0.096 LKL=8.343 LPS=0.117 LKLS=5.593 |
# Test F1: 0.6977
# Test ACC: 0.6232
# Test AUC: 0.5855
# Train F1: 0.9661
# 01200: TRAIN| LT=0.342 LP=0.087 LKL=8.183 LPS=0.119 LKLS=5.421 |
# Test F1: 0.6824
# Test ACC: 0.6087
# Test AUC: 0.5827
# Train F1: 0.9714
# 01250: TRAIN| LT=0.344 LP=0.118 LKL=8.266 LPS=0.089 LKLS=5.392 |
# Test F1: 0.6977
# Test ACC: 0.6232
# Test AUC: 0.5800
# Train F1: 0.9630
# 01300: TRAIN| LT=0.313 LP=0.099 LKL=8.392 LPS=0.074 LKLS=5.518 |
# Test F1: 0.7045
# Test ACC: 0.6232
# Test AUC: 0.5845
# Train F1: 0.9632
# 01350: TRAIN| LT=0.340 LP=0.113 LKL=8.165 LPS=0.095 LKLS=5.060 |
# Test F1: 0.7234
# Test ACC: 0.6232
# Test AUC: 0.5945
# Train F1: 0.9773
# 01400: TRAIN| LT=0.297 LP=0.077 LKL=8.235 LPS=0.085 LKLS=5.243 |
# Test F1: 0.6977
# Test ACC: 0.6232
# Test AUC: 0.5791
# Train F1: 0.9714
# 01450: TRAIN| LT=0.295 LP=0.071 LKL=8.293 LPS=0.089 LKLS=5.209 |
# Test F1: 0.6897
# Test ACC: 0.6087
# Test AUC: 0.5800
# Train F1: 0.9858
# 01500: TRAIN| LT=0.255 LP=0.064 LKL=8.193 LPS=0.059 LKLS=5.029 |
# Test F1: 0.6824
# Test ACC: 0.6087
# Test AUC: 0.5845
# Train F1: 0.9803
# 01550: TRAIN| LT=0.265 LP=0.075 LKL=8.071 LPS=0.061 LKLS=4.809 |
# Test F1: 0.6744
# Test ACC: 0.5942
# Test AUC: 0.5818
# Train F1: 0.9716
# 01600: TRAIN| LT=0.288 LP=0.078 LKL=7.993 LPS=0.081 LKLS=4.902 |
# Test F1: 0.7609
# Test ACC: 0.6812
# Test AUC: 0.5839
# Train F1: 0.9858
# 01650: TRAIN| LT=0.263 LP=0.062 LKL=8.109 LPS=0.072 LKLS=4.865 |
# Test F1: 0.7191
# Test ACC: 0.6377
# Test AUC: 0.5745
# Train F1: 0.9804
# 01700: TRAIN| LT=0.258 LP=0.066 LKL=8.253 LPS=0.059 LKLS=5.072 |
# Test F1: 0.6897
# Test ACC: 0.6087
# Test AUC: 0.5709
# Train F1: 0.9685
# 01750: TRAIN| LT=0.241 LP=0.056 LKL=7.918 LPS=0.058 LKLS=4.797 |
# Test F1: 0.7045
# Test ACC: 0.6232
# Test AUC: 0.5782
# Train F1: 0.9716
# 01800: TRAIN| LT=0.235 LP=0.049 LKL=8.135 LPS=0.055 LKLS=4.904 |
# Test F1: 0.6588
# Test ACC: 0.5797
# Test AUC: 0.5627
# Train F1: 0.9774
# 01850: TRAIN| LT=0.259 LP=0.070 LKL=7.894 LPS=0.064 LKLS=4.614 |
# Test F1: 0.6897
# Test ACC: 0.6087
# Test AUC: 0.5861
# Train F1: 0.9773
# 01900: TRAIN| LT=0.289 LP=0.089 LKL=7.989 LPS=0.074 LKLS=4.613 |
# Test F1: 0.6744
# Test ACC: 0.5942
# Test AUC: 0.5661
# Train F1: 0.9774
# 01950: TRAIN| LT=0.267 LP=0.060 LKL=7.950 LPS=0.080 LKLS=4.695 |
# Test F1: 0.7527
# Test ACC: 0.6667
# Test AUC: 0.5641
# Train F1: 0.9773
# 02000: TRAIN| LT=0.232 LP=0.062 LKL=7.892 LPS=0.045 LKLS=4.684 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5752
# f1: 0.7787610619469026
# acc: 0.6376811594202898
# auc: 0.6772727272727272
# Train F1: 0.7563
# 00050: TRAIN| LT=1.285 LP=0.595 LKL=5.637 LPS=0.593 LKLS=4.020 |
# Test F1: 0.7379
# Test ACC: 0.6087
# Test AUC: 0.5491
# Train F1: 0.8453
# 00100: TRAIN| LT=0.948 LP=0.424 LKL=7.482 LPS=0.365 LKLS=8.398 |
# Test F1: 0.5882
# Test ACC: 0.4928
# Test AUC: 0.5664
# Train F1: 0.8839
# 00150: TRAIN| LT=0.768 LP=0.311 LKL=7.935 LPS=0.291 LKLS=8.694 |
# Test F1: 0.6000
# Test ACC: 0.5362
# Test AUC: 0.5691
# Train F1: 0.9106
# 00200: TRAIN| LT=0.719 LP=0.311 LKL=8.452 LPS=0.227 LKLS=9.646 |
# Test F1: 0.6420
# Test ACC: 0.5797
# Test AUC: 0.5755
# Train F1: 0.9153
# 00250: TRAIN| LT=0.575 LP=0.224 LKL=8.557 LPS=0.169 LKLS=9.646 |
# Test F1: 0.6341
# Test ACC: 0.5652
# Test AUC: 0.5800
# Train F1: 0.9391
# 00300: TRAIN| LT=0.550 LP=0.213 LKL=8.556 LPS=0.158 LKLS=9.331 |
# Test F1: 0.6250
# Test ACC: 0.5652
# Test AUC: 0.5573
# Train F1: 0.9435
# 00350: TRAIN| LT=0.518 LP=0.178 LKL=8.476 LPS=0.168 LKLS=8.777 |
# Test F1: 0.6744
# Test ACC: 0.5942
# Test AUC: 0.5645
# Train F1: 0.9226
# 00400: TRAIN| LT=0.518 LP=0.193 LKL=8.227 LPS=0.164 LKLS=7.879 |
# Test F1: 0.6250
# Test ACC: 0.5652
# Test AUC: 0.5645
# Train F1: 0.9456
# 00450: TRAIN| LT=0.480 LP=0.165 LKL=8.389 LPS=0.152 LKLS=7.785 |
# Test F1: 0.6585
# Test ACC: 0.5942
# Test AUC: 0.5491
# Train F1: 0.9408
# 00500: TRAIN| LT=0.483 LP=0.184 LKL=8.711 LPS=0.127 LKLS=8.450 |
# Test F1: 0.6667
# Test ACC: 0.5797
# Test AUC: 0.5382
# Train F1: 0.9605
# 00550: TRAIN| LT=0.443 LP=0.159 LKL=8.568 LPS=0.119 LKLS=7.918 |
# Test F1: 0.6667
# Test ACC: 0.5797
# Test AUC: 0.5436
# Train F1: 0.9474
# 00600: TRAIN| LT=0.476 LP=0.149 LKL=8.428 LPS=0.164 LKLS=7.936 |
# Test F1: 0.6517
# Test ACC: 0.5507
# Test AUC: 0.5509
# Train F1: 0.9543
# 00650: TRAIN| LT=0.423 LP=0.157 LKL=8.608 LPS=0.104 LKLS=7.604 |
# Test F1: 0.6506
# Test ACC: 0.5797
# Test AUC: 0.5473
# Train F1: 0.9632
# 00700: TRAIN| LT=0.424 LP=0.132 LKL=8.603 LPS=0.129 LKLS=7.786 |
# Test F1: 0.6512
# Test ACC: 0.5652
# Test AUC: 0.5382
# Train F1: 0.9598
# 00750: TRAIN| LT=0.401 LP=0.125 LKL=8.620 LPS=0.117 LKLS=7.310 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.5445
# Train F1: 0.9545
# 00800: TRAIN| LT=0.399 LP=0.124 LKL=8.717 LPS=0.114 LKLS=7.484 |
# Test F1: 0.6588
# Test ACC: 0.5797
# Test AUC: 0.5418
# Train F1: 0.9489
# 00850: TRAIN| LT=0.398 LP=0.129 LKL=8.576 LPS=0.111 LKLS=7.238 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.5282
# Train F1: 0.9634
# 00900: TRAIN| LT=0.344 LP=0.088 LKL=8.649 LPS=0.097 LKLS=7.259 |
# Test F1: 0.6512
# Test ACC: 0.5652
# Test AUC: 0.5391
# Train F1: 0.9605
# 00950: TRAIN| LT=0.397 LP=0.115 LKL=8.688 LPS=0.124 LKLS=7.189 |
# Test F1: 0.6437
# Test ACC: 0.5507
# Test AUC: 0.5336
# Train F1: 0.9565
# 01000: TRAIN| LT=0.329 LP=0.087 LKL=8.619 LPS=0.085 LKLS=7.136 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.5436
# Train F1: 0.9595
# 01050: TRAIN| LT=0.372 LP=0.127 LKL=8.646 LPS=0.089 LKLS=6.924 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.5455
# Train F1: 0.9636
# 01100: TRAIN| LT=0.372 LP=0.114 LKL=8.310 LPS=0.110 LKLS=6.488 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.5345
# Train F1: 0.9657
# 01150: TRAIN| LT=0.339 LP=0.094 LKL=8.581 LPS=0.094 LKLS=6.570 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.5327
# Train F1: 0.9634
# 01200: TRAIN| LT=0.399 LP=0.135 LKL=8.503 LPS=0.114 LKLS=6.518 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.5291
# Train F1: 0.9630
# 01250: TRAIN| LT=0.375 LP=0.123 LKL=8.241 LPS=0.108 LKLS=6.094 |
# Test F1: 0.6429
# Test ACC: 0.5652
# Test AUC: 0.5300
# Train F1: 0.9634
# 01300: TRAIN| LT=0.377 LP=0.120 LKL=8.572 LPS=0.109 LKLS=6.299 |
# Test F1: 0.6512
# Test ACC: 0.5652
# Test AUC: 0.5343
# Train F1: 0.9507
# 01350: TRAIN| LT=0.331 LP=0.092 LKL=8.735 LPS=0.086 LKLS=6.526 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.5100
# Train F1: 0.9573
# 01400: TRAIN| LT=0.359 LP=0.111 LKL=8.551 LPS=0.099 LKLS=6.355 |
# Test F1: 0.6190
# Test ACC: 0.5362
# Test AUC: 0.5236
# Train F1: 0.9497
# 01450: TRAIN| LT=0.339 LP=0.110 LKL=8.308 LPS=0.088 LKLS=5.876 |
# Test F1: 0.6353
# Test ACC: 0.5507
# Test AUC: 0.5309
# Train F1: 0.9605
# 01500: TRAIN| LT=0.339 LP=0.109 LKL=8.331 LPS=0.088 LKLS=5.880 |
# Test F1: 0.6279
# Test ACC: 0.5362
# Test AUC: 0.5264
# Train F1: 0.9685
# 01550: TRAIN| LT=0.322 LP=0.092 LKL=8.318 LPS=0.089 LKLS=5.783 |
# Test F1: 0.6265
# Test ACC: 0.5507
# Test AUC: 0.5164
# Train F1: 0.9570
# 01600: TRAIN| LT=0.345 LP=0.105 LKL=8.088 LPS=0.103 LKLS=5.537 |
# Test F1: 0.6098
# Test ACC: 0.5362
# Test AUC: 0.5218
# Train F1: 0.9516
# 01650: TRAIN| LT=0.324 LP=0.108 LKL=8.272 LPS=0.078 LKLS=5.526 |
# Test F1: 0.6098
# Test ACC: 0.5362
# Test AUC: 0.5200
# Train F1: 0.9607
# 01700: TRAIN| LT=0.326 LP=0.096 LKL=7.970 LPS=0.099 LKLS=5.179 |
# Test F1: 0.6098
# Test ACC: 0.5362
# Test AUC: 0.5164
# Train F1: 0.9655
# 01750: TRAIN| LT=0.291 LP=0.077 LKL=8.059 LPS=0.081 LKLS=5.218 |
# Test F1: 0.5952
# Test ACC: 0.5072
# Test AUC: 0.5218
# Train F1: 0.9568
# 01800: TRAIN| LT=0.331 LP=0.100 LKL=8.140 LPS=0.097 LKLS=5.253 |
# Test F1: 0.6024
# Test ACC: 0.5217
# Test AUC: 0.4973
# Train F1: 0.9655
# 01850: TRAIN| LT=0.337 LP=0.108 LKL=8.232 LPS=0.094 LKLS=5.322 |
# Test F1: 0.5926
# Test ACC: 0.5217
# Test AUC: 0.5145
# Train F1: 0.9685
# 01900: TRAIN| LT=0.321 LP=0.095 LKL=8.281 LPS=0.089 LKLS=5.383 |
# Test F1: 0.6024
# Test ACC: 0.5217
# Test AUC: 0.5200
# Train F1: 0.9655
# 01950: TRAIN| LT=0.331 LP=0.082 LKL=8.103 LPS=0.116 LKLS=5.167 |
# Test F1: 0.5679
# Test ACC: 0.4928
# Test AUC: 0.5045
# Train F1: 0.9653
# 02000: TRAIN| LT=0.280 LP=0.081 LKL=8.018 LPS=0.070 LKLS=4.866 |
# Test F1: 0.5679
# Test ACC: 0.4928
# Test AUC: 0.5064
# f1: 0.7378640776699029
# acc: 0.6086956521739131
# auc: 0.5490909090909091
# f1 [0.8043478260869567, 0.7719298245614035, 0.7706422018348624, 0.7787610619469026, 0.7378640776699029]
# average f1: 0.7727089984200056±0.021244717701959938
# acc [0.7428571428571429, 0.6285714285714286, 0.6376811594202898, 0.6376811594202898, 0.6086956521739131]
# average acc: 0.6510973084886128±0.04708538847511045
# auc [0.7788461538461539, 0.6372377622377623, 0.5554545454545454, 0.6772727272727272, 0.5490909090909091]
# average auc: 0.6395804195804196±0.08495487867008518
