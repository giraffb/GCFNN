# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'Healthy':0,'Stage_0':1, 'Stage_I_II':1, 'Stage_III_IV':1, 'HS':1, 'MP':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (347, 851) (347, 450) (347, 1)
# Int64Index([10021, 10023, 10025, 10029, 10031, 10033, 10034, 10036, 10037,
#             10038,
#             ...
#             10818, 10825, 10827, 10829, 10835, 10838, 10839, 10847, 10850,
#             10853],
#            dtype='int64', name='Sample', length=347)
# 数据完整率missing_rate : 1.0
# 集合所有样本重构数据表： (347, 851) (347, 450) (347, 1)
# 标签转换为one-hot编码： (347, 2) 127.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 4, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1',f1_cv)
print('average maxf1',sum(f1_cv)/5)
print('acc',acc_cv)
print('average maxacc',sum(acc_cv)/5)
print('auc',auc_cv)
print('average maxauc',sum(auc_cv)/5)
# Out:
# Train F1: 0.7699
# 00050: TRAIN| LT=2.055 LP=0.638 LKL=10.667 LPS=1.284 LKLS=2.625 |
# Test F1: 0.7719
# Test ACC: 0.6286
# Test AUC: 0.6530
# Train F1: 0.8468
# 00100: TRAIN| LT=1.771 LP=0.474 LKL=11.768 LPS=1.093 LKLS=8.679 |
# Test F1: 0.7391
# Test ACC: 0.6571
# Test AUC: 0.6993
# Train F1: 0.8975
# 00150: TRAIN| LT=1.483 LP=0.293 LKL=12.787 LPS=0.946 LKLS=11.617 |
# Test F1: 0.7312
# Test ACC: 0.6429
# Test AUC: 0.7080
# Train F1: 0.9049
# 00200: TRAIN| LT=1.421 LP=0.293 LKL=12.812 LPS=0.893 LKLS=10.724 |
# Test F1: 0.7742
# Test ACC: 0.7000
# Test AUC: 0.7719
# Train F1: 0.9209
# 00250: TRAIN| LT=1.304 LP=0.213 LKL=12.689 LPS=0.868 LKLS=9.639 |
# Test F1: 0.7727
# Test ACC: 0.7143
# Test AUC: 0.7788
# Train F1: 0.9304
# 00300: TRAIN| LT=1.312 LP=0.213 LKL=12.905 LPS=0.875 LKLS=9.417 |
# Test F1: 0.7789
# Test ACC: 0.7000
# Test AUC: 0.7657
# Train F1: 0.9497
# 00350: TRAIN| LT=1.254 LP=0.224 LKL=12.911 LPS=0.807 LKLS=9.353 |
# Test F1: 0.7957
# Test ACC: 0.7286
# Test AUC: 0.7788
# Train F1: 0.9438
# 00400: TRAIN| LT=1.214 LP=0.164 LKL=12.873 LPS=0.836 LKLS=8.578 |
# Test F1: 0.7872
# Test ACC: 0.7143
# Test AUC: 0.7841
# Train F1: 0.9575
# 00450: TRAIN| LT=1.178 LP=0.155 LKL=13.492 LPS=0.788 LKLS=10.003 |
# Test F1: 0.7609
# Test ACC: 0.6857
# Test AUC: 0.7622
# Train F1: 0.9690
# 00500: TRAIN| LT=1.165 LP=0.148 LKL=13.844 LPS=0.776 LKLS=10.316 |
# Test F1: 0.7692
# Test ACC: 0.7000
# Test AUC: 0.7483
# Train F1: 0.9545
# 00550: TRAIN| LT=1.044 LP=0.114 LKL=13.710 LPS=0.693 LKLS=10.022 |
# Test F1: 0.7692
# Test ACC: 0.7000
# Test AUC: 0.7430
# Train F1: 0.9741
# 00600: TRAIN| LT=1.023 LP=0.090 LKL=13.911 LPS=0.687 LKLS=10.690 |
# Test F1: 0.7865
# Test ACC: 0.7286
# Test AUC: 0.7535
# Train F1: 0.9636
# 00650: TRAIN| LT=1.038 LP=0.135 LKL=13.578 LPS=0.670 LKLS=9.764 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7316
# Train F1: 0.9690
# 00700: TRAIN| LT=0.981 LP=0.102 LKL=13.764 LPS=0.642 LKLS=9.879 |
# Test F1: 0.7778
# Test ACC: 0.7143
# Test AUC: 0.7448
# Train F1: 0.9773
# 00750: TRAIN| LT=0.956 LP=0.087 LKL=13.935 LPS=0.627 LKLS=10.345 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7273
# Train F1: 0.9632
# 00800: TRAIN| LT=0.974 LP=0.089 LKL=13.758 LPS=0.644 LKLS=10.338 |
# Test F1: 0.7865
# Test ACC: 0.7286
# Test AUC: 0.7351
# Train F1: 0.9694
# 00850: TRAIN| LT=0.965 LP=0.107 LKL=13.957 LPS=0.614 LKLS=10.462 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7255
# Train F1: 0.9803
# 00900: TRAIN| LT=0.893 LP=0.072 LKL=13.920 LPS=0.581 LKLS=10.122 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7264
# Train F1: 0.9915
# 00950: TRAIN| LT=0.897 LP=0.097 LKL=13.749 LPS=0.563 LKLS=10.025 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7325
# Train F1: 0.9742
# 01000: TRAIN| LT=0.892 LP=0.097 LKL=13.800 LPS=0.554 LKLS=10.335 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7255
# Train F1: 0.9716
# 01050: TRAIN| LT=0.940 LP=0.072 LKL=13.664 LPS=0.633 LKLS=9.798 |
# Test F1: 0.7865
# Test ACC: 0.7286
# Test AUC: 0.7124
# Train F1: 0.9714
# 01100: TRAIN| LT=0.852 LP=0.073 LKL=13.871 LPS=0.540 LKLS=10.101 |
# Test F1: 0.8043
# Test ACC: 0.7429
# Test AUC: 0.7229
# Train F1: 0.9830
# 01150: TRAIN| LT=0.876 LP=0.079 LKL=13.618 LPS=0.565 LKLS=9.534 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7325
# Train F1: 0.9600
# 01200: TRAIN| LT=0.825 LP=0.067 LKL=13.872 LPS=0.521 LKLS=9.856 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7150
# Train F1: 0.9748
# 01250: TRAIN| LT=0.825 LP=0.081 LKL=13.832 LPS=0.506 LKLS=9.949 |
# Test F1: 0.8043
# Test ACC: 0.7429
# Test AUC: 0.7150
# Train F1: 0.9858
# 01300: TRAIN| LT=0.832 LP=0.074 LKL=13.675 LPS=0.526 LKLS=9.512 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7168
# Train F1: 0.9801
# 01350: TRAIN| LT=0.785 LP=0.050 LKL=13.784 LPS=0.499 LKLS=9.805 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7273
# Train F1: 0.9858
# 01400: TRAIN| LT=0.839 LP=0.092 LKL=13.698 LPS=0.512 LKLS=9.843 |
# Test F1: 0.7640
# Test ACC: 0.7000
# Test AUC: 0.7142
# Train F1: 0.9886
# 01450: TRAIN| LT=0.748 LP=0.055 LKL=13.486 LPS=0.468 LKLS=9.020 |
# Test F1: 0.7778
# Test ACC: 0.7143
# Test AUC: 0.7133
# Train F1: 0.9775
# 01500: TRAIN| LT=0.800 LP=0.072 LKL=13.691 LPS=0.495 LKLS=9.633 |
# Test F1: 0.7727
# Test ACC: 0.7143
# Test AUC: 0.7150
# Train F1: 0.9718
# 01550: TRAIN| LT=0.791 LP=0.056 LKL=13.580 LPS=0.501 LKLS=9.860 |
# Test F1: 0.7778
# Test ACC: 0.7143
# Test AUC: 0.7028
# Train F1: 0.9830
# 01600: TRAIN| LT=0.757 LP=0.045 LKL=13.743 LPS=0.475 LKLS=9.892 |
# Test F1: 0.7912
# Test ACC: 0.7286
# Test AUC: 0.7052
# Train F1: 0.9774
# 01650: TRAIN| LT=0.804 LP=0.074 LKL=13.568 LPS=0.504 LKLS=9.055 |
# Test F1: 0.7640
# Test ACC: 0.7000
# Test AUC: 0.7098
# Train F1: 0.9915
# 01700: TRAIN| LT=0.762 LP=0.050 LKL=13.625 LPS=0.480 LKLS=9.650 |
# Test F1: 0.7727
# Test ACC: 0.7143
# Test AUC: 0.7142
# Train F1: 0.9858
# 01750: TRAIN| LT=0.790 LP=0.067 LKL=13.570 LPS=0.493 LKLS=9.440 |
# Test F1: 0.7727
# Test ACC: 0.7143
# Test AUC: 0.7072
# Train F1: 0.9831
# 01800: TRAIN| LT=0.765 LP=0.042 LKL=13.585 LPS=0.492 LKLS=9.509 |
# Test F1: 0.7778
# Test ACC: 0.7143
# Test AUC: 0.7045
# Train F1: 0.9886
# 01850: TRAIN| LT=0.760 LP=0.027 LKL=13.532 LPS=0.501 LKLS=9.729 |
# Test F1: 0.7640
# Test ACC: 0.7000
# Test AUC: 0.7089
# Train F1: 0.9858
# 01900: TRAIN| LT=0.725 LP=0.046 LKL=13.529 LPS=0.453 LKLS=9.107 |
# Test F1: 0.7865
# Test ACC: 0.7286
# Test AUC: 0.6941
# Train F1: 0.9773
# 01950: TRAIN| LT=0.723 LP=0.033 LKL=13.619 LPS=0.460 LKLS=9.376 |
# Test F1: 0.7865
# Test ACC: 0.7286
# Test AUC: 0.7002
# Train F1: 0.9886
# 02000: TRAIN| LT=0.726 LP=0.043 LKL=13.479 LPS=0.455 LKLS=9.368 |
# Test F1: 0.7778
# Test ACC: 0.7143
# Test AUC: 0.6927
# f1: 0.8043478260869567
# acc: 0.7428571428571429
# auc: 0.7229020979020979
# Train F1: 0.7682
# 00050: TRAIN| LT=2.028 LP=0.631 LKL=10.765 LPS=1.255 LKLS=3.404 |
# Test F1: 0.7719
# Test ACC: 0.6286
# Test AUC: 0.6425
# Train F1: 0.8179
# 00100: TRAIN| LT=1.801 LP=0.478 LKL=12.189 LPS=1.101 LKLS=9.998 |
# Test F1: 0.7447
# Test ACC: 0.6571
# Test AUC: 0.6486
# Train F1: 0.8705
# 00150: TRAIN| LT=1.597 LP=0.366 LKL=12.172 LPS=1.014 LKLS=9.493 |
# Test F1: 0.7391
# Test ACC: 0.6571
# Test AUC: 0.6801
# Train F1: 0.8889
# 00200: TRAIN| LT=1.448 LP=0.287 LKL=12.737 LPS=0.928 LKLS=10.597 |
# Test F1: 0.6977
# Test ACC: 0.6286
# Test AUC: 0.6827
# Train F1: 0.8991
# 00250: TRAIN| LT=1.419 LP=0.259 LKL=12.918 LPS=0.925 LKLS=10.663 |
# Test F1: 0.7045
# Test ACC: 0.6286
# Test AUC: 0.6757
# Train F1: 0.9435
# 00300: TRAIN| LT=1.329 LP=0.220 LKL=12.820 LPS=0.884 LKLS=9.575 |
# Test F1: 0.6818
# Test ACC: 0.6000
# Test AUC: 0.6713
# Train F1: 0.9375
# 00350: TRAIN| LT=1.306 LP=0.218 LKL=13.156 LPS=0.855 LKLS=10.075 |
# Test F1: 0.6667
# Test ACC: 0.5857
# Test AUC: 0.6608
# Train F1: 0.9375
# 00400: TRAIN| LT=1.221 LP=0.190 LKL=12.975 LPS=0.809 LKLS=9.210 |
# Test F1: 0.6889
# Test ACC: 0.6000
# Test AUC: 0.6591
# Train F1: 0.9602
# 00450: TRAIN| LT=1.189 LP=0.176 LKL=13.536 LPS=0.774 LKLS=10.267 |
# Test F1: 0.6889
# Test ACC: 0.6000
# Test AUC: 0.6600
# Train F1: 0.9402
# 00500: TRAIN| LT=1.170 LP=0.149 LKL=13.691 LPS=0.778 LKLS=10.557 |
# Test F1: 0.6818
# Test ACC: 0.6000
# Test AUC: 0.6521
# Train F1: 0.9605
# 00550: TRAIN| LT=1.097 LP=0.122 LKL=13.757 LPS=0.732 LKLS=10.474 |
# Test F1: 0.7097
# Test ACC: 0.6143
# Test AUC: 0.6355
# Train F1: 0.9570
# 00600: TRAIN| LT=1.102 LP=0.118 LKL=13.631 LPS=0.747 LKLS=10.144 |
# Test F1: 0.6744
# Test ACC: 0.6000
# Test AUC: 0.6381
# Train F1: 0.9651
# 00650: TRAIN| LT=1.051 LP=0.121 LKL=13.596 LPS=0.694 LKLS=9.989 |
# Test F1: 0.6420
# Test ACC: 0.5857
# Test AUC: 0.6355
# Train F1: 0.9661
# 00700: TRAIN| LT=1.031 LP=0.118 LKL=13.715 LPS=0.673 LKLS=10.288 |
# Test F1: 0.6966
# Test ACC: 0.6143
# Test AUC: 0.6224
# Train F1: 0.9773
# 00750: TRAIN| LT=1.028 LP=0.086 LKL=13.722 LPS=0.702 LKLS=10.336 |
# Test F1: 0.6818
# Test ACC: 0.6000
# Test AUC: 0.6276
# Train F1: 0.9602
# 00800: TRAIN| LT=1.047 LP=0.093 LKL=13.919 LPS=0.710 LKLS=10.492 |
# Test F1: 0.6667
# Test ACC: 0.5714
# Test AUC: 0.6198
# Train F1: 0.9801
# 00850: TRAIN| LT=1.025 LP=0.094 LKL=13.695 LPS=0.692 LKLS=10.179 |
# Test F1: 0.6957
# Test ACC: 0.6000
# Test AUC: 0.6058
# Train F1: 0.9634
# 00900: TRAIN| LT=0.940 LP=0.078 LKL=13.686 LPS=0.626 LKLS=9.941 |
# Test F1: 0.7021
# Test ACC: 0.6000
# Test AUC: 0.6136
# Train F1: 0.9741
# 00950: TRAIN| LT=0.911 LP=0.061 LKL=13.891 LPS=0.607 LKLS=10.408 |
# Test F1: 0.6742
# Test ACC: 0.5857
# Test AUC: 0.6031
# Train F1: 0.9803
# 01000: TRAIN| LT=0.942 LP=0.086 LKL=13.891 LPS=0.614 LKLS=10.359 |
# Test F1: 0.6966
# Test ACC: 0.6143
# Test AUC: 0.5927
# Train F1: 0.9915
# 01050: TRAIN| LT=0.860 LP=0.037 LKL=14.201 LPS=0.570 LKLS=11.046 |
# Test F1: 0.7033
# Test ACC: 0.6143
# Test AUC: 0.6058
# Train F1: 0.9831
# 01100: TRAIN| LT=0.920 LP=0.083 LKL=13.744 LPS=0.596 LKLS=10.319 |
# Test F1: 0.6813
# Test ACC: 0.5857
# Test AUC: 0.5944
# Train F1: 0.9858
# 01150: TRAIN| LT=0.877 LP=0.061 LKL=14.114 LPS=0.569 LKLS=10.663 |
# Test F1: 0.6889
# Test ACC: 0.6000
# Test AUC: 0.5979
# Train F1: 0.9829
# 01200: TRAIN| LT=0.884 LP=0.069 LKL=13.904 LPS=0.576 LKLS=10.002 |
# Test F1: 0.6591
# Test ACC: 0.5714
# Test AUC: 0.6093
# Train F1: 0.9886
# 01250: TRAIN| LT=0.917 LP=0.080 LKL=13.881 LPS=0.597 LKLS=10.146 |
# Test F1: 0.6897
# Test ACC: 0.6143
# Test AUC: 0.6119
# Train F1: 0.9742
# 01300: TRAIN| LT=0.908 LP=0.088 LKL=13.743 LPS=0.581 LKLS=10.137 |
# Test F1: 0.6818
# Test ACC: 0.6000
# Test AUC: 0.6005
# Train F1: 0.9858
# 01350: TRAIN| LT=0.800 LP=0.037 LKL=13.890 LPS=0.519 LKLS=10.587 |
# Test F1: 0.6957
# Test ACC: 0.6000
# Test AUC: 0.6084
# Train F1: 0.9739
# 01400: TRAIN| LT=0.841 LP=0.042 LKL=13.844 LPS=0.561 LKLS=9.955 |
# Test F1: 0.6512
# Test ACC: 0.5714
# Test AUC: 0.5970
# Train F1: 0.9829
# 01450: TRAIN| LT=0.848 LP=0.054 LKL=13.617 LPS=0.563 LKLS=9.571 |
# Test F1: 0.6818
# Test ACC: 0.6000
# Test AUC: 0.5918
# Train F1: 0.9716
# 01500: TRAIN| LT=0.771 LP=0.044 LKL=13.610 LPS=0.496 LKLS=9.527 |
# Test F1: 0.7111
# Test ACC: 0.6286
# Test AUC: 0.6136
# Train F1: 0.9886
# 01550: TRAIN| LT=0.796 LP=0.053 LKL=13.760 LPS=0.504 LKLS=10.168 |
# Test F1: 0.6824
# Test ACC: 0.6143
# Test AUC: 0.6110
# Train F1: 0.9831
# 01600: TRAIN| LT=0.793 LP=0.043 LKL=13.882 LPS=0.508 LKLS=10.359 |
# Test F1: 0.7253
# Test ACC: 0.6429
# Test AUC: 0.6058
# Train F1: 0.9694
# 01650: TRAIN| LT=0.749 LP=0.021 LKL=13.822 LPS=0.491 LKLS=9.925 |
# Test F1: 0.7216
# Test ACC: 0.6143
# Test AUC: 0.6018
# Train F1: 0.9774
# 01700: TRAIN| LT=0.809 LP=0.052 LKL=13.958 LPS=0.511 LKLS=10.526 |
# Test F1: 0.7021
# Test ACC: 0.6000
# Test AUC: 0.6001
# Train F1: 0.9886
# 01750: TRAIN| LT=0.818 LP=0.055 LKL=13.707 LPS=0.528 LKLS=9.848 |
# Test F1: 0.7391
# Test ACC: 0.6571
# Test AUC: 0.6119
# Train F1: 0.9799
# 01800: TRAIN| LT=0.774 LP=0.041 LKL=13.605 LPS=0.503 LKLS=9.356 |
# Test F1: 0.6897
# Test ACC: 0.6143
# Test AUC: 0.6243
# Train F1: 0.9831
# 01850: TRAIN| LT=0.799 LP=0.046 LKL=13.790 LPS=0.517 LKLS=9.871 |
# Test F1: 0.7253
# Test ACC: 0.6429
# Test AUC: 0.6056
# Train F1: 0.9830
# 01900: TRAIN| LT=0.748 LP=0.014 LKL=13.697 LPS=0.496 LKLS=10.047 |
# Test F1: 0.7174
# Test ACC: 0.6286
# Test AUC: 0.6104
# Train F1: 0.9886
# 01950: TRAIN| LT=0.729 LP=0.043 LKL=13.799 LPS=0.444 LKLS=10.299 |
# Test F1: 0.7333
# Test ACC: 0.6571
# Test AUC: 0.6276
# Train F1: 0.9943
# 02000: TRAIN| LT=0.764 LP=0.018 LKL=13.865 LPS=0.505 LKLS=10.238 |
# Test F1: 0.6966
# Test ACC: 0.6143
# Test AUC: 0.6069
# f1: 0.7719298245614035
# acc: 0.6285714285714286
# auc: 0.6424825174825175
# Train F1: 0.7773
# 00050: TRAIN| LT=2.030 LP=0.628 LKL=10.673 LPS=1.263 LKLS=3.264 |
# Test F1: 0.7788
# Test ACC: 0.6377
# Test AUC: 0.5473
# Train F1: 0.8610
# 00100: TRAIN| LT=1.684 LP=0.441 LKL=12.050 LPS=1.023 LKLS=9.932 |
# Test F1: 0.6813
# Test ACC: 0.5797
# Test AUC: 0.5364
# Train F1: 0.8939
# 00150: TRAIN| LT=1.467 LP=0.291 LKL=12.153 LPS=0.954 LKLS=9.925 |
# Test F1: 0.6437
# Test ACC: 0.5507
# Test AUC: 0.5318
# Train F1: 0.9160
# 00200: TRAIN| LT=1.410 LP=0.301 LKL=12.284 LPS=0.888 LKLS=9.800 |
# Test F1: 0.6593
# Test ACC: 0.5507
# Test AUC: 0.4991
# Train F1: 0.9441
# 00250: TRAIN| LT=1.415 LP=0.281 LKL=12.539 LPS=0.906 LKLS=10.177 |
# Test F1: 0.6813
# Test ACC: 0.5797
# Test AUC: 0.5173
# Train F1: 0.9162
# 00300: TRAIN| LT=1.238 LP=0.186 LKL=12.687 LPS=0.825 LKLS=10.043 |
# Test F1: 0.6813
# Test ACC: 0.5797
# Test AUC: 0.5082
# Train F1: 0.9408
# 00350: TRAIN| LT=1.266 LP=0.216 LKL=12.538 LPS=0.831 LKLS=9.330 |
# Test F1: 0.7033
# Test ACC: 0.6087
# Test AUC: 0.5227
# Train F1: 0.9577
# 00400: TRAIN| LT=1.216 LP=0.177 LKL=12.906 LPS=0.810 LKLS=9.940 |
# Test F1: 0.7174
# Test ACC: 0.6232
# Test AUC: 0.4964
# Train F1: 0.9477
# 00450: TRAIN| LT=1.122 LP=0.125 LKL=12.909 LPS=0.771 LKLS=9.768 |
# Test F1: 0.7111
# Test ACC: 0.6232
# Test AUC: 0.5064
# Train F1: 0.9602
# 00500: TRAIN| LT=1.121 LP=0.128 LKL=13.056 LPS=0.760 LKLS=10.168 |
# Test F1: 0.7312
# Test ACC: 0.6377
# Test AUC: 0.5336
# Train F1: 0.9395
# 00550: TRAIN| LT=1.102 LP=0.131 LKL=13.175 LPS=0.746 LKLS=9.323 |
# Test F1: 0.7312
# Test ACC: 0.6377
# Test AUC: 0.5273
# Train F1: 0.9688
# 00600: TRAIN| LT=1.121 LP=0.126 LKL=13.259 LPS=0.758 LKLS=10.388 |
# Test F1: 0.7527
# Test ACC: 0.6667
# Test AUC: 0.5382
# Train F1: 0.9858
# 00650: TRAIN| LT=1.010 LP=0.077 LKL=13.459 LPS=0.691 LKLS=10.771 |
# Test F1: 0.7391
# Test ACC: 0.6522
# Test AUC: 0.5473
# Train F1: 0.9858
# 00700: TRAIN| LT=1.017 LP=0.064 LKL=13.580 LPS=0.710 LKLS=10.721 |
# Test F1: 0.7447
# Test ACC: 0.6522
# Test AUC: 0.5245
# Train F1: 0.9613
# 00750: TRAIN| LT=1.062 LP=0.127 LKL=13.331 LPS=0.698 LKLS=10.260 |
# Test F1: 0.7368
# Test ACC: 0.6377
# Test AUC: 0.5273
# Train F1: 0.9685
# 00800: TRAIN| LT=0.985 LP=0.065 LKL=13.597 LPS=0.679 LKLS=10.513 |
# Test F1: 0.6889
# Test ACC: 0.5942
# Test AUC: 0.5145
# Train F1: 0.9745
# 00850: TRAIN| LT=0.994 LP=0.089 LKL=13.559 LPS=0.665 LKLS=10.440 |
# Test F1: 0.7174
# Test ACC: 0.6232
# Test AUC: 0.5173
# Train F1: 0.9798
# 00900: TRAIN| LT=0.948 LP=0.076 LKL=13.302 LPS=0.640 LKLS=9.859 |
# Test F1: 0.7174
# Test ACC: 0.6232
# Test AUC: 0.5136
# Train F1: 0.9858
# 00950: TRAIN| LT=0.910 LP=0.079 LKL=13.536 LPS=0.594 LKLS=10.145 |
# Test F1: 0.7174
# Test ACC: 0.6232
# Test AUC: 0.5191
# Train F1: 0.9886
# 01000: TRAIN| LT=0.915 LP=0.059 LKL=13.602 LPS=0.619 LKLS=10.140 |
# Test F1: 0.7447
# Test ACC: 0.6522
# Test AUC: 0.5218
# Train F1: 0.9915
# 01050: TRAIN| LT=0.892 LP=0.064 LKL=13.758 LPS=0.585 LKLS=10.543 |
# Test F1: 0.7174
# Test ACC: 0.6232
# Test AUC: 0.5245
# Train F1: 0.9745
# 01100: TRAIN| LT=0.874 LP=0.053 LKL=13.471 LPS=0.589 LKLS=9.790 |
# Test F1: 0.7234
# Test ACC: 0.6232
# Test AUC: 0.5173
# Train F1: 0.9859
# 01150: TRAIN| LT=0.855 LP=0.045 LKL=13.606 LPS=0.572 LKLS=10.245 |
# Test F1: 0.7312
# Test ACC: 0.6377
# Test AUC: 0.5173
# Train F1: 0.9804
# 01200: TRAIN| LT=0.859 LP=0.038 LKL=13.742 LPS=0.579 LKLS=10.532 |
# Test F1: 0.7447
# Test ACC: 0.6522
# Test AUC: 0.5173
# Train F1: 0.9802
# 01250: TRAIN| LT=0.819 LP=0.051 LKL=13.753 LPS=0.528 LKLS=10.273 |
# Test F1: 0.7368
# Test ACC: 0.6377
# Test AUC: 0.5236
# Train F1: 0.9859
# 01300: TRAIN| LT=0.874 LP=0.059 LKL=13.587 LPS=0.580 LKLS=9.823 |
# Test F1: 0.7234
# Test ACC: 0.6232
# Test AUC: 0.5182
# Train F1: 0.9805
# 01350: TRAIN| LT=0.820 LP=0.029 LKL=13.816 LPS=0.546 LKLS=10.591 |
# Test F1: 0.7174
# Test ACC: 0.6232
# Test AUC: 0.5336
# Train F1: 0.9886
# 01400: TRAIN| LT=0.777 LP=0.049 LKL=13.484 LPS=0.494 LKLS=9.952 |
# Test F1: 0.7174
# Test ACC: 0.6232
# Test AUC: 0.5243
# Train F1: 0.9829
# 01450: TRAIN| LT=0.789 LP=0.044 LKL=13.581 LPS=0.510 LKLS=9.904 |
# Test F1: 0.6889
# Test ACC: 0.5942
# Test AUC: 0.5241
# Train F1: 0.9830
# 01500: TRAIN| LT=0.756 LP=0.029 LKL=13.653 LPS=0.490 LKLS=10.013 |
# Test F1: 0.7174
# Test ACC: 0.6232
# Test AUC: 0.5200
# Train F1: 0.9943
# 01550: TRAIN| LT=0.795 LP=0.034 LKL=13.715 LPS=0.523 LKLS=10.121 |
# Test F1: 0.7312
# Test ACC: 0.6377
# Test AUC: 0.5325
# Train F1: 0.9915
# 01600: TRAIN| LT=0.740 LP=0.028 LKL=13.750 LPS=0.475 LKLS=9.861 |
# Test F1: 0.7312
# Test ACC: 0.6377
# Test AUC: 0.5332
# Train F1: 0.9858
# 01650: TRAIN| LT=0.748 LP=0.032 LKL=13.622 LPS=0.483 LKLS=9.672 |
# Test F1: 0.7312
# Test ACC: 0.6377
# Test AUC: 0.5443
# Train F1: 0.9831
# 01700: TRAIN| LT=0.698 LP=0.030 LKL=13.689 LPS=0.431 LKLS=9.941 |
# Test F1: 0.6957
# Test ACC: 0.5942
# Test AUC: 0.5334
# Train F1: 0.9742
# 01750: TRAIN| LT=0.706 LP=0.027 LKL=13.460 LPS=0.453 LKLS=9.096 |
# Test F1: 0.6897
# Test ACC: 0.6087
# Test AUC: 0.5443
# Train F1: 0.9915
# 01800: TRAIN| LT=0.732 LP=0.022 LKL=13.605 LPS=0.477 LKLS=9.747 |
# Test F1: 0.7097
# Test ACC: 0.6087
# Test AUC: 0.5409
# Train F1: 0.9859
# 01850: TRAIN| LT=0.804 LP=0.030 LKL=13.592 LPS=0.543 LKLS=9.495 |
# Test F1: 0.7312
# Test ACC: 0.6377
# Test AUC: 0.5527
# Train F1: 0.9858
# 01900: TRAIN| LT=0.710 LP=0.020 LKL=13.600 LPS=0.456 LKLS=9.779 |
# Test F1: 0.6889
# Test ACC: 0.5942
# Test AUC: 0.5550
# Train F1: 0.9886
# 01950: TRAIN| LT=0.798 LP=0.090 LKL=13.365 LPS=0.481 LKLS=9.366 |
# Test F1: 0.6889
# Test ACC: 0.5942
# Test AUC: 0.5489
# Train F1: 0.9831
# 02000: TRAIN| LT=0.718 LP=0.033 LKL=13.436 LPS=0.457 LKLS=9.322 |
# Test F1: 0.7312
# Test ACC: 0.6377
# Test AUC: 0.5384
# f1: 0.7787610619469026
# acc: 0.6376811594202898
# auc: 0.5472727272727272
# Train F1: 0.7615
# 00050: TRAIN| LT=2.042 LP=0.629 LKL=10.721 LPS=1.270 LKLS=3.559 |
# Test F1: 0.7788
# Test ACC: 0.6377
# Test AUC: 0.6918
# Train F1: 0.8729
# 00100: TRAIN| LT=1.663 LP=0.422 LKL=12.013 LPS=1.014 LKLS=10.748 |
# Test F1: 0.6744
# Test ACC: 0.5942
# Test AUC: 0.5891
# Train F1: 0.8839
# 00150: TRAIN| LT=1.460 LP=0.318 LKL=12.290 LPS=0.912 LKLS=10.726 |
# Test F1: 0.7391
# Test ACC: 0.6522
# Test AUC: 0.5645
# Train F1: 0.8994
# 00200: TRAIN| LT=1.348 LP=0.248 LKL=12.555 LPS=0.869 LKLS=10.521 |
# Test F1: 0.6966
# Test ACC: 0.6087
# Test AUC: 0.5500
# Train F1: 0.9200
# 00250: TRAIN| LT=1.325 LP=0.224 LKL=12.602 LPS=0.874 LKLS=10.139 |
# Test F1: 0.6966
# Test ACC: 0.6087
# Test AUC: 0.5527
# Train F1: 0.9049
# 00300: TRAIN| LT=1.302 LP=0.194 LKL=12.806 LPS=0.874 LKLS=10.577 |
# Test F1: 0.6512
# Test ACC: 0.5652
# Test AUC: 0.5509
# Train F1: 0.9398
# 00350: TRAIN| LT=1.240 LP=0.194 LKL=12.811 LPS=0.821 LKLS=9.699 |
# Test F1: 0.6824
# Test ACC: 0.6087
# Test AUC: 0.5755
# Train F1: 0.9521
# 00400: TRAIN| LT=1.134 LP=0.144 LKL=13.069 LPS=0.756 LKLS=10.270 |
# Test F1: 0.7111
# Test ACC: 0.6232
# Test AUC: 0.5718
# Train F1: 0.9388
# 00450: TRAIN| LT=1.237 LP=0.193 LKL=13.301 LPS=0.805 LKLS=10.548 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.5682
# Train F1: 0.9543
# 00500: TRAIN| LT=1.141 LP=0.148 LKL=13.315 LPS=0.755 LKLS=10.420 |
# Test F1: 0.7253
# Test ACC: 0.6377
# Test AUC: 0.5809
# Train F1: 0.9683
# 00550: TRAIN| LT=1.117 LP=0.136 LKL=13.315 LPS=0.744 LKLS=10.355 |
# Test F1: 0.7527
# Test ACC: 0.6667
# Test AUC: 0.6036
# Train F1: 0.9804
# 00600: TRAIN| LT=1.050 LP=0.134 LKL=13.392 LPS=0.676 LKLS=10.629 |
# Test F1: 0.7391
# Test ACC: 0.6522
# Test AUC: 0.6155
# Train F1: 0.9524
# 00650: TRAIN| LT=1.005 LP=0.114 LKL=13.344 LPS=0.658 LKLS=9.967 |
# Test F1: 0.7527
# Test ACC: 0.6667
# Test AUC: 0.6127
# Train F1: 0.9513
# 00700: TRAIN| LT=0.978 LP=0.103 LKL=13.523 LPS=0.635 LKLS=10.594 |
# Test F1: 0.7556
# Test ACC: 0.6812
# Test AUC: 0.6218
# Train F1: 0.9742
# 00750: TRAIN| LT=0.941 LP=0.102 LKL=13.629 LPS=0.595 LKLS=10.669 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.6218
# Train F1: 0.9716
# 00800: TRAIN| LT=1.027 LP=0.129 LKL=13.729 LPS=0.653 LKLS=10.787 |
# Test F1: 0.7609
# Test ACC: 0.6812
# Test AUC: 0.6245
# Train F1: 0.9628
# 00850: TRAIN| LT=0.969 LP=0.089 LKL=13.747 LPS=0.628 LKLS=11.442 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.6173
# Train F1: 0.9602
# 00900: TRAIN| LT=0.978 LP=0.107 LKL=13.612 LPS=0.622 LKLS=11.293 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6273
# Train F1: 0.9719
# 00950: TRAIN| LT=0.960 LP=0.088 LKL=13.656 LPS=0.628 LKLS=10.779 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6155
# Train F1: 0.9830
# 01000: TRAIN| LT=0.929 LP=0.087 LKL=13.570 LPS=0.599 LKLS=10.683 |
# Test F1: 0.7333
# Test ACC: 0.6522
# Test AUC: 0.6264
# Train F1: 0.9716
# 01050: TRAIN| LT=0.906 LP=0.106 LKL=13.614 LPS=0.558 LKLS=10.650 |
# Test F1: 0.7333
# Test ACC: 0.6522
# Test AUC: 0.6209
# Train F1: 0.9831
# 01100: TRAIN| LT=0.854 LP=0.054 LKL=13.741 LPS=0.550 LKLS=11.256 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6291
# Train F1: 0.9655
# 01150: TRAIN| LT=0.846 LP=0.045 LKL=13.707 LPS=0.551 LKLS=11.346 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6255
# Train F1: 0.9748
# 01200: TRAIN| LT=0.885 LP=0.106 LKL=13.575 LPS=0.534 LKLS=10.840 |
# Test F1: 0.7333
# Test ACC: 0.6522
# Test AUC: 0.6218
# Train F1: 0.9745
# 01250: TRAIN| LT=0.819 LP=0.053 LKL=13.740 LPS=0.517 LKLS=11.177 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6255
# Train F1: 0.9771
# 01300: TRAIN| LT=0.828 LP=0.063 LKL=13.709 LPS=0.515 LKLS=11.184 |
# Test F1: 0.7500
# Test ACC: 0.6812
# Test AUC: 0.6173
# Train F1: 0.9857
# 01350: TRAIN| LT=0.859 LP=0.059 LKL=13.748 LPS=0.552 LKLS=11.098 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6209
# Train F1: 0.9716
# 01400: TRAIN| LT=0.920 LP=0.067 LKL=13.678 LPS=0.605 LKLS=11.059 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6236
# Train F1: 0.9745
# 01450: TRAIN| LT=0.775 LP=0.042 LKL=13.827 LPS=0.482 LKLS=11.280 |
# Test F1: 0.7333
# Test ACC: 0.6522
# Test AUC: 0.6209
# Train F1: 0.9745
# 01500: TRAIN| LT=0.805 LP=0.064 LKL=13.847 LPS=0.490 LKLS=11.217 |
# Test F1: 0.7333
# Test ACC: 0.6522
# Test AUC: 0.6191
# Train F1: 0.9858
# 01550: TRAIN| LT=0.829 LP=0.057 LKL=13.707 LPS=0.525 LKLS=10.949 |
# Test F1: 0.7333
# Test ACC: 0.6522
# Test AUC: 0.6218
# Train F1: 0.9773
# 01600: TRAIN| LT=0.786 LP=0.053 LKL=13.520 LPS=0.492 LKLS=10.547 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6045
# Train F1: 0.9830
# 01650: TRAIN| LT=0.773 LP=0.045 LKL=13.632 LPS=0.481 LKLS=11.056 |
# Test F1: 0.7333
# Test ACC: 0.6522
# Test AUC: 0.6245
# Train F1: 0.9773
# 01700: TRAIN| LT=0.838 LP=0.057 LKL=13.534 LPS=0.542 LKLS=10.278 |
# Test F1: 0.7333
# Test ACC: 0.6522
# Test AUC: 0.6082
# Train F1: 0.9802
# 01750: TRAIN| LT=0.826 LP=0.050 LKL=13.685 LPS=0.529 LKLS=11.005 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6100
# Train F1: 0.9886
# 01800: TRAIN| LT=0.752 LP=0.054 LKL=13.534 LPS=0.459 LKLS=10.359 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6245
# Train F1: 0.9858
# 01850: TRAIN| LT=0.766 LP=0.057 LKL=13.755 LPS=0.466 LKLS=10.607 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6155
# Train F1: 0.9858
# 01900: TRAIN| LT=0.795 LP=0.048 LKL=13.669 LPS=0.505 LKLS=10.553 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6155
# Train F1: 0.9661
# 01950: TRAIN| LT=0.794 LP=0.056 LKL=13.517 LPS=0.499 LKLS=10.435 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.6291
# Train F1: 0.9858
# 02000: TRAIN| LT=0.788 LP=0.078 LKL=13.574 LPS=0.470 LKLS=10.420 |
# Test F1: 0.7333
# Test ACC: 0.6522
# Test AUC: 0.6182
# f1: 0.7787610619469026
# acc: 0.6376811594202898
# auc: 0.6918181818181818
# Train F1: 0.7713
# 00050: TRAIN| LT=2.058 LP=0.657 LKL=10.905 LPS=1.258 LKLS=3.466 |
# Test F1: 0.7788
# Test ACC: 0.6377
# Test AUC: 0.5964
# Train F1: 0.8281
# 00100: TRAIN| LT=1.678 LP=0.443 LKL=11.713 LPS=1.025 LKLS=9.213 |
# Test F1: 0.7021
# Test ACC: 0.5942
# Test AUC: 0.5745
# Train F1: 0.8627
# 00150: TRAIN| LT=1.532 LP=0.353 LKL=12.052 LPS=0.960 LKLS=9.828 |
# Test F1: 0.5750
# Test ACC: 0.5072
# Test AUC: 0.5473
# Train F1: 0.8747
# 00200: TRAIN| LT=1.470 LP=0.319 LKL=12.555 LPS=0.921 LKLS=10.465 |
# Test F1: 0.6154
# Test ACC: 0.5652
# Test AUC: 0.5927
# Train F1: 0.8937
# 00250: TRAIN| LT=1.417 LP=0.282 LKL=12.518 LPS=0.913 LKLS=9.682 |
# Test F1: 0.6966
# Test ACC: 0.6087
# Test AUC: 0.5500
# Train F1: 0.9003
# 00300: TRAIN| LT=1.316 LP=0.237 LKL=12.709 LPS=0.854 LKLS=9.745 |
# Test F1: 0.6076
# Test ACC: 0.5507
# Test AUC: 0.5909
# Train F1: 0.9452
# 00350: TRAIN| LT=1.260 LP=0.212 LKL=12.806 LPS=0.823 LKLS=9.644 |
# Test F1: 0.6133
# Test ACC: 0.5797
# Test AUC: 0.5973
# Train F1: 0.9492
# 00400: TRAIN| LT=1.292 LP=0.221 LKL=13.092 LPS=0.844 LKLS=9.623 |
# Test F1: 0.6747
# Test ACC: 0.6087
# Test AUC: 0.5900
# Train F1: 0.9501
# 00450: TRAIN| LT=1.182 LP=0.165 LKL=13.365 LPS=0.778 LKLS=10.483 |
# Test F1: 0.6667
# Test ACC: 0.6232
# Test AUC: 0.5982
# Train F1: 0.9419
# 00500: TRAIN| LT=1.129 LP=0.159 LKL=13.330 LPS=0.736 LKLS=10.057 |
# Test F1: 0.6500
# Test ACC: 0.5942
# Test AUC: 0.5927
# Train F1: 0.9516
# 00550: TRAIN| LT=1.124 LP=0.152 LKL=13.667 LPS=0.732 LKLS=10.441 |
# Test F1: 0.6420
# Test ACC: 0.5797
# Test AUC: 0.5718
# Train F1: 0.9486
# 00600: TRAIN| LT=1.131 LP=0.163 LKL=13.745 LPS=0.725 LKLS=10.502 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.5864
# Train F1: 0.9425
# 00650: TRAIN| LT=1.080 LP=0.141 LKL=13.694 LPS=0.699 LKLS=10.270 |
# Test F1: 0.6250
# Test ACC: 0.5652
# Test AUC: 0.5764
# Train F1: 0.9477
# 00700: TRAIN| LT=1.024 LP=0.115 LKL=13.796 LPS=0.664 LKLS=10.710 |
# Test F1: 0.6420
# Test ACC: 0.5797
# Test AUC: 0.5827
# Train F1: 0.9602
# 00750: TRAIN| LT=1.038 LP=0.140 LKL=13.918 LPS=0.651 LKLS=10.767 |
# Test F1: 0.6905
# Test ACC: 0.6232
# Test AUC: 0.5845
# Train F1: 0.9545
# 00800: TRAIN| LT=0.988 LP=0.105 LKL=13.914 LPS=0.636 LKLS=10.790 |
# Test F1: 0.6966
# Test ACC: 0.6087
# Test AUC: 0.5782
# Train F1: 0.9657
# 00850: TRAIN| LT=0.967 LP=0.090 LKL=13.963 LPS=0.623 LKLS=11.484 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.5845
# Train F1: 0.9714
# 00900: TRAIN| LT=0.931 LP=0.075 LKL=13.811 LPS=0.611 LKLS=10.742 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.5655
# Train F1: 0.9663
# 00950: TRAIN| LT=0.925 LP=0.102 LKL=14.067 LPS=0.571 LKLS=11.177 |
# Test F1: 0.6824
# Test ACC: 0.6087
# Test AUC: 0.5782
# Train F1: 0.9688
# 01000: TRAIN| LT=0.923 LP=0.082 LKL=13.843 LPS=0.592 LKLS=11.063 |
# Test F1: 0.6824
# Test ACC: 0.6087
# Test AUC: 0.5800
# Train F1: 0.9742
# 01050: TRAIN| LT=0.953 LP=0.097 LKL=13.874 LPS=0.611 LKLS=10.543 |
# Test F1: 0.6585
# Test ACC: 0.5942
# Test AUC: 0.5800
# Train F1: 0.9742
# 01100: TRAIN| LT=0.927 LP=0.099 LKL=13.918 LPS=0.577 LKLS=11.188 |
# Test F1: 0.6588
# Test ACC: 0.5797
# Test AUC: 0.5864
# Train F1: 0.9829
# 01150: TRAIN| LT=0.909 LP=0.113 LKL=13.861 LPS=0.546 LKLS=11.065 |
# Test F1: 0.6506
# Test ACC: 0.5797
# Test AUC: 0.5891
# Train F1: 0.9681
# 01200: TRAIN| LT=0.890 LP=0.103 LKL=13.841 LPS=0.540 LKLS=10.948 |
# Test F1: 0.6585
# Test ACC: 0.5942
# Test AUC: 0.5900
# Train F1: 0.9773
# 01250: TRAIN| LT=0.888 LP=0.080 LKL=13.763 LPS=0.562 LKLS=10.790 |
# Test F1: 0.6977
# Test ACC: 0.6232
# Test AUC: 0.5936
# Train F1: 0.9687
# 01300: TRAIN| LT=0.841 LP=0.080 LKL=13.749 LPS=0.515 LKLS=10.827 |
# Test F1: 0.6905
# Test ACC: 0.6232
# Test AUC: 0.6000
# Train F1: 0.9858
# 01350: TRAIN| LT=0.894 LP=0.088 LKL=13.653 LPS=0.562 LKLS=10.753 |
# Test F1: 0.7045
# Test ACC: 0.6232
# Test AUC: 0.5918
# Train F1: 0.9858
# 01400: TRAIN| LT=0.807 LP=0.090 LKL=13.877 LPS=0.471 LKLS=10.777 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.5973
# Train F1: 0.9798
# 01450: TRAIN| LT=0.837 LP=0.067 LKL=13.975 LPS=0.517 LKLS=11.332 |
# Test F1: 0.6977
# Test ACC: 0.6232
# Test AUC: 0.6018
# Train F1: 0.9770
# 01500: TRAIN| LT=0.879 LP=0.062 LKL=13.770 LPS=0.571 LKLS=10.740 |
# Test F1: 0.6897
# Test ACC: 0.6087
# Test AUC: 0.6036
# Train F1: 0.9709
# 01550: TRAIN| LT=0.828 LP=0.054 LKL=13.694 LPS=0.534 LKLS=10.344 |
# Test F1: 0.6824
# Test ACC: 0.6087
# Test AUC: 0.6100
# Train F1: 0.9718
# 01600: TRAIN| LT=0.876 LP=0.093 LKL=13.922 LPS=0.531 LKLS=11.255 |
# Test F1: 0.7191
# Test ACC: 0.6377
# Test AUC: 0.6027
# Train F1: 0.9716
# 01650: TRAIN| LT=0.776 LP=0.060 LKL=13.800 LPS=0.471 LKLS=10.688 |
# Test F1: 0.7126
# Test ACC: 0.6377
# Test AUC: 0.6100
# Train F1: 0.9801
# 01700: TRAIN| LT=0.785 LP=0.080 LKL=13.915 LPS=0.454 LKLS=11.113 |
# Test F1: 0.6747
# Test ACC: 0.6087
# Test AUC: 0.6045
# Train F1: 0.9915
# 01750: TRAIN| LT=0.759 LP=0.052 LKL=13.698 LPS=0.462 LKLS=10.798 |
# Test F1: 0.6829
# Test ACC: 0.6232
# Test AUC: 0.6064
# Train F1: 0.9745
# 01800: TRAIN| LT=0.751 LP=0.051 LKL=13.843 LPS=0.455 LKLS=10.687 |
# Test F1: 0.6977
# Test ACC: 0.6232
# Test AUC: 0.6027
# Train F1: 0.9745
# 01850: TRAIN| LT=0.787 LP=0.071 LKL=13.757 LPS=0.473 LKLS=10.512 |
# Test F1: 0.7143
# Test ACC: 0.6522
# Test AUC: 0.6064
# Train F1: 0.9829
# 01900: TRAIN| LT=0.719 LP=0.069 LKL=13.757 LPS=0.403 LKLS=10.849 |
# Test F1: 0.7209
# Test ACC: 0.6522
# Test AUC: 0.6068
# Train F1: 0.9829
# 01950: TRAIN| LT=0.757 LP=0.073 LKL=13.854 LPS=0.436 LKLS=10.940 |
# Test F1: 0.6905
# Test ACC: 0.6232
# Test AUC: 0.6030
# Train F1: 0.9914
# 02000: TRAIN| LT=0.799 LP=0.082 LKL=13.660 LPS=0.476 LKLS=10.452 |
# Test F1: 0.7126
# Test ACC: 0.6377
# Test AUC: 0.6130
# f1: 0.7787610619469026
# acc: 0.6376811594202898
# auc: 0.5963636363636364
# f1 [0.8043478260869567, 0.7719298245614035, 0.7787610619469026, 0.7787610619469026, 0.7787610619469026]
# average maxf1 0.7825121672978136
# acc [0.7428571428571429, 0.6285714285714286, 0.6376811594202898, 0.6376811594202898, 0.6376811594202898]
# average maxacc 0.6568944099378882
# auc [0.7229020979020979, 0.6424825174825175, 0.5472727272727272, 0.6918181818181818, 0.5963636363636364]
# average maxauc 0.6401678321678321
