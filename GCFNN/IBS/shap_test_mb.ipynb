# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
data_class={'H':0,'C':1,'D':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metabolomics
print('输入各组学数据表：',x1.shape,meta_data.shape)

#重构数据表和标签表
X1 = x1
index_new=X1.index
print(index_new)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,meta_data.shape)
X_set=[X1]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (444, 43) (444, 1)
# Index(['1.T.0', '1.T.1', '1.T.2', '1.T.3', '1.T.4', '1.T.5', '1.T.6', '10.T.0',
#        '10.T.1', '10.T.2',
#        ...
#        '8.T.4', '8.T.5', '8.T.6', '9.T.0', '9.T.1', '9.T.2', '9.T.3', '9.T.4',
#        '9.T.6', '9.T.Flare'],
#       dtype='object', name='Sample', length=444)
# 集合所有样本重构数据表： (444, 43) (444, 1)
# 标签转换为one-hot编码： (444, 2) 139.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap_mb'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 4, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1', f1_cv)
print('average f1: {}±{}'.format(np.mean(f1_cv), np.std(f1_cv)))
print('acc', acc_cv)
print('average acc: {}±{}'.format(np.mean(acc_cv), np.std(acc_cv)))
print('auc', auc_cv)
print('average auc: {}±{}'.format(np.mean(auc_cv), np.std(auc_cv)))
# Out:
# Train F1: 0.8055
# 00050: TRAIN| LT=1.347 LP=0.652 LKL=4.538 LPS=0.647 LKLS=0.219 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4154
# Train F1: 0.8067
# 00100: TRAIN| LT=1.347 LP=0.660 LKL=4.284 LPS=0.643 LKLS=0.195 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4205
# Train F1: 0.8141
# 00150: TRAIN| LT=1.315 LP=0.632 LKL=4.052 LPS=0.639 LKLS=0.302 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4126
# Train F1: 0.8147
# 00200: TRAIN| LT=1.290 LP=0.625 LKL=3.988 LPS=0.623 LKLS=0.330 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4319
# Train F1: 0.8147
# 00250: TRAIN| LT=1.317 LP=0.640 LKL=3.939 LPS=0.633 LKLS=0.365 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4464
# Train F1: 0.8147
# 00300: TRAIN| LT=1.292 LP=0.626 LKL=3.900 LPS=0.623 LKLS=0.386 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4293
# Train F1: 0.8147
# 00350: TRAIN| LT=1.294 LP=0.623 LKL=3.891 LPS=0.628 LKLS=0.393 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4300
# Train F1: 0.8147
# 00400: TRAIN| LT=1.299 LP=0.623 LKL=3.881 LPS=0.633 LKLS=0.402 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4230
# Train F1: 0.8147
# 00450: TRAIN| LT=1.292 LP=0.630 LKL=3.844 LPS=0.620 LKLS=0.424 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4855
# Train F1: 0.8147
# 00500: TRAIN| LT=1.302 LP=0.634 LKL=3.882 LPS=0.625 LKLS=0.388 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4918
# Train F1: 0.8147
# 00550: TRAIN| LT=1.278 LP=0.621 LKL=3.822 LPS=0.614 LKLS=0.445 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4608
# Train F1: 0.8147
# 00600: TRAIN| LT=1.294 LP=0.626 LKL=3.844 LPS=0.625 LKLS=0.425 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4479
# Train F1: 0.8147
# 00650: TRAIN| LT=1.308 LP=0.637 LKL=3.844 LPS=0.629 LKLS=0.423 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4696
# Train F1: 0.8147
# 00700: TRAIN| LT=1.289 LP=0.627 LKL=3.849 LPS=0.619 LKLS=0.418 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4666
# Train F1: 0.8147
# 00750: TRAIN| LT=1.288 LP=0.625 LKL=3.821 LPS=0.620 LKLS=0.448 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5174
# Train F1: 0.8147
# 00800: TRAIN| LT=1.281 LP=0.615 LKL=3.833 LPS=0.624 LKLS=0.427 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5458
# Train F1: 0.8147
# 00850: TRAIN| LT=1.288 LP=0.627 LKL=3.793 LPS=0.619 LKLS=0.473 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5918
# Train F1: 0.8147
# 00900: TRAIN| LT=1.293 LP=0.624 LKL=3.814 LPS=0.627 LKLS=0.448 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5367
# Train F1: 0.8147
# 00950: TRAIN| LT=1.287 LP=0.619 LKL=3.831 LPS=0.625 LKLS=0.427 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5136
# Train F1: 0.8147
# 01000: TRAIN| LT=1.291 LP=0.627 LKL=3.811 LPS=0.622 LKLS=0.451 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5177
# Train F1: 0.8147
# 01050: TRAIN| LT=1.290 LP=0.625 LKL=3.788 LPS=0.623 LKLS=0.472 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5180
# Train F1: 0.8147
# 01100: TRAIN| LT=1.289 LP=0.623 LKL=3.800 LPS=0.623 LKLS=0.452 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5053
# Train F1: 0.8147
# 01150: TRAIN| LT=1.293 LP=0.626 LKL=3.798 LPS=0.625 LKLS=0.455 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5072
# Train F1: 0.8147
# 01200: TRAIN| LT=1.287 LP=0.618 LKL=3.809 LPS=0.626 LKLS=0.443 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5284
# Train F1: 0.8147
# 01250: TRAIN| LT=1.294 LP=0.626 LKL=3.819 LPS=0.625 LKLS=0.435 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5321
# Train F1: 0.8147
# 01300: TRAIN| LT=1.288 LP=0.619 LKL=3.807 LPS=0.626 LKLS=0.446 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5110
# Train F1: 0.8147
# 01350: TRAIN| LT=1.288 LP=0.622 LKL=3.794 LPS=0.623 LKLS=0.460 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4665
# Train F1: 0.8147
# 01400: TRAIN| LT=1.285 LP=0.618 LKL=3.797 LPS=0.624 LKLS=0.454 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4776
# Train F1: 0.8147
# 01450: TRAIN| LT=1.290 LP=0.627 LKL=3.806 LPS=0.621 LKLS=0.456 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5123
# Train F1: 0.8147
# 01500: TRAIN| LT=1.284 LP=0.619 LKL=3.836 LPS=0.623 LKLS=0.417 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5160
# Train F1: 0.8147
# 01550: TRAIN| LT=1.283 LP=0.621 LKL=3.783 LPS=0.619 LKLS=0.468 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5735
# Train F1: 0.8147
# 01600: TRAIN| LT=1.288 LP=0.623 LKL=3.797 LPS=0.622 LKLS=0.455 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5439
# Train F1: 0.8147
# 01650: TRAIN| LT=1.281 LP=0.619 LKL=3.799 LPS=0.620 LKLS=0.451 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5518
# Train F1: 0.8147
# 01700: TRAIN| LT=1.286 LP=0.619 LKL=3.790 LPS=0.624 LKLS=0.459 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5395
# Train F1: 0.8147
# 01750: TRAIN| LT=1.289 LP=0.621 LKL=3.785 LPS=0.625 LKLS=0.462 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5016
# Train F1: 0.8147
# 01800: TRAIN| LT=1.285 LP=0.622 LKL=3.815 LPS=0.621 LKLS=0.436 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4641
# Train F1: 0.8147
# 01850: TRAIN| LT=1.284 LP=0.620 LKL=3.793 LPS=0.622 LKLS=0.456 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4718
# Train F1: 0.8147
# 01900: TRAIN| LT=1.281 LP=0.618 LKL=3.789 LPS=0.620 LKLS=0.460 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4482
# Train F1: 0.8147
# 01950: TRAIN| LT=1.283 LP=0.620 LKL=3.796 LPS=0.621 LKLS=0.451 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4568
# Train F1: 0.8147
# 02000: TRAIN| LT=1.289 LP=0.624 LKL=3.781 LPS=0.622 LKLS=0.468 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4734
# f1: 0.8133333333333332
# acc: 0.6853932584269663
# auc: 0.5917740046838408
# Train F1: 0.8114
# 00050: TRAIN| LT=1.336 LP=0.636 LKL=4.549 LPS=0.653 LKLS=0.199 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5924
# Train F1: 0.8147
# 00100: TRAIN| LT=1.300 LP=0.629 LKL=4.335 LPS=0.627 LKLS=0.174 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5823
# Train F1: 0.8127
# 00150: TRAIN| LT=1.312 LP=0.632 LKL=4.135 LPS=0.637 LKLS=0.247 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5849
# Train F1: 0.8147
# 00200: TRAIN| LT=1.303 LP=0.627 LKL=4.048 LPS=0.634 LKLS=0.286 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5792
# Train F1: 0.8127
# 00250: TRAIN| LT=1.312 LP=0.630 LKL=3.966 LPS=0.640 LKLS=0.344 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5814
# Train F1: 0.8147
# 00300: TRAIN| LT=1.310 LP=0.629 LKL=3.939 LPS=0.638 LKLS=0.353 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5798
# Train F1: 0.8147
# 00350: TRAIN| LT=1.293 LP=0.623 LKL=3.924 LPS=0.627 LKLS=0.359 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.6020
# Train F1: 0.8147
# 00400: TRAIN| LT=1.304 LP=0.630 LKL=3.885 LPS=0.630 LKLS=0.388 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5517
# Train F1: 0.8147
# 00450: TRAIN| LT=1.287 LP=0.623 LKL=3.867 LPS=0.621 LKLS=0.405 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5357
# Train F1: 0.8147
# 00500: TRAIN| LT=1.294 LP=0.630 LKL=3.876 LPS=0.621 LKLS=0.394 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4775
# Train F1: 0.8147
# 00550: TRAIN| LT=1.287 LP=0.625 LKL=3.855 LPS=0.619 LKLS=0.410 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4819
# Train F1: 0.8147
# 00600: TRAIN| LT=1.290 LP=0.624 LKL=3.842 LPS=0.624 LKLS=0.421 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5383
# Train F1: 0.8147
# 00650: TRAIN| LT=1.302 LP=0.626 LKL=3.840 LPS=0.633 LKLS=0.427 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5381
# Train F1: 0.8147
# 00700: TRAIN| LT=1.292 LP=0.628 LKL=3.851 LPS=0.621 LKLS=0.415 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4778
# Train F1: 0.8147
# 00750: TRAIN| LT=1.285 LP=0.622 LKL=3.839 LPS=0.620 LKLS=0.424 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.6048
# Train F1: 0.8147
# 00800: TRAIN| LT=1.304 LP=0.633 LKL=3.827 LPS=0.629 LKLS=0.434 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4540
# Train F1: 0.8147
# 00850: TRAIN| LT=1.281 LP=0.618 LKL=3.799 LPS=0.621 LKLS=0.462 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4359
# Train F1: 0.8147
# 00900: TRAIN| LT=1.285 LP=0.624 LKL=3.793 LPS=0.617 LKLS=0.471 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4482
# Train F1: 0.8147
# 00950: TRAIN| LT=1.286 LP=0.622 LKL=3.827 LPS=0.622 LKLS=0.434 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4153
# Train F1: 0.8147
# 01000: TRAIN| LT=1.289 LP=0.623 LKL=3.821 LPS=0.624 LKLS=0.444 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4513
# Train F1: 0.8147
# 01050: TRAIN| LT=1.282 LP=0.619 LKL=3.821 LPS=0.620 LKLS=0.439 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4776
# Train F1: 0.8147
# 01100: TRAIN| LT=1.284 LP=0.622 LKL=3.813 LPS=0.620 LKLS=0.444 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4877
# Train F1: 0.8147
# 01150: TRAIN| LT=1.288 LP=0.622 LKL=3.803 LPS=0.623 LKLS=0.455 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4492
# Train F1: 0.8147
# 01200: TRAIN| LT=1.287 LP=0.621 LKL=3.805 LPS=0.624 LKLS=0.449 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4224
# Train F1: 0.8147
# 01250: TRAIN| LT=1.290 LP=0.624 LKL=3.814 LPS=0.623 LKLS=0.451 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4261
# Train F1: 0.8147
# 01300: TRAIN| LT=1.290 LP=0.621 LKL=3.833 LPS=0.626 LKLS=0.424 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4556
# Train F1: 0.8147
# 01350: TRAIN| LT=1.286 LP=0.621 LKL=3.798 LPS=0.623 LKLS=0.474 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4862
# Train F1: 0.8147
# 01400: TRAIN| LT=1.282 LP=0.623 LKL=3.811 LPS=0.616 LKLS=0.443 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4608
# Train F1: 0.8147
# 01450: TRAIN| LT=1.287 LP=0.620 LKL=3.796 LPS=0.624 LKLS=0.460 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4135
# Train F1: 0.8147
# 01500: TRAIN| LT=1.288 LP=0.622 LKL=3.794 LPS=0.623 LKLS=0.463 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4618
# Train F1: 0.8147
# 01550: TRAIN| LT=1.292 LP=0.625 LKL=3.812 LPS=0.624 LKLS=0.446 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5061
# Train F1: 0.8147
# 01600: TRAIN| LT=1.287 LP=0.624 LKL=3.788 LPS=0.620 LKLS=0.477 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4390
# Train F1: 0.8147
# 01650: TRAIN| LT=1.286 LP=0.623 LKL=3.809 LPS=0.621 LKLS=0.450 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4502
# Train F1: 0.8147
# 01700: TRAIN| LT=1.279 LP=0.618 LKL=3.797 LPS=0.618 LKLS=0.461 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4537
# Train F1: 0.8147
# 01750: TRAIN| LT=1.287 LP=0.621 LKL=3.795 LPS=0.624 LKLS=0.462 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4344
# Train F1: 0.8147
# 01800: TRAIN| LT=1.288 LP=0.621 LKL=3.796 LPS=0.624 LKLS=0.457 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4422
# Train F1: 0.8147
# 01850: TRAIN| LT=1.283 LP=0.620 LKL=3.796 LPS=0.621 LKLS=0.465 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4264
# Train F1: 0.8147
# 01900: TRAIN| LT=1.286 LP=0.619 LKL=3.786 LPS=0.625 LKLS=0.467 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4267
# Train F1: 0.8147
# 01950: TRAIN| LT=1.282 LP=0.621 LKL=3.767 LPS=0.619 LKLS=0.484 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4603
# Train F1: 0.8147
# 02000: TRAIN| LT=1.287 LP=0.622 LKL=3.779 LPS=0.623 LKLS=0.470 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4355
# f1: 0.8133333333333332
# acc: 0.6853932584269663
# auc: 0.6048009367681499
# Train F1: 0.8041
# 00050: TRAIN| LT=1.323 LP=0.654 LKL=4.512 LPS=0.621 LKLS=0.275 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5199
# Train F1: 0.8141
# 00100: TRAIN| LT=1.325 LP=0.631 LKL=4.334 LPS=0.649 LKLS=0.212 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5151
# Train F1: 0.8147
# 00150: TRAIN| LT=1.313 LP=0.634 LKL=4.142 LPS=0.634 LKLS=0.273 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4981
# Train F1: 0.8147
# 00200: TRAIN| LT=1.301 LP=0.618 LKL=4.055 LPS=0.639 LKLS=0.289 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4969
# Train F1: 0.8127
# 00250: TRAIN| LT=1.288 LP=0.623 LKL=3.973 LPS=0.623 LKLS=0.341 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4915
# Train F1: 0.8147
# 00300: TRAIN| LT=1.295 LP=0.621 LKL=3.965 LPS=0.632 LKLS=0.339 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4325
# Train F1: 0.8147
# 00350: TRAIN| LT=1.294 LP=0.631 LKL=3.922 LPS=0.621 LKLS=0.365 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5040
# Train F1: 0.8147
# 00400: TRAIN| LT=1.306 LP=0.628 LKL=3.891 LPS=0.635 LKLS=0.392 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4508
# Train F1: 0.8147
# 00450: TRAIN| LT=1.309 LP=0.632 LKL=3.881 LPS=0.635 LKLS=0.395 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4570
# Train F1: 0.8147
# 00500: TRAIN| LT=1.301 LP=0.628 LKL=3.854 LPS=0.630 LKLS=0.417 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4886
# Train F1: 0.8147
# 00550: TRAIN| LT=1.279 LP=0.623 LKL=3.855 LPS=0.613 LKLS=0.412 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4647
# Train F1: 0.8147
# 00600: TRAIN| LT=1.288 LP=0.619 LKL=3.861 LPS=0.626 LKLS=0.408 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4794
# Train F1: 0.8147
# 00650: TRAIN| LT=1.299 LP=0.625 LKL=3.828 LPS=0.631 LKLS=0.432 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4827
# Train F1: 0.8147
# 00700: TRAIN| LT=1.299 LP=0.627 LKL=3.837 LPS=0.628 LKLS=0.426 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4832
# Train F1: 0.8147
# 00750: TRAIN| LT=1.297 LP=0.628 LKL=3.825 LPS=0.627 LKLS=0.438 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4890
# Train F1: 0.8147
# 00800: TRAIN| LT=1.286 LP=0.630 LKL=3.819 LPS=0.614 LKLS=0.439 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4713
# Train F1: 0.8147
# 00850: TRAIN| LT=1.292 LP=0.625 LKL=3.840 LPS=0.625 LKLS=0.420 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4772
# Train F1: 0.8147
# 00900: TRAIN| LT=1.300 LP=0.627 LKL=3.816 LPS=0.630 LKLS=0.445 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4924
# Train F1: 0.8147
# 00950: TRAIN| LT=1.284 LP=0.620 LKL=3.809 LPS=0.622 LKLS=0.449 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4893
# Train F1: 0.8147
# 01000: TRAIN| LT=1.291 LP=0.621 LKL=3.816 LPS=0.627 LKLS=0.437 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4772
# Train F1: 0.8147
# 01050: TRAIN| LT=1.286 LP=0.622 LKL=3.824 LPS=0.622 LKLS=0.431 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4836
# Train F1: 0.8147
# 01100: TRAIN| LT=1.290 LP=0.621 LKL=3.817 LPS=0.627 LKLS=0.435 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4772
# Train F1: 0.8147
# 01150: TRAIN| LT=1.289 LP=0.619 LKL=3.827 LPS=0.627 LKLS=0.431 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4741
# Train F1: 0.8147
# 01200: TRAIN| LT=1.280 LP=0.617 LKL=3.810 LPS=0.620 LKLS=0.449 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4586
# Train F1: 0.8147
# 01250: TRAIN| LT=1.281 LP=0.622 LKL=3.826 LPS=0.617 LKLS=0.432 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4634
# Train F1: 0.8147
# 01300: TRAIN| LT=1.284 LP=0.618 LKL=3.802 LPS=0.623 LKLS=0.455 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4922
# Train F1: 0.8147
# 01350: TRAIN| LT=1.290 LP=0.628 LKL=3.802 LPS=0.619 LKLS=0.451 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4835
# Train F1: 0.8147
# 01400: TRAIN| LT=1.283 LP=0.621 LKL=3.797 LPS=0.620 LKLS=0.454 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4830
# Train F1: 0.8147
# 01450: TRAIN| LT=1.290 LP=0.622 LKL=3.784 LPS=0.624 LKLS=0.477 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4662
# Train F1: 0.8147
# 01500: TRAIN| LT=1.288 LP=0.622 LKL=3.802 LPS=0.624 LKLS=0.450 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4816
# Train F1: 0.8147
# 01550: TRAIN| LT=1.283 LP=0.624 LKL=3.805 LPS=0.616 LKLS=0.448 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4788
# Train F1: 0.8147
# 01600: TRAIN| LT=1.296 LP=0.628 LKL=3.817 LPS=0.625 LKLS=0.434 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4892
# Train F1: 0.8147
# 01650: TRAIN| LT=1.278 LP=0.620 LKL=3.808 LPS=0.615 LKLS=0.445 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4919
# Train F1: 0.8147
# 01700: TRAIN| LT=1.290 LP=0.618 LKL=3.813 LPS=0.629 LKLS=0.440 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4855
# Train F1: 0.8147
# 01750: TRAIN| LT=1.293 LP=0.621 LKL=3.793 LPS=0.629 LKLS=0.458 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4861
# Train F1: 0.8147
# 01800: TRAIN| LT=1.283 LP=0.620 LKL=3.780 LPS=0.620 LKLS=0.475 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4861
# Train F1: 0.8147
# 01850: TRAIN| LT=1.289 LP=0.623 LKL=3.783 LPS=0.623 LKLS=0.475 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4832
# Train F1: 0.8147
# 01900: TRAIN| LT=1.297 LP=0.624 LKL=3.817 LPS=0.630 LKLS=0.430 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4858
# Train F1: 0.8147
# 01950: TRAIN| LT=1.287 LP=0.622 LKL=3.799 LPS=0.622 LKLS=0.451 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4627
# Train F1: 0.8147
# 02000: TRAIN| LT=1.283 LP=0.622 LKL=3.809 LPS=0.618 LKLS=0.440 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4928
# f1: 0.8133333333333332
# acc: 0.6853932584269663
# auc: 0.5199063231850116
# Train F1: 0.8048
# 00050: TRAIN| LT=1.344 LP=0.649 LKL=4.569 LPS=0.646 LKLS=0.295 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4393
# Train F1: 0.8147
# 00100: TRAIN| LT=1.295 LP=0.636 LKL=4.360 LPS=0.614 LKLS=0.195 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4391
# Train F1: 0.8127
# 00150: TRAIN| LT=1.316 LP=0.641 LKL=4.135 LPS=0.630 LKLS=0.282 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4325
# Train F1: 0.8127
# 00200: TRAIN| LT=1.291 LP=0.626 LKL=4.032 LPS=0.621 LKLS=0.315 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4246
# Train F1: 0.8147
# 00250: TRAIN| LT=1.306 LP=0.631 LKL=3.988 LPS=0.632 LKLS=0.333 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5076
# Train F1: 0.8127
# 00300: TRAIN| LT=1.282 LP=0.621 LKL=3.956 LPS=0.619 LKLS=0.342 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5130
# Train F1: 0.8147
# 00350: TRAIN| LT=1.302 LP=0.627 LKL=3.899 LPS=0.633 LKLS=0.391 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4079
# Train F1: 0.8147
# 00400: TRAIN| LT=1.298 LP=0.625 LKL=3.885 LPS=0.630 LKLS=0.397 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4259
# Train F1: 0.8147
# 00450: TRAIN| LT=1.288 LP=0.620 LKL=3.878 LPS=0.626 LKLS=0.401 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4477
# Train F1: 0.8147
# 00500: TRAIN| LT=1.296 LP=0.626 LKL=3.865 LPS=0.628 LKLS=0.410 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4274
# Train F1: 0.8147
# 00550: TRAIN| LT=1.285 LP=0.625 LKL=3.872 LPS=0.617 LKLS=0.402 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4262
# Train F1: 0.8147
# 00600: TRAIN| LT=1.296 LP=0.629 LKL=3.860 LPS=0.625 LKLS=0.411 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4264
# Train F1: 0.8147
# 00650: TRAIN| LT=1.293 LP=0.628 LKL=3.822 LPS=0.622 LKLS=0.444 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5252
# Train F1: 0.8147
# 00700: TRAIN| LT=1.289 LP=0.632 LKL=3.854 LPS=0.615 LKLS=0.415 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4297
# Train F1: 0.8147
# 00750: TRAIN| LT=1.288 LP=0.625 LKL=3.824 LPS=0.620 LKLS=0.441 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5206
# Train F1: 0.8147
# 00800: TRAIN| LT=1.289 LP=0.626 LKL=3.826 LPS=0.621 LKLS=0.443 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.5170
# Train F1: 0.8147
# 00850: TRAIN| LT=1.284 LP=0.620 LKL=3.834 LPS=0.621 LKLS=0.433 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4576
# Train F1: 0.8147
# 00900: TRAIN| LT=1.289 LP=0.625 LKL=3.839 LPS=0.621 LKLS=0.425 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4505
# Train F1: 0.8147
# 00950: TRAIN| LT=1.289 LP=0.632 LKL=3.810 LPS=0.615 LKLS=0.452 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4409
# Train F1: 0.8147
# 01000: TRAIN| LT=1.291 LP=0.625 LKL=3.814 LPS=0.623 LKLS=0.450 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4356
# Train F1: 0.8147
# 01050: TRAIN| LT=1.293 LP=0.630 LKL=3.807 LPS=0.621 LKLS=0.451 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4407
# Train F1: 0.8147
# 01100: TRAIN| LT=1.291 LP=0.624 LKL=3.815 LPS=0.624 LKLS=0.443 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4375
# Train F1: 0.8147
# 01150: TRAIN| LT=1.294 LP=0.628 LKL=3.806 LPS=0.623 LKLS=0.454 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4415
# Train F1: 0.8147
# 01200: TRAIN| LT=1.288 LP=0.622 LKL=3.818 LPS=0.623 LKLS=0.439 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4482
# Train F1: 0.8147
# 01250: TRAIN| LT=1.291 LP=0.624 LKL=3.814 LPS=0.625 LKLS=0.444 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4526
# Train F1: 0.8147
# 01300: TRAIN| LT=1.285 LP=0.625 LKL=3.803 LPS=0.617 LKLS=0.455 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4416
# Train F1: 0.8147
# 01350: TRAIN| LT=1.291 LP=0.624 LKL=3.809 LPS=0.624 LKLS=0.445 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4403
# Train F1: 0.8147
# 01400: TRAIN| LT=1.292 LP=0.624 LKL=3.793 LPS=0.625 LKLS=0.460 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4376
# Train F1: 0.8147
# 01450: TRAIN| LT=1.285 LP=0.622 LKL=3.793 LPS=0.620 LKLS=0.462 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4025
# Train F1: 0.8147
# 01500: TRAIN| LT=1.292 LP=0.623 LKL=3.806 LPS=0.627 LKLS=0.446 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4174
# Train F1: 0.8147
# 01550: TRAIN| LT=1.284 LP=0.621 LKL=3.810 LPS=0.621 LKLS=0.443 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4038
# Train F1: 0.8147
# 01600: TRAIN| LT=1.291 LP=0.621 LKL=3.790 LPS=0.627 LKLS=0.464 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4185
# Train F1: 0.8147
# 01650: TRAIN| LT=1.285 LP=0.623 LKL=3.797 LPS=0.620 LKLS=0.454 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4220
# Train F1: 0.8147
# 01700: TRAIN| LT=1.282 LP=0.623 LKL=3.789 LPS=0.617 LKLS=0.462 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4088
# Train F1: 0.8147
# 01750: TRAIN| LT=1.292 LP=0.630 LKL=3.804 LPS=0.619 LKLS=0.447 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4220
# Train F1: 0.8147
# 01800: TRAIN| LT=1.285 LP=0.621 LKL=3.787 LPS=0.622 LKLS=0.462 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4268
# Train F1: 0.8147
# 01850: TRAIN| LT=1.287 LP=0.620 LKL=3.809 LPS=0.624 LKLS=0.440 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4286
# Train F1: 0.8147
# 01900: TRAIN| LT=1.286 LP=0.622 LKL=3.800 LPS=0.621 LKLS=0.450 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4425
# Train F1: 0.8147
# 01950: TRAIN| LT=1.289 LP=0.624 LKL=3.779 LPS=0.622 LKLS=0.470 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4766
# Train F1: 0.8147
# 02000: TRAIN| LT=1.286 LP=0.620 LKL=3.807 LPS=0.624 LKLS=0.440 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.4343
# f1: 0.8133333333333332
# acc: 0.6853932584269663
# auc: 0.525175644028103
# Train F1: 0.8068
# 00050: TRAIN| LT=1.317 LP=0.634 LKL=4.491 LPS=0.634 LKLS=0.404 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5425
# Train F1: 0.8127
# 00100: TRAIN| LT=1.325 LP=0.647 LKL=4.275 LPS=0.632 LKLS=0.261 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5537
# Train F1: 0.8147
# 00150: TRAIN| LT=1.311 LP=0.629 LKL=4.116 LPS=0.638 LKLS=0.277 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5332
# Train F1: 0.8133
# 00200: TRAIN| LT=1.300 LP=0.627 LKL=4.014 LPS=0.630 LKLS=0.316 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.6158
# Train F1: 0.8133
# 00250: TRAIN| LT=1.299 LP=0.622 LKL=3.967 LPS=0.633 LKLS=0.346 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5679
# Train F1: 0.8133
# 00300: TRAIN| LT=1.298 LP=0.631 LKL=3.928 LPS=0.624 LKLS=0.365 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5322
# Train F1: 0.8147
# 00350: TRAIN| LT=1.298 LP=0.623 LKL=3.927 LPS=0.632 LKLS=0.358 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5175
# Train F1: 0.8133
# 00400: TRAIN| LT=1.299 LP=0.631 LKL=3.872 LPS=0.626 LKLS=0.405 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5373
# Train F1: 0.8133
# 00450: TRAIN| LT=1.303 LP=0.632 LKL=3.863 LPS=0.628 LKLS=0.406 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5592
# Train F1: 0.8133
# 00500: TRAIN| LT=1.312 LP=0.633 LKL=3.834 LPS=0.636 LKLS=0.436 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5175
# Train F1: 0.8133
# 00550: TRAIN| LT=1.311 LP=0.640 LKL=3.841 LPS=0.628 LKLS=0.426 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5209
# Train F1: 0.8133
# 00600: TRAIN| LT=1.302 LP=0.625 LKL=3.844 LPS=0.634 LKLS=0.421 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5305
# Train F1: 0.8133
# 00650: TRAIN| LT=1.301 LP=0.624 LKL=3.850 LPS=0.634 LKLS=0.413 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5106
# Train F1: 0.8133
# 00700: TRAIN| LT=1.296 LP=0.623 LKL=3.834 LPS=0.630 LKLS=0.429 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.4605
# Train F1: 0.8133
# 00750: TRAIN| LT=1.292 LP=0.623 LKL=3.828 LPS=0.626 LKLS=0.432 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5320
# Train F1: 0.8133
# 00800: TRAIN| LT=1.298 LP=0.629 LKL=3.818 LPS=0.626 LKLS=0.442 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5329
# Train F1: 0.8133
# 00850: TRAIN| LT=1.291 LP=0.625 LKL=3.825 LPS=0.623 LKLS=0.432 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5546
# Train F1: 0.8133
# 00900: TRAIN| LT=1.289 LP=0.624 LKL=3.835 LPS=0.622 LKLS=0.424 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5468
# Train F1: 0.8133
# 00950: TRAIN| LT=1.285 LP=0.621 LKL=3.813 LPS=0.621 LKLS=0.444 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.4892
# Train F1: 0.8133
# 01000: TRAIN| LT=1.288 LP=0.624 LKL=3.825 LPS=0.621 LKLS=0.432 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5466
# Train F1: 0.8133
# 01050: TRAIN| LT=1.301 LP=0.625 LKL=3.829 LPS=0.633 LKLS=0.427 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5392
# Train F1: 0.8133
# 01100: TRAIN| LT=1.291 LP=0.624 LKL=3.821 LPS=0.624 LKLS=0.434 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5367
# Train F1: 0.8133
# 01150: TRAIN| LT=1.291 LP=0.621 LKL=3.826 LPS=0.628 LKLS=0.430 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5361
# Train F1: 0.8133
# 01200: TRAIN| LT=1.295 LP=0.625 LKL=3.821 LPS=0.627 LKLS=0.433 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5498
# Train F1: 0.8133
# 01250: TRAIN| LT=1.290 LP=0.625 LKL=3.794 LPS=0.622 LKLS=0.458 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5723
# Train F1: 0.8133
# 01300: TRAIN| LT=1.291 LP=0.622 LKL=3.797 LPS=0.626 LKLS=0.457 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5080
# Train F1: 0.8133
# 01350: TRAIN| LT=1.300 LP=0.628 LKL=3.810 LPS=0.629 LKLS=0.451 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5903
# Train F1: 0.8133
# 01400: TRAIN| LT=1.285 LP=0.624 LKL=3.797 LPS=0.618 LKLS=0.456 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.4765
# Train F1: 0.8133
# 01450: TRAIN| LT=1.288 LP=0.621 LKL=3.806 LPS=0.624 LKLS=0.448 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.4865
# Train F1: 0.8133
# 01500: TRAIN| LT=1.290 LP=0.624 LKL=3.798 LPS=0.623 LKLS=0.456 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5448
# Train F1: 0.8133
# 01550: TRAIN| LT=1.289 LP=0.624 LKL=3.815 LPS=0.623 LKLS=0.444 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.4778
# Train F1: 0.8133
# 01600: TRAIN| LT=1.291 LP=0.622 LKL=3.804 LPS=0.627 LKLS=0.450 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.4589
# Train F1: 0.8133
# 01650: TRAIN| LT=1.286 LP=0.625 LKL=3.800 LPS=0.619 LKLS=0.452 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5046
# Train F1: 0.8133
# 01700: TRAIN| LT=1.292 LP=0.622 LKL=3.813 LPS=0.627 LKLS=0.437 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.4944
# Train F1: 0.8133
# 01750: TRAIN| LT=1.293 LP=0.628 LKL=3.799 LPS=0.623 LKLS=0.454 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.4828
# Train F1: 0.8133
# 01800: TRAIN| LT=1.291 LP=0.622 LKL=3.815 LPS=0.627 LKLS=0.433 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5639
# Train F1: 0.8133
# 01850: TRAIN| LT=1.290 LP=0.625 LKL=3.806 LPS=0.623 LKLS=0.443 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5253
# Train F1: 0.8133
# 01900: TRAIN| LT=1.290 LP=0.623 LKL=3.788 LPS=0.624 LKLS=0.461 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5888
# Train F1: 0.8133
# 01950: TRAIN| LT=1.291 LP=0.623 LKL=3.809 LPS=0.625 LKLS=0.443 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.5431
# Train F1: 0.8133
# 02000: TRAIN| LT=1.289 LP=0.623 LKL=3.785 LPS=0.624 LKLS=0.462 |
# Test F1: 0.8188
# Test ACC: 0.6932
# Test AUC: 0.4903
# f1: 0.8187919463087248
# acc: 0.6931818181818182
# auc: 0.6158166363084396
# f1 [0.8133333333333332, 0.8133333333333332, 0.8133333333333332, 0.8133333333333332, 0.8187919463087248]
# average f1: 0.8144250559284115±0.002183445190156608
# acc [0.6853932584269663, 0.6853932584269663, 0.6853932584269663, 0.6853932584269663, 0.6931818181818182]
# average acc: 0.6869509703779367±0.0031154239019407725
# auc [0.5917740046838408, 0.6048009367681499, 0.5199063231850116, 0.525175644028103, 0.6158166363084396]
# average auc: 0.571494708994709±0.04072297929370601
