# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'H':0,'C':1,'D':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (444, 1034) (444, 43) (444, 1)
# Index(['1.T.0', '1.T.1', '1.T.2', '1.T.3', '1.T.4', '1.T.5', '1.T.6', '10.T.0',
#        '10.T.1', '10.T.2',
#        ...
#        '8.T.4', '8.T.5', '8.T.6', '9.T.0', '9.T.1', '9.T.2', '9.T.3', '9.T.4',
#        '9.T.6', '9.T.Flare'],
#       dtype='object', name='Sample', length=444)
# 数据完整率missing_rate : 1.0
# 集合所有样本重构数据表： (444, 1034) (444, 43) (444, 1)
# 标签转换为one-hot编码： (444, 2) 139.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 4, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1',f1_cv)
print('average maxf1',sum(f1_cv)/5)
print('acc',acc_cv)
print('average maxacc',sum(acc_cv)/5)
print('auc',auc_cv)
print('average maxauc',sum(auc_cv)/5)
# Out:
# Train F1: 0.9501
# 00050: TRAIN| LT=1.382 LP=0.322 LKL=13.330 LPS=0.779 LKLS=14.807 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9766
# Train F1: 0.9756
# 00100: TRAIN| LT=1.060 LP=0.105 LKL=12.931 LPS=0.703 LKLS=12.329 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9883
# Train F1: 0.9814
# 00150: TRAIN| LT=1.045 LP=0.122 LKL=12.366 LPS=0.702 LKLS=9.760 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9906
# Train F1: 0.9835
# 00200: TRAIN| LT=0.963 LP=0.080 LKL=11.993 LPS=0.681 LKLS=8.199 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9930
# Train F1: 0.9837
# 00250: TRAIN| LT=0.963 LP=0.077 LKL=12.105 LPS=0.682 LKLS=8.263 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9930
# Train F1: 0.9980
# 00300: TRAIN| LT=0.935 LP=0.060 LKL=11.979 LPS=0.674 LKLS=8.138 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9918
# Train F1: 0.9898
# 00350: TRAIN| LT=0.956 LP=0.093 LKL=11.995 LPS=0.669 LKLS=7.341 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9906
# Train F1: 0.9857
# 00400: TRAIN| LT=0.941 LP=0.069 LKL=12.010 LPS=0.675 LKLS=7.621 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9918
# Train F1: 0.9878
# 00450: TRAIN| LT=0.917 LP=0.050 LKL=12.066 LPS=0.669 LKLS=7.780 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9883
# Train F1: 0.9793
# 00500: TRAIN| LT=0.929 LP=0.083 LKL=12.055 LPS=0.652 LKLS=7.336 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9918
# Train F1: 0.9878
# 00550: TRAIN| LT=0.897 LP=0.051 LKL=11.782 LPS=0.659 LKLS=6.833 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9912
# Train F1: 0.9918
# 00600: TRAIN| LT=0.899 LP=0.041 LKL=11.989 LPS=0.668 LKLS=7.036 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9924
# Train F1: 0.9918
# 00650: TRAIN| LT=0.887 LP=0.051 LKL=11.814 LPS=0.649 LKLS=6.847 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9900
# Train F1: 0.9918
# 00700: TRAIN| LT=0.872 LP=0.043 LKL=11.983 LPS=0.644 LKLS=6.490 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9900
# Train F1: 0.9878
# 00750: TRAIN| LT=0.880 LP=0.032 LKL=11.903 LPS=0.665 LKLS=6.395 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9912
# Train F1: 0.9918
# 00800: TRAIN| LT=0.856 LP=0.031 LKL=11.913 LPS=0.642 LKLS=6.404 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9930
# Train F1: 0.9917
# 00850: TRAIN| LT=0.875 LP=0.045 LKL=11.908 LPS=0.651 LKLS=5.956 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9906
# Train F1: 0.9877
# 00900: TRAIN| LT=0.869 LP=0.047 LKL=11.888 LPS=0.645 LKLS=5.822 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9877
# Train F1: 0.9959
# 00950: TRAIN| LT=0.833 LP=0.023 LKL=11.780 LPS=0.638 LKLS=5.474 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9912
# Train F1: 0.9939
# 01000: TRAIN| LT=0.840 LP=0.025 LKL=11.635 LPS=0.648 LKLS=5.088 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9906
# Train F1: 0.9878
# 01050: TRAIN| LT=0.856 LP=0.034 LKL=11.753 LPS=0.651 LKLS=5.330 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9912
# Train F1: 0.9857
# 01100: TRAIN| LT=0.859 LP=0.047 LKL=11.466 LPS=0.649 LKLS=4.825 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9871
# Train F1: 0.9898
# 01150: TRAIN| LT=0.842 LP=0.024 LKL=11.676 LPS=0.653 LKLS=4.761 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9877
# Train F1: 0.9938
# 01200: TRAIN| LT=0.871 LP=0.048 LKL=11.627 LPS=0.659 LKLS=4.770 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9895
# Train F1: 0.9959
# 01250: TRAIN| LT=0.831 LP=0.021 LKL=11.592 LPS=0.646 LKLS=4.791 |
# Test F1: 0.9587
# Test ACC: 0.9438
# Test AUC: 0.9883
# Train F1: 0.9939
# 01300: TRAIN| LT=0.830 LP=0.032 LKL=11.261 LPS=0.642 LKLS=4.298 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9900
# Train F1: 0.9980
# 01350: TRAIN| LT=0.823 LP=0.036 LKL=11.324 LPS=0.630 LKLS=4.377 |
# Test F1: 0.9587
# Test ACC: 0.9438
# Test AUC: 0.9883
# Train F1: 0.9897
# 01400: TRAIN| LT=0.809 LP=0.019 LKL=11.337 LPS=0.636 LKLS=4.080 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9889
# Train F1: 0.9959
# 01450: TRAIN| LT=0.816 LP=0.020 LKL=11.358 LPS=0.642 LKLS=4.058 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9895
# Train F1: 0.9938
# 01500: TRAIN| LT=0.823 LP=0.039 LKL=11.193 LPS=0.632 LKLS=3.954 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9889
# Train F1: 0.9918
# 01550: TRAIN| LT=0.842 LP=0.033 LKL=11.181 LPS=0.659 LKLS=3.884 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9889
# Train F1: 0.9918
# 01600: TRAIN| LT=0.808 LP=0.020 LKL=11.091 LPS=0.639 LKLS=3.761 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9859
# Train F1: 0.9959
# 01650: TRAIN| LT=0.793 LP=0.011 LKL=11.013 LPS=0.636 LKLS=3.558 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9830
# Train F1: 0.9938
# 01700: TRAIN| LT=0.808 LP=0.022 LKL=11.123 LPS=0.639 LKLS=3.646 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9877
# Train F1: 0.9959
# 01750: TRAIN| LT=0.814 LP=0.029 LKL=11.005 LPS=0.641 LKLS=3.354 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9889
# Train F1: 0.9939
# 01800: TRAIN| LT=0.830 LP=0.033 LKL=11.183 LPS=0.652 LKLS=3.329 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9900
# Train F1: 0.9939
# 01850: TRAIN| LT=0.806 LP=0.020 LKL=10.925 LPS=0.643 LKLS=3.325 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9883
# Train F1: 0.9939
# 01900: TRAIN| LT=0.797 LP=0.017 LKL=10.868 LPS=0.639 LKLS=3.269 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9877
# Train F1: 0.9938
# 01950: TRAIN| LT=0.810 LP=0.019 LKL=11.188 LPS=0.644 LKLS=3.538 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9877
# Train F1: 0.9959
# 02000: TRAIN| LT=0.795 LP=0.015 LKL=10.962 LPS=0.637 LKLS=3.374 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9889
# f1: 0.9836065573770492
# acc: 0.9775280898876404
# auc: 0.9859484777517564
# Train F1: 0.9251
# 00050: TRAIN| LT=1.370 LP=0.339 LKL=13.166 LPS=0.763 LKLS=13.684 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9971
# Train F1: 0.9796
# 00100: TRAIN| LT=1.073 LP=0.115 LKL=12.854 LPS=0.715 LKLS=11.497 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9982
# Train F1: 0.9836
# 00150: TRAIN| LT=0.998 LP=0.092 LKL=12.394 LPS=0.688 LKLS=9.358 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9755
# 00200: TRAIN| LT=0.983 LP=0.066 LKL=12.449 LPS=0.701 LKLS=9.091 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9971
# Train F1: 0.9878
# 00250: TRAIN| LT=0.964 LP=0.060 LKL=12.342 LPS=0.697 LKLS=8.319 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9965
# Train F1: 0.9837
# 00300: TRAIN| LT=0.960 LP=0.078 LKL=12.226 LPS=0.680 LKLS=8.025 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9965
# Train F1: 0.9877
# 00350: TRAIN| LT=0.925 LP=0.076 LKL=12.151 LPS=0.649 LKLS=7.882 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9857
# 00400: TRAIN| LT=0.935 LP=0.080 LKL=12.053 LPS=0.660 LKLS=7.380 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9793
# 00450: TRAIN| LT=0.894 LP=0.041 LKL=12.205 LPS=0.656 LKLS=7.464 |
# Test F1: 0.9833
# Test ACC: 0.9775
# Test AUC: 0.9965
# Train F1: 0.9897
# 00500: TRAIN| LT=0.917 LP=0.039 LKL=12.158 LPS=0.681 LKLS=7.608 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9878
# 00550: TRAIN| LT=0.926 LP=0.066 LKL=11.927 LPS=0.674 LKLS=6.625 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9947
# Train F1: 0.9918
# 00600: TRAIN| LT=0.907 LP=0.058 LKL=11.943 LPS=0.664 LKLS=6.577 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9835
# 00650: TRAIN| LT=0.913 LP=0.056 LKL=12.185 LPS=0.669 LKLS=6.687 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9959
# Train F1: 0.9837
# 00700: TRAIN| LT=0.919 LP=0.074 LKL=11.998 LPS=0.659 LKLS=6.674 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9965
# Train F1: 0.9857
# 00750: TRAIN| LT=0.887 LP=0.037 LKL=12.176 LPS=0.659 LKLS=6.987 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9965
# Train F1: 0.9838
# 00800: TRAIN| LT=0.882 LP=0.043 LKL=11.925 LPS=0.657 LKLS=6.288 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9971
# Train F1: 0.9794
# 00850: TRAIN| LT=0.874 LP=0.046 LKL=11.863 LPS=0.649 LKLS=5.982 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9857
# 00900: TRAIN| LT=0.874 LP=0.036 LKL=11.814 LPS=0.662 LKLS=5.816 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9959
# Train F1: 0.9836
# 00950: TRAIN| LT=0.869 LP=0.034 LKL=11.863 LPS=0.654 LKLS=6.194 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9953
# Train F1: 0.9835
# 01000: TRAIN| LT=0.869 LP=0.036 LKL=11.883 LPS=0.658 LKLS=5.674 |
# Test F1: 0.9833
# Test ACC: 0.9775
# Test AUC: 0.9965
# Train F1: 0.9897
# 01050: TRAIN| LT=0.855 LP=0.034 LKL=11.796 LPS=0.647 LKLS=5.625 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9959
# Train F1: 0.9898
# 01100: TRAIN| LT=0.867 LP=0.033 LKL=11.756 LPS=0.664 LKLS=5.259 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9953
# Train F1: 0.9939
# 01150: TRAIN| LT=0.853 LP=0.037 LKL=11.538 LPS=0.649 LKLS=5.211 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9965
# Train F1: 0.9898
# 01200: TRAIN| LT=0.867 LP=0.045 LKL=11.973 LPS=0.651 LKLS=5.124 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9959
# Train F1: 0.9918
# 01250: TRAIN| LT=0.856 LP=0.028 LKL=11.617 LPS=0.662 LKLS=4.963 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9959
# Train F1: 0.9959
# 01300: TRAIN| LT=0.868 LP=0.048 LKL=11.626 LPS=0.654 LKLS=4.926 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9965
# Train F1: 0.9878
# 01350: TRAIN| LT=0.841 LP=0.027 LKL=11.731 LPS=0.647 LKLS=5.009 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9959
# Train F1: 0.9918
# 01400: TRAIN| LT=0.854 LP=0.046 LKL=11.494 LPS=0.648 LKLS=4.537 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9947
# Train F1: 0.9959
# 01450: TRAIN| LT=0.839 LP=0.020 LKL=11.553 LPS=0.655 LKLS=4.756 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9959
# Train F1: 0.9938
# 01500: TRAIN| LT=0.842 LP=0.032 LKL=11.428 LPS=0.654 LKLS=4.195 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9965
# Train F1: 0.9918
# 01550: TRAIN| LT=0.844 LP=0.040 LKL=11.361 LPS=0.647 LKLS=4.246 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9965
# Train F1: 0.9939
# 01600: TRAIN| LT=0.829 LP=0.021 LKL=11.603 LPS=0.648 LKLS=4.319 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9959
# Train F1: 0.9897
# 01650: TRAIN| LT=0.854 LP=0.040 LKL=11.300 LPS=0.657 LKLS=4.310 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9941
# Train F1: 0.9857
# 01700: TRAIN| LT=0.834 LP=0.034 LKL=11.385 LPS=0.644 LKLS=4.194 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9953
# Train F1: 0.9918
# 01750: TRAIN| LT=0.832 LP=0.042 LKL=11.285 LPS=0.637 LKLS=3.944 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9965
# Train F1: 0.9918
# 01800: TRAIN| LT=0.832 LP=0.030 LKL=11.358 LPS=0.645 LKLS=4.233 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9953
# Train F1: 0.9878
# 01850: TRAIN| LT=0.825 LP=0.027 LKL=11.477 LPS=0.644 LKLS=3.955 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9965
# Train F1: 0.9898
# 01900: TRAIN| LT=0.821 LP=0.021 LKL=11.265 LPS=0.648 LKLS=3.929 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9953
# Train F1: 0.9918
# 01950: TRAIN| LT=0.817 LP=0.023 LKL=11.302 LPS=0.643 LKLS=3.724 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9953
# Train F1: 0.9980
# 02000: TRAIN| LT=0.818 LP=0.023 LKL=11.386 LPS=0.642 LKLS=3.864 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9947
# f1: 0.9917355371900827
# acc: 0.9887640449438202
# auc: 0.9982435597189696
# Train F1: 0.9507
# 00050: TRAIN| LT=1.359 LP=0.308 LKL=13.658 LPS=0.756 LKLS=15.863 |
# Test F1: 0.9219
# Test ACC: 0.8876
# Test AUC: 0.9344
# Train F1: 0.9835
# 00100: TRAIN| LT=1.049 LP=0.123 LKL=12.790 LPS=0.690 LKLS=10.869 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9561
# Train F1: 0.9817
# 00150: TRAIN| LT=0.972 LP=0.071 LKL=12.336 LPS=0.675 LKLS=10.290 |
# Test F1: 0.9516
# Test ACC: 0.9326
# Test AUC: 0.9514
# Train F1: 0.9835
# 00200: TRAIN| LT=0.963 LP=0.077 LKL=12.043 LPS=0.685 LKLS=8.031 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9578
# Train F1: 0.9837
# 00250: TRAIN| LT=0.964 LP=0.076 LKL=12.229 LPS=0.677 LKLS=8.895 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9596
# Train F1: 0.9877
# 00300: TRAIN| LT=0.949 LP=0.069 LKL=12.056 LPS=0.678 LKLS=8.211 |
# Test F1: 0.9516
# Test ACC: 0.9326
# Test AUC: 0.9532
# Train F1: 0.9837
# 00350: TRAIN| LT=0.896 LP=0.048 LKL=12.019 LPS=0.647 LKLS=7.993 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9625
# Train F1: 0.9837
# 00400: TRAIN| LT=0.921 LP=0.068 LKL=11.916 LPS=0.654 LKLS=7.911 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9608
# Train F1: 0.9794
# 00450: TRAIN| LT=0.954 LP=0.082 LKL=11.862 LPS=0.685 LKLS=6.896 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9590
# Train F1: 0.9816
# 00500: TRAIN| LT=0.880 LP=0.030 LKL=11.943 LPS=0.658 LKLS=7.232 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9584
# Train F1: 0.9814
# 00550: TRAIN| LT=0.942 LP=0.094 LKL=11.986 LPS=0.658 LKLS=6.989 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9614
# Train F1: 0.9877
# 00600: TRAIN| LT=0.897 LP=0.030 LKL=11.987 LPS=0.678 LKLS=6.873 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9578
# Train F1: 0.9939
# 00650: TRAIN| LT=0.890 LP=0.028 LKL=11.905 LPS=0.674 LKLS=6.930 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9614
# Train F1: 0.9776
# 00700: TRAIN| LT=0.901 LP=0.053 LKL=11.924 LPS=0.666 LKLS=6.356 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9631
# Train F1: 0.9856
# 00750: TRAIN| LT=0.891 LP=0.057 LKL=11.924 LPS=0.648 LKLS=6.566 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9596
# Train F1: 0.9835
# 00800: TRAIN| LT=0.873 LP=0.046 LKL=11.692 LPS=0.650 LKLS=5.971 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9602
# Train F1: 0.9878
# 00850: TRAIN| LT=0.881 LP=0.039 LKL=11.856 LPS=0.664 LKLS=5.962 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9637
# Train F1: 0.9835
# 00900: TRAIN| LT=0.893 LP=0.035 LKL=11.849 LPS=0.679 LKLS=6.103 |
# Test F1: 0.9516
# Test ACC: 0.9326
# Test AUC: 0.9625
# Train F1: 0.9959
# 00950: TRAIN| LT=0.851 LP=0.036 LKL=11.875 LPS=0.639 LKLS=5.773 |
# Test F1: 0.9449
# Test ACC: 0.9213
# Test AUC: 0.9625
# Train F1: 0.9856
# 01000: TRAIN| LT=0.870 LP=0.034 LKL=11.726 LPS=0.661 LKLS=5.722 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9602
# Train F1: 0.9918
# 01050: TRAIN| LT=0.849 LP=0.025 LKL=11.686 LPS=0.653 LKLS=5.424 |
# Test F1: 0.9280
# Test ACC: 0.8989
# Test AUC: 0.9596
# Train F1: 0.9918
# 01100: TRAIN| LT=0.851 LP=0.040 LKL=11.496 LPS=0.645 LKLS=5.097 |
# Test F1: 0.9365
# Test ACC: 0.9101
# Test AUC: 0.9614
# Train F1: 0.9898
# 01150: TRAIN| LT=0.858 LP=0.036 LKL=11.742 LPS=0.653 LKLS=5.177 |
# Test F1: 0.9449
# Test ACC: 0.9213
# Test AUC: 0.9602
# Train F1: 0.9959
# 01200: TRAIN| LT=0.834 LP=0.027 LKL=11.593 LPS=0.642 LKLS=4.956 |
# Test F1: 0.9355
# Test ACC: 0.9101
# Test AUC: 0.9631
# Train F1: 0.9959
# 01250: TRAIN| LT=0.839 LP=0.021 LKL=11.736 LPS=0.651 LKLS=4.987 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9637
# Train F1: 0.9918
# 01300: TRAIN| LT=0.844 LP=0.028 LKL=11.532 LPS=0.653 LKLS=4.772 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9655
# Train F1: 0.9857
# 01350: TRAIN| LT=0.831 LP=0.027 LKL=11.788 LPS=0.638 LKLS=4.729 |
# Test F1: 0.9355
# Test ACC: 0.9101
# Test AUC: 0.9649
# Train F1: 0.9919
# 01400: TRAIN| LT=0.836 LP=0.028 LKL=11.183 LPS=0.655 LKLS=4.185 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9655
# Train F1: 0.9918
# 01450: TRAIN| LT=0.821 LP=0.020 LKL=11.397 LPS=0.644 LKLS=4.294 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9619
# Train F1: 0.9918
# 01500: TRAIN| LT=0.819 LP=0.023 LKL=11.339 LPS=0.640 LKLS=4.322 |
# Test F1: 0.9355
# Test ACC: 0.9101
# Test AUC: 0.9625
# Train F1: 0.9980
# 01550: TRAIN| LT=0.835 LP=0.023 LKL=11.271 LPS=0.656 LKLS=4.260 |
# Test F1: 0.9375
# Test ACC: 0.9101
# Test AUC: 0.9596
# Train F1: 0.9918
# 01600: TRAIN| LT=0.817 LP=0.033 LKL=11.174 LPS=0.634 LKLS=3.902 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9643
# Train F1: 0.9897
# 01650: TRAIN| LT=0.820 LP=0.026 LKL=11.214 LPS=0.642 LKLS=4.014 |
# Test F1: 0.9449
# Test ACC: 0.9213
# Test AUC: 0.9643
# Train F1: 0.9939
# 01700: TRAIN| LT=0.818 LP=0.026 LKL=11.298 LPS=0.639 LKLS=3.993 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9631
# Train F1: 0.9898
# 01750: TRAIN| LT=0.819 LP=0.019 LKL=11.069 LPS=0.651 LKLS=3.848 |
# Test F1: 0.9280
# Test ACC: 0.8989
# Test AUC: 0.9602
# Train F1: 0.9939
# 01800: TRAIN| LT=0.818 LP=0.027 LKL=11.389 LPS=0.638 LKLS=3.920 |
# Test F1: 0.9280
# Test ACC: 0.8989
# Test AUC: 0.9614
# Train F1: 0.9897
# 01850: TRAIN| LT=0.807 LP=0.014 LKL=11.106 LPS=0.644 LKLS=3.818 |
# Test F1: 0.9355
# Test ACC: 0.9101
# Test AUC: 0.9596
# Train F1: 0.9939
# 01900: TRAIN| LT=0.806 LP=0.016 LKL=11.146 LPS=0.640 LKLS=3.890 |
# Test F1: 0.9449
# Test ACC: 0.9213
# Test AUC: 0.9608
# Train F1: 0.9898
# 01950: TRAIN| LT=0.811 LP=0.022 LKL=11.042 LPS=0.641 LKLS=3.765 |
# Test F1: 0.9449
# Test ACC: 0.9213
# Test AUC: 0.9637
# Train F1: 0.9939
# 02000: TRAIN| LT=0.819 LP=0.025 LKL=11.116 LPS=0.647 LKLS=3.557 |
# Test F1: 0.9449
# Test ACC: 0.9213
# Test AUC: 0.9637
# f1: 0.9677419354838709
# acc: 0.9550561797752809
# auc: 0.9625292740046838
# Train F1: 0.9163
# 00050: TRAIN| LT=1.446 LP=0.341 LKL=13.780 LPS=0.821 LKLS=14.583 |
# Test F1: 0.9683
# Test ACC: 0.9551
# Test AUC: 0.9742
# Train F1: 0.9814
# 00100: TRAIN| LT=1.055 LP=0.106 LKL=13.225 LPS=0.696 LKLS=12.069 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9637
# Train F1: 0.9795
# 00150: TRAIN| LT=0.975 LP=0.078 LKL=12.493 LPS=0.677 LKLS=9.548 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9625
# Train F1: 0.9938
# 00200: TRAIN| LT=0.958 LP=0.061 LKL=12.326 LPS=0.685 LKLS=8.867 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9602
# Train F1: 0.9837
# 00250: TRAIN| LT=0.917 LP=0.040 LKL=12.275 LPS=0.669 LKLS=8.533 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9420
# Train F1: 0.9898
# 00300: TRAIN| LT=0.881 LP=0.043 LKL=12.213 LPS=0.640 LKLS=7.596 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9426
# Train F1: 0.9918
# 00350: TRAIN| LT=0.887 LP=0.042 LKL=12.357 LPS=0.638 LKLS=8.269 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9508
# Train F1: 0.9939
# 00400: TRAIN| LT=0.897 LP=0.046 LKL=12.020 LPS=0.656 LKLS=7.461 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9444
# Train F1: 0.9898
# 00450: TRAIN| LT=0.841 LP=0.020 LKL=11.929 LPS=0.631 LKLS=7.094 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9416
# Train F1: 0.9856
# 00500: TRAIN| LT=0.849 LP=0.030 LKL=11.981 LPS=0.631 LKLS=6.835 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9420
# Train F1: 0.9980
# 00550: TRAIN| LT=0.877 LP=0.033 LKL=12.166 LPS=0.652 LKLS=7.072 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9456
# Train F1: 0.9918
# 00600: TRAIN| LT=0.870 LP=0.052 LKL=11.884 LPS=0.633 LKLS=6.553 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9456
# Train F1: 0.9898
# 00650: TRAIN| LT=0.855 LP=0.037 LKL=11.925 LPS=0.636 LKLS=6.227 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9549
# Train F1: 0.9918
# 00700: TRAIN| LT=0.852 LP=0.035 LKL=11.955 LPS=0.636 LKLS=6.216 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9438
# Train F1: 0.9959
# 00750: TRAIN| LT=0.862 LP=0.035 LKL=11.855 LPS=0.648 LKLS=6.002 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9397
# Train F1: 0.9898
# 00800: TRAIN| LT=0.861 LP=0.028 LKL=11.886 LPS=0.652 LKLS=6.245 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9403
# Train F1: 0.9897
# 00850: TRAIN| LT=0.848 LP=0.027 LKL=11.935 LPS=0.642 LKLS=6.045 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9461
# Train F1: 1.0000
# 00900: TRAIN| LT=0.864 LP=0.034 LKL=11.841 LPS=0.655 LKLS=5.686 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9420
# Train F1: 0.9959
# 00950: TRAIN| LT=0.849 LP=0.034 LKL=11.810 LPS=0.641 LKLS=5.624 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9451
# Train F1: 0.9959
# 01000: TRAIN| LT=0.839 LP=0.025 LKL=11.729 LPS=0.642 LKLS=5.492 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9526
# Train F1: 0.9897
# 01050: TRAIN| LT=0.850 LP=0.044 LKL=11.587 LPS=0.638 LKLS=5.216 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9520
# Train F1: 0.9878
# 01100: TRAIN| LT=0.831 LP=0.019 LKL=11.521 LPS=0.644 LKLS=5.239 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9438
# Train F1: 0.9959
# 01150: TRAIN| LT=0.824 LP=0.016 LKL=11.615 LPS=0.639 LKLS=5.277 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9532
# Train F1: 0.9939
# 01200: TRAIN| LT=0.831 LP=0.018 LKL=11.552 LPS=0.650 LKLS=4.757 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9444
# Train F1: 0.9897
# 01250: TRAIN| LT=0.818 LP=0.016 LKL=11.666 LPS=0.635 LKLS=5.057 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9502
# Train F1: 0.9938
# 01300: TRAIN| LT=0.819 LP=0.017 LKL=11.452 LPS=0.639 LKLS=4.846 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9532
# Train F1: 0.9959
# 01350: TRAIN| LT=0.813 LP=0.016 LKL=11.177 LPS=0.641 LKLS=4.347 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9495
# Train F1: 0.9979
# 01400: TRAIN| LT=0.818 LP=0.018 LKL=11.491 LPS=0.638 LKLS=4.610 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9384
# Train F1: 0.9939
# 01450: TRAIN| LT=0.835 LP=0.036 LKL=11.510 LPS=0.640 LKLS=4.483 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9559
# Train F1: 0.9918
# 01500: TRAIN| LT=0.819 LP=0.021 LKL=11.466 LPS=0.639 LKLS=4.365 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9415
# Train F1: 0.9918
# 01550: TRAIN| LT=0.811 LP=0.026 LKL=11.334 LPS=0.629 LKLS=4.334 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9549
# Train F1: 0.9959
# 01600: TRAIN| LT=0.816 LP=0.025 LKL=11.275 LPS=0.636 LKLS=4.140 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9453
# Train F1: 0.9897
# 01650: TRAIN| LT=0.813 LP=0.023 LKL=11.127 LPS=0.640 LKLS=3.838 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9533
# Train F1: 0.9959
# 01700: TRAIN| LT=0.827 LP=0.030 LKL=11.144 LPS=0.645 LKLS=4.041 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9466
# Train F1: 0.9959
# 01750: TRAIN| LT=0.810 LP=0.017 LKL=11.202 LPS=0.641 LKLS=3.909 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9526
# Train F1: 0.9918
# 01800: TRAIN| LT=0.812 LP=0.019 LKL=11.130 LPS=0.644 LKLS=3.862 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9536
# Train F1: 0.9938
# 01850: TRAIN| LT=0.795 LP=0.014 LKL=11.099 LPS=0.632 LKLS=3.824 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9470
# Train F1: 0.9959
# 01900: TRAIN| LT=0.795 LP=0.014 LKL=10.977 LPS=0.635 LKLS=3.601 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9507
# Train F1: 0.9918
# 01950: TRAIN| LT=0.802 LP=0.019 LKL=10.852 LPS=0.641 LKLS=3.450 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9463
# Train F1: 0.9898
# 02000: TRAIN| LT=0.790 LP=0.016 LKL=10.829 LPS=0.632 LKLS=3.349 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9581
# f1: 0.9838709677419354
# acc: 0.9775280898876404
# auc: 0.9637002341920375
# Train F1: 0.9228
# 00050: TRAIN| LT=1.482 LP=0.361 LKL=13.261 LPS=0.845 LKLS=14.372 |
# Test F1: 0.9508
# Test ACC: 0.9318
# Test AUC: 0.9781
# Train F1: 0.9778
# 00100: TRAIN| LT=1.094 LP=0.109 LKL=13.240 LPS=0.727 LKLS=12.522 |
# Test F1: 0.9508
# Test ACC: 0.9318
# Test AUC: 0.9879
# Train F1: 0.9713
# 00150: TRAIN| LT=1.004 LP=0.080 LKL=12.410 LPS=0.703 LKLS=9.724 |
# Test F1: 0.9587
# Test ACC: 0.9432
# Test AUC: 0.9897
# Train F1: 0.9815
# 00200: TRAIN| LT=0.993 LP=0.066 LKL=12.290 LPS=0.712 LKLS=9.181 |
# Test F1: 0.9667
# Test ACC: 0.9545
# Test AUC: 0.9927
# Train F1: 0.9898
# 00250: TRAIN| LT=0.947 LP=0.077 LKL=12.032 LPS=0.672 LKLS=7.790 |
# Test F1: 0.9667
# Test ACC: 0.9545
# Test AUC: 0.9957
# Train F1: 0.9816
# 00300: TRAIN| LT=0.950 LP=0.092 LKL=12.018 LPS=0.655 LKLS=8.239 |
# Test F1: 0.9752
# Test ACC: 0.9659
# Test AUC: 0.9951
# Train F1: 0.9777
# 00350: TRAIN| LT=0.896 LP=0.044 LKL=12.223 LPS=0.643 LKLS=8.672 |
# Test F1: 0.9836
# Test ACC: 0.9773
# Test AUC: 0.9957
# Train F1: 0.9856
# 00400: TRAIN| LT=0.923 LP=0.049 LKL=12.181 LPS=0.672 LKLS=8.043 |
# Test F1: 0.9836
# Test ACC: 0.9773
# Test AUC: 0.9957
# Train F1: 0.9878
# 00450: TRAIN| LT=0.942 LP=0.059 LKL=12.174 LPS=0.687 LKLS=7.338 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9957
# Train F1: 0.9836
# 00500: TRAIN| LT=0.913 LP=0.054 LKL=12.045 LPS=0.664 LKLS=7.438 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9957
# Train F1: 0.9816
# 00550: TRAIN| LT=0.884 LP=0.029 LKL=11.917 LPS=0.668 LKLS=6.788 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9964
# Train F1: 0.9856
# 00600: TRAIN| LT=0.869 LP=0.032 LKL=11.940 LPS=0.648 LKLS=6.908 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9951
# Train F1: 0.9856
# 00650: TRAIN| LT=0.848 LP=0.021 LKL=11.872 LPS=0.643 LKLS=6.494 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9964
# Train F1: 0.9817
# 00700: TRAIN| LT=0.886 LP=0.042 LKL=11.993 LPS=0.656 LKLS=6.734 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9945
# Train F1: 0.9898
# 00750: TRAIN| LT=0.875 LP=0.041 LKL=11.932 LPS=0.653 LKLS=6.110 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9976
# Train F1: 0.9878
# 00800: TRAIN| LT=0.887 LP=0.047 LKL=11.997 LPS=0.659 LKLS=6.136 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9970
# Train F1: 0.9835
# 00850: TRAIN| LT=0.886 LP=0.050 LKL=11.996 LPS=0.658 LKLS=5.867 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9951
# Train F1: 0.9878
# 00900: TRAIN| LT=0.857 LP=0.027 LKL=11.925 LPS=0.654 LKLS=5.713 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9951
# Train F1: 0.9877
# 00950: TRAIN| LT=0.847 LP=0.025 LKL=11.936 LPS=0.645 LKLS=5.737 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9957
# Train F1: 0.9939
# 01000: TRAIN| LT=0.867 LP=0.035 LKL=11.618 LPS=0.662 LKLS=5.446 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9921
# Train F1: 0.9877
# 01050: TRAIN| LT=0.852 LP=0.041 LKL=11.765 LPS=0.641 LKLS=5.214 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9945
# Train F1: 0.9877
# 01100: TRAIN| LT=0.851 LP=0.030 LKL=11.688 LPS=0.654 LKLS=4.960 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9951
# Train F1: 0.9939
# 01150: TRAIN| LT=0.832 LP=0.025 LKL=11.387 LPS=0.647 LKLS=4.550 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9939
# Train F1: 0.9918
# 01200: TRAIN| LT=0.839 LP=0.032 LKL=11.496 LPS=0.649 LKLS=4.391 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9939
# Train F1: 0.9918
# 01250: TRAIN| LT=0.831 LP=0.028 LKL=11.453 LPS=0.643 LKLS=4.475 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9933
# Train F1: 0.9959
# 01300: TRAIN| LT=0.838 LP=0.035 LKL=11.456 LPS=0.645 LKLS=4.346 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9921
# Train F1: 0.9878
# 01350: TRAIN| LT=0.858 LP=0.049 LKL=11.459 LPS=0.650 LKLS=4.435 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9897
# Train F1: 0.9857
# 01400: TRAIN| LT=0.839 LP=0.035 LKL=11.403 LPS=0.647 LKLS=4.239 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9897
# Train F1: 0.9918
# 01450: TRAIN| LT=0.819 LP=0.022 LKL=11.127 LPS=0.647 LKLS=3.811 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9927
# Train F1: 0.9939
# 01500: TRAIN| LT=0.842 LP=0.030 LKL=11.504 LPS=0.656 LKLS=4.074 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9957
# Train F1: 0.9896
# 01550: TRAIN| LT=0.819 LP=0.024 LKL=11.279 LPS=0.643 LKLS=3.884 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9939
# Train F1: 0.9938
# 01600: TRAIN| LT=0.847 LP=0.051 LKL=11.186 LPS=0.646 LKLS=3.805 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9957
# Train F1: 0.9938
# 01650: TRAIN| LT=0.822 LP=0.024 LKL=11.319 LPS=0.648 LKLS=3.686 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9915
# Train F1: 0.9959
# 01700: TRAIN| LT=0.818 LP=0.015 LKL=11.280 LPS=0.654 LKLS=3.661 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9951
# Train F1: 0.9918
# 01750: TRAIN| LT=0.813 LP=0.021 LKL=11.034 LPS=0.647 LKLS=3.507 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9927
# Train F1: 0.9939
# 01800: TRAIN| LT=0.823 LP=0.029 LKL=11.016 LPS=0.649 LKLS=3.444 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9921
# Train F1: 0.9918
# 01850: TRAIN| LT=0.804 LP=0.023 LKL=11.036 LPS=0.635 LKLS=3.533 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9945
# Train F1: 0.9939
# 01900: TRAIN| LT=0.801 LP=0.015 LKL=10.885 LPS=0.644 LKLS=3.347 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9933
# Train F1: 0.9918
# 01950: TRAIN| LT=0.798 LP=0.018 LKL=10.992 LPS=0.637 LKLS=3.295 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9909
# Train F1: 0.9877
# 02000: TRAIN| LT=0.820 LP=0.028 LKL=11.081 LPS=0.649 LKLS=3.290 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9933
# f1: 0.9836065573770492
# acc: 0.9772727272727273
# auc: 0.9957498482088647
# f1 [0.9836065573770492, 0.9917355371900827, 0.9677419354838709, 0.9838709677419354, 0.9836065573770492]
# average maxf1 0.9821123110339975
# acc [0.9775280898876404, 0.9887640449438202, 0.9550561797752809, 0.9775280898876404, 0.9772727272727273]
# average maxacc 0.9752298263534218
# auc [0.9859484777517564, 0.9982435597189696, 0.9625292740046838, 0.9637002341920375, 0.9957498482088647]
# average maxauc 0.9812342787752625
