# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'H':0,'C':1,'D':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
print('输入各组学数据表：',x1.shape,meta_data.shape)

#重构数据表和标签表
X1 = x1
index_new=X1.index
print(index_new)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,meta_data.shape)
X_set=[X1]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (444, 1034) (444, 1)
# Index(['1.T.0', '1.T.1', '1.T.2', '1.T.3', '1.T.4', '1.T.5', '1.T.6', '10.T.0',
#        '10.T.1', '10.T.2',
#        ...
#        '8.T.4', '8.T.5', '8.T.6', '9.T.0', '9.T.1', '9.T.2', '9.T.3', '9.T.4',
#        '9.T.6', '9.T.Flare'],
#       dtype='object', name='Sample', length=444)
# 集合所有样本重构数据表： (444, 1034) (444, 1)
# 标签转换为one-hot编码： (444, 2) 139.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap_mg'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 4, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1', f1_cv)
print('average f1: {}±{}'.format(np.mean(f1_cv), np.std(f1_cv)))
print('acc', acc_cv)
print('average acc: {}±{}'.format(np.mean(acc_cv), np.std(acc_cv)))
print('auc', auc_cv)
print('average auc: {}±{}'.format(np.mean(auc_cv), np.std(auc_cv)))
# Out:
# Train F1: 0.9421
# 00050: TRAIN| LT=0.723 LP=0.284 LKL=9.264 LPS=0.201 LKLS=14.532 |
# Test F1: 0.9752
# Test ACC: 0.9663
# Test AUC: 0.9719
# Train F1: 0.9795
# 00100: TRAIN| LT=0.366 LP=0.105 LKL=8.309 LPS=0.078 LKLS=10.003 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9842
# Train F1: 0.9835
# 00150: TRAIN| LT=0.278 LP=0.064 LKL=7.794 LPS=0.050 LKLS=8.493 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9819
# Train F1: 0.9815
# 00200: TRAIN| LT=0.297 LP=0.085 LKL=7.453 LPS=0.062 LKLS=7.558 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9871
# Train F1: 0.9876
# 00250: TRAIN| LT=0.255 LP=0.062 LKL=7.349 LPS=0.053 LKLS=6.656 |
# Test F1: 0.9402
# Test ACC: 0.9213
# Test AUC: 0.9871
# Train F1: 0.9856
# 00300: TRAIN| LT=0.250 LP=0.060 LKL=7.398 LPS=0.046 LKLS=6.994 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9883
# Train F1: 0.9939
# 00350: TRAIN| LT=0.255 LP=0.052 LKL=7.462 LPS=0.059 LKLS=6.978 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9854
# Train F1: 0.9938
# 00400: TRAIN| LT=0.225 LP=0.042 LKL=7.363 LPS=0.040 LKLS=6.914 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9819
# Train F1: 0.9877
# 00450: TRAIN| LT=0.243 LP=0.071 LKL=7.014 LPS=0.043 LKLS=5.921 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9883
# Train F1: 0.9938
# 00500: TRAIN| LT=0.212 LP=0.051 LKL=7.166 LPS=0.026 LKLS=6.296 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9895
# Train F1: 0.9897
# 00550: TRAIN| LT=0.225 LP=0.053 LKL=7.264 LPS=0.038 LKLS=6.092 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9854
# Train F1: 0.9877
# 00600: TRAIN| LT=0.222 LP=0.054 LKL=7.066 LPS=0.038 LKLS=5.912 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9900
# Train F1: 0.9898
# 00650: TRAIN| LT=0.235 LP=0.060 LKL=7.172 LPS=0.043 LKLS=5.988 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9912
# Train F1: 0.9857
# 00700: TRAIN| LT=0.208 LP=0.056 LKL=7.207 LPS=0.015 LKLS=6.553 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9795
# Train F1: 0.9837
# 00750: TRAIN| LT=0.211 LP=0.045 LKL=7.312 LPS=0.030 LKLS=6.282 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9854
# Train F1: 0.9877
# 00800: TRAIN| LT=0.186 LP=0.030 LKL=7.141 LPS=0.026 LKLS=5.916 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9848
# Train F1: 0.9877
# 00850: TRAIN| LT=0.174 LP=0.031 LKL=7.003 LPS=0.018 LKLS=5.592 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9883
# Train F1: 0.9878
# 00900: TRAIN| LT=0.211 LP=0.059 LKL=6.966 LPS=0.027 LKLS=5.583 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9842
# Train F1: 0.9856
# 00950: TRAIN| LT=0.199 LP=0.043 LKL=7.118 LPS=0.030 LKLS=5.475 |
# Test F1: 0.9402
# Test ACC: 0.9213
# Test AUC: 0.9842
# Train F1: 0.9938
# 01000: TRAIN| LT=0.189 LP=0.037 LKL=7.108 LPS=0.023 LKLS=5.816 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9906
# Train F1: 0.9918
# 01050: TRAIN| LT=0.199 LP=0.040 LKL=7.130 LPS=0.032 LKLS=5.582 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9859
# Train F1: 0.9918
# 01100: TRAIN| LT=0.176 LP=0.021 LKL=6.994 LPS=0.031 LKLS=5.436 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9848
# Train F1: 0.9959
# 01150: TRAIN| LT=0.196 LP=0.051 LKL=6.953 LPS=0.023 LKLS=5.258 |
# Test F1: 0.9412
# Test ACC: 0.9213
# Test AUC: 0.9836
# Train F1: 0.9836
# 01200: TRAIN| LT=0.179 LP=0.044 LKL=6.885 LPS=0.014 LKLS=5.225 |
# Test F1: 0.9412
# Test ACC: 0.9213
# Test AUC: 0.9848
# Train F1: 0.9938
# 01250: TRAIN| LT=0.173 LP=0.029 LKL=7.034 LPS=0.023 LKLS=5.117 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9848
# Train F1: 0.9938
# 01300: TRAIN| LT=0.174 LP=0.030 LKL=7.060 LPS=0.024 LKLS=4.983 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9865
# Train F1: 0.9877
# 01350: TRAIN| LT=0.168 LP=0.033 LKL=6.816 LPS=0.019 LKLS=4.870 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9865
# Train F1: 0.9835
# 01400: TRAIN| LT=0.187 LP=0.044 LKL=6.783 LPS=0.025 LKLS=5.071 |
# Test F1: 0.9412
# Test ACC: 0.9213
# Test AUC: 0.9819
# Train F1: 0.9856
# 01450: TRAIN| LT=0.169 LP=0.028 LKL=6.894 LPS=0.021 LKLS=5.039 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9820
# Train F1: 0.9897
# 01500: TRAIN| LT=0.182 LP=0.037 LKL=7.010 LPS=0.024 LKLS=5.037 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9842
# Train F1: 0.9918
# 01550: TRAIN| LT=0.205 LP=0.038 LKL=6.782 LPS=0.052 LKLS=4.803 |
# Test F1: 0.9402
# Test ACC: 0.9213
# Test AUC: 0.9865
# Train F1: 0.9898
# 01600: TRAIN| LT=0.157 LP=0.024 LKL=6.765 LPS=0.016 LKLS=4.901 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9883
# Train F1: 0.9918
# 01650: TRAIN| LT=0.156 LP=0.023 LKL=6.673 LPS=0.020 LKLS=4.579 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9889
# Train F1: 0.9897
# 01700: TRAIN| LT=0.159 LP=0.028 LKL=6.755 LPS=0.019 LKLS=4.473 |
# Test F1: 0.9402
# Test ACC: 0.9213
# Test AUC: 0.9906
# Train F1: 0.9897
# 01750: TRAIN| LT=0.154 LP=0.024 LKL=6.593 LPS=0.019 LKLS=4.482 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9842
# Train F1: 0.9856
# 01800: TRAIN| LT=0.148 LP=0.019 LKL=6.663 LPS=0.019 LKLS=4.375 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9877
# Train F1: 0.9939
# 01850: TRAIN| LT=0.167 LP=0.031 LKL=6.758 LPS=0.025 LKLS=4.347 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9854
# Train F1: 0.9897
# 01900: TRAIN| LT=0.157 LP=0.028 LKL=6.552 LPS=0.023 LKLS=4.073 |
# Test F1: 0.9402
# Test ACC: 0.9213
# Test AUC: 0.9883
# Train F1: 0.9918
# 01950: TRAIN| LT=0.152 LP=0.023 LKL=6.358 LPS=0.025 LKLS=4.043 |
# Test F1: 0.9412
# Test ACC: 0.9213
# Test AUC: 0.9842
# Train F1: 0.9918
# 02000: TRAIN| LT=0.150 LP=0.021 LKL=6.662 LPS=0.023 LKLS=3.920 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9859
# f1: 0.9752066115702478
# acc: 0.9662921348314607
# auc: 0.9718969555035128
# Train F1: 0.9282
# 00050: TRAIN| LT=0.666 LP=0.303 LKL=8.984 LPS=0.143 LKLS=12.985 |
# Test F1: 0.9833
# Test ACC: 0.9775
# Test AUC: 0.9971
# Train F1: 0.9754
# 00100: TRAIN| LT=0.375 LP=0.121 LKL=8.065 LPS=0.081 LKLS=9.203 |
# Test F1: 0.9833
# Test ACC: 0.9775
# Test AUC: 0.9977
# Train F1: 0.9918
# 00150: TRAIN| LT=0.301 LP=0.065 LKL=7.950 LPS=0.068 LKLS=8.899 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9774
# 00200: TRAIN| LT=0.254 LP=0.069 LKL=7.416 LPS=0.037 LKLS=7.356 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9775
# 00250: TRAIN| LT=0.266 LP=0.070 LKL=7.303 LPS=0.054 LKLS=6.788 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9912
# Train F1: 0.9836
# 00300: TRAIN| LT=0.224 LP=0.043 LKL=7.239 LPS=0.041 LKLS=6.827 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9953
# Train F1: 0.9856
# 00350: TRAIN| LT=0.263 LP=0.074 LKL=7.282 LPS=0.052 LKLS=6.503 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9877
# 00400: TRAIN| LT=0.259 LP=0.079 LKL=7.213 LPS=0.047 LKLS=6.125 |
# Test F1: 0.9833
# Test ACC: 0.9775
# Test AUC: 0.9953
# Train F1: 0.9856
# 00450: TRAIN| LT=0.248 LP=0.070 LKL=7.233 LPS=0.042 LKLS=6.321 |
# Test F1: 0.9748
# Test ACC: 0.9663
# Test AUC: 0.9959
# Train F1: 0.9774
# 00500: TRAIN| LT=0.224 LP=0.047 LKL=7.192 LPS=0.042 LKLS=6.280 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9836
# 00550: TRAIN| LT=0.245 LP=0.060 LKL=7.179 LPS=0.053 LKLS=6.031 |
# Test F1: 0.9833
# Test ACC: 0.9775
# Test AUC: 0.9959
# Train F1: 0.9798
# 00600: TRAIN| LT=0.219 LP=0.049 LKL=7.048 LPS=0.040 LKLS=5.977 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9959
# Train F1: 0.9835
# 00650: TRAIN| LT=0.229 LP=0.059 LKL=7.051 LPS=0.042 LKLS=5.766 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9876
# 00700: TRAIN| LT=0.238 LP=0.070 LKL=7.110 LPS=0.039 LKLS=5.829 |
# Test F1: 0.9833
# Test ACC: 0.9775
# Test AUC: 0.9965
# Train F1: 0.9939
# 00750: TRAIN| LT=0.210 LP=0.046 LKL=7.170 LPS=0.035 LKLS=5.702 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9977
# Train F1: 0.9857
# 00800: TRAIN| LT=0.238 LP=0.058 LKL=7.327 LPS=0.045 LKLS=6.154 |
# Test F1: 0.9836
# Test ACC: 0.9775
# Test AUC: 0.9965
# Train F1: 0.9857
# 00850: TRAIN| LT=0.223 LP=0.051 LKL=7.205 LPS=0.044 LKLS=5.552 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9971
# Train F1: 0.9857
# 00900: TRAIN| LT=0.210 LP=0.044 LKL=7.081 LPS=0.039 LKLS=5.601 |
# Test F1: 0.9748
# Test ACC: 0.9663
# Test AUC: 0.9965
# Train F1: 0.9857
# 00950: TRAIN| LT=0.215 LP=0.053 LKL=7.093 LPS=0.035 LKLS=5.624 |
# Test F1: 0.9748
# Test ACC: 0.9663
# Test AUC: 0.9959
# Train F1: 0.9878
# 01000: TRAIN| LT=0.203 LP=0.040 LKL=7.122 LPS=0.035 LKLS=5.762 |
# Test F1: 0.9748
# Test ACC: 0.9663
# Test AUC: 0.9965
# Train F1: 0.9918
# 01050: TRAIN| LT=0.216 LP=0.041 LKL=7.114 LPS=0.049 LKLS=5.459 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9965
# Train F1: 0.9898
# 01100: TRAIN| LT=0.188 LP=0.043 LKL=6.965 LPS=0.023 LKLS=5.245 |
# Test F1: 0.9748
# Test ACC: 0.9663
# Test AUC: 0.9965
# Train F1: 0.9897
# 01150: TRAIN| LT=0.182 LP=0.037 LKL=6.929 LPS=0.025 LKLS=5.127 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9971
# Train F1: 0.9898
# 01200: TRAIN| LT=0.193 LP=0.035 LKL=7.094 LPS=0.037 LKLS=5.084 |
# Test F1: 0.9748
# Test ACC: 0.9663
# Test AUC: 0.9959
# Train F1: 0.9959
# 01250: TRAIN| LT=0.175 LP=0.029 LKL=6.961 LPS=0.029 LKLS=4.837 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9965
# Train F1: 0.9878
# 01300: TRAIN| LT=0.199 LP=0.048 LKL=6.867 LPS=0.035 LKLS=4.747 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9941
# Train F1: 0.9857
# 01350: TRAIN| LT=0.171 LP=0.038 LKL=6.852 LPS=0.018 LKLS=4.616 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9941
# Train F1: 0.9856
# 01400: TRAIN| LT=0.178 LP=0.035 LKL=7.119 LPS=0.024 LKLS=4.724 |
# Test F1: 0.9661
# Test ACC: 0.9551
# Test AUC: 0.9971
# Train F1: 0.9898
# 01450: TRAIN| LT=0.186 LP=0.044 LKL=6.866 LPS=0.028 LKLS=4.544 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9953
# Train F1: 0.9897
# 01500: TRAIN| LT=0.157 LP=0.026 LKL=6.797 LPS=0.019 LKLS=4.452 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9959
# Train F1: 0.9898
# 01550: TRAIN| LT=0.205 LP=0.051 LKL=6.994 LPS=0.037 LKLS=4.770 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9959
# Train F1: 0.9938
# 01600: TRAIN| LT=0.144 LP=0.017 LKL=6.730 LPS=0.019 LKLS=4.116 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9959
# Train F1: 0.9938
# 01650: TRAIN| LT=0.167 LP=0.035 LKL=6.600 LPS=0.026 LKLS=3.992 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9953
# Train F1: 0.9898
# 01700: TRAIN| LT=0.159 LP=0.028 LKL=6.709 LPS=0.024 LKLS=4.050 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9953
# Train F1: 0.9939
# 01750: TRAIN| LT=0.172 LP=0.036 LKL=6.567 LPS=0.029 LKLS=4.138 |
# Test F1: 0.9667
# Test ACC: 0.9551
# Test AUC: 0.9959
# Train F1: 0.9939
# 01800: TRAIN| LT=0.168 LP=0.032 LKL=6.511 LPS=0.031 LKLS=3.948 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9959
# Train F1: 0.9918
# 01850: TRAIN| LT=0.157 LP=0.030 LKL=6.585 LPS=0.022 LKLS=3.918 |
# Test F1: 0.9573
# Test ACC: 0.9438
# Test AUC: 0.9965
# Train F1: 0.9939
# 01900: TRAIN| LT=0.137 LP=0.018 LKL=6.515 LPS=0.016 LKLS=3.761 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9953
# Train F1: 0.9959
# 01950: TRAIN| LT=0.151 LP=0.028 LKL=6.384 LPS=0.023 LKLS=3.568 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9947
# Train F1: 0.9959
# 02000: TRAIN| LT=0.153 LP=0.030 LKL=6.566 LPS=0.019 LKLS=3.841 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9953
# f1: 0.9917355371900827
# acc: 0.9887640449438202
# auc: 0.9976580796252927
# Train F1: 0.9681
# 00050: TRAIN| LT=0.665 LP=0.279 LKL=9.190 LPS=0.153 LKLS=14.099 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9303
# Train F1: 0.9835
# 00100: TRAIN| LT=0.320 LP=0.091 LKL=8.177 LPS=0.046 LKLS=10.083 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9508
# Train F1: 0.9837
# 00150: TRAIN| LT=0.302 LP=0.087 LKL=7.694 LPS=0.056 LKLS=8.191 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9520
# Train F1: 0.9836
# 00200: TRAIN| LT=0.277 LP=0.075 LKL=7.358 LPS=0.058 LKLS=7.014 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9526
# Train F1: 0.9837
# 00250: TRAIN| LT=0.253 LP=0.070 LKL=7.163 LPS=0.042 LKLS=6.979 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9561
# Train F1: 0.9856
# 00300: TRAIN| LT=0.232 LP=0.050 LKL=7.259 LPS=0.042 LKLS=6.743 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9532
# Train F1: 0.9817
# 00350: TRAIN| LT=0.242 LP=0.081 LKL=7.044 LPS=0.028 LKLS=6.212 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9543
# Train F1: 0.9918
# 00400: TRAIN| LT=0.209 LP=0.033 LKL=7.196 LPS=0.038 LKLS=6.704 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9485
# Train F1: 0.9918
# 00450: TRAIN| LT=0.267 LP=0.078 LKL=7.108 LPS=0.056 LKLS=6.170 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9508
# Train F1: 0.9816
# 00500: TRAIN| LT=0.227 LP=0.051 LKL=7.173 LPS=0.039 LKLS=6.602 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9602
# Train F1: 0.9835
# 00550: TRAIN| LT=0.226 LP=0.054 LKL=7.059 LPS=0.041 LKLS=6.113 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9508
# Train F1: 0.9898
# 00600: TRAIN| LT=0.234 LP=0.069 LKL=6.943 LPS=0.034 LKLS=6.067 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9590
# Train F1: 0.9938
# 00650: TRAIN| LT=0.207 LP=0.053 LKL=7.007 LPS=0.025 LKLS=5.856 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9631
# Train F1: 0.9856
# 00700: TRAIN| LT=0.208 LP=0.044 LKL=7.038 LPS=0.034 LKLS=5.947 |
# Test F1: 0.9431
# Test ACC: 0.9213
# Test AUC: 0.9590
# Train F1: 0.9836
# 00750: TRAIN| LT=0.219 LP=0.045 LKL=6.813 LPS=0.050 LKLS=5.507 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9590
# Train F1: 0.9793
# 00800: TRAIN| LT=0.198 LP=0.043 LKL=6.932 LPS=0.028 LKLS=5.759 |
# Test F1: 0.9355
# Test ACC: 0.9101
# Test AUC: 0.9614
# Train F1: 0.9816
# 00850: TRAIN| LT=0.223 LP=0.074 LKL=6.888 LPS=0.025 LKLS=5.548 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9619
# Train F1: 0.9917
# 00900: TRAIN| LT=0.180 LP=0.034 LKL=6.961 LPS=0.023 LKLS=5.298 |
# Test F1: 0.9431
# Test ACC: 0.9213
# Test AUC: 0.9614
# Train F1: 0.9897
# 00950: TRAIN| LT=0.209 LP=0.050 LKL=6.984 LPS=0.034 LKLS=5.483 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9631
# Train F1: 0.9939
# 01000: TRAIN| LT=0.207 LP=0.052 LKL=7.121 LPS=0.028 LKLS=5.643 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9631
# Train F1: 0.9938
# 01050: TRAIN| LT=0.209 LP=0.059 LKL=7.032 LPS=0.022 LKLS=5.777 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9625
# Train F1: 0.9856
# 01100: TRAIN| LT=0.192 LP=0.044 LKL=6.880 LPS=0.025 LKLS=5.438 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9637
# Train F1: 0.9877
# 01150: TRAIN| LT=0.199 LP=0.036 LKL=6.932 LPS=0.042 LKLS=5.140 |
# Test F1: 0.9431
# Test ACC: 0.9213
# Test AUC: 0.9660
# Train F1: 0.9877
# 01200: TRAIN| LT=0.210 LP=0.060 LKL=6.843 LPS=0.031 LKLS=5.127 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9637
# Train F1: 0.9877
# 01250: TRAIN| LT=0.188 LP=0.031 LKL=6.827 LPS=0.037 LKLS=5.061 |
# Test F1: 0.9355
# Test ACC: 0.9101
# Test AUC: 0.9655
# Train F1: 0.9898
# 01300: TRAIN| LT=0.173 LP=0.027 LKL=6.923 LPS=0.024 LKLS=5.288 |
# Test F1: 0.9431
# Test ACC: 0.9213
# Test AUC: 0.9690
# Train F1: 0.9938
# 01350: TRAIN| LT=0.193 LP=0.041 LKL=7.114 LPS=0.028 LKLS=5.190 |
# Test F1: 0.9431
# Test ACC: 0.9213
# Test AUC: 0.9660
# Train F1: 0.9877
# 01400: TRAIN| LT=0.174 LP=0.037 LKL=7.171 LPS=0.014 LKLS=5.121 |
# Test F1: 0.9431
# Test ACC: 0.9213
# Test AUC: 0.9655
# Train F1: 0.9898
# 01450: TRAIN| LT=0.191 LP=0.046 LKL=6.945 LPS=0.025 LKLS=5.073 |
# Test F1: 0.9524
# Test ACC: 0.9326
# Test AUC: 0.9643
# Train F1: 0.9897
# 01500: TRAIN| LT=0.204 LP=0.040 LKL=6.766 LPS=0.048 LKLS=4.810 |
# Test F1: 0.9431
# Test ACC: 0.9213
# Test AUC: 0.9649
# Train F1: 0.9856
# 01550: TRAIN| LT=0.157 LP=0.020 LKL=6.696 LPS=0.021 LKLS=4.881 |
# Test F1: 0.9355
# Test ACC: 0.9101
# Test AUC: 0.9649
# Train F1: 0.9835
# 01600: TRAIN| LT=0.167 LP=0.024 LKL=6.965 LPS=0.024 LKLS=4.832 |
# Test F1: 0.9355
# Test ACC: 0.9101
# Test AUC: 0.9660
# Train F1: 0.9939
# 01650: TRAIN| LT=0.164 LP=0.026 LKL=6.692 LPS=0.025 LKLS=4.547 |
# Test F1: 0.9355
# Test ACC: 0.9101
# Test AUC: 0.9643
# Train F1: 0.9877
# 01700: TRAIN| LT=0.177 LP=0.026 LKL=6.853 LPS=0.036 LKLS=4.627 |
# Test F1: 0.9355
# Test ACC: 0.9101
# Test AUC: 0.9643
# Train F1: 0.9938
# 01750: TRAIN| LT=0.148 LP=0.015 LKL=6.648 LPS=0.021 LKLS=4.527 |
# Test F1: 0.9431
# Test ACC: 0.9213
# Test AUC: 0.9649
# Train F1: 0.9898
# 01800: TRAIN| LT=0.153 LP=0.018 LKL=6.994 LPS=0.020 LKLS=4.475 |
# Test F1: 0.9280
# Test ACC: 0.8989
# Test AUC: 0.9614
# Train F1: 0.9899
# 01850: TRAIN| LT=0.147 LP=0.023 LKL=6.454 LPS=0.015 LKLS=4.389 |
# Test F1: 0.9449
# Test ACC: 0.9213
# Test AUC: 0.9637
# Train F1: 0.9918
# 01900: TRAIN| LT=0.155 LP=0.029 LKL=6.573 LPS=0.019 LKLS=4.172 |
# Test F1: 0.9365
# Test ACC: 0.9101
# Test AUC: 0.9631
# Train F1: 0.9877
# 01950: TRAIN| LT=0.153 LP=0.018 LKL=6.651 LPS=0.028 LKLS=4.064 |
# Test F1: 0.9449
# Test ACC: 0.9213
# Test AUC: 0.9637
# Train F1: 0.9959
# 02000: TRAIN| LT=0.169 LP=0.038 LKL=6.474 LPS=0.028 LKLS=3.882 |
# Test F1: 0.9375
# Test ACC: 0.9101
# Test AUC: 0.9637
# f1: 0.9677419354838709
# acc: 0.9550561797752809
# auc: 0.9508196721311475
# Train F1: 0.9476
# 00050: TRAIN| LT=0.698 LP=0.287 LKL=8.917 LPS=0.188 LKLS=13.383 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9766
# Train F1: 0.9753
# 00100: TRAIN| LT=0.337 LP=0.101 LKL=8.218 LPS=0.058 LKLS=9.677 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9637
# Train F1: 0.9856
# 00150: TRAIN| LT=0.290 LP=0.074 LKL=7.667 LPS=0.058 LKLS=8.106 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9555
# Train F1: 0.9814
# 00200: TRAIN| LT=0.216 LP=0.045 LKL=7.462 LPS=0.022 LKLS=7.462 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9485
# Train F1: 0.9876
# 00250: TRAIN| LT=0.281 LP=0.082 LKL=7.498 LPS=0.051 LKLS=7.364 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9467
# Train F1: 0.9837
# 00300: TRAIN| LT=0.218 LP=0.036 LKL=7.515 LPS=0.032 LKLS=7.562 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9473
# Train F1: 0.9878
# 00350: TRAIN| LT=0.213 LP=0.049 LKL=7.366 LPS=0.021 LKLS=6.884 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9456
# Train F1: 0.9856
# 00400: TRAIN| LT=0.230 LP=0.064 LKL=7.275 LPS=0.031 LKLS=6.221 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9438
# Train F1: 0.9837
# 00450: TRAIN| LT=0.221 LP=0.059 LKL=7.215 LPS=0.024 LKLS=6.630 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9350
# Train F1: 0.9897
# 00500: TRAIN| LT=0.193 LP=0.037 LKL=7.304 LPS=0.017 LKLS=6.596 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9532
# Train F1: 0.9959
# 00550: TRAIN| LT=0.189 LP=0.036 LKL=7.127 LPS=0.022 LKLS=6.028 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9438
# Train F1: 0.9898
# 00600: TRAIN| LT=0.208 LP=0.051 LKL=7.121 LPS=0.025 LKLS=6.125 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9444
# Train F1: 0.9835
# 00650: TRAIN| LT=0.194 LP=0.034 LKL=7.298 LPS=0.025 LKLS=6.159 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9556
# Train F1: 0.9918
# 00700: TRAIN| LT=0.166 LP=0.021 LKL=7.008 LPS=0.018 LKLS=5.667 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9485
# Train F1: 0.9938
# 00750: TRAIN| LT=0.177 LP=0.036 LKL=7.037 LPS=0.014 LKLS=5.620 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9573
# Train F1: 0.9918
# 00800: TRAIN| LT=0.184 LP=0.038 LKL=7.104 LPS=0.015 LKLS=5.945 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9438
# Train F1: 0.9980
# 00850: TRAIN| LT=0.179 LP=0.039 LKL=7.075 LPS=0.013 LKLS=5.600 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9508
# Train F1: 0.9938
# 00900: TRAIN| LT=0.209 LP=0.053 LKL=7.189 LPS=0.025 LKLS=5.928 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9606
# Train F1: 0.9877
# 00950: TRAIN| LT=0.183 LP=0.041 LKL=7.029 LPS=0.017 LKLS=5.454 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9549
# Train F1: 0.9896
# 01000: TRAIN| LT=0.185 LP=0.037 LKL=7.060 LPS=0.022 LKLS=5.492 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9461
# Train F1: 0.9897
# 01050: TRAIN| LT=0.174 LP=0.032 LKL=7.064 LPS=0.016 LKLS=5.568 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9507
# Train F1: 0.9918
# 01100: TRAIN| LT=0.177 LP=0.035 LKL=6.828 LPS=0.022 LKLS=5.171 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9469
# Train F1: 0.9877
# 01150: TRAIN| LT=0.161 LP=0.021 LKL=6.907 LPS=0.020 LKLS=5.049 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9590
# Train F1: 0.9898
# 01200: TRAIN| LT=0.169 LP=0.024 LKL=6.936 LPS=0.022 LKLS=5.302 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9539
# Train F1: 0.9939
# 01250: TRAIN| LT=0.178 LP=0.027 LKL=6.901 LPS=0.029 LKLS=5.279 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9561
# Train F1: 0.9959
# 01300: TRAIN| LT=0.159 LP=0.014 LKL=7.178 LPS=0.018 LKLS=5.528 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9596
# Train F1: 0.9898
# 01350: TRAIN| LT=0.159 LP=0.024 LKL=6.904 LPS=0.016 LKLS=5.043 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9555
# Train F1: 0.9876
# 01400: TRAIN| LT=0.163 LP=0.023 LKL=7.020 LPS=0.018 LKLS=5.155 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9526
# Train F1: 0.9836
# 01450: TRAIN| LT=0.157 LP=0.026 LKL=6.905 LPS=0.013 LKLS=4.932 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9578
# Train F1: 0.9876
# 01500: TRAIN| LT=0.199 LP=0.058 LKL=6.931 LPS=0.023 LKLS=4.868 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9606
# Train F1: 0.9939
# 01550: TRAIN| LT=0.142 LP=0.018 LKL=6.812 LPS=0.009 LKLS=4.688 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9546
# Train F1: 0.9939
# 01600: TRAIN| LT=0.166 LP=0.031 LKL=6.667 LPS=0.023 LKLS=4.549 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9631
# Train F1: 0.9896
# 01650: TRAIN| LT=0.165 LP=0.028 LKL=6.822 LPS=0.022 LKLS=4.757 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9543
# Train F1: 0.9938
# 01700: TRAIN| LT=0.142 LP=0.013 LKL=6.646 LPS=0.018 LKLS=4.447 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9562
# Train F1: 0.9939
# 01750: TRAIN| LT=0.148 LP=0.028 LKL=6.545 LPS=0.013 LKLS=4.155 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9633
# Train F1: 0.9959
# 01800: TRAIN| LT=0.142 LP=0.022 LKL=6.517 LPS=0.013 LKLS=4.206 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9556
# Train F1: 0.9938
# 01850: TRAIN| LT=0.154 LP=0.028 LKL=6.813 LPS=0.014 LKLS=4.393 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9678
# Train F1: 0.9959
# 01900: TRAIN| LT=0.136 LP=0.012 LKL=6.976 LPS=0.010 LKLS=4.386 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9637
# Train F1: 0.9938
# 01950: TRAIN| LT=0.139 LP=0.015 LKL=6.736 LPS=0.014 LKLS=4.197 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9555
# Train F1: 0.9938
# 02000: TRAIN| LT=0.138 LP=0.019 LKL=6.571 LPS=0.012 LKLS=4.022 |
# Test F1: 0.9839
# Test ACC: 0.9775
# Test AUC: 0.9564
# f1: 0.9838709677419354
# acc: 0.9775280898876404
# auc: 0.9677985948477752
# Train F1: 0.9555
# 00050: TRAIN| LT=0.668 LP=0.279 LKL=8.978 LPS=0.160 LKLS=13.981 |
# Test F1: 0.9748
# Test ACC: 0.9659
# Test AUC: 0.9830
# Train F1: 0.9733
# 00100: TRAIN| LT=0.358 LP=0.106 LKL=8.137 LPS=0.076 LKLS=9.523 |
# Test F1: 0.9587
# Test ACC: 0.9432
# Test AUC: 0.9945
# Train F1: 0.9777
# 00150: TRAIN| LT=0.287 LP=0.073 LKL=7.433 LPS=0.062 LKLS=7.785 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9957
# Train F1: 0.9857
# 00200: TRAIN| LT=0.292 LP=0.083 LKL=7.536 LPS=0.057 LKLS=7.661 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9951
# Train F1: 0.9856
# 00250: TRAIN| LT=0.258 LP=0.075 LKL=7.269 LPS=0.041 LKLS=6.873 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9957
# Train F1: 0.9877
# 00300: TRAIN| LT=0.268 LP=0.058 LKL=7.530 LPS=0.060 LKLS=7.484 |
# Test F1: 0.9752
# Test ACC: 0.9659
# Test AUC: 0.9957
# Train F1: 0.9898
# 00350: TRAIN| LT=0.244 LP=0.042 LKL=7.396 LPS=0.058 LKLS=6.866 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9964
# Train F1: 0.9898
# 00400: TRAIN| LT=0.244 LP=0.081 LKL=7.109 LPS=0.032 LKLS=6.020 |
# Test F1: 0.9752
# Test ACC: 0.9659
# Test AUC: 0.9951
# Train F1: 0.9855
# 00450: TRAIN| LT=0.238 LP=0.048 LKL=7.137 LPS=0.058 LKLS=6.065 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9964
# Train F1: 0.9815
# 00500: TRAIN| LT=0.222 LP=0.050 LKL=7.220 LPS=0.036 LKLS=6.436 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9951
# Train F1: 0.9918
# 00550: TRAIN| LT=0.244 LP=0.055 LKL=7.166 LPS=0.055 LKLS=6.222 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9951
# Train F1: 0.9877
# 00600: TRAIN| LT=0.227 LP=0.063 LKL=7.063 LPS=0.032 LKLS=6.162 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9957
# Train F1: 0.9878
# 00650: TRAIN| LT=0.222 LP=0.052 LKL=7.004 LPS=0.040 LKLS=5.945 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9951
# Train F1: 0.9939
# 00700: TRAIN| LT=0.217 LP=0.055 LKL=7.212 LPS=0.028 LKLS=6.170 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9957
# Train F1: 0.9898
# 00750: TRAIN| LT=0.173 LP=0.020 LKL=7.123 LPS=0.024 LKLS=5.782 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9964
# Train F1: 0.9898
# 00800: TRAIN| LT=0.197 LP=0.041 LKL=7.109 LPS=0.024 LKLS=6.108 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9964
# Train F1: 0.9939
# 00850: TRAIN| LT=0.199 LP=0.052 LKL=6.958 LPS=0.022 LKLS=5.538 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9964
# Train F1: 0.9878
# 00900: TRAIN| LT=0.208 LP=0.054 LKL=6.957 LPS=0.029 LKLS=5.517 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9964
# Train F1: 0.9918
# 00950: TRAIN| LT=0.185 LP=0.039 LKL=7.022 LPS=0.018 LKLS=5.749 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9964
# Train F1: 0.9939
# 01000: TRAIN| LT=0.216 LP=0.061 LKL=6.993 LPS=0.031 LKLS=5.453 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9964
# Train F1: 0.9918
# 01050: TRAIN| LT=0.190 LP=0.028 LKL=7.021 LPS=0.037 LKLS=5.454 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9957
# Train F1: 0.9835
# 01100: TRAIN| LT=0.181 LP=0.032 LKL=7.128 LPS=0.025 LKLS=5.353 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9976
# Train F1: 0.9878
# 01150: TRAIN| LT=0.208 LP=0.043 LKL=7.082 LPS=0.042 LKLS=5.245 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9964
# Train F1: 0.9877
# 01200: TRAIN| LT=0.173 LP=0.029 LKL=6.945 LPS=0.023 LKLS=5.194 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9964
# Train F1: 0.9856
# 01250: TRAIN| LT=0.176 LP=0.034 LKL=6.970 LPS=0.022 LKLS=5.082 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9964
# Train F1: 0.9857
# 01300: TRAIN| LT=0.184 LP=0.035 LKL=7.091 LPS=0.027 LKLS=5.038 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9957
# Train F1: 0.9898
# 01350: TRAIN| LT=0.186 LP=0.042 LKL=6.654 LPS=0.032 LKLS=4.553 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9957
# Train F1: 0.9939
# 01400: TRAIN| LT=0.181 LP=0.036 LKL=7.130 LPS=0.025 LKLS=4.925 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9964
# Train F1: 0.9878
# 01450: TRAIN| LT=0.182 LP=0.026 LKL=6.819 LPS=0.043 LKLS=4.494 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9945
# Train F1: 0.9878
# 01500: TRAIN| LT=0.189 LP=0.040 LKL=6.624 LPS=0.039 LKLS=4.382 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9933
# Train F1: 0.9939
# 01550: TRAIN| LT=0.167 LP=0.038 LKL=6.607 LPS=0.019 LKLS=4.454 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9951
# Train F1: 0.9878
# 01600: TRAIN| LT=0.163 LP=0.032 LKL=6.624 LPS=0.024 LKLS=4.107 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9964
# Train F1: 0.9938
# 01650: TRAIN| LT=0.170 LP=0.032 LKL=6.895 LPS=0.025 LKLS=4.408 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9970
# Train F1: 0.9899
# 01700: TRAIN| LT=0.157 LP=0.027 LKL=6.580 LPS=0.023 LKLS=4.118 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9957
# Train F1: 0.9898
# 01750: TRAIN| LT=0.181 LP=0.031 LKL=6.659 LPS=0.043 LKLS=4.002 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9970
# Train F1: 0.9918
# 01800: TRAIN| LT=0.169 LP=0.038 LKL=6.464 LPS=0.026 LKLS=4.087 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9927
# Train F1: 0.9918
# 01850: TRAIN| LT=0.189 LP=0.034 LKL=6.761 LPS=0.050 LKLS=3.756 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9970
# Train F1: 0.9939
# 01900: TRAIN| LT=0.153 LP=0.030 LKL=6.406 LPS=0.023 LKLS=3.591 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9964
# Train F1: 0.9918
# 01950: TRAIN| LT=0.141 LP=0.023 LKL=6.381 LPS=0.018 LKLS=3.661 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9970
# Train F1: 0.9918
# 02000: TRAIN| LT=0.160 LP=0.031 LKL=6.478 LPS=0.028 LKLS=3.629 |
# Test F1: 0.9756
# Test ACC: 0.9659
# Test AUC: 0.9957
# f1: 0.975609756097561
# acc: 0.9659090909090909
# auc: 0.9975713418336368
# f1 [0.9752066115702478, 0.9917355371900827, 0.9677419354838709, 0.9838709677419354, 0.975609756097561]
# average f1: 0.9788329616167395±0.008226886304086998
# acc [0.9662921348314607, 0.9887640449438202, 0.9550561797752809, 0.9775280898876404, 0.9659090909090909]
# average acc: 0.9707099080694587±0.011489501615662522
# auc [0.9718969555035128, 0.9976580796252927, 0.9508196721311475, 0.9677985948477752, 0.9975713418336368]
# average auc: 0.977148928788273±0.018143549525660746
