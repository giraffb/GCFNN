# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
data_class={'nonIBD':0,'CD':1,'UC':1}
meta_data['diagnosis']=meta_data['diagnosis'].map(data_class)

x1=metabolomics
print('输入各组学数据表：',x1.shape,meta_data.shape)

#重构数据表和标签表
X1 = x1
index_new=X1.index
print(index_new)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,meta_data.shape)
X_set=[X1]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0

#print(Mask)
#print(X_set)
Y = meta_data['diagnosis'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (546, 596) (2891, 1)
# Index(['PSM7J1BF', 'CSM7KORK', 'HSM7J4HS', 'MSM9VZNL', 'MSMB4LYB', 'MSM6J2PM',
#        'MSMA26ET', 'CSM79HMN', 'CSM67UB1', 'HSM7J4IS',
#        ...
#        'PSM7J134', 'HSM5FZBJ', 'CSM79HK1', 'CSM5MCTZ', 'CSM9X21P', 'CSM5MCXF',
#        'CSM67U9P', 'CSM7KOPQ', 'HSMA33LV', 'MSM5LLFK'],
#       dtype='object', name='External ID', length=546)
# 集合所有样本重构数据表： (546, 596) (546, 1)
# 标签转换为one-hot编码： (546, 2) 135.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap_mb'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 8, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1', f1_cv)
print('average f1: {}±{}'.format(np.mean(f1_cv), np.std(f1_cv)))
print('acc', acc_cv)
print('average acc: {}±{}'.format(np.mean(acc_cv), np.std(acc_cv)))
print('auc', auc_cv)
print('average auc: {}±{}'.format(np.mean(auc_cv), np.std(auc_cv)))
# Out:
# Train F1: 0.8594
# 00050: TRAIN| LT=1.204 LP=0.580 LKL=4.312 LPS=0.573 LKLS=0.721 |
# Test F1: 0.8601
# Test ACC: 0.7545
# Test AUC: 0.6867
# Train F1: 0.8598
# 00100: TRAIN| LT=1.135 LP=0.537 LKL=4.456 LPS=0.532 LKLS=2.169 |
# Test F1: 0.8601
# Test ACC: 0.7545
# Test AUC: 0.6912
# Train F1: 0.8477
# 00150: TRAIN| LT=1.058 LP=0.486 LKL=5.386 LPS=0.481 LKLS=3.725 |
# Test F1: 0.8402
# Test ACC: 0.7545
# Test AUC: 0.7158
# Train F1: 0.8685
# 00200: TRAIN| LT=0.998 LP=0.456 LKL=5.632 LPS=0.449 LKLS=3.740 |
# Test F1: 0.8121
# Test ACC: 0.7182
# Test AUC: 0.7296
# Train F1: 0.8473
# 00250: TRAIN| LT=0.989 LP=0.445 LKL=5.795 LPS=0.445 LKLS=4.152 |
# Test F1: 0.8121
# Test ACC: 0.7182
# Test AUC: 0.7439
# Train F1: 0.8688
# 00300: TRAIN| LT=0.965 LP=0.442 LKL=5.760 LPS=0.427 LKLS=3.888 |
# Test F1: 0.8242
# Test ACC: 0.7364
# Test AUC: 0.7523
# Train F1: 0.8559
# 00350: TRAIN| LT=0.979 LP=0.449 LKL=5.817 LPS=0.430 LKLS=4.132 |
# Test F1: 0.8171
# Test ACC: 0.7273
# Test AUC: 0.7604
# Train F1: 0.8784
# 00400: TRAIN| LT=0.936 LP=0.433 LKL=5.898 LPS=0.401 LKLS=4.284 |
# Test F1: 0.8148
# Test ACC: 0.7273
# Test AUC: 0.7671
# Train F1: 0.8646
# 00450: TRAIN| LT=0.885 LP=0.393 LKL=5.991 LPS=0.386 LKLS=4.614 |
# Test F1: 0.8148
# Test ACC: 0.7273
# Test AUC: 0.7693
# Train F1: 0.8779
# 00500: TRAIN| LT=0.914 LP=0.409 LKL=5.970 LPS=0.398 LKLS=4.710 |
# Test F1: 0.8199
# Test ACC: 0.7364
# Test AUC: 0.7733
# Train F1: 0.8657
# 00550: TRAIN| LT=0.914 LP=0.419 LKL=5.924 LPS=0.392 LKLS=4.404 |
# Test F1: 0.8125
# Test ACC: 0.7273
# Test AUC: 0.7769
# Train F1: 0.8824
# 00600: TRAIN| LT=0.910 LP=0.427 LKL=5.913 LPS=0.381 LKLS=4.311 |
# Test F1: 0.8125
# Test ACC: 0.7273
# Test AUC: 0.7782
# Train F1: 0.8850
# 00650: TRAIN| LT=0.870 LP=0.383 LKL=6.107 LPS=0.377 LKLS=4.839 |
# Test F1: 0.8176
# Test ACC: 0.7364
# Test AUC: 0.7822
# Train F1: 0.8645
# 00700: TRAIN| LT=0.872 LP=0.391 LKL=6.027 LPS=0.374 LKLS=4.664 |
# Test F1: 0.8250
# Test ACC: 0.7455
# Test AUC: 0.7845
# Train F1: 0.8689
# 00750: TRAIN| LT=0.840 LP=0.359 LKL=6.110 LPS=0.370 LKLS=4.873 |
# Test F1: 0.8302
# Test ACC: 0.7545
# Test AUC: 0.7867
# Train F1: 0.8843
# 00800: TRAIN| LT=0.862 LP=0.395 LKL=6.199 LPS=0.355 LKLS=5.062 |
# Test F1: 0.8205
# Test ACC: 0.7455
# Test AUC: 0.7898
# Train F1: 0.8817
# 00850: TRAIN| LT=0.847 LP=0.385 LKL=6.185 LPS=0.350 LKLS=5.042 |
# Test F1: 0.8153
# Test ACC: 0.7364
# Test AUC: 0.7894
# Train F1: 0.8750
# 00900: TRAIN| LT=0.867 LP=0.370 LKL=6.112 LPS=0.391 LKLS=4.460 |
# Test F1: 0.8026
# Test ACC: 0.7273
# Test AUC: 0.7938
# Train F1: 0.8701
# 00950: TRAIN| LT=0.819 LP=0.363 LKL=6.140 LPS=0.348 LKLS=4.687 |
# Test F1: 0.8052
# Test ACC: 0.7273
# Test AUC: 0.7903
# Train F1: 0.8846
# 01000: TRAIN| LT=0.814 LP=0.361 LKL=6.179 LPS=0.342 LKLS=4.908 |
# Test F1: 0.8077
# Test ACC: 0.7273
# Test AUC: 0.7938
# Train F1: 0.8780
# 01050: TRAIN| LT=0.805 LP=0.342 LKL=6.286 LPS=0.352 LKLS=4.840 |
# Test F1: 0.8026
# Test ACC: 0.7273
# Test AUC: 0.7938
# Train F1: 0.8879
# 01100: TRAIN| LT=0.826 LP=0.365 LKL=6.238 LPS=0.353 LKLS=4.520 |
# Test F1: 0.8026
# Test ACC: 0.7273
# Test AUC: 0.7965
# Train F1: 0.8832
# 01150: TRAIN| LT=0.785 LP=0.338 LKL=6.294 LPS=0.336 LKLS=4.763 |
# Test F1: 0.8205
# Test ACC: 0.7455
# Test AUC: 0.7947
# Train F1: 0.8636
# 01200: TRAIN| LT=0.787 LP=0.356 LKL=6.381 LPS=0.318 LKLS=4.958 |
# Test F1: 0.8258
# Test ACC: 0.7545
# Test AUC: 0.7952
# Train F1: 0.9034
# 01250: TRAIN| LT=0.780 LP=0.337 LKL=6.519 LPS=0.325 LKLS=5.226 |
# Test F1: 0.8182
# Test ACC: 0.7455
# Test AUC: 0.7970
# Train F1: 0.9053
# 01300: TRAIN| LT=0.783 LP=0.348 LKL=6.575 LPS=0.317 LKLS=5.216 |
# Test F1: 0.8158
# Test ACC: 0.7455
# Test AUC: 0.7983
# Train F1: 0.8892
# 01350: TRAIN| LT=0.725 LP=0.312 LKL=6.592 LPS=0.294 LKLS=5.339 |
# Test F1: 0.8333
# Test ACC: 0.7636
# Test AUC: 0.8050
# Train F1: 0.8919
# 01400: TRAIN| LT=0.761 LP=0.333 LKL=6.503 LPS=0.314 LKLS=4.919 |
# Test F1: 0.8333
# Test ACC: 0.7636
# Test AUC: 0.8046
# Train F1: 0.8844
# 01450: TRAIN| LT=0.786 LP=0.343 LKL=6.638 LPS=0.326 LKLS=4.991 |
# Test F1: 0.8000
# Test ACC: 0.7273
# Test AUC: 0.8010
# Train F1: 0.9013
# 01500: TRAIN| LT=0.725 LP=0.313 LKL=6.577 LPS=0.297 LKLS=4.927 |
# Test F1: 0.8500
# Test ACC: 0.7818
# Test AUC: 0.8117
# Train F1: 0.9170
# 01550: TRAIN| LT=0.731 LP=0.306 LKL=6.596 LPS=0.312 LKLS=4.695 |
# Test F1: 0.8312
# Test ACC: 0.7636
# Test AUC: 0.8059
# Train F1: 0.8953
# 01600: TRAIN| LT=0.728 LP=0.301 LKL=6.886 LPS=0.303 LKLS=5.504 |
# Test F1: 0.8366
# Test ACC: 0.7727
# Test AUC: 0.8037
# Train F1: 0.8925
# 01650: TRAIN| LT=0.753 LP=0.326 LKL=6.718 LPS=0.310 LKLS=5.001 |
# Test F1: 0.8642
# Test ACC: 0.8000
# Test AUC: 0.8121
# Train F1: 0.8962
# 01700: TRAIN| LT=0.724 LP=0.307 LKL=6.820 LPS=0.298 LKLS=5.120 |
# Test F1: 0.8642
# Test ACC: 0.8000
# Test AUC: 0.8104
# Train F1: 0.9179
# 01750: TRAIN| LT=0.677 LP=0.298 LKL=6.733 LPS=0.260 LKLS=5.067 |
# Test F1: 0.8589
# Test ACC: 0.7909
# Test AUC: 0.8086
# Train F1: 0.9096
# 01800: TRAIN| LT=0.685 LP=0.280 LKL=6.993 LPS=0.281 LKLS=5.406 |
# Test F1: 0.8642
# Test ACC: 0.8000
# Test AUC: 0.8112
# Train F1: 0.9074
# 01850: TRAIN| LT=0.711 LP=0.306 LKL=6.899 LPS=0.284 LKLS=5.157 |
# Test F1: 0.8696
# Test ACC: 0.8091
# Test AUC: 0.8130
# Train F1: 0.9048
# 01900: TRAIN| LT=0.706 LP=0.289 LKL=6.887 LPS=0.296 LKLS=5.090 |
# Test F1: 0.8639
# Test ACC: 0.7909
# Test AUC: 0.8086
# Train F1: 0.9085
# 01950: TRAIN| LT=0.683 LP=0.265 LKL=6.969 LPS=0.297 LKLS=5.162 |
# Test F1: 0.8642
# Test ACC: 0.8000
# Test AUC: 0.8162
# Train F1: 0.9039
# 02000: TRAIN| LT=0.657 LP=0.281 LKL=7.051 LPS=0.251 LKLS=5.343 |
# Test F1: 0.8571
# Test ACC: 0.7818
# Test AUC: 0.8063
# f1: 0.8695652173913043
# acc: 0.8090909090909091
# auc: 0.8130298973672467
# Train F1: 0.8515
# 00050: TRAIN| LT=1.226 LP=0.590 LKL=4.379 LPS=0.580 LKLS=1.166 |
# Test F1: 0.8586
# Test ACC: 0.7523
# Test AUC: 0.6527
# Train F1: 0.8583
# 00100: TRAIN| LT=1.125 LP=0.535 LKL=4.618 LPS=0.524 LKLS=2.019 |
# Test F1: 0.8586
# Test ACC: 0.7523
# Test AUC: 0.7191
# Train F1: 0.8501
# 00150: TRAIN| LT=1.061 LP=0.500 LKL=5.469 LPS=0.468 LKLS=3.941 |
# Test F1: 0.8605
# Test ACC: 0.7798
# Test AUC: 0.7123
# Train F1: 0.8701
# 00200: TRAIN| LT=1.016 LP=0.471 LKL=5.694 LPS=0.448 LKLS=4.034 |
# Test F1: 0.8333
# Test ACC: 0.7431
# Test AUC: 0.7114
# Train F1: 0.8636
# 00250: TRAIN| LT=0.984 LP=0.454 LKL=5.776 LPS=0.431 LKLS=4.097 |
# Test F1: 0.8121
# Test ACC: 0.7156
# Test AUC: 0.7173
# Train F1: 0.8672
# 00300: TRAIN| LT=0.941 LP=0.424 LKL=5.876 LPS=0.415 LKLS=4.356 |
# Test F1: 0.7975
# Test ACC: 0.6972
# Test AUC: 0.7254
# Train F1: 0.8530
# 00350: TRAIN| LT=0.980 LP=0.449 LKL=5.906 LPS=0.428 LKLS=4.399 |
# Test F1: 0.7975
# Test ACC: 0.6972
# Test AUC: 0.7335
# Train F1: 0.8713
# 00400: TRAIN| LT=0.929 LP=0.424 LKL=6.144 LPS=0.393 LKLS=5.098 |
# Test F1: 0.7901
# Test ACC: 0.6881
# Test AUC: 0.7326
# Train F1: 0.8533
# 00450: TRAIN| LT=0.863 LP=0.380 LKL=6.110 LPS=0.372 LKLS=4.906 |
# Test F1: 0.7925
# Test ACC: 0.6972
# Test AUC: 0.7367
# Train F1: 0.8459
# 00500: TRAIN| LT=0.884 LP=0.408 LKL=6.036 LPS=0.368 LKLS=4.752 |
# Test F1: 0.7792
# Test ACC: 0.6881
# Test AUC: 0.7389
# Train F1: 0.8830
# 00550: TRAIN| LT=0.869 LP=0.397 LKL=6.126 LPS=0.360 LKLS=4.999 |
# Test F1: 0.7742
# Test ACC: 0.6789
# Test AUC: 0.7444
# Train F1: 0.8675
# 00600: TRAIN| LT=0.865 LP=0.379 LKL=6.167 LPS=0.373 LKLS=5.119 |
# Test F1: 0.7821
# Test ACC: 0.6881
# Test AUC: 0.7435
# Train F1: 0.8807
# 00650: TRAIN| LT=0.828 LP=0.369 LKL=6.223 LPS=0.343 LKLS=5.255 |
# Test F1: 0.7821
# Test ACC: 0.6881
# Test AUC: 0.7430
# Train F1: 0.8602
# 00700: TRAIN| LT=0.817 LP=0.369 LKL=6.203 LPS=0.336 LKLS=4.930 |
# Test F1: 0.7662
# Test ACC: 0.6697
# Test AUC: 0.7430
# Train F1: 0.8916
# 00750: TRAIN| LT=0.797 LP=0.350 LKL=6.351 LPS=0.330 LKLS=5.387 |
# Test F1: 0.7742
# Test ACC: 0.6789
# Test AUC: 0.7435
# Train F1: 0.8882
# 00800: TRAIN| LT=0.806 LP=0.367 LKL=6.275 LPS=0.327 LKLS=4.944 |
# Test F1: 0.7662
# Test ACC: 0.6697
# Test AUC: 0.7453
# Train F1: 0.8879
# 00850: TRAIN| LT=0.792 LP=0.349 LKL=6.402 LPS=0.327 LKLS=5.188 |
# Test F1: 0.7432
# Test ACC: 0.6514
# Test AUC: 0.7389
# Train F1: 0.8865
# 00900: TRAIN| LT=0.803 LP=0.361 LKL=6.326 LPS=0.328 LKLS=5.096 |
# Test F1: 0.7742
# Test ACC: 0.6789
# Test AUC: 0.7403
# Train F1: 0.8872
# 00950: TRAIN| LT=0.750 LP=0.322 LKL=6.563 LPS=0.307 LKLS=5.553 |
# Test F1: 0.7662
# Test ACC: 0.6697
# Test AUC: 0.7385
# Train F1: 0.8974
# 01000: TRAIN| LT=0.745 LP=0.323 LKL=6.473 LPS=0.304 LKLS=5.326 |
# Test F1: 0.7662
# Test ACC: 0.6697
# Test AUC: 0.7416
# Train F1: 0.8885
# 01050: TRAIN| LT=0.754 LP=0.328 LKL=6.596 LPS=0.306 LKLS=5.509 |
# Test F1: 0.7712
# Test ACC: 0.6789
# Test AUC: 0.7317
# Train F1: 0.8855
# 01100: TRAIN| LT=0.696 LP=0.297 LKL=6.616 LPS=0.279 LKLS=5.440 |
# Test F1: 0.7467
# Test ACC: 0.6514
# Test AUC: 0.7290
# Train F1: 0.9096
# 01150: TRAIN| LT=0.706 LP=0.314 LKL=6.578 LPS=0.272 LKLS=5.471 |
# Test F1: 0.7898
# Test ACC: 0.6972
# Test AUC: 0.7294
# Train F1: 0.9012
# 01200: TRAIN| LT=0.704 LP=0.307 LKL=6.473 LPS=0.282 LKLS=5.073 |
# Test F1: 0.8025
# Test ACC: 0.7156
# Test AUC: 0.7317
# Train F1: 0.9119
# 01250: TRAIN| LT=0.704 LP=0.308 LKL=6.626 LPS=0.277 LKLS=5.308 |
# Test F1: 0.7600
# Test ACC: 0.6697
# Test AUC: 0.7276
# Train F1: 0.8983
# 01300: TRAIN| LT=0.672 LP=0.278 LKL=6.805 LPS=0.269 LKLS=5.689 |
# Test F1: 0.8000
# Test ACC: 0.7156
# Test AUC: 0.7304
# Train F1: 0.9110
# 01350: TRAIN| LT=0.740 LP=0.309 LKL=6.806 LPS=0.307 LKLS=5.545 |
# Test F1: 0.7763
# Test ACC: 0.6881
# Test AUC: 0.7281
# Train F1: 0.9009
# 01400: TRAIN| LT=0.683 LP=0.264 LKL=7.055 LPS=0.287 LKLS=6.076 |
# Test F1: 0.8000
# Test ACC: 0.7156
# Test AUC: 0.7285
# Train F1: 0.9044
# 01450: TRAIN| LT=0.665 LP=0.282 LKL=6.690 LPS=0.265 LKLS=5.097 |
# Test F1: 0.7763
# Test ACC: 0.6881
# Test AUC: 0.7258
# Train F1: 0.9063
# 01500: TRAIN| LT=0.671 LP=0.278 LKL=6.787 LPS=0.272 LKLS=5.268 |
# Test F1: 0.8000
# Test ACC: 0.7156
# Test AUC: 0.7254
# Train F1: 0.9048
# 01550: TRAIN| LT=0.663 LP=0.278 LKL=6.703 LPS=0.264 LKLS=5.329 |
# Test F1: 0.8098
# Test ACC: 0.7156
# Test AUC: 0.7281
# Train F1: 0.9023
# 01600: TRAIN| LT=0.677 LP=0.283 LKL=6.989 LPS=0.267 LKLS=5.665 |
# Test F1: 0.8077
# Test ACC: 0.7248
# Test AUC: 0.7236
# Train F1: 0.9158
# 01650: TRAIN| LT=0.678 LP=0.285 LKL=6.854 LPS=0.271 LKLS=5.340 |
# Test F1: 0.8050
# Test ACC: 0.7156
# Test AUC: 0.7249
# Train F1: 0.8969
# 01700: TRAIN| LT=0.641 LP=0.262 LKL=7.061 LPS=0.252 LKLS=5.604 |
# Test F1: 0.7763
# Test ACC: 0.6881
# Test AUC: 0.7191
# Train F1: 0.9016
# 01750: TRAIN| LT=0.668 LP=0.278 LKL=7.141 LPS=0.262 LKLS=5.665 |
# Test F1: 0.7815
# Test ACC: 0.6972
# Test AUC: 0.7231
# Train F1: 0.9191
# 01800: TRAIN| LT=0.664 LP=0.289 LKL=6.906 LPS=0.254 LKLS=5.237 |
# Test F1: 0.8025
# Test ACC: 0.7156
# Test AUC: 0.7227
# Train F1: 0.9148
# 01850: TRAIN| LT=0.627 LP=0.261 LKL=6.852 LPS=0.247 LKLS=5.161 |
# Test F1: 0.8125
# Test ACC: 0.7248
# Test AUC: 0.7213
# Train F1: 0.9158
# 01900: TRAIN| LT=0.671 LP=0.288 LKL=7.026 LPS=0.259 LKLS=5.400 |
# Test F1: 0.7975
# Test ACC: 0.7064
# Test AUC: 0.7173
# Train F1: 0.9112
# 01950: TRAIN| LT=0.637 LP=0.267 LKL=6.832 LPS=0.250 LKLS=5.128 |
# Test F1: 0.8000
# Test ACC: 0.6972
# Test AUC: 0.7195
# Train F1: 0.9110
# 02000: TRAIN| LT=0.634 LP=0.245 LKL=7.034 LPS=0.266 LKLS=5.211 |
# Test F1: 0.8050
# Test ACC: 0.7156
# Test AUC: 0.7173
# f1: 0.8604651162790697
# acc: 0.7798165137614679
# auc: 0.7122854561878953
# Train F1: 0.8556
# 00050: TRAIN| LT=1.238 LP=0.582 LKL=4.360 LPS=0.596 LKLS=1.744 |
# Test F1: 0.8586
# Test ACC: 0.7523
# Test AUC: 0.7570
# Train F1: 0.8590
# 00100: TRAIN| LT=1.159 LP=0.546 LKL=4.533 LPS=0.550 LKLS=1.788 |
# Test F1: 0.8586
# Test ACC: 0.7523
# Test AUC: 0.7498
# Train F1: 0.8583
# 00150: TRAIN| LT=1.092 LP=0.507 LKL=5.254 LPS=0.498 LKLS=3.443 |
# Test F1: 0.8586
# Test ACC: 0.7523
# Test AUC: 0.7737
# Train F1: 0.8691
# 00200: TRAIN| LT=0.992 LP=0.455 LKL=5.586 LPS=0.443 LKLS=3.799 |
# Test F1: 0.8636
# Test ACC: 0.7798
# Test AUC: 0.7900
# Train F1: 0.8571
# 00250: TRAIN| LT=0.973 LP=0.453 LKL=5.749 LPS=0.421 LKLS=4.134 |
# Test F1: 0.8636
# Test ACC: 0.7798
# Test AUC: 0.7958
# Train F1: 0.8612
# 00300: TRAIN| LT=0.950 LP=0.434 LKL=5.790 LPS=0.418 LKLS=4.024 |
# Test F1: 0.8636
# Test ACC: 0.7798
# Test AUC: 0.7972
# Train F1: 0.8596
# 00350: TRAIN| LT=0.928 LP=0.425 LKL=5.869 LPS=0.401 LKLS=4.210 |
# Test F1: 0.8571
# Test ACC: 0.7706
# Test AUC: 0.8008
# Train F1: 0.8571
# 00400: TRAIN| LT=0.987 LP=0.451 LKL=5.911 LPS=0.435 LKLS=4.223 |
# Test F1: 0.8506
# Test ACC: 0.7615
# Test AUC: 0.8004
# Train F1: 0.8642
# 00450: TRAIN| LT=0.941 LP=0.399 LKL=5.980 LPS=0.438 LKLS=4.474 |
# Test F1: 0.8506
# Test ACC: 0.7615
# Test AUC: 0.7972
# Train F1: 0.8563
# 00500: TRAIN| LT=0.950 LP=0.441 LKL=5.949 LPS=0.406 LKLS=4.380 |
# Test F1: 0.8555
# Test ACC: 0.7706
# Test AUC: 0.8004
# Train F1: 0.8721
# 00550: TRAIN| LT=0.921 LP=0.421 LKL=5.992 LPS=0.395 LKLS=4.570 |
# Test F1: 0.8555
# Test ACC: 0.7706
# Test AUC: 0.8035
# Train F1: 0.8725
# 00600: TRAIN| LT=0.913 LP=0.427 LKL=5.963 LPS=0.383 LKLS=4.392 |
# Test F1: 0.8655
# Test ACC: 0.7890
# Test AUC: 0.7977
# Train F1: 0.8708
# 00650: TRAIN| LT=0.910 LP=0.425 LKL=6.151 LPS=0.375 LKLS=4.856 |
# Test F1: 0.8639
# Test ACC: 0.7890
# Test AUC: 0.7990
# Train F1: 0.8600
# 00700: TRAIN| LT=0.927 LP=0.436 LKL=6.050 LPS=0.385 LKLS=4.553 |
# Test F1: 0.8639
# Test ACC: 0.7890
# Test AUC: 0.7972
# Train F1: 0.8684
# 00750: TRAIN| LT=0.871 LP=0.386 LKL=6.156 LPS=0.376 LKLS=4.823 |
# Test F1: 0.8571
# Test ACC: 0.7798
# Test AUC: 0.8022
# Train F1: 0.8647
# 00800: TRAIN| LT=0.872 LP=0.385 LKL=6.177 LPS=0.377 LKLS=4.813 |
# Test F1: 0.8503
# Test ACC: 0.7706
# Test AUC: 0.8031
# Train F1: 0.8694
# 00850: TRAIN| LT=0.883 LP=0.406 LKL=6.232 LPS=0.368 LKLS=4.736 |
# Test F1: 0.8642
# Test ACC: 0.7982
# Test AUC: 0.8022
# Train F1: 0.8794
# 00900: TRAIN| LT=0.848 LP=0.388 LKL=6.198 LPS=0.352 LKLS=4.657 |
# Test F1: 0.8434
# Test ACC: 0.7615
# Test AUC: 0.8026
# Train F1: 0.8680
# 00950: TRAIN| LT=0.836 LP=0.371 LKL=6.209 LPS=0.357 LKLS=4.617 |
# Test F1: 0.8485
# Test ACC: 0.7706
# Test AUC: 0.8004
# Train F1: 0.8733
# 01000: TRAIN| LT=0.840 LP=0.382 LKL=6.249 LPS=0.351 LKLS=4.414 |
# Test F1: 0.8519
# Test ACC: 0.7798
# Test AUC: 0.7981
# Train F1: 0.8767
# 01050: TRAIN| LT=0.820 LP=0.366 LKL=6.355 LPS=0.346 LKLS=4.566 |
# Test F1: 0.8344
# Test ACC: 0.7523
# Test AUC: 0.7958
# Train F1: 0.8741
# 01100: TRAIN| LT=0.811 LP=0.347 LKL=6.468 LPS=0.350 LKLS=4.886 |
# Test F1: 0.8434
# Test ACC: 0.7615
# Test AUC: 0.7936
# Train F1: 0.8778
# 01150: TRAIN| LT=0.819 LP=0.353 LKL=6.494 LPS=0.354 LKLS=4.818 |
# Test F1: 0.8323
# Test ACC: 0.7523
# Test AUC: 0.7913
# Train F1: 0.8788
# 01200: TRAIN| LT=0.792 LP=0.342 LKL=6.416 LPS=0.341 LKLS=4.519 |
# Test F1: 0.7838
# Test ACC: 0.7064
# Test AUC: 0.7818
# Train F1: 0.8713
# 01250: TRAIN| LT=0.786 LP=0.355 LKL=6.534 LPS=0.318 LKLS=4.658 |
# Test F1: 0.8250
# Test ACC: 0.7431
# Test AUC: 0.7864
# Train F1: 0.8840
# 01300: TRAIN| LT=0.795 LP=0.352 LKL=6.673 LPS=0.326 LKLS=5.025 |
# Test F1: 0.8313
# Test ACC: 0.7431
# Test AUC: 0.7796
# Train F1: 0.8852
# 01350: TRAIN| LT=0.772 LP=0.345 LKL=6.652 LPS=0.313 LKLS=4.746 |
# Test F1: 0.8364
# Test ACC: 0.7523
# Test AUC: 0.7846
# Train F1: 0.8790
# 01400: TRAIN| LT=0.783 LP=0.336 LKL=6.759 LPS=0.330 LKLS=4.953 |
# Test F1: 0.8344
# Test ACC: 0.7523
# Test AUC: 0.7724
# Train F1: 0.9000
# 01450: TRAIN| LT=0.775 LP=0.339 LKL=6.846 LPS=0.316 LKLS=5.181 |
# Test F1: 0.8383
# Test ACC: 0.7523
# Test AUC: 0.7534
# Train F1: 0.8852
# 01500: TRAIN| LT=0.758 LP=0.320 LKL=6.815 LPS=0.320 LKLS=4.922 |
# Test F1: 0.8101
# Test ACC: 0.7248
# Test AUC: 0.7660
# Train F1: 0.8922
# 01550: TRAIN| LT=0.726 LP=0.316 LKL=6.760 LPS=0.296 LKLS=4.645 |
# Test F1: 0.8344
# Test ACC: 0.7523
# Test AUC: 0.7602
# Train F1: 0.8852
# 01600: TRAIN| LT=0.757 LP=0.331 LKL=6.808 LPS=0.312 LKLS=4.589 |
# Test F1: 0.7871
# Test ACC: 0.6972
# Test AUC: 0.7570
# Train F1: 0.8832
# 01650: TRAIN| LT=0.766 LP=0.333 LKL=6.909 LPS=0.315 LKLS=4.782 |
# Test F1: 0.8171
# Test ACC: 0.7248
# Test AUC: 0.7416
# Train F1: 0.8966
# 01700: TRAIN| LT=0.726 LP=0.315 LKL=6.922 LPS=0.294 LKLS=4.714 |
# Test F1: 0.8171
# Test ACC: 0.7248
# Test AUC: 0.7556
# Train F1: 0.8885
# 01750: TRAIN| LT=0.728 LP=0.309 LKL=6.844 LPS=0.306 LKLS=4.442 |
# Test F1: 0.7662
# Test ACC: 0.6697
# Test AUC: 0.7525
# Train F1: 0.8832
# 01800: TRAIN| LT=0.734 LP=0.309 LKL=6.867 LPS=0.312 LKLS=4.423 |
# Test F1: 0.8171
# Test ACC: 0.7248
# Test AUC: 0.7425
# Train F1: 0.8831
# 01850: TRAIN| LT=0.709 LP=0.291 LKL=6.940 LPS=0.303 LKLS=4.521 |
# Test F1: 0.8221
# Test ACC: 0.7339
# Test AUC: 0.7385
# Train F1: 0.8999
# 01900: TRAIN| LT=0.708 LP=0.292 LKL=6.972 LPS=0.302 LKLS=4.474 |
# Test F1: 0.8242
# Test ACC: 0.7339
# Test AUC: 0.7344
# Train F1: 0.8978
# 01950: TRAIN| LT=0.701 LP=0.283 LKL=6.911 LPS=0.306 LKLS=4.361 |
# Test F1: 0.8242
# Test ACC: 0.7339
# Test AUC: 0.7308
# Train F1: 0.8920
# 02000: TRAIN| LT=0.676 LP=0.282 LKL=7.053 LPS=0.278 LKLS=4.528 |
# Test F1: 0.8171
# Test ACC: 0.7248
# Test AUC: 0.7371
# f1: 0.8654970760233918
# acc: 0.7889908256880734
# auc: 0.7976513098464317
# Train F1: 0.8560
# 00050: TRAIN| LT=1.186 LP=0.558 LKL=4.359 LPS=0.576 LKLS=0.809 |
# Test F1: 0.8586
# Test ACC: 0.7523
# Test AUC: 0.8717
# Train F1: 0.8613
# 00100: TRAIN| LT=1.148 LP=0.540 LKL=4.428 LPS=0.549 LKLS=1.452 |
# Test F1: 0.8586
# Test ACC: 0.7523
# Test AUC: 0.8681
# Train F1: 0.8609
# 00150: TRAIN| LT=1.070 LP=0.503 LKL=5.058 LPS=0.488 LKLS=2.887 |
# Test F1: 0.8586
# Test ACC: 0.7523
# Test AUC: 0.8939
# Train F1: 0.8634
# 00200: TRAIN| LT=1.043 LP=0.486 LKL=5.457 LPS=0.466 LKLS=3.554 |
# Test F1: 0.8927
# Test ACC: 0.8257
# Test AUC: 0.8826
# Train F1: 0.8739
# 00250: TRAIN| LT=1.004 LP=0.459 LKL=5.551 LPS=0.454 LKLS=3.563 |
# Test F1: 0.8902
# Test ACC: 0.8257
# Test AUC: 0.8857
# Train F1: 0.8547
# 00300: TRAIN| LT=0.983 LP=0.445 LKL=5.631 LPS=0.444 LKLS=3.763 |
# Test F1: 0.8902
# Test ACC: 0.8257
# Test AUC: 0.8898
# Train F1: 0.8580
# 00350: TRAIN| LT=0.960 LP=0.421 LKL=5.742 LPS=0.440 LKLS=4.168 |
# Test F1: 0.8837
# Test ACC: 0.8165
# Test AUC: 0.8898
# Train F1: 0.8689
# 00400: TRAIN| LT=0.966 LP=0.431 LKL=5.830 LPS=0.432 LKLS=4.435 |
# Test F1: 0.8889
# Test ACC: 0.8257
# Test AUC: 0.8844
# Train F1: 0.8665
# 00450: TRAIN| LT=0.937 LP=0.429 LKL=5.909 LPS=0.402 LKLS=4.634 |
# Test F1: 0.8889
# Test ACC: 0.8257
# Test AUC: 0.8826
# Train F1: 0.8708
# 00500: TRAIN| LT=0.939 LP=0.428 LKL=5.929 LPS=0.407 LKLS=4.539 |
# Test F1: 0.8824
# Test ACC: 0.8165
# Test AUC: 0.8794
# Train F1: 0.8761
# 00550: TRAIN| LT=0.921 LP=0.410 LKL=5.889 LPS=0.408 LKLS=4.400 |
# Test F1: 0.8757
# Test ACC: 0.8073
# Test AUC: 0.8776
# Train F1: 0.8710
# 00600: TRAIN| LT=0.894 LP=0.411 LKL=5.934 LPS=0.380 LKLS=4.369 |
# Test F1: 0.8690
# Test ACC: 0.7982
# Test AUC: 0.8767
# Train F1: 0.8673
# 00650: TRAIN| LT=0.923 LP=0.423 LKL=6.074 LPS=0.390 LKLS=4.878 |
# Test F1: 0.8623
# Test ACC: 0.7890
# Test AUC: 0.8717
# Train F1: 0.8673
# 00700: TRAIN| LT=0.881 LP=0.392 LKL=6.074 LPS=0.381 LKLS=4.819 |
# Test F1: 0.8623
# Test ACC: 0.7890
# Test AUC: 0.8735
# Train F1: 0.8769
# 00750: TRAIN| LT=0.866 LP=0.396 LKL=6.133 LPS=0.362 LKLS=4.657 |
# Test F1: 0.8554
# Test ACC: 0.7798
# Test AUC: 0.8731
# Train F1: 0.8928
# 00800: TRAIN| LT=0.856 LP=0.377 LKL=6.229 LPS=0.367 LKLS=4.940 |
# Test F1: 0.8623
# Test ACC: 0.7890
# Test AUC: 0.8767
# Train F1: 0.8863
# 00850: TRAIN| LT=0.834 LP=0.385 LKL=6.292 LPS=0.335 LKLS=5.094 |
# Test F1: 0.8639
# Test ACC: 0.7890
# Test AUC: 0.8790
# Train F1: 0.8726
# 00900: TRAIN| LT=0.838 LP=0.383 LKL=6.257 LPS=0.344 LKLS=4.877 |
# Test F1: 0.8606
# Test ACC: 0.7890
# Test AUC: 0.8776
# Train F1: 0.8706
# 00950: TRAIN| LT=0.779 LP=0.350 LKL=6.355 LPS=0.315 LKLS=5.021 |
# Test F1: 0.8606
# Test ACC: 0.7890
# Test AUC: 0.8771
# Train F1: 0.8914
# 01000: TRAIN| LT=0.783 LP=0.356 LKL=6.356 LPS=0.311 LKLS=5.262 |
# Test F1: 0.8621
# Test ACC: 0.7798
# Test AUC: 0.8794
# Train F1: 0.8853
# 01050: TRAIN| LT=0.786 LP=0.346 LKL=6.371 LPS=0.326 LKLS=5.068 |
# Test F1: 0.8521
# Test ACC: 0.7706
# Test AUC: 0.8785
# Train F1: 0.8825
# 01100: TRAIN| LT=0.786 LP=0.355 LKL=6.366 LPS=0.317 LKLS=4.957 |
# Test F1: 0.8589
# Test ACC: 0.7890
# Test AUC: 0.8808
# Train F1: 0.8944
# 01150: TRAIN| LT=0.773 LP=0.342 LKL=6.477 LPS=0.314 LKLS=5.168 |
# Test F1: 0.8503
# Test ACC: 0.7706
# Test AUC: 0.8753
# Train F1: 0.9025
# 01200: TRAIN| LT=0.773 LP=0.358 LKL=6.324 LPS=0.304 LKLS=4.787 |
# Test F1: 0.8471
# Test ACC: 0.7615
# Test AUC: 0.8726
# Train F1: 0.9010
# 01250: TRAIN| LT=0.724 LP=0.320 LKL=6.424 LPS=0.288 LKLS=5.204 |
# Test F1: 0.8555
# Test ACC: 0.7706
# Test AUC: 0.8740
# Train F1: 0.8866
# 01300: TRAIN| LT=0.752 LP=0.325 LKL=6.632 LPS=0.308 LKLS=5.296 |
# Test F1: 0.8452
# Test ACC: 0.7615
# Test AUC: 0.8717
# Train F1: 0.8853
# 01350: TRAIN| LT=0.720 LP=0.318 LKL=6.455 LPS=0.289 LKLS=4.883 |
# Test F1: 0.8488
# Test ACC: 0.7615
# Test AUC: 0.8695
# Train F1: 0.8994
# 01400: TRAIN| LT=0.709 LP=0.314 LKL=6.482 LPS=0.281 LKLS=4.905 |
# Test F1: 0.8500
# Test ACC: 0.7798
# Test AUC: 0.8681
# Train F1: 0.9066
# 01450: TRAIN| LT=0.698 LP=0.313 LKL=6.610 LPS=0.267 LKLS=5.140 |
# Test F1: 0.8428
# Test ACC: 0.7706
# Test AUC: 0.8708
# Train F1: 0.9005
# 01500: TRAIN| LT=0.720 LP=0.311 LKL=6.744 LPS=0.290 LKLS=5.128 |
# Test F1: 0.8354
# Test ACC: 0.7615
# Test AUC: 0.8663
# Train F1: 0.9091
# 01550: TRAIN| LT=0.672 LP=0.283 LKL=6.744 LPS=0.271 LKLS=5.057 |
# Test F1: 0.8500
# Test ACC: 0.7798
# Test AUC: 0.8622
# Train F1: 0.8937
# 01600: TRAIN| LT=0.691 LP=0.293 LKL=6.799 LPS=0.279 LKLS=5.125 |
# Test F1: 0.8481
# Test ACC: 0.7798
# Test AUC: 0.8650
# Train F1: 0.9164
# 01650: TRAIN| LT=0.681 LP=0.295 LKL=6.940 LPS=0.261 LKLS=5.527 |
# Test F1: 0.8750
# Test ACC: 0.7982
# Test AUC: 0.8767
# Train F1: 0.9131
# 01700: TRAIN| LT=0.658 LP=0.271 LKL=6.804 LPS=0.268 LKLS=5.133 |
# Test F1: 0.8671
# Test ACC: 0.7890
# Test AUC: 0.8677
# Train F1: 0.9147
# 01750: TRAIN| LT=0.676 LP=0.292 LKL=6.678 LPS=0.270 LKLS=4.810 |
# Test F1: 0.8555
# Test ACC: 0.7706
# Test AUC: 0.8627
# Train F1: 0.9141
# 01800: TRAIN| LT=0.637 LP=0.253 LKL=6.745 LPS=0.266 LKLS=4.996 |
# Test F1: 0.8555
# Test ACC: 0.7706
# Test AUC: 0.8681
# Train F1: 0.9226
# 01850: TRAIN| LT=0.660 LP=0.263 LKL=6.978 LPS=0.274 LKLS=5.340 |
# Test F1: 0.8521
# Test ACC: 0.7706
# Test AUC: 0.8726
# Train F1: 0.8974
# 01900: TRAIN| LT=0.659 LP=0.289 LKL=7.044 LPS=0.246 LKLS=5.286 |
# Test F1: 0.8706
# Test ACC: 0.7982
# Test AUC: 0.8672
# Train F1: 0.9143
# 01950: TRAIN| LT=0.635 LP=0.273 LKL=6.885 LPS=0.243 LKLS=5.071 |
# Test F1: 0.8555
# Test ACC: 0.7706
# Test AUC: 0.8668
# Train F1: 0.9048
# 02000: TRAIN| LT=0.642 LP=0.269 LKL=7.079 LPS=0.248 LKLS=5.477 |
# Test F1: 0.8555
# Test ACC: 0.7706
# Test AUC: 0.8672
# f1: 0.8926553672316384
# acc: 0.8256880733944955
# auc: 0.8825654923215898
# Train F1: 0.8545
# 00050: TRAIN| LT=1.203 LP=0.568 LKL=4.225 LPS=0.585 LKLS=0.716 |
# Test F1: 0.8586
# Test ACC: 0.7523
# Test AUC: 0.8243
# Train F1: 0.8575
# 00100: TRAIN| LT=1.140 LP=0.544 LKL=4.391 LPS=0.535 LKLS=1.709 |
# Test F1: 0.8586
# Test ACC: 0.7523
# Test AUC: 0.8220
# Train F1: 0.8522
# 00150: TRAIN| LT=1.086 LP=0.506 LKL=5.101 LPS=0.499 LKLS=2.948 |
# Test F1: 0.8696
# Test ACC: 0.7798
# Test AUC: 0.8455
# Train F1: 0.8515
# 00200: TRAIN| LT=1.050 LP=0.471 LKL=5.483 LPS=0.489 LKLS=3.480 |
# Test F1: 0.8780
# Test ACC: 0.8165
# Test AUC: 0.8514
# Train F1: 0.8490
# 00250: TRAIN| LT=1.016 LP=0.468 LKL=5.660 LPS=0.452 LKLS=3.919 |
# Test F1: 0.8780
# Test ACC: 0.8165
# Test AUC: 0.8496
# Train F1: 0.8628
# 00300: TRAIN| LT=0.994 LP=0.465 LKL=5.698 LPS=0.433 LKLS=3.890 |
# Test F1: 0.8642
# Test ACC: 0.7982
# Test AUC: 0.8473
# Train F1: 0.8547
# 00350: TRAIN| LT=0.953 LP=0.440 LKL=5.809 LPS=0.412 LKLS=4.281 |
# Test F1: 0.8642
# Test ACC: 0.7982
# Test AUC: 0.8460
# Train F1: 0.8514
# 00400: TRAIN| LT=0.970 LP=0.428 LKL=5.847 LPS=0.440 LKLS=4.347 |
# Test F1: 0.8625
# Test ACC: 0.7982
# Test AUC: 0.8415
# Train F1: 0.8653
# 00450: TRAIN| LT=0.922 LP=0.425 LKL=5.838 LPS=0.395 LKLS=4.295 |
# Test F1: 0.8553
# Test ACC: 0.7890
# Test AUC: 0.8437
# Train F1: 0.8539
# 00500: TRAIN| LT=0.911 LP=0.416 LKL=5.821 LPS=0.395 LKLS=4.227 |
# Test F1: 0.8625
# Test ACC: 0.7982
# Test AUC: 0.8383
# Train F1: 0.8525
# 00550: TRAIN| LT=0.935 LP=0.442 LKL=5.923 LPS=0.390 LKLS=4.420 |
# Test F1: 0.8590
# Test ACC: 0.7982
# Test AUC: 0.8365
# Train F1: 0.8551
# 00600: TRAIN| LT=0.900 LP=0.405 LKL=5.985 LPS=0.390 LKLS=4.545 |
# Test F1: 0.8590
# Test ACC: 0.7982
# Test AUC: 0.8342
# Train F1: 0.8593
# 00650: TRAIN| LT=0.902 LP=0.403 LKL=6.008 LPS=0.395 LKLS=4.472 |
# Test F1: 0.8497
# Test ACC: 0.7890
# Test AUC: 0.8311
# Train F1: 0.8802
# 00700: TRAIN| LT=0.886 LP=0.382 LKL=6.129 LPS=0.393 LKLS=4.979 |
# Test F1: 0.8516
# Test ACC: 0.7890
# Test AUC: 0.8266
# Train F1: 0.8720
# 00750: TRAIN| LT=0.833 LP=0.364 LKL=6.161 LPS=0.357 LKLS=5.034 |
# Test F1: 0.8442
# Test ACC: 0.7798
# Test AUC: 0.8198
# Train F1: 0.8908
# 00800: TRAIN| LT=0.848 LP=0.369 LKL=6.297 LPS=0.363 LKLS=5.380 |
# Test F1: 0.8442
# Test ACC: 0.7798
# Test AUC: 0.8175
# Train F1: 0.8819
# 00850: TRAIN| LT=0.852 LP=0.373 LKL=6.285 LPS=0.365 LKLS=5.124 |
# Test F1: 0.8212
# Test ACC: 0.7523
# Test AUC: 0.8157
# Train F1: 0.8916
# 00900: TRAIN| LT=0.834 LP=0.365 LKL=6.315 LPS=0.353 LKLS=5.294 |
# Test F1: 0.8289
# Test ACC: 0.7615
# Test AUC: 0.8044
# Train F1: 0.8765
# 00950: TRAIN| LT=0.839 LP=0.385 LKL=6.365 LPS=0.339 LKLS=5.157 |
# Test F1: 0.8289
# Test ACC: 0.7615
# Test AUC: 0.8044
# Train F1: 0.8752
# 01000: TRAIN| LT=0.817 LP=0.348 LKL=6.464 LPS=0.349 LKLS=5.431 |
# Test F1: 0.8366
# Test ACC: 0.7706
# Test AUC: 0.8035
# Train F1: 0.8711
# 01050: TRAIN| LT=0.818 LP=0.357 LKL=6.579 LPS=0.338 LKLS=5.714 |
# Test F1: 0.8289
# Test ACC: 0.7615
# Test AUC: 0.8022
# Train F1: 0.8826
# 01100: TRAIN| LT=0.846 LP=0.375 LKL=6.550 LPS=0.351 LKLS=5.460 |
# Test F1: 0.8442
# Test ACC: 0.7798
# Test AUC: 0.8008
# Train F1: 0.8806
# 01150: TRAIN| LT=0.801 LP=0.366 LKL=6.478 LPS=0.317 LKLS=5.252 |
# Test F1: 0.8442
# Test ACC: 0.7798
# Test AUC: 0.7967
# Train F1: 0.9028
# 01200: TRAIN| LT=0.774 LP=0.351 LKL=6.601 LPS=0.301 LKLS=5.604 |
# Test F1: 0.8289
# Test ACC: 0.7615
# Test AUC: 0.7900
# Train F1: 0.8912
# 01250: TRAIN| LT=0.751 LP=0.331 LKL=6.643 LPS=0.297 LKLS=5.612 |
# Test F1: 0.8442
# Test ACC: 0.7798
# Test AUC: 0.7977
# Train F1: 0.8777
# 01300: TRAIN| LT=0.766 LP=0.343 LKL=6.655 LPS=0.303 LKLS=5.398 |
# Test F1: 0.8133
# Test ACC: 0.7431
# Test AUC: 0.7873
# Train F1: 0.8838
# 01350: TRAIN| LT=0.765 LP=0.332 LKL=6.787 LPS=0.307 LKLS=5.776 |
# Test F1: 0.8289
# Test ACC: 0.7615
# Test AUC: 0.7864
# Train F1: 0.8994
# 01400: TRAIN| LT=0.794 LP=0.339 LKL=6.737 LPS=0.332 LKLS=5.572 |
# Test F1: 0.8366
# Test ACC: 0.7706
# Test AUC: 0.7827
# Train F1: 0.9023
# 01450: TRAIN| LT=0.728 LP=0.309 LKL=6.866 LPS=0.292 LKLS=5.824 |
# Test F1: 0.8590
# Test ACC: 0.7982
# Test AUC: 0.7841
# Train F1: 0.8932
# 01500: TRAIN| LT=0.735 LP=0.327 LKL=6.827 LPS=0.284 LKLS=5.684 |
# Test F1: 0.8590
# Test ACC: 0.7982
# Test AUC: 0.7859
# Train F1: 0.8971
# 01550: TRAIN| LT=0.755 LP=0.326 LKL=6.935 LPS=0.302 LKLS=5.746 |
# Test F1: 0.8366
# Test ACC: 0.7706
# Test AUC: 0.7832
# Train F1: 0.9105
# 01600: TRAIN| LT=0.703 LP=0.297 LKL=7.027 LPS=0.278 LKLS=5.732 |
# Test F1: 0.8590
# Test ACC: 0.7982
# Test AUC: 0.7814
# Train F1: 0.8929
# 01650: TRAIN| LT=0.741 LP=0.324 LKL=7.076 LPS=0.288 LKLS=5.880 |
# Test F1: 0.8571
# Test ACC: 0.7890
# Test AUC: 0.7836
# Train F1: 0.8966
# 01700: TRAIN| LT=0.749 LP=0.319 LKL=7.197 LPS=0.298 LKLS=5.964 |
# Test F1: 0.8516
# Test ACC: 0.7890
# Test AUC: 0.7823
# Train F1: 0.9055
# 01750: TRAIN| LT=0.729 LP=0.313 LKL=7.122 LPS=0.286 LKLS=5.769 |
# Test F1: 0.8537
# Test ACC: 0.7798
# Test AUC: 0.7823
# Train F1: 0.8919
# 01800: TRAIN| LT=0.760 LP=0.316 LKL=7.106 LPS=0.316 LKLS=5.733 |
# Test F1: 0.8554
# Test ACC: 0.7798
# Test AUC: 0.7796
# Train F1: 0.9074
# 01850: TRAIN| LT=0.671 LP=0.268 LKL=7.160 LPS=0.274 LKLS=5.737 |
# Test F1: 0.8606
# Test ACC: 0.7890
# Test AUC: 0.7805
# Train F1: 0.8808
# 01900: TRAIN| LT=0.718 LP=0.317 LKL=6.997 LPS=0.278 LKLS=5.349 |
# Test F1: 0.8554
# Test ACC: 0.7798
# Test AUC: 0.7764
# Train F1: 0.9086
# 01950: TRAIN| LT=0.717 LP=0.300 LKL=7.404 LPS=0.281 LKLS=6.196 |
# Test F1: 0.8452
# Test ACC: 0.7615
# Test AUC: 0.7814
# Train F1: 0.9142
# 02000: TRAIN| LT=0.713 LP=0.302 LKL=7.164 LPS=0.282 LKLS=5.703 |
# Test F1: 0.8623
# Test ACC: 0.7890
# Test AUC: 0.7823
# f1: 0.8780487804878049
# acc: 0.8165137614678899
# auc: 0.8514001806684733
# f1 [0.8695652173913043, 0.8604651162790697, 0.8654970760233918, 0.8926553672316384, 0.8780487804878049]
# average f1: 0.8732463114826418±0.011284814649405646
# acc [0.8090909090909091, 0.7798165137614679, 0.7889908256880734, 0.8256880733944955, 0.8165137614678899]
# average acc: 0.8040200166805672±0.017105545450816426
# auc [0.8130298973672467, 0.7122854561878953, 0.7976513098464317, 0.8825654923215898, 0.8514001806684733]
# average auc: 0.8113864672783274±0.057757972050029915
