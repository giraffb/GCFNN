# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics.csv',index_col=0)
data_class={'nonIBD':0,'CD':1,'UC':1}
meta_data['diagnosis']=meta_data['diagnosis'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['diagnosis'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (1638, 578) (546, 596) (2891, 1)
# Index(['PSM7J1BF', 'CSM7KORK', 'HSM7J4HS', 'MSM9VZNL', 'MSMB4LYB', 'MSM6J2PM',
#        'MSMA26ET', 'CSM79HMN', 'CSM67UB1', 'HSM7J4IS',
#        ...
#        'PSM7J134', 'HSM5FZBJ', 'CSM79HK1', 'CSM5MCTZ', 'CSM9X21P', 'CSM5MCXF',
#        'CSM67U9P', 'CSM7KOPQ', 'HSMA33LV', 'MSM5LLFK'],
#       dtype='object', length=1796)
# 数据完整率missing_rate : 0.6080178173719376
# 集合所有样本重构数据表： (1796, 578) (1796, 596) (1796, 1)
# 标签转换为one-hot编码： (1796, 2) 459.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 8, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1',f1_cv)
print('average maxf1',sum(f1_cv)/5)
print('acc',acc_cv)
print('average maxacc',sum(acc_cv)/5)
print('auc',auc_cv)
print('average maxauc',sum(auc_cv)/5)
# Out:
# Train F1: 0.8681
# 00050: TRAIN| LT=1.565 LP=0.463 LKL=7.378 LPS=0.955 LKLS=7.331 |
# Test F1: 0.8664
# Test ACC: 0.7722
# Test AUC: 0.9107
# Train F1: 0.9480
# 00100: TRAIN| LT=1.093 LP=0.224 LKL=9.006 LPS=0.653 LKLS=12.553 |
# Test F1: 0.9573
# Test ACC: 0.9361
# Test AUC: 0.9697
# Train F1: 0.9682
# 00150: TRAIN| LT=0.920 LP=0.137 LKL=8.955 LPS=0.572 LKLS=12.140 |
# Test F1: 0.9740
# Test ACC: 0.9611
# Test AUC: 0.9815
# Train F1: 0.9718
# 00200: TRAIN| LT=0.839 LP=0.132 LKL=8.909 LPS=0.500 LKLS=11.750 |
# Test F1: 0.9776
# Test ACC: 0.9667
# Test AUC: 0.9852
# Train F1: 0.9743
# 00250: TRAIN| LT=0.782 LP=0.104 LKL=8.867 LPS=0.476 LKLS=11.354 |
# Test F1: 0.9777
# Test ACC: 0.9667
# Test AUC: 0.9864
# Train F1: 0.9780
# 00300: TRAIN| LT=0.772 LP=0.109 LKL=8.795 LPS=0.467 LKLS=10.915 |
# Test F1: 0.9796
# Test ACC: 0.9694
# Test AUC: 0.9861
# Train F1: 0.9786
# 00350: TRAIN| LT=0.729 LP=0.097 LKL=8.685 LPS=0.439 LKLS=10.611 |
# Test F1: 0.9778
# Test ACC: 0.9667
# Test AUC: 0.9866
# Train F1: 0.9796
# 00400: TRAIN| LT=0.674 LP=0.078 LKL=8.635 LPS=0.403 LKLS=10.582 |
# Test F1: 0.9760
# Test ACC: 0.9639
# Test AUC: 0.9875
# Train F1: 0.9789
# 00450: TRAIN| LT=0.659 LP=0.087 LKL=8.669 LPS=0.382 LKLS=10.309 |
# Test F1: 0.9778
# Test ACC: 0.9667
# Test AUC: 0.9867
# Train F1: 0.9813
# 00500: TRAIN| LT=0.623 LP=0.075 LKL=8.639 LPS=0.361 LKLS=10.121 |
# Test F1: 0.9760
# Test ACC: 0.9639
# Test AUC: 0.9869
# Train F1: 0.9827
# 00550: TRAIN| LT=0.606 LP=0.069 LKL=8.549 LPS=0.352 LKLS=10.004 |
# Test F1: 0.9722
# Test ACC: 0.9583
# Test AUC: 0.9863
# Train F1: 0.9812
# 00600: TRAIN| LT=0.564 LP=0.075 LKL=8.436 LPS=0.306 LKLS=9.903 |
# Test F1: 0.9685
# Test ACC: 0.9528
# Test AUC: 0.9858
# Train F1: 0.9860
# 00650: TRAIN| LT=0.506 LP=0.062 LKL=8.403 LPS=0.258 LKLS=10.268 |
# Test F1: 0.9685
# Test ACC: 0.9528
# Test AUC: 0.9862
# Train F1: 0.9837
# 00700: TRAIN| LT=0.501 LP=0.058 LKL=8.409 LPS=0.258 LKLS=10.007 |
# Test F1: 0.9665
# Test ACC: 0.9500
# Test AUC: 0.9846
# Train F1: 0.9893
# 00750: TRAIN| LT=0.456 LP=0.051 LKL=8.312 LPS=0.220 LKLS=10.126 |
# Test F1: 0.9722
# Test ACC: 0.9583
# Test AUC: 0.9861
# Train F1: 0.9906
# 00800: TRAIN| LT=0.420 LP=0.045 LKL=8.366 LPS=0.190 LKLS=10.088 |
# Test F1: 0.9664
# Test ACC: 0.9500
# Test AUC: 0.9849
# Train F1: 0.9883
# 00850: TRAIN| LT=0.428 LP=0.042 LKL=8.308 LPS=0.204 LKLS=9.876 |
# Test F1: 0.9722
# Test ACC: 0.9583
# Test AUC: 0.9848
# Train F1: 0.9906
# 00900: TRAIN| LT=0.408 LP=0.054 LKL=8.189 LPS=0.174 LKLS=9.787 |
# Test F1: 0.9683
# Test ACC: 0.9528
# Test AUC: 0.9848
# Train F1: 0.9930
# 00950: TRAIN| LT=0.390 LP=0.042 LKL=8.192 LPS=0.170 LKLS=9.685 |
# Test F1: 0.9703
# Test ACC: 0.9556
# Test AUC: 0.9862
# Train F1: 0.9911
# 01000: TRAIN| LT=0.366 LP=0.040 LKL=8.039 LPS=0.150 LKLS=9.505 |
# Test F1: 0.9683
# Test ACC: 0.9528
# Test AUC: 0.9841
# Train F1: 0.9949
# 01050: TRAIN| LT=0.362 LP=0.038 LKL=8.092 LPS=0.148 LKLS=9.477 |
# Test F1: 0.9683
# Test ACC: 0.9528
# Test AUC: 0.9863
# Train F1: 0.9930
# 01100: TRAIN| LT=0.358 LP=0.028 LKL=8.010 LPS=0.157 LKLS=9.348 |
# Test F1: 0.9703
# Test ACC: 0.9556
# Test AUC: 0.9854
# Train F1: 0.9921
# 01150: TRAIN| LT=0.360 LP=0.041 LKL=8.104 LPS=0.144 LKLS=9.387 |
# Test F1: 0.9703
# Test ACC: 0.9556
# Test AUC: 0.9857
# Train F1: 0.9934
# 01200: TRAIN| LT=0.305 LP=0.028 LKL=7.931 LPS=0.109 LKLS=8.926 |
# Test F1: 0.9703
# Test ACC: 0.9556
# Test AUC: 0.9857
# Train F1: 0.9930
# 01250: TRAIN| LT=0.338 LP=0.031 LKL=7.899 LPS=0.139 LKLS=8.893 |
# Test F1: 0.9703
# Test ACC: 0.9556
# Test AUC: 0.9857
# Train F1: 0.9888
# 01300: TRAIN| LT=0.315 LP=0.031 LKL=7.838 LPS=0.122 LKLS=8.457 |
# Test F1: 0.9685
# Test ACC: 0.9528
# Test AUC: 0.9858
# Train F1: 0.9934
# 01350: TRAIN| LT=0.282 LP=0.028 LKL=7.907 LPS=0.088 LKLS=8.727 |
# Test F1: 0.9704
# Test ACC: 0.9556
# Test AUC: 0.9851
# Train F1: 0.9930
# 01400: TRAIN| LT=0.317 LP=0.039 LKL=7.770 LPS=0.118 LKLS=8.189 |
# Test F1: 0.9722
# Test ACC: 0.9583
# Test AUC: 0.9865
# Train F1: 0.9972
# 01450: TRAIN| LT=0.261 LP=0.025 LKL=7.858 LPS=0.074 LKLS=8.333 |
# Test F1: 0.9722
# Test ACC: 0.9583
# Test AUC: 0.9867
# Train F1: 0.9939
# 01500: TRAIN| LT=0.276 LP=0.018 LKL=7.885 LPS=0.099 LKLS=8.103 |
# Test F1: 0.9704
# Test ACC: 0.9556
# Test AUC: 0.9862
# Train F1: 0.9948
# 01550: TRAIN| LT=0.270 LP=0.027 LKL=7.913 LPS=0.081 LKLS=8.239 |
# Test F1: 0.9645
# Test ACC: 0.9472
# Test AUC: 0.9869
# Train F1: 0.9939
# 01600: TRAIN| LT=0.275 LP=0.019 LKL=7.623 LPS=0.103 LKLS=7.646 |
# Test F1: 0.9703
# Test ACC: 0.9556
# Test AUC: 0.9858
# Train F1: 0.9963
# 01650: TRAIN| LT=0.266 LP=0.020 LKL=7.717 LPS=0.086 LKLS=8.203 |
# Test F1: 0.9664
# Test ACC: 0.9500
# Test AUC: 0.9851
# Train F1: 0.9944
# 01700: TRAIN| LT=0.281 LP=0.027 LKL=7.658 LPS=0.099 LKLS=7.934 |
# Test F1: 0.9646
# Test ACC: 0.9472
# Test AUC: 0.9850
# Train F1: 0.9958
# 01750: TRAIN| LT=0.236 LP=0.021 LKL=7.635 LPS=0.062 LKLS=7.646 |
# Test F1: 0.9703
# Test ACC: 0.9556
# Test AUC: 0.9861
# Train F1: 0.9977
# 01800: TRAIN| LT=0.222 LP=0.012 LKL=7.624 LPS=0.056 LKLS=7.893 |
# Test F1: 0.9664
# Test ACC: 0.9500
# Test AUC: 0.9851
# Train F1: 0.9967
# 01850: TRAIN| LT=0.257 LP=0.021 LKL=7.477 LPS=0.087 LKLS=7.440 |
# Test F1: 0.9664
# Test ACC: 0.9500
# Test AUC: 0.9844
# Train F1: 0.9944
# 01900: TRAIN| LT=0.251 LP=0.021 LKL=7.651 LPS=0.073 LKLS=8.068 |
# Test F1: 0.9627
# Test ACC: 0.9444
# Test AUC: 0.9844
# Train F1: 0.9958
# 01950: TRAIN| LT=0.212 LP=0.016 LKL=7.720 LPS=0.037 LKLS=8.181 |
# Test F1: 0.9663
# Test ACC: 0.9500
# Test AUC: 0.9847
# Train F1: 0.9958
# 02000: TRAIN| LT=0.207 LP=0.016 LKL=7.646 LPS=0.041 LKLS=7.442 |
# Test F1: 0.9683
# Test ACC: 0.9528
# Test AUC: 0.9859
# f1: 0.9795918367346939
# acc: 0.9694444444444444
# auc: 0.9860885788449059
# Train F1: 0.8615
# 00050: TRAIN| LT=1.619 LP=0.491 LKL=7.104 LPS=0.991 LKLS=6.534 |
# Test F1: 0.8595
# Test ACC: 0.7577
# Test AUC: 0.8765
# Train F1: 0.9608
# 00100: TRAIN| LT=1.054 LP=0.204 LKL=8.803 LPS=0.640 LKLS=12.213 |
# Test F1: 0.9578
# Test ACC: 0.9359
# Test AUC: 0.9668
# Train F1: 0.9678
# 00150: TRAIN| LT=0.879 LP=0.120 LKL=8.791 LPS=0.550 LKLS=12.113 |
# Test F1: 0.9668
# Test ACC: 0.9499
# Test AUC: 0.9794
# Train F1: 0.9776
# 00200: TRAIN| LT=0.813 LP=0.108 LKL=8.731 LPS=0.505 LKLS=11.340 |
# Test F1: 0.9667
# Test ACC: 0.9499
# Test AUC: 0.9808
# Train F1: 0.9747
# 00250: TRAIN| LT=0.762 LP=0.101 LKL=8.696 LPS=0.463 LKLS=11.085 |
# Test F1: 0.9667
# Test ACC: 0.9499
# Test AUC: 0.9809
# Train F1: 0.9785
# 00300: TRAIN| LT=0.716 LP=0.102 LKL=8.564 LPS=0.422 LKLS=10.626 |
# Test F1: 0.9631
# Test ACC: 0.9443
# Test AUC: 0.9796
# Train F1: 0.9814
# 00350: TRAIN| LT=0.706 LP=0.095 LKL=8.477 LPS=0.425 LKLS=10.058 |
# Test F1: 0.9631
# Test ACC: 0.9443
# Test AUC: 0.9801
# Train F1: 0.9758
# 00400: TRAIN| LT=0.682 LP=0.090 LKL=8.422 LPS=0.406 LKLS=10.156 |
# Test F1: 0.9632
# Test ACC: 0.9443
# Test AUC: 0.9797
# Train F1: 0.9813
# 00450: TRAIN| LT=0.655 LP=0.080 LKL=8.538 LPS=0.388 LKLS=10.147 |
# Test F1: 0.9593
# Test ACC: 0.9387
# Test AUC: 0.9799
# Train F1: 0.9846
# 00500: TRAIN| LT=0.604 LP=0.080 LKL=8.609 LPS=0.332 LKLS=10.640 |
# Test F1: 0.9610
# Test ACC: 0.9415
# Test AUC: 0.9795
# Train F1: 0.9813
# 00550: TRAIN| LT=0.619 LP=0.071 LKL=8.358 LPS=0.367 LKLS=9.793 |
# Test F1: 0.9593
# Test ACC: 0.9387
# Test AUC: 0.9793
# Train F1: 0.9850
# 00600: TRAIN| LT=0.597 LP=0.082 LKL=8.322 LPS=0.334 LKLS=9.806 |
# Test F1: 0.9593
# Test ACC: 0.9387
# Test AUC: 0.9782
# Train F1: 0.9851
# 00650: TRAIN| LT=0.543 LP=0.069 LKL=8.184 LPS=0.295 LKLS=9.679 |
# Test F1: 0.9650
# Test ACC: 0.9471
# Test AUC: 0.9784
# Train F1: 0.9883
# 00700: TRAIN| LT=0.523 LP=0.062 LKL=8.334 LPS=0.280 LKLS=9.780 |
# Test F1: 0.9573
# Test ACC: 0.9359
# Test AUC: 0.9791
# Train F1: 0.9883
# 00750: TRAIN| LT=0.499 LP=0.055 LKL=8.281 LPS=0.261 LKLS=9.968 |
# Test F1: 0.9591
# Test ACC: 0.9387
# Test AUC: 0.9792
# Train F1: 0.9869
# 00800: TRAIN| LT=0.497 LP=0.054 LKL=8.189 LPS=0.263 LKLS=9.757 |
# Test F1: 0.9593
# Test ACC: 0.9387
# Test AUC: 0.9807
# Train F1: 0.9864
# 00850: TRAIN| LT=0.465 LP=0.042 LKL=8.136 LPS=0.246 LKLS=9.499 |
# Test F1: 0.9593
# Test ACC: 0.9387
# Test AUC: 0.9793
# Train F1: 0.9948
# 00900: TRAIN| LT=0.446 LP=0.047 LKL=8.229 LPS=0.219 LKLS=9.724 |
# Test F1: 0.9593
# Test ACC: 0.9387
# Test AUC: 0.9795
# Train F1: 0.9939
# 00950: TRAIN| LT=0.415 LP=0.048 LKL=8.074 LPS=0.195 LKLS=9.097 |
# Test F1: 0.9593
# Test ACC: 0.9387
# Test AUC: 0.9809
# Train F1: 0.9911
# 01000: TRAIN| LT=0.375 LP=0.039 LKL=8.152 LPS=0.163 LKLS=9.197 |
# Test F1: 0.9573
# Test ACC: 0.9359
# Test AUC: 0.9790
# Train F1: 0.9944
# 01050: TRAIN| LT=0.374 LP=0.033 LKL=7.908 LPS=0.173 LKLS=8.823 |
# Test F1: 0.9575
# Test ACC: 0.9359
# Test AUC: 0.9799
# Train F1: 0.9930
# 01100: TRAIN| LT=0.371 LP=0.031 LKL=7.962 LPS=0.174 LKLS=8.669 |
# Test F1: 0.9628
# Test ACC: 0.9443
# Test AUC: 0.9820
# Train F1: 0.9944
# 01150: TRAIN| LT=0.325 LP=0.027 LKL=8.020 LPS=0.130 LKLS=8.782 |
# Test F1: 0.9575
# Test ACC: 0.9359
# Test AUC: 0.9811
# Train F1: 0.9920
# 01200: TRAIN| LT=0.362 LP=0.040 LKL=7.832 LPS=0.159 LKLS=8.415 |
# Test F1: 0.9575
# Test ACC: 0.9359
# Test AUC: 0.9797
# Train F1: 0.9916
# 01250: TRAIN| LT=0.296 LP=0.021 LKL=7.952 LPS=0.112 LKLS=8.354 |
# Test F1: 0.9610
# Test ACC: 0.9415
# Test AUC: 0.9813
# Train F1: 0.9967
# 01300: TRAIN| LT=0.305 LP=0.031 LKL=7.886 LPS=0.111 LKLS=8.447 |
# Test F1: 0.9575
# Test ACC: 0.9359
# Test AUC: 0.9814
# Train F1: 0.9920
# 01350: TRAIN| LT=0.301 LP=0.028 LKL=7.842 LPS=0.113 LKLS=8.239 |
# Test F1: 0.9557
# Test ACC: 0.9331
# Test AUC: 0.9789
# Train F1: 0.9930
# 01400: TRAIN| LT=0.310 LP=0.032 LKL=7.792 LPS=0.118 LKLS=8.231 |
# Test F1: 0.9575
# Test ACC: 0.9359
# Test AUC: 0.9802
# Train F1: 0.9963
# 01450: TRAIN| LT=0.293 LP=0.025 LKL=7.693 LPS=0.115 LKLS=7.608 |
# Test F1: 0.9612
# Test ACC: 0.9415
# Test AUC: 0.9811
# Train F1: 0.9944
# 01500: TRAIN| LT=0.273 LP=0.019 LKL=7.728 LPS=0.097 LKLS=7.907 |
# Test F1: 0.9575
# Test ACC: 0.9359
# Test AUC: 0.9812
# Train F1: 0.9949
# 01550: TRAIN| LT=0.252 LP=0.017 LKL=7.719 LPS=0.082 LKLS=7.595 |
# Test F1: 0.9593
# Test ACC: 0.9387
# Test AUC: 0.9815
# Train F1: 0.9977
# 01600: TRAIN| LT=0.287 LP=0.026 LKL=7.580 LPS=0.112 LKLS=7.291 |
# Test F1: 0.9594
# Test ACC: 0.9387
# Test AUC: 0.9819
# Train F1: 0.9958
# 01650: TRAIN| LT=0.273 LP=0.030 LKL=7.533 LPS=0.091 LKLS=7.603 |
# Test F1: 0.9559
# Test ACC: 0.9331
# Test AUC: 0.9798
# Train F1: 0.9953
# 01700: TRAIN| LT=0.266 LP=0.017 LKL=7.626 LPS=0.100 LKLS=7.229 |
# Test F1: 0.9612
# Test ACC: 0.9415
# Test AUC: 0.9815
# Train F1: 0.9939
# 01750: TRAIN| LT=0.291 LP=0.028 LKL=7.650 LPS=0.110 LKLS=7.695 |
# Test F1: 0.9612
# Test ACC: 0.9415
# Test AUC: 0.9817
# Train F1: 0.9958
# 01800: TRAIN| LT=0.295 LP=0.028 LKL=7.617 LPS=0.111 LKLS=8.054 |
# Test F1: 0.9575
# Test ACC: 0.9359
# Test AUC: 0.9813
# Train F1: 0.9953
# 01850: TRAIN| LT=0.257 LP=0.009 LKL=7.635 LPS=0.100 LKLS=7.192 |
# Test F1: 0.9610
# Test ACC: 0.9415
# Test AUC: 0.9803
# Train F1: 0.9953
# 01900: TRAIN| LT=0.213 LP=0.019 LKL=7.529 LPS=0.044 LKLS=7.466 |
# Test F1: 0.9612
# Test ACC: 0.9415
# Test AUC: 0.9796
# Train F1: 0.9958
# 01950: TRAIN| LT=0.237 LP=0.015 LKL=7.473 LPS=0.074 LKLS=7.334 |
# Test F1: 0.9576
# Test ACC: 0.9359
# Test AUC: 0.9802
# Train F1: 0.9958
# 02000: TRAIN| LT=0.214 LP=0.018 LKL=7.541 LPS=0.046 LKLS=7.460 |
# Test F1: 0.9630
# Test ACC: 0.9443
# Test AUC: 0.9794
# f1: 0.966789667896679
# acc: 0.9498607242339833
# auc: 0.9794161062817779
# Train F1: 0.8600
# 00050: TRAIN| LT=1.587 LP=0.468 LKL=7.301 LPS=0.978 LKLS=6.778 |
# Test F1: 0.9007
# Test ACC: 0.8384
# Test AUC: 0.9029
# Train F1: 0.9487
# 00100: TRAIN| LT=1.103 LP=0.218 LKL=8.971 LPS=0.673 LKLS=12.331 |
# Test F1: 0.9627
# Test ACC: 0.9443
# Test AUC: 0.9807
# Train F1: 0.9722
# 00150: TRAIN| LT=0.901 LP=0.135 LKL=8.995 LPS=0.550 LKLS=12.683 |
# Test F1: 0.9628
# Test ACC: 0.9443
# Test AUC: 0.9876
# Train F1: 0.9705
# 00200: TRAIN| LT=0.833 LP=0.120 LKL=8.971 LPS=0.504 LKLS=11.940 |
# Test F1: 0.9664
# Test ACC: 0.9499
# Test AUC: 0.9900
# Train F1: 0.9740
# 00250: TRAIN| LT=0.773 LP=0.099 LKL=8.873 LPS=0.471 LKLS=11.488 |
# Test F1: 0.9704
# Test ACC: 0.9554
# Test AUC: 0.9908
# Train F1: 0.9771
# 00300: TRAIN| LT=0.725 LP=0.091 LKL=8.825 LPS=0.435 LKLS=11.022 |
# Test F1: 0.9665
# Test ACC: 0.9499
# Test AUC: 0.9914
# Train F1: 0.9860
# 00350: TRAIN| LT=0.710 LP=0.072 LKL=8.901 LPS=0.440 LKLS=10.954 |
# Test F1: 0.9704
# Test ACC: 0.9554
# Test AUC: 0.9919
# Train F1: 0.9747
# 00400: TRAIN| LT=0.697 LP=0.085 LKL=8.688 LPS=0.420 LKLS=10.472 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9920
# Train F1: 0.9795
# 00450: TRAIN| LT=0.625 LP=0.087 LKL=8.473 LPS=0.358 LKLS=9.597 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9927
# Train F1: 0.9850
# 00500: TRAIN| LT=0.653 LP=0.079 LKL=8.614 LPS=0.383 LKLS=10.455 |
# Test F1: 0.9704
# Test ACC: 0.9554
# Test AUC: 0.9921
# Train F1: 0.9865
# 00550: TRAIN| LT=0.602 LP=0.081 LKL=8.555 LPS=0.333 LKLS=10.214 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9931
# Train F1: 0.9865
# 00600: TRAIN| LT=0.564 LP=0.065 LKL=8.536 LPS=0.313 LKLS=10.169 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9925
# Train F1: 0.9837
# 00650: TRAIN| LT=0.546 LP=0.055 LKL=8.473 LPS=0.306 LKLS=10.027 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9924
# Train F1: 0.9874
# 00700: TRAIN| LT=0.499 LP=0.057 LKL=8.448 LPS=0.256 LKLS=10.089 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9929
# Train F1: 0.9865
# 00750: TRAIN| LT=0.536 LP=0.070 LKL=8.248 LPS=0.285 LKLS=9.806 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9921
# Train F1: 0.9864
# 00800: TRAIN| LT=0.483 LP=0.053 LKL=8.335 LPS=0.247 LKLS=9.969 |
# Test F1: 0.9704
# Test ACC: 0.9554
# Test AUC: 0.9924
# Train F1: 0.9906
# 00850: TRAIN| LT=0.454 LP=0.050 LKL=8.319 LPS=0.223 LKLS=9.734 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9920
# Train F1: 0.9901
# 00900: TRAIN| LT=0.414 LP=0.032 LKL=8.266 LPS=0.201 LKLS=9.931 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9927
# Train F1: 0.9902
# 00950: TRAIN| LT=0.410 LP=0.040 LKL=8.283 LPS=0.190 LKLS=9.744 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9923
# Train F1: 0.9911
# 01000: TRAIN| LT=0.391 LP=0.042 LKL=8.298 LPS=0.170 LKLS=9.618 |
# Test F1: 0.9741
# Test ACC: 0.9610
# Test AUC: 0.9925
# Train F1: 0.9901
# 01050: TRAIN| LT=0.429 LP=0.030 LKL=8.305 LPS=0.218 LKLS=9.837 |
# Test F1: 0.9703
# Test ACC: 0.9554
# Test AUC: 0.9918
# Train F1: 0.9921
# 01100: TRAIN| LT=0.387 LP=0.038 LKL=8.154 LPS=0.173 LKLS=9.531 |
# Test F1: 0.9742
# Test ACC: 0.9610
# Test AUC: 0.9925
# Train F1: 0.9916
# 01150: TRAIN| LT=0.357 LP=0.026 LKL=8.074 LPS=0.155 LKLS=9.486 |
# Test F1: 0.9742
# Test ACC: 0.9610
# Test AUC: 0.9920
# Train F1: 0.9921
# 01200: TRAIN| LT=0.316 LP=0.025 LKL=8.089 LPS=0.118 LKLS=9.275 |
# Test F1: 0.9688
# Test ACC: 0.9526
# Test AUC: 0.9931
# Train F1: 0.9921
# 01250: TRAIN| LT=0.325 LP=0.031 LKL=8.018 LPS=0.123 LKLS=9.085 |
# Test F1: 0.9760
# Test ACC: 0.9638
# Test AUC: 0.9921
# Train F1: 0.9939
# 01300: TRAIN| LT=0.344 LP=0.021 LKL=8.037 LPS=0.154 LKLS=8.879 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9927
# Train F1: 0.9939
# 01350: TRAIN| LT=0.307 LP=0.035 LKL=7.908 LPS=0.105 LKLS=8.732 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9923
# Train F1: 0.9944
# 01400: TRAIN| LT=0.298 LP=0.023 LKL=7.939 LPS=0.106 LKLS=8.940 |
# Test F1: 0.9722
# Test ACC: 0.9582
# Test AUC: 0.9920
# Train F1: 0.9935
# 01450: TRAIN| LT=0.291 LP=0.018 LKL=7.938 LPS=0.107 LKLS=8.589 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9920
# Train F1: 0.9958
# 01500: TRAIN| LT=0.292 LP=0.030 LKL=8.008 LPS=0.095 LKLS=8.669 |
# Test F1: 0.9721
# Test ACC: 0.9582
# Test AUC: 0.9919
# Train F1: 0.9953
# 01550: TRAIN| LT=0.258 LP=0.014 LKL=7.925 LPS=0.081 LKLS=8.296 |
# Test F1: 0.9704
# Test ACC: 0.9554
# Test AUC: 0.9916
# Train F1: 0.9958
# 01600: TRAIN| LT=0.251 LP=0.015 LKL=7.881 LPS=0.077 LKLS=8.056 |
# Test F1: 0.9741
# Test ACC: 0.9610
# Test AUC: 0.9919
# Train F1: 0.9948
# 01650: TRAIN| LT=0.321 LP=0.023 LKL=7.840 LPS=0.135 LKLS=8.418 |
# Test F1: 0.9703
# Test ACC: 0.9554
# Test AUC: 0.9914
# Train F1: 0.9963
# 01700: TRAIN| LT=0.237 LP=0.019 LKL=7.891 LPS=0.056 LKLS=8.314 |
# Test F1: 0.9703
# Test ACC: 0.9554
# Test AUC: 0.9922
# Train F1: 0.9953
# 01750: TRAIN| LT=0.273 LP=0.023 LKL=7.795 LPS=0.094 LKLS=7.848 |
# Test F1: 0.9722
# Test ACC: 0.9582
# Test AUC: 0.9916
# Train F1: 0.9967
# 01800: TRAIN| LT=0.225 LP=0.016 LKL=7.741 LPS=0.052 LKLS=7.928 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9913
# Train F1: 0.9949
# 01850: TRAIN| LT=0.273 LP=0.022 LKL=7.745 LPS=0.096 LKLS=7.833 |
# Test F1: 0.9722
# Test ACC: 0.9582
# Test AUC: 0.9918
# Train F1: 0.9953
# 01900: TRAIN| LT=0.240 LP=0.018 LKL=7.847 LPS=0.061 LKLS=8.301 |
# Test F1: 0.9722
# Test ACC: 0.9582
# Test AUC: 0.9914
# Train F1: 0.9953
# 01950: TRAIN| LT=0.238 LP=0.027 LKL=7.651 LPS=0.060 LKLS=7.423 |
# Test F1: 0.9704
# Test ACC: 0.9554
# Test AUC: 0.9915
# Train F1: 0.9967
# 02000: TRAIN| LT=0.229 LP=0.009 LKL=7.721 LPS=0.065 LKLS=7.775 |
# Test F1: 0.9722
# Test ACC: 0.9582
# Test AUC: 0.9922
# f1: 0.9759704251386322
# acc: 0.9637883008356546
# auc: 0.9921226184660479
# Train F1: 0.8614
# 00050: TRAIN| LT=1.613 LP=0.494 LKL=7.038 LPS=0.989 LKLS=5.916 |
# Test F1: 0.8530
# Test ACC: 0.7437
# Test AUC: 0.9196
# Train F1: 0.9482
# 00100: TRAIN| LT=1.070 LP=0.220 LKL=8.919 LPS=0.641 LKLS=11.981 |
# Test F1: 0.9596
# Test ACC: 0.9387
# Test AUC: 0.9788
# Train F1: 0.9701
# 00150: TRAIN| LT=0.864 LP=0.131 LKL=8.949 LPS=0.523 LKLS=11.982 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9892
# Train F1: 0.9689
# 00200: TRAIN| LT=0.801 LP=0.108 LKL=8.854 LPS=0.491 LKLS=11.377 |
# Test F1: 0.9687
# Test ACC: 0.9526
# Test AUC: 0.9891
# Train F1: 0.9757
# 00250: TRAIN| LT=0.772 LP=0.099 LKL=8.781 LPS=0.479 LKLS=10.671 |
# Test F1: 0.9706
# Test ACC: 0.9554
# Test AUC: 0.9910
# Train F1: 0.9779
# 00300: TRAIN| LT=0.768 LP=0.100 LKL=8.733 LPS=0.474 LKLS=10.739 |
# Test F1: 0.9707
# Test ACC: 0.9554
# Test AUC: 0.9915
# Train F1: 0.9814
# 00350: TRAIN| LT=0.707 LP=0.094 LKL=8.767 LPS=0.418 LKLS=10.798 |
# Test F1: 0.9707
# Test ACC: 0.9554
# Test AUC: 0.9921
# Train F1: 0.9743
# 00400: TRAIN| LT=0.662 LP=0.077 LKL=8.575 LPS=0.399 LKLS=9.972 |
# Test F1: 0.9725
# Test ACC: 0.9582
# Test AUC: 0.9925
# Train F1: 0.9818
# 00450: TRAIN| LT=0.642 LP=0.076 LKL=8.667 LPS=0.378 LKLS=10.132 |
# Test F1: 0.9668
# Test ACC: 0.9499
# Test AUC: 0.9929
# Train F1: 0.9799
# 00500: TRAIN| LT=0.601 LP=0.070 LKL=8.456 LPS=0.347 LKLS=9.843 |
# Test F1: 0.9669
# Test ACC: 0.9499
# Test AUC: 0.9930
# Train F1: 0.9869
# 00550: TRAIN| LT=0.580 LP=0.073 LKL=8.421 LPS=0.325 LKLS=9.760 |
# Test F1: 0.9725
# Test ACC: 0.9582
# Test AUC: 0.9937
# Train F1: 0.9823
# 00600: TRAIN| LT=0.589 LP=0.071 LKL=8.427 LPS=0.336 LKLS=9.786 |
# Test F1: 0.9707
# Test ACC: 0.9554
# Test AUC: 0.9941
# Train F1: 0.9855
# 00650: TRAIN| LT=0.559 LP=0.067 LKL=8.436 LPS=0.308 LKLS=9.917 |
# Test F1: 0.9725
# Test ACC: 0.9582
# Test AUC: 0.9946
# Train F1: 0.9832
# 00700: TRAIN| LT=0.496 LP=0.068 LKL=8.231 LPS=0.251 LKLS=9.473 |
# Test F1: 0.9707
# Test ACC: 0.9554
# Test AUC: 0.9947
# Train F1: 0.9902
# 00750: TRAIN| LT=0.503 LP=0.069 LKL=8.375 LPS=0.253 LKLS=9.731 |
# Test F1: 0.9670
# Test ACC: 0.9499
# Test AUC: 0.9952
# Train F1: 0.9897
# 00800: TRAIN| LT=0.504 LP=0.052 LKL=8.308 LPS=0.272 LKLS=9.708 |
# Test F1: 0.9690
# Test ACC: 0.9526
# Test AUC: 0.9954
# Train F1: 0.9869
# 00850: TRAIN| LT=0.471 LP=0.054 LKL=8.301 LPS=0.239 LKLS=9.493 |
# Test F1: 0.9672
# Test ACC: 0.9499
# Test AUC: 0.9956
# Train F1: 0.9902
# 00900: TRAIN| LT=0.434 LP=0.047 LKL=8.239 LPS=0.211 LKLS=9.346 |
# Test F1: 0.9689
# Test ACC: 0.9526
# Test AUC: 0.9956
# Train F1: 0.9911
# 00950: TRAIN| LT=0.412 LP=0.047 LKL=8.167 LPS=0.190 LKLS=9.330 |
# Test F1: 0.9707
# Test ACC: 0.9554
# Test AUC: 0.9960
# Train F1: 0.9906
# 01000: TRAIN| LT=0.373 LP=0.043 LKL=8.266 LPS=0.154 LKLS=9.389 |
# Test F1: 0.9689
# Test ACC: 0.9526
# Test AUC: 0.9962
# Train F1: 0.9921
# 01050: TRAIN| LT=0.389 LP=0.048 LKL=8.032 LPS=0.172 LKLS=8.824 |
# Test F1: 0.9707
# Test ACC: 0.9554
# Test AUC: 0.9961
# Train F1: 0.9902
# 01100: TRAIN| LT=0.343 LP=0.035 LKL=8.005 LPS=0.143 LKLS=8.480 |
# Test F1: 0.9708
# Test ACC: 0.9554
# Test AUC: 0.9965
# Train F1: 0.9944
# 01150: TRAIN| LT=0.345 LP=0.034 LKL=7.938 LPS=0.147 LKLS=8.475 |
# Test F1: 0.9673
# Test ACC: 0.9499
# Test AUC: 0.9963
# Train F1: 0.9930
# 01200: TRAIN| LT=0.356 LP=0.044 LKL=7.830 LPS=0.152 LKLS=8.143 |
# Test F1: 0.9708
# Test ACC: 0.9554
# Test AUC: 0.9961
# Train F1: 0.9949
# 01250: TRAIN| LT=0.325 LP=0.042 LKL=7.913 LPS=0.124 LKLS=8.059 |
# Test F1: 0.9690
# Test ACC: 0.9526
# Test AUC: 0.9960
# Train F1: 0.9953
# 01300: TRAIN| LT=0.325 LP=0.030 LKL=7.935 LPS=0.134 LKLS=8.140 |
# Test F1: 0.9744
# Test ACC: 0.9610
# Test AUC: 0.9965
# Train F1: 0.9944
# 01350: TRAIN| LT=0.283 LP=0.029 LKL=7.847 LPS=0.099 LKLS=7.659 |
# Test F1: 0.9708
# Test ACC: 0.9554
# Test AUC: 0.9961
# Train F1: 0.9958
# 01400: TRAIN| LT=0.285 LP=0.030 LKL=7.820 LPS=0.098 LKLS=7.862 |
# Test F1: 0.9744
# Test ACC: 0.9610
# Test AUC: 0.9962
# Train F1: 0.9958
# 01450: TRAIN| LT=0.286 LP=0.031 LKL=7.663 LPS=0.104 LKLS=7.416 |
# Test F1: 0.9761
# Test ACC: 0.9638
# Test AUC: 0.9963
# Train F1: 0.9939
# 01500: TRAIN| LT=0.284 LP=0.036 LKL=7.639 LPS=0.098 LKLS=7.313 |
# Test F1: 0.9726
# Test ACC: 0.9582
# Test AUC: 0.9962
# Train F1: 0.9949
# 01550: TRAIN| LT=0.291 LP=0.023 LKL=7.620 LPS=0.120 LKLS=7.221 |
# Test F1: 0.9726
# Test ACC: 0.9582
# Test AUC: 0.9962
# Train F1: 0.9920
# 01600: TRAIN| LT=0.257 LP=0.025 LKL=7.777 LPS=0.076 LKLS=7.796 |
# Test F1: 0.9779
# Test ACC: 0.9666
# Test AUC: 0.9967
# Train F1: 0.9977
# 01650: TRAIN| LT=0.241 LP=0.017 LKL=7.503 LPS=0.079 LKLS=7.003 |
# Test F1: 0.9744
# Test ACC: 0.9610
# Test AUC: 0.9967
# Train F1: 0.9958
# 01700: TRAIN| LT=0.262 LP=0.022 LKL=7.676 LPS=0.088 LKLS=7.536 |
# Test F1: 0.9761
# Test ACC: 0.9638
# Test AUC: 0.9969
# Train F1: 0.9963
# 01750: TRAIN| LT=0.274 LP=0.036 LKL=7.459 LPS=0.098 LKLS=6.629 |
# Test F1: 0.9726
# Test ACC: 0.9582
# Test AUC: 0.9968
# Train F1: 0.9958
# 01800: TRAIN| LT=0.234 LP=0.016 LKL=7.367 LPS=0.079 LKLS=6.477 |
# Test F1: 0.9708
# Test ACC: 0.9554
# Test AUC: 0.9963
# Train F1: 0.9953
# 01850: TRAIN| LT=0.259 LP=0.039 LKL=7.380 LPS=0.082 LKLS=6.494 |
# Test F1: 0.9744
# Test ACC: 0.9610
# Test AUC: 0.9968
# Train F1: 0.9972
# 01900: TRAIN| LT=0.224 LP=0.012 LKL=7.347 LPS=0.071 LKLS=6.739 |
# Test F1: 0.9761
# Test ACC: 0.9638
# Test AUC: 0.9967
# Train F1: 0.9963
# 01950: TRAIN| LT=0.232 LP=0.020 LKL=7.302 LPS=0.074 LKLS=6.488 |
# Test F1: 0.9726
# Test ACC: 0.9582
# Test AUC: 0.9968
# Train F1: 0.9949
# 02000: TRAIN| LT=0.225 LP=0.017 LKL=7.269 LPS=0.069 LKLS=6.657 |
# Test F1: 0.9708
# Test ACC: 0.9554
# Test AUC: 0.9968
# f1: 0.9779411764705882
# acc: 0.9665738161559888
# auc: 0.9967432014329913
# Train F1: 0.8651
# 00050: TRAIN| LT=1.628 LP=0.469 LKL=7.317 LPS=1.015 LKLS=6.994 |
# Test F1: 0.8699
# Test ACC: 0.7799
# Test AUC: 0.9107
# Train F1: 0.9511
# 00100: TRAIN| LT=1.123 LP=0.228 LKL=9.014 LPS=0.681 LKLS=12.408 |
# Test F1: 0.9722
# Test ACC: 0.9582
# Test AUC: 0.9792
# Train F1: 0.9710
# 00150: TRAIN| LT=0.938 LP=0.144 LKL=9.170 LPS=0.572 LKLS=13.053 |
# Test F1: 0.9721
# Test ACC: 0.9582
# Test AUC: 0.9836
# Train F1: 0.9701
# 00200: TRAIN| LT=0.830 LP=0.124 LKL=9.139 LPS=0.489 LKLS=12.470 |
# Test F1: 0.9736
# Test ACC: 0.9610
# Test AUC: 0.9844
# Train F1: 0.9756
# 00250: TRAIN| LT=0.801 LP=0.124 LKL=8.963 LPS=0.472 LKLS=11.503 |
# Test F1: 0.9716
# Test ACC: 0.9582
# Test AUC: 0.9847
# Train F1: 0.9747
# 00300: TRAIN| LT=0.765 LP=0.106 LKL=8.935 LPS=0.457 LKLS=11.347 |
# Test F1: 0.9716
# Test ACC: 0.9582
# Test AUC: 0.9843
# Train F1: 0.9770
# 00350: TRAIN| LT=0.714 LP=0.089 LKL=8.845 LPS=0.429 LKLS=10.747 |
# Test F1: 0.9716
# Test ACC: 0.9582
# Test AUC: 0.9845
# Train F1: 0.9818
# 00400: TRAIN| LT=0.689 LP=0.085 LKL=8.755 LPS=0.409 LKLS=10.771 |
# Test F1: 0.9755
# Test ACC: 0.9638
# Test AUC: 0.9843
# Train F1: 0.9823
# 00450: TRAIN| LT=0.686 LP=0.089 LKL=8.767 LPS=0.400 LKLS=10.977 |
# Test F1: 0.9757
# Test ACC: 0.9638
# Test AUC: 0.9839
# Train F1: 0.9850
# 00500: TRAIN| LT=0.639 LP=0.079 LKL=8.663 LPS=0.367 LKLS=10.497 |
# Test F1: 0.9700
# Test ACC: 0.9554
# Test AUC: 0.9836
# Train F1: 0.9822
# 00550: TRAIN| LT=0.665 LP=0.076 LKL=8.596 LPS=0.399 LKLS=10.365 |
# Test F1: 0.9738
# Test ACC: 0.9610
# Test AUC: 0.9848
# Train F1: 0.9874
# 00600: TRAIN| LT=0.596 LP=0.066 LKL=8.616 LPS=0.336 LKLS=10.737 |
# Test F1: 0.9720
# Test ACC: 0.9582
# Test AUC: 0.9838
# Train F1: 0.9841
# 00650: TRAIN| LT=0.597 LP=0.072 LKL=8.618 LPS=0.333 LKLS=10.583 |
# Test F1: 0.9774
# Test ACC: 0.9666
# Test AUC: 0.9834
# Train F1: 0.9855
# 00700: TRAIN| LT=0.553 LP=0.058 LKL=8.545 LPS=0.302 LKLS=10.690 |
# Test F1: 0.9775
# Test ACC: 0.9666
# Test AUC: 0.9820
# Train F1: 0.9827
# 00750: TRAIN| LT=0.529 LP=0.057 LKL=8.404 LPS=0.287 LKLS=10.170 |
# Test F1: 0.9776
# Test ACC: 0.9666
# Test AUC: 0.9806
# Train F1: 0.9897
# 00800: TRAIN| LT=0.502 LP=0.067 LKL=8.529 LPS=0.240 LKLS=10.996 |
# Test F1: 0.9813
# Test ACC: 0.9721
# Test AUC: 0.9772
# Train F1: 0.9912
# 00850: TRAIN| LT=0.503 LP=0.061 LKL=8.486 LPS=0.248 LKLS=10.870 |
# Test F1: 0.9794
# Test ACC: 0.9694
# Test AUC: 0.9771
# Train F1: 0.9893
# 00900: TRAIN| LT=0.489 LP=0.046 LKL=8.468 LPS=0.248 LKLS=10.912 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9742
# Train F1: 0.9892
# 00950: TRAIN| LT=0.461 LP=0.035 LKL=8.393 LPS=0.235 LKLS=10.604 |
# Test F1: 0.9794
# Test ACC: 0.9694
# Test AUC: 0.9736
# Train F1: 0.9902
# 01000: TRAIN| LT=0.440 LP=0.047 LKL=8.318 LPS=0.203 LKLS=10.678 |
# Test F1: 0.9776
# Test ACC: 0.9666
# Test AUC: 0.9741
# Train F1: 0.9939
# 01050: TRAIN| LT=0.410 LP=0.044 LKL=8.355 LPS=0.178 LKLS=10.443 |
# Test F1: 0.9795
# Test ACC: 0.9694
# Test AUC: 0.9735
# Train F1: 0.9902
# 01100: TRAIN| LT=0.365 LP=0.029 LKL=8.321 LPS=0.148 LKLS=10.485 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9731
# Train F1: 0.9912
# 01150: TRAIN| LT=0.396 LP=0.035 LKL=8.211 LPS=0.177 LKLS=10.107 |
# Test F1: 0.9757
# Test ACC: 0.9638
# Test AUC: 0.9744
# Train F1: 0.9921
# 01200: TRAIN| LT=0.364 LP=0.036 LKL=8.223 LPS=0.145 LKLS=10.077 |
# Test F1: 0.9739
# Test ACC: 0.9610
# Test AUC: 0.9734
# Train F1: 0.9939
# 01250: TRAIN| LT=0.394 LP=0.042 LKL=8.257 LPS=0.166 LKLS=10.362 |
# Test F1: 0.9777
# Test ACC: 0.9666
# Test AUC: 0.9723
# Train F1: 0.9921
# 01300: TRAIN| LT=0.349 LP=0.031 LKL=8.074 LPS=0.137 LKLS=9.954 |
# Test F1: 0.9778
# Test ACC: 0.9666
# Test AUC: 0.9734
# Train F1: 0.9958
# 01350: TRAIN| LT=0.316 LP=0.037 LKL=8.143 LPS=0.100 LKLS=9.793 |
# Test F1: 0.9739
# Test ACC: 0.9610
# Test AUC: 0.9739
# Train F1: 0.9934
# 01400: TRAIN| LT=0.300 LP=0.019 LKL=8.120 LPS=0.102 LKLS=9.783 |
# Test F1: 0.9776
# Test ACC: 0.9666
# Test AUC: 0.9747
# Train F1: 0.9944
# 01450: TRAIN| LT=0.290 LP=0.017 LKL=8.169 LPS=0.095 LKLS=9.648 |
# Test F1: 0.9813
# Test ACC: 0.9721
# Test AUC: 0.9735
# Train F1: 0.9953
# 01500: TRAIN| LT=0.277 LP=0.023 LKL=8.096 LPS=0.076 LKLS=9.681 |
# Test F1: 0.9794
# Test ACC: 0.9694
# Test AUC: 0.9720
# Train F1: 0.9939
# 01550: TRAIN| LT=0.276 LP=0.023 LKL=7.931 LPS=0.085 LKLS=8.846 |
# Test F1: 0.9776
# Test ACC: 0.9666
# Test AUC: 0.9732
# Train F1: 0.9958
# 01600: TRAIN| LT=0.285 LP=0.025 LKL=7.876 LPS=0.090 LKLS=9.100 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9731
# Train F1: 0.9958
# 01650: TRAIN| LT=0.266 LP=0.014 LKL=7.837 LPS=0.084 LKLS=8.886 |
# Test F1: 0.9740
# Test ACC: 0.9610
# Test AUC: 0.9726
# Train F1: 0.9935
# 01700: TRAIN| LT=0.258 LP=0.014 LKL=7.823 LPS=0.080 LKLS=8.491 |
# Test F1: 0.9777
# Test ACC: 0.9666
# Test AUC: 0.9717
# Train F1: 0.9953
# 01750: TRAIN| LT=0.252 LP=0.014 LKL=7.679 LPS=0.080 LKLS=8.187 |
# Test F1: 0.9776
# Test ACC: 0.9666
# Test AUC: 0.9733
# Train F1: 0.9967
# 01800: TRAIN| LT=0.275 LP=0.018 LKL=7.634 LPS=0.101 LKLS=8.043 |
# Test F1: 0.9777
# Test ACC: 0.9666
# Test AUC: 0.9738
# Train F1: 0.9963
# 01850: TRAIN| LT=0.246 LP=0.016 LKL=7.608 LPS=0.074 LKLS=7.988 |
# Test F1: 0.9777
# Test ACC: 0.9666
# Test AUC: 0.9739
# Train F1: 0.9949
# 01900: TRAIN| LT=0.244 LP=0.014 LKL=7.619 LPS=0.075 LKLS=7.859 |
# Test F1: 0.9795
# Test ACC: 0.9694
# Test AUC: 0.9724
# Train F1: 0.9972
# 01950: TRAIN| LT=0.244 LP=0.014 LKL=7.557 LPS=0.077 LKLS=7.767 |
# Test F1: 0.9777
# Test ACC: 0.9666
# Test AUC: 0.9730
# Train F1: 0.9949
# 02000: TRAIN| LT=0.237 LP=0.027 LKL=7.506 LPS=0.061 LKLS=7.386 |
# Test F1: 0.9795
# Test ACC: 0.9694
# Test AUC: 0.9745
# f1: 0.9813432835820894
# acc: 0.9721448467966574
# auc: 0.9771922325354176
# f1 [0.9795918367346939, 0.966789667896679, 0.9759704251386322, 0.9779411764705882, 0.9813432835820894]
# average maxf1 0.9763272779645366
# acc [0.9694444444444444, 0.9498607242339833, 0.9637883008356546, 0.9665738161559888, 0.9721448467966574]
# average maxacc 0.9643624264933457
# auc [0.9860885788449059, 0.9794161062817779, 0.9921226184660479, 0.9967432014329913, 0.9771922325354176]
# average maxauc 0.9863125475122281
