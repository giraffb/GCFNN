# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'Control':0,'ESRD':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (287, 780) (287, 276) (287, 1)
# Index(['CON-001', 'CON-002', 'CON-003', 'CON-004', 'CON-005', 'CON-006',
#        'CON-007', 'CON-008', 'CON-009', 'CON-010',
#        ...
#        'KD-214', 'KD-215', 'KD-216', 'KD-217', 'KD-218', 'KD-219', 'KD-220',
#        'KD-221', 'KD-222', 'KD-223'],
#       dtype='object', name='Sample', length=287)
# 数据完整率missing_rate : 1.0
# 集合所有样本重构数据表： (287, 780) (287, 276) (287, 1)
# 标签转换为one-hot编码： (287, 2) 67.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 20)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 1, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1',f1_cv)
print('average maxf1',sum(f1_cv)/5)
print('acc',acc_cv)
print('average maxacc',sum(acc_cv)/5)
print('auc',auc_cv)
print('average maxauc',sum(auc_cv)/5)
# Out:
# Train F1: 0.8878
# 00050: TRAIN| LT=1.551 LP=0.428 LKL=12.331 LPS=0.883 LKLS=11.708 |
# Test F1: 0.8800
# Test ACC: 0.7931
# Test AUC: 0.9562
# Train F1: 0.9915
# 00100: TRAIN| LT=0.949 LP=0.106 LKL=12.963 LPS=0.570 LKLS=14.372 |
# Test F1: 0.9462
# Test ACC: 0.9138
# Test AUC: 0.9724
# Train F1: 0.9972
# 00150: TRAIN| LT=0.855 LP=0.054 LKL=12.467 LPS=0.559 LKLS=11.720 |
# Test F1: 0.9462
# Test ACC: 0.9138
# Test AUC: 0.9756
# Train F1: 0.9972
# 00200: TRAIN| LT=0.777 LP=0.035 LKL=12.355 LPS=0.513 LKLS=10.641 |
# Test F1: 0.9362
# Test ACC: 0.8966
# Test AUC: 0.9821
# Train F1: 0.9857
# 00250: TRAIN| LT=0.731 LP=0.055 LKL=12.324 LPS=0.446 LKLS=10.716 |
# Test F1: 0.9362
# Test ACC: 0.8966
# Test AUC: 0.9805
# Train F1: 0.9943
# 00300: TRAIN| LT=0.609 LP=0.016 LKL=12.602 LPS=0.361 LKLS=10.575 |
# Test F1: 0.9348
# Test ACC: 0.8966
# Test AUC: 0.9821
# Train F1: 0.9943
# 00350: TRAIN| LT=0.538 LP=0.011 LKL=12.557 LPS=0.294 LKLS=10.764 |
# Test F1: 0.9247
# Test ACC: 0.8793
# Test AUC: 0.9805
# Train F1: 0.9972
# 00400: TRAIN| LT=0.468 LP=0.013 LKL=12.754 LPS=0.210 LKLS=11.697 |
# Test F1: 0.9348
# Test ACC: 0.8966
# Test AUC: 0.9805
# Train F1: 0.9943
# 00450: TRAIN| LT=0.399 LP=0.007 LKL=12.697 LPS=0.145 LKLS=11.997 |
# Test F1: 0.9348
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 0.9972
# 00500: TRAIN| LT=0.378 LP=0.015 LKL=12.702 LPS=0.121 LKLS=11.508 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9805
# Train F1: 0.9914
# 00550: TRAIN| LT=0.420 LP=0.016 LKL=12.474 LPS=0.170 LKLS=11.012 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9773
# Train F1: 1.0000
# 00600: TRAIN| LT=0.330 LP=0.035 LKL=12.607 LPS=0.059 LKLS=11.080 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9789
# Train F1: 0.9972
# 00650: TRAIN| LT=0.328 LP=0.006 LKL=12.454 LPS=0.089 LKLS=10.776 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9708
# Train F1: 0.9972
# 00700: TRAIN| LT=0.309 LP=0.005 LKL=12.484 LPS=0.074 LKLS=10.591 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9756
# Train F1: 1.0000
# 00750: TRAIN| LT=0.278 LP=0.003 LKL=12.580 LPS=0.037 LKLS=11.226 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9773
# Train F1: 0.9972
# 00800: TRAIN| LT=0.307 LP=0.017 LKL=12.481 LPS=0.058 LKLS=10.736 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9773
# Train F1: 0.9972
# 00850: TRAIN| LT=0.283 LP=0.009 LKL=12.440 LPS=0.042 LKLS=10.739 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 1.0000
# 00900: TRAIN| LT=0.289 LP=0.003 LKL=12.499 LPS=0.050 LKLS=11.163 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9773
# Train F1: 0.9972
# 00950: TRAIN| LT=0.295 LP=0.006 LKL=12.522 LPS=0.056 LKLS=10.779 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 1.0000
# 01000: TRAIN| LT=0.295 LP=0.007 LKL=12.179 LPS=0.070 LKLS=9.650 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9773
# Train F1: 0.9972
# 01050: TRAIN| LT=0.266 LP=0.013 LKL=12.283 LPS=0.033 LKLS=9.720 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 1.0000
# 01100: TRAIN| LT=0.281 LP=0.007 LKL=12.189 LPS=0.059 LKLS=9.302 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 1.0000
# 01150: TRAIN| LT=0.244 LP=0.005 LKL=12.186 LPS=0.024 LKLS=9.438 |
# Test F1: 0.9348
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 1.0000
# 01200: TRAIN| LT=0.254 LP=0.007 LKL=12.104 LPS=0.032 LKLS=9.274 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9773
# Train F1: 1.0000
# 01250: TRAIN| LT=0.271 LP=0.021 LKL=12.087 LPS=0.036 LKLS=9.283 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 0.9972
# 01300: TRAIN| LT=0.268 LP=0.002 LKL=12.127 LPS=0.053 LKLS=9.249 |
# Test F1: 0.9348
# Test ACC: 0.8966
# Test AUC: 0.9773
# Train F1: 1.0000
# 01350: TRAIN| LT=0.303 LP=0.015 LKL=12.190 LPS=0.071 LKLS=9.562 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9773
# Train F1: 1.0000
# 01400: TRAIN| LT=0.259 LP=0.001 LKL=12.165 LPS=0.043 LKLS=9.217 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 0.9972
# 01450: TRAIN| LT=0.251 LP=0.005 LKL=12.097 LPS=0.033 LKLS=9.222 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9773
# Train F1: 1.0000
# 01500: TRAIN| LT=0.249 LP=0.001 LKL=12.064 LPS=0.035 LKLS=9.230 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 0.9972
# 01550: TRAIN| LT=0.268 LP=0.005 LKL=11.891 LPS=0.062 LKLS=8.240 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9805
# Train F1: 0.9972
# 01600: TRAIN| LT=0.248 LP=0.011 LKL=12.132 LPS=0.023 LKLS=9.279 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9773
# Train F1: 0.9972
# 01650: TRAIN| LT=0.298 LP=0.004 LKL=12.018 LPS=0.087 LKLS=8.679 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9805
# Train F1: 1.0000
# 01700: TRAIN| LT=0.293 LP=0.005 LKL=12.007 LPS=0.079 LKLS=8.861 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9805
# Train F1: 1.0000
# 01750: TRAIN| LT=0.229 LP=0.003 LKL=12.008 LPS=0.018 LKLS=8.766 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 1.0000
# 01800: TRAIN| LT=0.219 LP=0.007 LKL=11.908 LPS=0.009 LKLS=8.451 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9805
# Train F1: 1.0000
# 01850: TRAIN| LT=0.226 LP=0.005 LKL=11.874 LPS=0.020 LKLS=8.176 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9773
# Train F1: 0.9972
# 01900: TRAIN| LT=0.247 LP=0.003 LKL=11.895 LPS=0.044 LKLS=8.160 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9773
# Train F1: 1.0000
# 01950: TRAIN| LT=0.258 LP=0.004 LKL=11.967 LPS=0.049 LKLS=8.568 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9805
# Train F1: 0.9972
# 02000: TRAIN| LT=0.223 LP=0.001 LKL=11.903 LPS=0.023 LKLS=8.041 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9789
# f1: 0.9462365591397849
# acc: 0.9137931034482759
# auc: 0.9756493506493507
# Train F1: 0.9010
# 00050: TRAIN| LT=1.372 LP=0.341 LKL=12.491 LPS=0.768 LKLS=13.845 |
# Test F1: 0.8352
# Test ACC: 0.7414
# Test AUC: 0.8571
# Train F1: 0.9944
# 00100: TRAIN| LT=0.944 LP=0.095 LKL=12.787 LPS=0.588 LKLS=13.336 |
# Test F1: 0.9268
# Test ACC: 0.8966
# Test AUC: 0.9627
# Train F1: 0.9915
# 00150: TRAIN| LT=0.806 LP=0.043 LKL=12.575 LPS=0.521 LKLS=11.615 |
# Test F1: 0.9286
# Test ACC: 0.8966
# Test AUC: 0.9562
# Train F1: 0.9972
# 00200: TRAIN| LT=0.712 LP=0.033 LKL=12.658 LPS=0.435 LKLS=11.776 |
# Test F1: 0.9286
# Test ACC: 0.8966
# Test AUC: 0.9610
# Train F1: 0.9972
# 00250: TRAIN| LT=0.642 LP=0.038 LKL=12.802 LPS=0.357 LKLS=11.918 |
# Test F1: 0.9535
# Test ACC: 0.9310
# Test AUC: 0.9692
# Train F1: 0.9972
# 00300: TRAIN| LT=0.571 LP=0.017 LKL=12.751 LPS=0.314 LKLS=11.274 |
# Test F1: 0.9655
# Test ACC: 0.9483
# Test AUC: 0.9870
# Train F1: 1.0000
# 00350: TRAIN| LT=0.500 LP=0.018 LKL=12.731 LPS=0.236 LKLS=11.998 |
# Test F1: 0.9888
# Test ACC: 0.9828
# Test AUC: 1.0000
# Train F1: 1.0000
# 00400: TRAIN| LT=0.396 LP=0.017 LKL=12.822 LPS=0.131 LKLS=11.909 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9935
# Train F1: 0.9972
# 00450: TRAIN| LT=0.357 LP=0.014 LKL=12.635 LPS=0.105 LKLS=11.192 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9951
# Train F1: 1.0000
# 00500: TRAIN| LT=0.378 LP=0.019 LKL=12.682 LPS=0.119 LKLS=11.319 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 1.0000
# 00550: TRAIN| LT=0.342 LP=0.009 LKL=12.683 LPS=0.089 LKLS=11.654 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9984
# Train F1: 1.0000
# 00600: TRAIN| LT=0.355 LP=0.008 LKL=12.672 LPS=0.106 LKLS=11.422 |
# Test F1: 0.9885
# Test ACC: 0.9828
# Test AUC: 0.9984
# Train F1: 0.9972
# 00650: TRAIN| LT=0.336 LP=0.007 LKL=12.634 LPS=0.089 LKLS=11.410 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 1.0000
# 00700: TRAIN| LT=0.311 LP=0.003 LKL=12.699 LPS=0.064 LKLS=11.687 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 0.9943
# 00750: TRAIN| LT=0.330 LP=0.014 LKL=12.378 LPS=0.089 LKLS=10.397 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 0.9972
# 00800: TRAIN| LT=0.302 LP=0.012 LKL=12.396 LPS=0.062 LKLS=10.443 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 1.0000
# 00850: TRAIN| LT=0.335 LP=0.014 LKL=12.268 LPS=0.098 LKLS=10.047 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 1.0000
# 00900: TRAIN| LT=0.280 LP=0.007 LKL=12.464 LPS=0.046 LKLS=10.231 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 1.0000
# 00950: TRAIN| LT=0.265 LP=0.003 LKL=12.453 LPS=0.032 LKLS=10.518 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9984
# Train F1: 0.9972
# 01000: TRAIN| LT=0.290 LP=0.014 LKL=12.117 LPS=0.061 LKLS=9.329 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9984
# Train F1: 0.9972
# 01050: TRAIN| LT=0.278 LP=0.007 LKL=12.266 LPS=0.049 LKLS=9.986 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9984
# Train F1: 0.9972
# 01100: TRAIN| LT=0.266 LP=0.003 LKL=12.147 LPS=0.048 LKLS=9.386 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 1.0000
# 01150: TRAIN| LT=0.283 LP=0.006 LKL=12.252 LPS=0.058 LKLS=9.631 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9984
# Train F1: 0.9943
# 01200: TRAIN| LT=0.289 LP=0.008 LKL=12.228 LPS=0.065 LKLS=9.283 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9984
# Train F1: 1.0000
# 01250: TRAIN| LT=0.243 LP=0.010 LKL=12.146 LPS=0.020 LKLS=9.085 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9984
# Train F1: 1.0000
# 01300: TRAIN| LT=0.260 LP=0.003 LKL=12.110 LPS=0.045 LKLS=9.120 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 0.9972
# 01350: TRAIN| LT=0.253 LP=0.005 LKL=12.042 LPS=0.043 LKLS=8.390 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 0.9972
# 01400: TRAIN| LT=0.242 LP=0.001 LKL=12.127 LPS=0.027 LKLS=9.234 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 1.0000
# 01450: TRAIN| LT=0.276 LP=0.008 LKL=12.110 LPS=0.057 LKLS=8.962 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 1.0000
# 01500: TRAIN| LT=0.236 LP=0.006 LKL=11.993 LPS=0.026 LKLS=8.396 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9984
# Train F1: 1.0000
# 01550: TRAIN| LT=0.245 LP=0.008 LKL=12.058 LPS=0.029 LKLS=8.807 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 1.0000
# 01600: TRAIN| LT=0.272 LP=0.001 LKL=12.120 LPS=0.060 LKLS=8.983 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9984
# Train F1: 1.0000
# 01650: TRAIN| LT=0.229 LP=0.004 LKL=11.992 LPS=0.020 LKLS=8.554 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 1.0000
# 01700: TRAIN| LT=0.248 LP=0.006 LKL=12.005 LPS=0.035 LKLS=8.672 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 1.0000
# 01750: TRAIN| LT=0.235 LP=0.002 LKL=11.980 LPS=0.031 LKLS=8.291 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9984
# Train F1: 1.0000
# 01800: TRAIN| LT=0.237 LP=0.005 LKL=11.916 LPS=0.028 LKLS=8.410 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9935
# Train F1: 1.0000
# 01850: TRAIN| LT=0.234 LP=0.003 LKL=11.930 LPS=0.027 LKLS=8.528 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 1.0000
# 01900: TRAIN| LT=0.242 LP=0.006 LKL=11.807 LPS=0.040 LKLS=7.832 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 1.0000
# 01950: TRAIN| LT=0.228 LP=0.003 LKL=11.738 LPS=0.032 LKLS=7.516 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 1.0000
# 02000: TRAIN| LT=0.226 LP=0.003 LKL=11.975 LPS=0.022 LKLS=8.102 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# f1: 0.9887640449438202
# acc: 0.9827586206896551
# auc: 1.0
# Train F1: 0.9309
# 00050: TRAIN| LT=1.440 LP=0.362 LKL=12.821 LPS=0.810 LKLS=13.923 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9196
# Train F1: 0.9915
# 00100: TRAIN| LT=0.976 LP=0.103 LKL=13.161 LPS=0.594 LKLS=14.824 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9580
# Train F1: 1.0000
# 00150: TRAIN| LT=0.876 LP=0.067 LKL=12.417 LPS=0.573 LKLS=11.164 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9563
# Train F1: 0.9943
# 00200: TRAIN| LT=0.814 LP=0.051 LKL=12.399 LPS=0.534 LKLS=10.462 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9685
# Train F1: 1.0000
# 00250: TRAIN| LT=0.794 LP=0.031 LKL=12.501 LPS=0.532 LKLS=10.689 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9738
# Train F1: 0.9915
# 00300: TRAIN| LT=0.644 LP=0.023 LKL=12.536 LPS=0.392 LKLS=10.421 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9773
# Train F1: 0.9887
# 00350: TRAIN| LT=0.619 LP=0.020 LKL=12.536 LPS=0.366 LKLS=10.720 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9860
# Train F1: 0.9972
# 00400: TRAIN| LT=0.523 LP=0.009 LKL=12.847 LPS=0.267 LKLS=11.880 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9895
# Train F1: 1.0000
# 00450: TRAIN| LT=0.426 LP=0.021 LKL=12.791 LPS=0.159 LKLS=11.838 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9972
# 00500: TRAIN| LT=0.456 LP=0.006 LKL=12.607 LPS=0.215 LKLS=10.843 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9948
# Train F1: 0.9943
# 00550: TRAIN| LT=0.358 LP=0.004 LKL=12.529 LPS=0.117 LKLS=11.102 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 1.0000
# Train F1: 1.0000
# 00600: TRAIN| LT=0.411 LP=0.009 LKL=12.558 LPS=0.160 LKLS=11.646 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 1.0000
# Train F1: 0.9972
# 00650: TRAIN| LT=0.375 LP=0.010 LKL=12.498 LPS=0.130 LKLS=10.934 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 1.0000
# Train F1: 1.0000
# 00700: TRAIN| LT=0.357 LP=0.008 LKL=12.565 LPS=0.111 LKLS=11.253 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 1.0000
# Train F1: 0.9915
# 00750: TRAIN| LT=0.338 LP=0.012 LKL=12.547 LPS=0.086 LKLS=11.358 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9983
# Train F1: 0.9972
# 00800: TRAIN| LT=0.382 LP=0.019 LKL=12.407 LPS=0.131 LKLS=10.778 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 1.0000
# Train F1: 0.9972
# 00850: TRAIN| LT=0.328 LP=0.005 LKL=12.518 LPS=0.086 LKLS=11.161 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9983
# Train F1: 0.9972
# 00900: TRAIN| LT=0.336 LP=0.011 LKL=12.329 LPS=0.097 LKLS=10.519 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9983
# Train F1: 0.9972
# 00950: TRAIN| LT=0.317 LP=0.008 LKL=12.193 LPS=0.091 LKLS=9.600 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 1.0000
# Train F1: 0.9972
# 01000: TRAIN| LT=0.297 LP=0.008 LKL=12.264 LPS=0.064 LKLS=10.123 |
# Test F1: 0.9885
# Test ACC: 0.9825
# Test AUC: 1.0000
# Train F1: 0.9915
# 01050: TRAIN| LT=0.279 LP=0.013 LKL=12.196 LPS=0.046 LKLS=9.778 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# Train F1: 1.0000
# 01100: TRAIN| LT=0.335 LP=0.016 LKL=12.404 LPS=0.094 LKLS=10.152 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9983
# Train F1: 1.0000
# 01150: TRAIN| LT=0.269 LP=0.011 LKL=12.189 LPS=0.037 LKLS=9.957 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# Train F1: 0.9943
# 01200: TRAIN| LT=0.311 LP=0.010 LKL=12.045 LPS=0.091 LKLS=8.949 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 1.0000
# Train F1: 1.0000
# 01250: TRAIN| LT=0.321 LP=0.011 LKL=12.106 LPS=0.095 LKLS=9.451 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# Train F1: 0.9972
# 01300: TRAIN| LT=0.276 LP=0.003 LKL=12.176 LPS=0.056 LKLS=9.486 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# Train F1: 1.0000
# 01350: TRAIN| LT=0.281 LP=0.015 LKL=12.214 LPS=0.045 LKLS=9.876 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9983
# Train F1: 0.9972
# 01400: TRAIN| LT=0.253 LP=0.002 LKL=12.088 LPS=0.036 LKLS=9.358 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# Train F1: 1.0000
# 01450: TRAIN| LT=0.288 LP=0.004 LKL=12.140 LPS=0.067 LKLS=9.593 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9972
# 01500: TRAIN| LT=0.249 LP=0.004 LKL=12.051 LPS=0.034 LKLS=8.933 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 1.0000
# Train F1: 1.0000
# 01550: TRAIN| LT=0.318 LP=0.035 LKL=12.061 LPS=0.069 LKLS=9.369 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# Train F1: 0.9972
# 01600: TRAIN| LT=0.254 LP=0.013 LKL=11.985 LPS=0.030 LKLS=9.124 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 1.0000
# Train F1: 0.9915
# 01650: TRAIN| LT=0.267 LP=0.010 LKL=11.984 LPS=0.049 LKLS=8.794 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# Train F1: 0.9972
# 01700: TRAIN| LT=0.288 LP=0.005 LKL=11.934 LPS=0.073 LKLS=8.991 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# Train F1: 1.0000
# 01750: TRAIN| LT=0.259 LP=0.003 LKL=12.078 LPS=0.043 LKLS=9.246 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9965
# Train F1: 1.0000
# 01800: TRAIN| LT=0.267 LP=0.004 LKL=12.023 LPS=0.057 LKLS=8.615 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9983
# Train F1: 0.9972
# 01850: TRAIN| LT=0.261 LP=0.005 LKL=11.901 LPS=0.051 LKLS=8.571 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9965
# Train F1: 0.9972
# 01900: TRAIN| LT=0.288 LP=0.001 LKL=11.964 LPS=0.078 LKLS=8.841 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 1.0000
# Train F1: 0.9972
# 01950: TRAIN| LT=0.235 LP=0.007 LKL=11.876 LPS=0.028 LKLS=8.122 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# Train F1: 1.0000
# 02000: TRAIN| LT=0.247 LP=0.014 LKL=11.898 LPS=0.029 LKLS=8.470 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 1.0000
# f1: 1.0
# acc: 1.0
# auc: 1.0
# Train F1: 0.8772
# 00050: TRAIN| LT=1.503 LP=0.438 LKL=12.072 LPS=0.830 LKLS=11.501 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.9301
# Train F1: 0.9748
# 00100: TRAIN| LT=0.998 LP=0.119 LKL=13.012 LPS=0.610 LKLS=13.817 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9318
# Train F1: 1.0000
# 00150: TRAIN| LT=0.897 LP=0.071 LKL=12.550 LPS=0.587 LKLS=11.315 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9248
# Train F1: 0.9858
# 00200: TRAIN| LT=0.779 LP=0.035 LKL=12.453 LPS=0.514 LKLS=10.620 |
# Test F1: 0.9247
# Test ACC: 0.8772
# Test AUC: 0.9266
# Train F1: 0.9972
# 00250: TRAIN| LT=0.754 LP=0.051 LKL=12.473 LPS=0.470 LKLS=10.853 |
# Test F1: 0.9149
# Test ACC: 0.8596
# Test AUC: 0.9388
# Train F1: 1.0000
# 00300: TRAIN| LT=0.676 LP=0.033 LKL=12.591 LPS=0.412 LKLS=10.532 |
# Test F1: 0.9247
# Test ACC: 0.8772
# Test AUC: 0.9441
# Train F1: 0.9943
# 00350: TRAIN| LT=0.654 LP=0.046 LKL=12.531 LPS=0.384 LKLS=9.888 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9510
# Train F1: 0.9943
# 00400: TRAIN| LT=0.651 LP=0.055 LKL=12.610 LPS=0.360 LKLS=11.063 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9615
# Train F1: 0.9972
# 00450: TRAIN| LT=0.496 LP=0.038 LKL=12.694 LPS=0.214 LKLS=11.663 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9738
# Train F1: 0.9915
# 00500: TRAIN| LT=0.417 LP=0.021 LKL=12.734 LPS=0.148 LKLS=12.025 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9808
# Train F1: 0.9858
# 00550: TRAIN| LT=0.442 LP=0.023 LKL=12.754 LPS=0.173 LKLS=11.786 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9843
# Train F1: 1.0000
# 00600: TRAIN| LT=0.445 LP=0.012 LKL=12.584 LPS=0.195 LKLS=11.221 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9825
# Train F1: 0.9915
# 00650: TRAIN| LT=0.450 LP=0.025 LKL=12.533 LPS=0.191 LKLS=10.906 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9843
# Train F1: 0.9944
# 00700: TRAIN| LT=0.360 LP=0.010 LKL=12.523 LPS=0.119 LKLS=10.578 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9895
# Train F1: 1.0000
# 00750: TRAIN| LT=0.414 LP=0.013 LKL=12.540 LPS=0.168 LKLS=10.789 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9983
# Train F1: 1.0000
# 00800: TRAIN| LT=0.335 LP=0.003 LKL=12.661 LPS=0.091 LKLS=11.478 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 1.0000
# 00850: TRAIN| LT=0.346 LP=0.020 LKL=12.433 LPS=0.096 LKLS=10.498 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9948
# Train F1: 0.9943
# 00900: TRAIN| LT=0.343 LP=0.008 LKL=12.350 LPS=0.105 LKLS=10.681 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 1.0000
# 00950: TRAIN| LT=0.382 LP=0.016 LKL=12.288 LPS=0.143 LKLS=10.043 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 0.9972
# 01000: TRAIN| LT=0.348 LP=0.007 LKL=12.304 LPS=0.116 LKLS=10.098 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 0.9972
# 01050: TRAIN| LT=0.323 LP=0.005 LKL=12.284 LPS=0.097 LKLS=9.887 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9965
# Train F1: 0.9943
# 01100: TRAIN| LT=0.305 LP=0.013 LKL=12.242 LPS=0.071 LKLS=9.827 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9965
# Train F1: 1.0000
# 01150: TRAIN| LT=0.345 LP=0.005 LKL=12.275 LPS=0.116 LKLS=10.128 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9983
# Train F1: 1.0000
# 01200: TRAIN| LT=0.336 LP=0.023 LKL=12.159 LPS=0.096 LKLS=9.521 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9965
# Train F1: 1.0000
# 01250: TRAIN| LT=0.271 LP=0.008 LKL=12.124 LPS=0.046 LKLS=9.559 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 1.0000
# 01300: TRAIN| LT=0.307 LP=0.020 LKL=12.024 LPS=0.078 LKLS=8.971 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 1.0000
# 01350: TRAIN| LT=0.259 LP=0.007 LKL=12.244 LPS=0.033 LKLS=9.727 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 0.9972
# 01400: TRAIN| LT=0.266 LP=0.003 LKL=12.132 LPS=0.050 LKLS=9.164 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9965
# Train F1: 1.0000
# 01450: TRAIN| LT=0.316 LP=0.018 LKL=12.080 LPS=0.083 LKLS=9.377 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9965
# Train F1: 1.0000
# 01500: TRAIN| LT=0.313 LP=0.023 LKL=12.180 LPS=0.077 LKLS=9.126 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9965
# Train F1: 1.0000
# 01550: TRAIN| LT=0.291 LP=0.001 LKL=12.079 LPS=0.081 LKLS=8.762 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 1.0000
# 01600: TRAIN| LT=0.243 LP=0.005 LKL=11.959 LPS=0.034 LKLS=8.444 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 0.9972
# 01650: TRAIN| LT=0.283 LP=0.001 LKL=11.996 LPS=0.074 LKLS=8.796 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 0.9943
# 01700: TRAIN| LT=0.293 LP=0.017 LKL=11.906 LPS=0.073 LKLS=8.338 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 1.0000
# 01750: TRAIN| LT=0.255 LP=0.017 LKL=11.910 LPS=0.034 LKLS=8.408 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9930
# Train F1: 1.0000
# 01800: TRAIN| LT=0.274 LP=0.002 LKL=11.843 LPS=0.075 LKLS=7.841 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9913
# Train F1: 1.0000
# 01850: TRAIN| LT=0.265 LP=0.001 LKL=11.960 LPS=0.059 LKLS=8.509 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 1.0000
# 01900: TRAIN| LT=0.241 LP=0.004 LKL=11.812 LPS=0.040 LKLS=7.883 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 1.0000
# 01950: TRAIN| LT=0.280 LP=0.016 LKL=11.830 LPS=0.067 LKLS=7.855 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 1.0000
# 02000: TRAIN| LT=0.307 LP=0.005 LKL=11.917 LPS=0.102 LKLS=8.066 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9930
# f1: 0.9777777777777777
# acc: 0.9649122807017544
# auc: 0.9947552447552448
# Train F1: 0.8734
# 00050: TRAIN| LT=1.559 LP=0.457 LKL=11.794 LPS=0.877 LKLS=10.670 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.9126
# Train F1: 0.9915
# 00100: TRAIN| LT=0.965 LP=0.111 LKL=12.977 LPS=0.576 LKLS=14.795 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9336
# Train F1: 1.0000
# 00150: TRAIN| LT=0.875 LP=0.062 LKL=12.297 LPS=0.582 LKLS=10.828 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.9248
# Train F1: 1.0000
# 00200: TRAIN| LT=0.742 LP=0.041 LKL=12.328 LPS=0.477 LKLS=10.063 |
# Test F1: 0.9231
# Test ACC: 0.8772
# Test AUC: 0.9126
# Train F1: 0.9972
# 00250: TRAIN| LT=0.661 LP=0.042 LKL=12.569 LPS=0.386 LKLS=10.826 |
# Test F1: 0.8989
# Test ACC: 0.8421
# Test AUC: 0.9091
# Train F1: 0.9972
# 00300: TRAIN| LT=0.631 LP=0.024 LKL=12.392 LPS=0.387 LKLS=9.542 |
# Test F1: 0.9091
# Test ACC: 0.8596
# Test AUC: 0.9161
# Train F1: 0.9972
# 00350: TRAIN| LT=0.550 LP=0.022 LKL=12.586 LPS=0.293 LKLS=10.885 |
# Test F1: 0.9213
# Test ACC: 0.8772
# Test AUC: 0.9318
# Train F1: 1.0000
# 00400: TRAIN| LT=0.503 LP=0.033 LKL=12.582 LPS=0.236 LKLS=10.687 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9528
# Train F1: 0.9972
# 00450: TRAIN| LT=0.470 LP=0.026 LKL=12.665 LPS=0.205 LKLS=11.291 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9615
# Train F1: 1.0000
# 00500: TRAIN| LT=0.406 LP=0.023 LKL=12.455 LPS=0.154 LKLS=10.407 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9790
# Train F1: 1.0000
# 00550: TRAIN| LT=0.359 LP=0.009 LKL=12.543 LPS=0.116 LKLS=10.849 |
# Test F1: 0.9438
# Test ACC: 0.9123
# Test AUC: 0.9843
# Train F1: 0.9972
# 00600: TRAIN| LT=0.372 LP=0.006 LKL=12.513 LPS=0.134 LKLS=10.731 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9860
# Train F1: 0.9972
# 00650: TRAIN| LT=0.344 LP=0.007 LKL=12.570 LPS=0.102 LKLS=10.936 |
# Test F1: 0.9438
# Test ACC: 0.9123
# Test AUC: 0.9843
# Train F1: 1.0000
# 00700: TRAIN| LT=0.317 LP=0.019 LKL=12.589 LPS=0.062 LKLS=11.051 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9895
# Train F1: 1.0000
# 00750: TRAIN| LT=0.311 LP=0.014 LKL=12.403 LPS=0.070 LKLS=10.296 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 1.0000
# 00800: TRAIN| LT=0.300 LP=0.004 LKL=12.455 LPS=0.066 LKLS=10.539 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9895
# Train F1: 0.9972
# 00850: TRAIN| LT=0.320 LP=0.008 LKL=12.596 LPS=0.078 LKLS=10.759 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9895
# Train F1: 1.0000
# 00900: TRAIN| LT=0.317 LP=0.008 LKL=12.274 LPS=0.086 LKLS=10.050 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9930
# Train F1: 1.0000
# 00950: TRAIN| LT=0.297 LP=0.006 LKL=12.328 LPS=0.071 LKLS=9.611 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9913
# Train F1: 1.0000
# 01000: TRAIN| LT=0.313 LP=0.009 LKL=12.394 LPS=0.078 LKLS=10.206 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9895
# Train F1: 0.9972
# 01050: TRAIN| LT=0.335 LP=0.002 LKL=12.255 LPS=0.110 LKLS=10.067 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 0.9943
# 01100: TRAIN| LT=0.281 LP=0.002 LKL=12.301 LPS=0.058 LKLS=9.817 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9913
# Train F1: 0.9972
# 01150: TRAIN| LT=0.266 LP=0.008 LKL=12.280 LPS=0.036 LKLS=9.915 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9895
# Train F1: 1.0000
# 01200: TRAIN| LT=0.292 LP=0.005 LKL=12.237 LPS=0.067 LKLS=9.800 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 1.0000
# 01250: TRAIN| LT=0.239 LP=0.002 LKL=12.158 LPS=0.023 LKLS=9.175 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9913
# Train F1: 0.9972
# 01300: TRAIN| LT=0.258 LP=0.003 LKL=12.173 LPS=0.036 LKLS=9.601 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9895
# Train F1: 1.0000
# 01350: TRAIN| LT=0.281 LP=0.009 LKL=12.056 LPS=0.062 LKLS=8.990 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9895
# Train F1: 1.0000
# 01400: TRAIN| LT=0.283 LP=0.017 LKL=12.047 LPS=0.055 LKLS=9.064 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9930
# Train F1: 0.9972
# 01450: TRAIN| LT=0.275 LP=0.010 LKL=12.042 LPS=0.054 LKLS=9.139 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 1.0000
# 01500: TRAIN| LT=0.261 LP=0.004 LKL=12.138 LPS=0.043 LKLS=9.249 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9930
# Train F1: 1.0000
# 01550: TRAIN| LT=0.238 LP=0.004 LKL=11.955 LPS=0.032 LKLS=8.313 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9895
# Train F1: 1.0000
# 01600: TRAIN| LT=0.248 LP=0.003 LKL=11.977 LPS=0.039 LKLS=8.680 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9895
# Train F1: 1.0000
# 01650: TRAIN| LT=0.302 LP=0.022 LKL=11.952 LPS=0.076 LKLS=8.564 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 0.9972
# 01700: TRAIN| LT=0.224 LP=0.006 LKL=11.955 LPS=0.015 LKLS=8.299 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9895
# Train F1: 0.9972
# 01750: TRAIN| LT=0.251 LP=0.014 LKL=11.821 LPS=0.036 LKLS=8.215 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9895
# Train F1: 1.0000
# 01800: TRAIN| LT=0.258 LP=0.009 LKL=11.894 LPS=0.048 LKLS=8.200 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9913
# Train F1: 1.0000
# 01850: TRAIN| LT=0.242 LP=0.016 LKL=11.786 LPS=0.030 LKLS=7.884 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9825
# Train F1: 1.0000
# 01900: TRAIN| LT=0.229 LP=0.005 LKL=11.931 LPS=0.027 LKLS=7.827 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9878
# Train F1: 0.9972
# 01950: TRAIN| LT=0.216 LP=0.004 LKL=11.657 LPS=0.021 LKLS=7.553 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9913
# Train F1: 1.0000
# 02000: TRAIN| LT=0.247 LP=0.002 LKL=11.845 LPS=0.049 LKLS=7.792 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9843
# f1: 0.9777777777777777
# acc: 0.9649122807017544
# auc: 0.993006993006993
# f1 [0.9462365591397849, 0.9887640449438202, 1.0, 0.9777777777777777, 0.9777777777777777]
# average maxf1 0.9781112319278321
# acc [0.9137931034482759, 0.9827586206896551, 1.0, 0.9649122807017544, 0.9649122807017544]
# average maxacc 0.965275257108288
# auc [0.9756493506493507, 1.0, 1.0, 0.9947552447552448, 0.993006993006993]
# average maxauc 0.9926823176823177
