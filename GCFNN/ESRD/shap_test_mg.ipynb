# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'Control':0,'ESRD':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
print('输入各组学数据表：',x1.shape,meta_data.shape)

#重构数据表和标签表
X1 = x1
index_new=X1.index
print(index_new)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,meta_data.shape)
X_set=[X1]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (287, 780) (287, 1)
# Index(['CON-001', 'CON-002', 'CON-003', 'CON-004', 'CON-005', 'CON-006',
#        'CON-007', 'CON-008', 'CON-009', 'CON-010',
#        ...
#        'KD-214', 'KD-215', 'KD-216', 'KD-217', 'KD-218', 'KD-219', 'KD-220',
#        'KD-221', 'KD-222', 'KD-223'],
#       dtype='object', name='Sample', length=287)
# 集合所有样本重构数据表： (287, 780) (287, 1)
# 标签转换为one-hot编码： (287, 2) 67.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap_mg'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 20)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 1, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1', f1_cv)
print('average f1: {}±{}'.format(np.mean(f1_cv), np.std(f1_cv)))
print('acc', acc_cv)
print('average acc: {}±{}'.format(np.mean(acc_cv), np.std(acc_cv)))
print('auc', auc_cv)
print('average auc: {}±{}'.format(np.mean(auc_cv), np.std(auc_cv)))
# Out:
# Train F1: 0.8895
# 00050: TRAIN| LT=0.801 LP=0.341 LKL=7.828 LPS=0.276 LKLS=10.638 |
# Test F1: 0.9149
# Test ACC: 0.8621
# Test AUC: 0.9594
# Train F1: 0.9888
# 00100: TRAIN| LT=0.329 LP=0.087 LKL=8.365 LPS=0.042 LKLS=11.676 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9756
# Train F1: 0.9944
# 00150: TRAIN| LT=0.246 LP=0.044 LKL=7.911 LPS=0.024 LKLS=9.916 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9789
# Train F1: 1.0000
# 00200: TRAIN| LT=0.200 LP=0.031 LKL=7.473 LPS=0.009 LKLS=8.497 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9821
# Train F1: 0.9943
# 00250: TRAIN| LT=0.207 LP=0.034 LKL=7.743 LPS=0.007 LKLS=8.883 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9708
# Train F1: 0.9972
# 00300: TRAIN| LT=0.180 LP=0.021 LKL=7.286 LPS=0.012 LKLS=7.394 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9692
# Train F1: 0.9943
# 00350: TRAIN| LT=0.181 LP=0.031 LKL=7.342 LPS=0.004 LKLS=7.237 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9724
# Train F1: 0.9943
# 00400: TRAIN| LT=0.178 LP=0.030 LKL=7.066 LPS=0.010 LKLS=6.765 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9724
# Train F1: 0.9972
# 00450: TRAIN| LT=0.147 LP=0.008 LKL=7.078 LPS=0.004 LKLS=6.464 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9870
# Train F1: 1.0000
# 00500: TRAIN| LT=0.167 LP=0.022 LKL=7.089 LPS=0.008 LKLS=6.626 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9740
# Train F1: 1.0000
# 00550: TRAIN| LT=0.154 LP=0.016 LKL=7.034 LPS=0.001 LKLS=6.590 |
# Test F1: 0.9348
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 0.9914
# 00600: TRAIN| LT=0.152 LP=0.014 LKL=6.929 LPS=0.008 LKLS=6.008 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9821
# Train F1: 0.9943
# 00650: TRAIN| LT=0.149 LP=0.016 LKL=7.002 LPS=0.003 LKLS=6.093 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9854
# Train F1: 0.9943
# 00700: TRAIN| LT=0.145 LP=0.021 LKL=6.718 LPS=0.002 LKLS=5.547 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9886
# Train F1: 0.9943
# 00750: TRAIN| LT=0.153 LP=0.015 LKL=6.880 LPS=0.010 LKLS=5.985 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9886
# Train F1: 0.9943
# 00800: TRAIN| LT=0.142 LP=0.021 LKL=6.648 LPS=0.002 LKLS=5.313 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9886
# Train F1: 0.9886
# 00850: TRAIN| LT=0.129 LP=0.006 LKL=6.571 LPS=0.004 LKLS=5.364 |
# Test F1: 0.9348
# Test ACC: 0.8966
# Test AUC: 0.9821
# Train F1: 0.9972
# 00900: TRAIN| LT=0.134 LP=0.011 LKL=6.700 LPS=0.002 LKLS=5.412 |
# Test F1: 0.9348
# Test ACC: 0.8966
# Test AUC: 0.9870
# Train F1: 0.9915
# 00950: TRAIN| LT=0.138 LP=0.012 LKL=6.654 LPS=0.006 LKLS=5.373 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9886
# Train F1: 0.9943
# 01000: TRAIN| LT=0.143 LP=0.017 LKL=6.735 LPS=0.001 LKLS=5.784 |
# Test F1: 0.9462
# Test ACC: 0.9138
# Test AUC: 0.9886
# Train F1: 0.9972
# 01050: TRAIN| LT=0.148 LP=0.022 LKL=6.424 LPS=0.011 LKLS=5.109 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9886
# Train F1: 0.9943
# 01100: TRAIN| LT=0.150 LP=0.030 LKL=6.594 LPS=0.002 LKLS=5.198 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9903
# Train F1: 0.9943
# 01150: TRAIN| LT=0.129 LP=0.014 LKL=6.416 LPS=0.002 LKLS=4.893 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9773
# Train F1: 0.9943
# 01200: TRAIN| LT=0.125 LP=0.011 LKL=6.475 LPS=0.001 LKLS=4.795 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9870
# Train F1: 0.9943
# 01250: TRAIN| LT=0.138 LP=0.022 LKL=6.452 LPS=0.002 LKLS=4.986 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9854
# Train F1: 0.9944
# 01300: TRAIN| LT=0.125 LP=0.013 LKL=6.334 LPS=0.004 LKLS=4.512 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9903
# Train F1: 0.9944
# 01350: TRAIN| LT=0.118 LP=0.002 LKL=6.506 LPS=0.001 LKLS=4.974 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9854
# Train F1: 0.9972
# 01400: TRAIN| LT=0.124 LP=0.013 LKL=6.283 LPS=0.004 LKLS=4.386 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9789
# Train F1: 0.9944
# 01450: TRAIN| LT=0.144 LP=0.032 LKL=6.446 LPS=0.002 LKLS=4.543 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9886
# Train F1: 0.9972
# 01500: TRAIN| LT=0.115 LP=0.004 LKL=6.353 LPS=0.001 LKLS=4.646 |
# Test F1: 0.9362
# Test ACC: 0.8966
# Test AUC: 0.9886
# Train F1: 0.9972
# 01550: TRAIN| LT=0.122 LP=0.005 LKL=6.482 LPS=0.005 LKLS=4.631 |
# Test F1: 0.9348
# Test ACC: 0.8966
# Test AUC: 0.9789
# Train F1: 0.9943
# 01600: TRAIN| LT=0.135 LP=0.008 LKL=6.290 LPS=0.019 LKLS=4.522 |
# Test F1: 0.9362
# Test ACC: 0.8966
# Test AUC: 0.9870
# Train F1: 0.9943
# 01650: TRAIN| LT=0.118 LP=0.008 LKL=6.143 LPS=0.008 LKLS=4.127 |
# Test F1: 0.9462
# Test ACC: 0.9138
# Test AUC: 0.9854
# Train F1: 0.9943
# 01700: TRAIN| LT=0.124 LP=0.015 LKL=6.298 LPS=0.001 LKLS=4.478 |
# Test F1: 0.9247
# Test ACC: 0.8793
# Test AUC: 0.9740
# Train F1: 0.9972
# 01750: TRAIN| LT=0.136 LP=0.029 LKL=6.158 LPS=0.005 LKLS=4.030 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9805
# Train F1: 0.9943
# 01800: TRAIN| LT=0.107 LP=0.001 LKL=6.229 LPS=0.001 LKLS=4.204 |
# Test F1: 0.9462
# Test ACC: 0.9138
# Test AUC: 0.9870
# Train F1: 0.9972
# 01850: TRAIN| LT=0.117 LP=0.013 LKL=6.235 LPS=0.002 LKLS=4.002 |
# Test F1: 0.9462
# Test ACC: 0.9138
# Test AUC: 0.9870
# Train F1: 1.0000
# 01900: TRAIN| LT=0.108 LP=0.001 LKL=6.303 LPS=0.003 LKLS=4.054 |
# Test F1: 0.9565
# Test ACC: 0.9310
# Test AUC: 0.9919
# Train F1: 0.9972
# 01950: TRAIN| LT=0.126 LP=0.009 LKL=6.207 LPS=0.014 LKLS=4.135 |
# Test F1: 0.9362
# Test ACC: 0.8966
# Test AUC: 0.9838
# Train F1: 0.9943
# 02000: TRAIN| LT=0.107 LP=0.009 LKL=5.946 LPS=0.003 LKLS=3.549 |
# Test F1: 0.9462
# Test ACC: 0.9138
# Test AUC: 0.9886
# f1: 0.9565217391304348
# acc: 0.9310344827586207
# auc: 0.9918831168831169
# Train F1: 0.9243
# 00050: TRAIN| LT=0.756 LP=0.316 LKL=8.436 LPS=0.231 LKLS=12.470 |
# Test F1: 0.8810
# Test ACC: 0.8276
# Test AUC: 0.8701
# Train F1: 0.9915
# 00100: TRAIN| LT=0.349 LP=0.094 LKL=8.459 LPS=0.057 LKLS=11.331 |
# Test F1: 0.8889
# Test ACC: 0.8448
# Test AUC: 0.9464
# Train F1: 0.9856
# 00150: TRAIN| LT=0.234 LP=0.045 LKL=7.964 LPS=0.015 LKLS=9.499 |
# Test F1: 0.9048
# Test ACC: 0.8621
# Test AUC: 0.9497
# Train F1: 0.9972
# 00200: TRAIN| LT=0.199 LP=0.032 LKL=7.525 LPS=0.008 LKLS=8.426 |
# Test F1: 0.9070
# Test ACC: 0.8621
# Test AUC: 0.9318
# Train F1: 0.9914
# 00250: TRAIN| LT=0.178 LP=0.024 LKL=7.301 LPS=0.008 LKLS=7.318 |
# Test F1: 0.8941
# Test ACC: 0.8448
# Test AUC: 0.9399
# Train F1: 0.9915
# 00300: TRAIN| LT=0.177 LP=0.030 LKL=7.024 LPS=0.012 LKLS=6.503 |
# Test F1: 0.9070
# Test ACC: 0.8621
# Test AUC: 0.9253
# Train F1: 0.9972
# 00350: TRAIN| LT=0.164 LP=0.018 LKL=7.239 LPS=0.003 LKLS=7.014 |
# Test F1: 0.9048
# Test ACC: 0.8621
# Test AUC: 0.9464
# Train F1: 1.0000
# 00400: TRAIN| LT=0.152 LP=0.010 LKL=7.106 LPS=0.005 LKLS=6.566 |
# Test F1: 0.9176
# Test ACC: 0.8793
# Test AUC: 0.9399
# Train F1: 0.9972
# 00450: TRAIN| LT=0.155 LP=0.010 LKL=7.264 LPS=0.003 LKLS=6.974 |
# Test F1: 0.9176
# Test ACC: 0.8793
# Test AUC: 0.9464
# Train F1: 0.9972
# 00500: TRAIN| LT=0.160 LP=0.015 LKL=7.030 LPS=0.010 LKLS=6.506 |
# Test F1: 0.9195
# Test ACC: 0.8793
# Test AUC: 0.9432
# Train F1: 0.9972
# 00550: TRAIN| LT=0.181 LP=0.044 LKL=6.989 LPS=0.005 LKLS=6.281 |
# Test F1: 0.9091
# Test ACC: 0.8621
# Test AUC: 0.9399
# Train F1: 1.0000
# 00600: TRAIN| LT=0.149 LP=0.016 LKL=6.846 LPS=0.005 LKLS=5.907 |
# Test F1: 0.8966
# Test ACC: 0.8448
# Test AUC: 0.9334
# Train F1: 0.9943
# 00650: TRAIN| LT=0.166 LP=0.026 LKL=6.959 LPS=0.009 LKLS=6.171 |
# Test F1: 0.9176
# Test ACC: 0.8793
# Test AUC: 0.9351
# Train F1: 1.0000
# 00700: TRAIN| LT=0.148 LP=0.017 LKL=6.885 LPS=0.006 LKLS=5.663 |
# Test F1: 0.9176
# Test ACC: 0.8793
# Test AUC: 0.9399
# Train F1: 0.9972
# 00750: TRAIN| LT=0.151 LP=0.021 LKL=6.908 LPS=0.002 LKLS=5.839 |
# Test F1: 0.9070
# Test ACC: 0.8621
# Test AUC: 0.9269
# Train F1: 0.9972
# 00800: TRAIN| LT=0.146 LP=0.009 LKL=6.863 LPS=0.011 LKLS=5.766 |
# Test F1: 0.9070
# Test ACC: 0.8621
# Test AUC: 0.9383
# Train F1: 1.0000
# 00850: TRAIN| LT=0.137 LP=0.015 LKL=6.616 LPS=0.004 LKLS=5.133 |
# Test F1: 0.9070
# Test ACC: 0.8621
# Test AUC: 0.9351
# Train F1: 0.9887
# 00900: TRAIN| LT=0.140 LP=0.006 LKL=6.995 LPS=0.002 LKLS=6.204 |
# Test F1: 0.9091
# Test ACC: 0.8621
# Test AUC: 0.9269
# Train F1: 0.9943
# 00950: TRAIN| LT=0.129 LP=0.003 LKL=6.780 LPS=0.001 LKLS=5.675 |
# Test F1: 0.8966
# Test ACC: 0.8448
# Test AUC: 0.9367
# Train F1: 1.0000
# 01000: TRAIN| LT=0.138 LP=0.018 LKL=6.575 LPS=0.005 LKLS=4.950 |
# Test F1: 0.8966
# Test ACC: 0.8448
# Test AUC: 0.9383
# Train F1: 0.9943
# 01050: TRAIN| LT=0.130 LP=0.005 LKL=6.662 LPS=0.003 LKLS=5.594 |
# Test F1: 0.8864
# Test ACC: 0.8276
# Test AUC: 0.9318
# Train F1: 0.9914
# 01100: TRAIN| LT=0.167 LP=0.051 LKL=6.439 LPS=0.004 LKLS=4.725 |
# Test F1: 0.9070
# Test ACC: 0.8621
# Test AUC: 0.9286
# Train F1: 1.0000
# 01150: TRAIN| LT=0.134 LP=0.009 LKL=6.666 LPS=0.007 LKLS=5.188 |
# Test F1: 0.9070
# Test ACC: 0.8621
# Test AUC: 0.9286
# Train F1: 0.9972
# 01200: TRAIN| LT=0.126 LP=0.008 LKL=6.674 LPS=0.001 LKLS=5.090 |
# Test F1: 0.9048
# Test ACC: 0.8621
# Test AUC: 0.9286
# Train F1: 0.9972
# 01250: TRAIN| LT=0.129 LP=0.016 LKL=6.484 LPS=0.000 LKLS=4.726 |
# Test F1: 0.8966
# Test ACC: 0.8448
# Test AUC: 0.9416
# Train F1: 0.9972
# 01300: TRAIN| LT=0.134 LP=0.018 LKL=6.474 LPS=0.003 LKLS=4.848 |
# Test F1: 0.8966
# Test ACC: 0.8448
# Test AUC: 0.9318
# Train F1: 0.9972
# 01350: TRAIN| LT=0.122 LP=0.006 LKL=6.375 LPS=0.007 LKLS=4.485 |
# Test F1: 0.9091
# Test ACC: 0.8621
# Test AUC: 0.9318
# Train F1: 0.9972
# 01400: TRAIN| LT=0.127 LP=0.013 LKL=6.535 LPS=0.002 LKLS=4.635 |
# Test F1: 0.9070
# Test ACC: 0.8621
# Test AUC: 0.9416
# Train F1: 0.9972
# 01450: TRAIN| LT=0.113 LP=0.003 LKL=6.298 LPS=0.002 LKLS=4.551 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.9351
# Train F1: 0.9972
# 01500: TRAIN| LT=0.124 LP=0.005 LKL=6.401 LPS=0.012 LKLS=4.371 |
# Test F1: 0.9091
# Test ACC: 0.8621
# Test AUC: 0.9351
# Train F1: 0.9972
# 01550: TRAIN| LT=0.115 LP=0.004 LKL=6.407 LPS=0.001 LKLS=4.545 |
# Test F1: 0.9091
# Test ACC: 0.8621
# Test AUC: 0.9318
# Train F1: 0.9972
# 01600: TRAIN| LT=0.116 LP=0.004 LKL=6.378 LPS=0.005 LKLS=4.288 |
# Test F1: 0.8966
# Test ACC: 0.8448
# Test AUC: 0.9302
# Train F1: 0.9944
# 01650: TRAIN| LT=0.145 LP=0.030 LKL=6.068 LPS=0.014 LKLS=3.989 |
# Test F1: 0.8989
# Test ACC: 0.8448
# Test AUC: 0.9205
# Train F1: 1.0000
# 01700: TRAIN| LT=0.143 LP=0.018 LKL=6.279 LPS=0.021 LKLS=4.099 |
# Test F1: 0.9070
# Test ACC: 0.8621
# Test AUC: 0.9318
# Train F1: 0.9972
# 01750: TRAIN| LT=0.143 LP=0.030 LKL=6.474 LPS=0.005 LKLS=4.244 |
# Test F1: 0.9070
# Test ACC: 0.8621
# Test AUC: 0.9432
# Train F1: 1.0000
# 01800: TRAIN| LT=0.108 LP=0.004 LKL=6.219 LPS=0.000 LKLS=4.205 |
# Test F1: 0.8889
# Test ACC: 0.8276
# Test AUC: 0.9367
# Train F1: 1.0000
# 01850: TRAIN| LT=0.105 LP=0.005 LKL=6.169 LPS=0.001 LKLS=3.821 |
# Test F1: 0.8989
# Test ACC: 0.8448
# Test AUC: 0.9399
# Train F1: 0.9943
# 01900: TRAIN| LT=0.105 LP=0.006 LKL=6.107 LPS=0.001 LKLS=3.704 |
# Test F1: 0.9111
# Test ACC: 0.8621
# Test AUC: 0.9432
# Train F1: 0.9972
# 01950: TRAIN| LT=0.104 LP=0.005 LKL=6.046 LPS=0.003 LKLS=3.642 |
# Test F1: 0.8966
# Test ACC: 0.8448
# Test AUC: 0.9383
# Train F1: 0.9972
# 02000: TRAIN| LT=0.095 LP=0.002 LKL=5.859 LPS=0.001 LKLS=3.439 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.9302
# f1: 0.9195402298850575
# acc: 0.8793103448275862
# auc: 0.9431818181818182
# Train F1: 0.9301
# 00050: TRAIN| LT=0.803 LP=0.352 LKL=8.018 LPS=0.256 LKLS=11.520 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9266
# Train F1: 0.9972
# 00100: TRAIN| LT=0.313 LP=0.078 LKL=8.484 LPS=0.035 LKLS=11.528 |
# Test F1: 0.9438
# Test ACC: 0.9123
# Test AUC: 0.9598
# Train F1: 0.9943
# 00150: TRAIN| LT=0.231 LP=0.044 LKL=7.821 LPS=0.015 LKLS=9.426 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9563
# Train F1: 0.9972
# 00200: TRAIN| LT=0.202 LP=0.038 LKL=7.410 LPS=0.011 LKLS=7.899 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9493
# Train F1: 0.9887
# 00250: TRAIN| LT=0.175 LP=0.016 LKL=7.332 LPS=0.009 LKLS=7.655 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9458
# Train F1: 1.0000
# 00300: TRAIN| LT=0.179 LP=0.020 LKL=7.302 LPS=0.010 LKLS=7.593 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9510
# Train F1: 0.9972
# 00350: TRAIN| LT=0.179 LP=0.029 LKL=7.234 LPS=0.007 LKLS=7.102 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9458
# Train F1: 1.0000
# 00400: TRAIN| LT=0.160 LP=0.020 LKL=6.978 LPS=0.008 LKLS=6.209 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9458
# Train F1: 0.9943
# 00450: TRAIN| LT=0.174 LP=0.028 LKL=6.930 LPS=0.015 LKLS=6.172 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9493
# Train F1: 0.9888
# 00500: TRAIN| LT=0.178 LP=0.047 LKL=6.792 LPS=0.003 LKLS=6.030 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9510
# Train F1: 0.9943
# 00550: TRAIN| LT=0.148 LP=0.009 LKL=7.025 LPS=0.004 LKLS=6.422 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9406
# Train F1: 0.9972
# 00600: TRAIN| LT=0.199 LP=0.053 LKL=6.699 LPS=0.021 LKLS=5.803 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9493
# Train F1: 0.9972
# 00650: TRAIN| LT=0.146 LP=0.017 LKL=6.878 LPS=0.005 LKLS=5.542 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9458
# Train F1: 1.0000
# 00700: TRAIN| LT=0.143 LP=0.013 LKL=6.827 LPS=0.006 LKLS=5.632 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9476
# Train F1: 0.9972
# 00750: TRAIN| LT=0.151 LP=0.025 LKL=6.825 LPS=0.003 LKLS=5.517 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9406
# Train F1: 0.9915
# 00800: TRAIN| LT=0.128 LP=0.007 LKL=6.507 LPS=0.005 LKLS=5.077 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9441
# Train F1: 0.9943
# 00850: TRAIN| LT=0.141 LP=0.016 LKL=6.646 LPS=0.006 LKLS=5.230 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9423
# Train F1: 0.9972
# 00900: TRAIN| LT=0.137 LP=0.015 LKL=6.771 LPS=0.001 LKLS=5.328 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9371
# Train F1: 1.0000
# 00950: TRAIN| LT=0.150 LP=0.034 LKL=6.477 LPS=0.003 LKLS=4.843 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9406
# Train F1: 0.9972
# 01000: TRAIN| LT=0.135 LP=0.021 LKL=6.395 LPS=0.002 LKLS=4.795 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9406
# Train F1: 1.0000
# 01050: TRAIN| LT=0.144 LP=0.026 LKL=6.530 LPS=0.004 LKLS=4.902 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9283
# Train F1: 0.9972
# 01100: TRAIN| LT=0.127 LP=0.016 LKL=6.239 LPS=0.003 LKLS=4.572 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9458
# Train F1: 0.9943
# 01150: TRAIN| LT=0.116 LP=0.007 LKL=6.320 LPS=0.002 LKLS=4.335 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9371
# Train F1: 0.9856
# 01200: TRAIN| LT=0.139 LP=0.021 LKL=6.682 LPS=0.004 LKLS=4.695 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9318
# Train F1: 0.9943
# 01250: TRAIN| LT=0.130 LP=0.015 LKL=6.513 LPS=0.003 LKLS=4.636 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9406
# Train F1: 1.0000
# 01300: TRAIN| LT=0.120 LP=0.008 LKL=6.275 LPS=0.004 LKLS=4.518 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9388
# Train F1: 0.9972
# 01350: TRAIN| LT=0.112 LP=0.005 LKL=6.215 LPS=0.004 LKLS=4.133 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9318
# Train F1: 0.9972
# 01400: TRAIN| LT=0.125 LP=0.002 LKL=6.446 LPS=0.013 LKLS=4.524 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9423
# Train F1: 0.9972
# 01450: TRAIN| LT=0.112 LP=0.002 LKL=6.463 LPS=0.002 LKLS=4.360 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9388
# Train F1: 1.0000
# 01500: TRAIN| LT=0.117 LP=0.008 LKL=6.327 LPS=0.004 LKLS=4.136 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9353
# Train F1: 0.9972
# 01550: TRAIN| LT=0.115 LP=0.003 LKL=6.173 LPS=0.013 LKLS=3.780 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9353
# Train F1: 0.9972
# 01600: TRAIN| LT=0.114 LP=0.016 LKL=5.991 LPS=0.002 LKLS=3.670 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9388
# Train F1: 1.0000
# 01650: TRAIN| LT=0.107 LP=0.005 LKL=6.237 LPS=0.001 LKLS=3.921 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9388
# Train F1: 0.9972
# 01700: TRAIN| LT=0.107 LP=0.011 LKL=5.866 LPS=0.004 LKLS=3.418 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9371
# Train F1: 0.9972
# 01750: TRAIN| LT=0.106 LP=0.003 LKL=6.105 LPS=0.004 LKLS=3.751 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9441
# Train F1: 0.9972
# 01800: TRAIN| LT=0.117 LP=0.013 LKL=5.907 LPS=0.011 LKLS=3.378 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9301
# Train F1: 0.9972
# 01850: TRAIN| LT=0.100 LP=0.004 LKL=5.951 LPS=0.002 LKLS=3.422 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9353
# Train F1: 1.0000
# 01900: TRAIN| LT=0.095 LP=0.002 LKL=5.914 LPS=0.001 LKLS=3.344 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9336
# Train F1: 0.9972
# 01950: TRAIN| LT=0.095 LP=0.002 LKL=5.776 LPS=0.003 LKLS=3.212 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9353
# Train F1: 1.0000
# 02000: TRAIN| LT=0.119 LP=0.004 LKL=5.777 LPS=0.026 LKLS=3.111 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9301
# f1: 0.9565217391304348
# acc: 0.9298245614035088
# auc: 0.951048951048951
# Train F1: 0.9081
# 00050: TRAIN| LT=0.747 LP=0.326 LKL=7.799 LPS=0.225 LKLS=11.751 |
# Test F1: 0.9231
# Test ACC: 0.8772
# Test AUC: 0.9266
# Train F1: 0.9801
# 00100: TRAIN| LT=0.342 LP=0.099 LKL=8.504 LPS=0.036 LKLS=12.191 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9336
# Train F1: 0.9858
# 00150: TRAIN| LT=0.252 LP=0.053 LKL=7.781 LPS=0.028 LKLS=9.257 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9318
# Train F1: 0.9915
# 00200: TRAIN| LT=0.225 LP=0.055 LKL=7.441 LPS=0.014 LKLS=8.155 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9301
# Train F1: 0.9972
# 00250: TRAIN| LT=0.241 LP=0.054 LKL=7.484 LPS=0.030 LKLS=8.204 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9318
# Train F1: 0.9943
# 00300: TRAIN| LT=0.203 LP=0.032 LKL=7.326 LPS=0.022 LKLS=7.664 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9318
# Train F1: 0.9915
# 00350: TRAIN| LT=0.200 LP=0.036 LKL=7.112 LPS=0.026 LKLS=6.723 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9231
# Train F1: 0.9943
# 00400: TRAIN| LT=0.175 LP=0.029 LKL=7.287 LPS=0.005 LKLS=6.850 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9266
# Train F1: 0.9972
# 00450: TRAIN| LT=0.195 LP=0.036 LKL=7.096 LPS=0.022 LKLS=6.657 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9301
# Train F1: 0.9885
# 00500: TRAIN| LT=0.176 LP=0.034 LKL=6.927 LPS=0.012 LKLS=5.984 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9371
# Train F1: 0.9915
# 00550: TRAIN| LT=0.189 LP=0.038 LKL=6.904 LPS=0.022 LKLS=6.013 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9371
# Train F1: 0.9972
# 00600: TRAIN| LT=0.172 LP=0.017 LKL=7.023 LPS=0.021 LKLS=6.365 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9318
# Train F1: 1.0000
# 00650: TRAIN| LT=0.189 LP=0.055 LKL=6.864 LPS=0.007 LKLS=5.822 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9301
# Train F1: 0.9887
# 00700: TRAIN| LT=0.166 LP=0.036 LKL=6.816 LPS=0.004 LKLS=5.736 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9283
# Train F1: 0.9972
# 00750: TRAIN| LT=0.164 LP=0.032 LKL=6.958 LPS=0.005 LKLS=5.744 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9248
# Train F1: 0.9972
# 00800: TRAIN| LT=0.165 LP=0.034 LKL=6.796 LPS=0.007 LKLS=5.517 |
# Test F1: 0.9247
# Test ACC: 0.8772
# Test AUC: 0.9336
# Train F1: 0.9972
# 00850: TRAIN| LT=0.184 LP=0.039 LKL=6.750 LPS=0.024 LKLS=5.477 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9213
# Train F1: 0.9943
# 00900: TRAIN| LT=0.153 LP=0.019 LKL=6.868 LPS=0.011 LKLS=5.455 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9301
# Train F1: 0.9915
# 00950: TRAIN| LT=0.162 LP=0.022 LKL=6.741 LPS=0.019 LKLS=5.347 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9301
# Train F1: 0.9887
# 01000: TRAIN| LT=0.150 LP=0.026 LKL=6.416 LPS=0.013 LKLS=4.599 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9266
# Train F1: 0.9943
# 01050: TRAIN| LT=0.184 LP=0.043 LKL=6.687 LPS=0.021 LKLS=5.219 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9248
# Train F1: 0.9972
# 01100: TRAIN| LT=0.141 LP=0.016 LKL=6.674 LPS=0.011 LKLS=4.755 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9318
# Train F1: 0.9915
# 01150: TRAIN| LT=0.122 LP=0.007 LKL=6.512 LPS=0.002 LKLS=4.735 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9248
# Train F1: 0.9943
# 01200: TRAIN| LT=0.150 LP=0.028 LKL=6.439 LPS=0.011 LKLS=4.613 |
# Test F1: 0.9247
# Test ACC: 0.8772
# Test AUC: 0.9283
# Train F1: 0.9943
# 01250: TRAIN| LT=0.138 LP=0.020 LKL=6.451 LPS=0.007 LKLS=4.593 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9231
# Train F1: 0.9972
# 01300: TRAIN| LT=0.172 LP=0.032 LKL=6.409 LPS=0.031 LKLS=4.503 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9283
# Train F1: 0.9943
# 01350: TRAIN| LT=0.133 LP=0.018 LKL=6.560 LPS=0.003 LKLS=4.584 |
# Test F1: 0.9247
# Test ACC: 0.8772
# Test AUC: 0.9336
# Train F1: 0.9886
# 01400: TRAIN| LT=0.145 LP=0.017 LKL=6.333 LPS=0.023 LKLS=4.197 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9266
# Train F1: 0.9943
# 01450: TRAIN| LT=0.143 LP=0.024 LKL=6.390 LPS=0.012 LKLS=4.349 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9353
# Train F1: 0.9944
# 01500: TRAIN| LT=0.138 LP=0.017 LKL=6.325 LPS=0.015 LKLS=4.270 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9248
# Train F1: 0.9972
# 01550: TRAIN| LT=0.119 LP=0.011 LKL=6.354 LPS=0.004 LKLS=4.061 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9178
# Train F1: 0.9943
# 01600: TRAIN| LT=0.123 LP=0.008 LKL=6.326 LPS=0.011 LKLS=4.071 |
# Test F1: 0.9362
# Test ACC: 0.8947
# Test AUC: 0.9283
# Train F1: 0.9944
# 01650: TRAIN| LT=0.147 LP=0.028 LKL=6.180 LPS=0.018 LKLS=3.887 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9301
# Train F1: 1.0000
# 01700: TRAIN| LT=0.140 LP=0.035 LKL=6.044 LPS=0.006 LKLS=3.795 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9283
# Train F1: 0.9972
# 01750: TRAIN| LT=0.127 LP=0.019 LKL=6.003 LPS=0.010 LKLS=3.848 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9318
# Train F1: 0.9972
# 01800: TRAIN| LT=0.128 LP=0.019 LKL=6.248 LPS=0.008 LKLS=3.845 |
# Test F1: 0.9247
# Test ACC: 0.8772
# Test AUC: 0.9248
# Train F1: 0.9943
# 01850: TRAIN| LT=0.119 LP=0.008 LKL=6.311 LPS=0.008 LKLS=3.924 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9161
# Train F1: 0.9972
# 01900: TRAIN| LT=0.121 LP=0.011 LKL=6.176 LPS=0.010 LKLS=3.820 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9248
# Train F1: 0.9972
# 01950: TRAIN| LT=0.129 LP=0.015 LKL=6.055 LPS=0.017 LKLS=3.621 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9231
# Train F1: 0.9972
# 02000: TRAIN| LT=0.130 LP=0.025 LKL=6.145 LPS=0.007 LKLS=3.697 |
# Test F1: 0.9263
# Test ACC: 0.8772
# Test AUC: 0.9301
# f1: 0.9361702127659575
# acc: 0.8947368421052632
# auc: 0.9370629370629371
# Train F1: 0.9062
# 00050: TRAIN| LT=0.760 LP=0.318 LKL=8.100 LPS=0.238 LKLS=12.331 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9283
# Train F1: 0.9943
# 00100: TRAIN| LT=0.304 LP=0.081 LKL=8.369 LPS=0.025 LKLS=11.362 |
# Test F1: 0.8966
# Test ACC: 0.8421
# Test AUC: 0.9248
# Train F1: 0.9886
# 00150: TRAIN| LT=0.219 LP=0.045 LKL=7.356 LPS=0.018 LKLS=8.168 |
# Test F1: 0.9070
# Test ACC: 0.8596
# Test AUC: 0.9196
# Train F1: 1.0000
# 00200: TRAIN| LT=0.213 LP=0.045 LKL=7.596 LPS=0.008 LKLS=8.497 |
# Test F1: 0.8966
# Test ACC: 0.8421
# Test AUC: 0.9178
# Train F1: 1.0000
# 00250: TRAIN| LT=0.182 LP=0.029 LKL=7.156 LPS=0.006 LKLS=7.446 |
# Test F1: 0.9011
# Test ACC: 0.8421
# Test AUC: 0.9231
# Train F1: 0.9943
# 00300: TRAIN| LT=0.178 LP=0.025 LKL=7.190 LPS=0.010 LKLS=7.155 |
# Test F1: 0.8989
# Test ACC: 0.8421
# Test AUC: 0.9143
# Train F1: 0.9887
# 00350: TRAIN| LT=0.185 LP=0.045 LKL=6.982 LPS=0.005 LKLS=6.553 |
# Test F1: 0.9011
# Test ACC: 0.8421
# Test AUC: 0.9231
# Train F1: 0.9943
# 00400: TRAIN| LT=0.162 LP=0.019 LKL=7.141 LPS=0.005 LKLS=6.760 |
# Test F1: 0.8864
# Test ACC: 0.8246
# Test AUC: 0.9143
# Train F1: 1.0000
# 00450: TRAIN| LT=0.153 LP=0.014 LKL=7.070 LPS=0.004 LKLS=6.450 |
# Test F1: 0.8989
# Test ACC: 0.8421
# Test AUC: 0.9091
# Train F1: 0.9972
# 00500: TRAIN| LT=0.168 LP=0.029 LKL=7.000 LPS=0.003 LKLS=6.527 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.9126
# Train F1: 0.9857
# 00550: TRAIN| LT=0.164 LP=0.032 LKL=6.982 LPS=0.002 LKLS=6.062 |
# Test F1: 0.8791
# Test ACC: 0.8070
# Test AUC: 0.9126
# Train F1: 0.9943
# 00600: TRAIN| LT=0.157 LP=0.025 LKL=6.611 LPS=0.012 LKLS=5.337 |
# Test F1: 0.8889
# Test ACC: 0.8246
# Test AUC: 0.9126
# Train F1: 0.9943
# 00650: TRAIN| LT=0.144 LP=0.013 LKL=6.818 LPS=0.003 LKLS=5.883 |
# Test F1: 0.8989
# Test ACC: 0.8421
# Test AUC: 0.9196
# Train F1: 0.9943
# 00700: TRAIN| LT=0.158 LP=0.031 LKL=6.726 LPS=0.004 LKLS=5.523 |
# Test F1: 0.8791
# Test ACC: 0.8070
# Test AUC: 0.9056
# Train F1: 0.9972
# 00750: TRAIN| LT=0.140 LP=0.010 LKL=6.854 LPS=0.002 LKLS=5.867 |
# Test F1: 0.8889
# Test ACC: 0.8246
# Test AUC: 0.9161
# Train F1: 1.0000
# 00800: TRAIN| LT=0.161 LP=0.036 LKL=6.710 LPS=0.005 LKLS=5.312 |
# Test F1: 0.9011
# Test ACC: 0.8421
# Test AUC: 0.9091
# Train F1: 0.9915
# 00850: TRAIN| LT=0.140 LP=0.011 LKL=6.572 LPS=0.012 LKLS=5.131 |
# Test F1: 0.8791
# Test ACC: 0.8070
# Test AUC: 0.9056
# Train F1: 0.9972
# 00900: TRAIN| LT=0.131 LP=0.009 LKL=6.636 LPS=0.002 LKLS=5.371 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.9073
# Train F1: 1.0000
# 00950: TRAIN| LT=0.152 LP=0.029 LKL=6.677 LPS=0.001 LKLS=5.559 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.9108
# Train F1: 0.9944
# 01000: TRAIN| LT=0.137 LP=0.013 LKL=6.594 LPS=0.002 LKLS=5.688 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.9143
# Train F1: 0.9943
# 01050: TRAIN| LT=0.130 LP=0.013 LKL=6.543 LPS=0.002 LKLS=4.993 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.9143
# Train F1: 0.9972
# 01100: TRAIN| LT=0.137 LP=0.019 LKL=6.486 LPS=0.002 LKLS=5.097 |
# Test F1: 0.9011
# Test ACC: 0.8421
# Test AUC: 0.9108
# Train F1: 0.9944
# 01150: TRAIN| LT=0.136 LP=0.014 LKL=6.665 LPS=0.001 LKLS=5.462 |
# Test F1: 0.8889
# Test ACC: 0.8246
# Test AUC: 0.9161
# Train F1: 0.9944
# 01200: TRAIN| LT=0.128 LP=0.014 LKL=6.299 LPS=0.002 LKLS=4.896 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.9091
# Train F1: 0.9972
# 01250: TRAIN| LT=0.131 LP=0.017 LKL=6.313 LPS=0.004 LKLS=4.628 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.9038
# Train F1: 1.0000
# 01300: TRAIN| LT=0.122 LP=0.010 LKL=6.357 LPS=0.001 LKLS=4.672 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.9073
# Train F1: 0.9943
# 01350: TRAIN| LT=0.137 LP=0.014 LKL=6.417 LPS=0.014 LKLS=4.503 |
# Test F1: 0.8764
# Test ACC: 0.8070
# Test AUC: 0.9021
# Train F1: 1.0000
# 01400: TRAIN| LT=0.124 LP=0.010 LKL=6.277 LPS=0.008 LKLS=4.330 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9056
# Train F1: 0.9944
# 01450: TRAIN| LT=0.130 LP=0.019 LKL=6.328 LPS=0.001 LKLS=4.595 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.9161
# Train F1: 0.9972
# 01500: TRAIN| LT=0.145 LP=0.024 LKL=6.308 LPS=0.012 LKLS=4.537 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.9178
# Train F1: 1.0000
# 01550: TRAIN| LT=0.125 LP=0.011 LKL=6.595 LPS=0.001 LKLS=4.771 |
# Test F1: 0.8791
# Test ACC: 0.8070
# Test AUC: 0.9056
# Train F1: 0.9915
# 01600: TRAIN| LT=0.124 LP=0.008 LKL=6.492 LPS=0.003 LKLS=4.798 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.9091
# Train F1: 0.9943
# 01650: TRAIN| LT=0.132 LP=0.014 LKL=6.108 LPS=0.017 LKLS=3.897 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.9038
# Train F1: 1.0000
# 01700: TRAIN| LT=0.116 LP=0.008 LKL=6.248 LPS=0.003 LKLS=4.337 |
# Test F1: 0.9032
# Test ACC: 0.8421
# Test AUC: 0.9038
# Train F1: 0.9972
# 01750: TRAIN| LT=0.157 LP=0.045 LKL=6.520 LPS=0.002 LKLS=4.450 |
# Test F1: 0.9011
# Test ACC: 0.8421
# Test AUC: 0.9143
# Train F1: 1.0000
# 01800: TRAIN| LT=0.107 LP=0.002 LKL=6.251 LPS=0.002 LKLS=4.162 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9091
# Train F1: 1.0000
# 01850: TRAIN| LT=0.140 LP=0.034 LKL=6.185 LPS=0.004 LKLS=4.043 |
# Test F1: 0.9011
# Test ACC: 0.8421
# Test AUC: 0.9003
# Train F1: 1.0000
# 01900: TRAIN| LT=0.112 LP=0.004 LKL=6.300 LPS=0.003 LKLS=4.227 |
# Test F1: 0.9011
# Test ACC: 0.8421
# Test AUC: 0.9091
# Train F1: 1.0000
# 01950: TRAIN| LT=0.137 LP=0.020 LKL=6.256 LPS=0.012 LKLS=4.250 |
# Test F1: 0.9011
# Test ACC: 0.8421
# Test AUC: 0.9143
# Train F1: 0.9943
# 02000: TRAIN| LT=0.117 LP=0.011 LKL=6.352 LPS=0.001 LKLS=4.106 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.9126
# f1: 0.9333333333333332
# acc: 0.8947368421052632
# auc: 0.9283216783216783
# f1 [0.9565217391304348, 0.9195402298850575, 0.9565217391304348, 0.9361702127659575, 0.9333333333333332]
# average f1: 0.9404174508490437±0.014302295686988311
# acc [0.9310344827586207, 0.8793103448275862, 0.9298245614035088, 0.8947368421052632, 0.8947368421052632]
# average acc: 0.9059286146400485±0.020786364369264093
# auc [0.9918831168831169, 0.9431818181818182, 0.951048951048951, 0.9370629370629371, 0.9283216783216783]
# average auc: 0.9502997002997002±0.022084616855774654
