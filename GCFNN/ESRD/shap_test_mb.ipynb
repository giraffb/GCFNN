# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
data_class={'Control':0,'ESRD':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metabolomics
print('输入各组学数据表：',x1.shape,meta_data.shape)

#重构数据表和标签表
X1 = x1
index_new=X1.index
print(index_new)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,meta_data.shape)
X_set=[X1]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (287, 276) (287, 1)
# Index(['CON-001', 'CON-002', 'CON-003', 'CON-004', 'CON-005', 'CON-006',
#        'CON-007', 'CON-008', 'CON-009', 'CON-010',
#        ...
#        'KD-214', 'KD-215', 'KD-216', 'KD-217', 'KD-218', 'KD-219', 'KD-220',
#        'KD-221', 'KD-222', 'KD-223'],
#       dtype='object', name='Sample', length=287)
# 集合所有样本重构数据表： (287, 276) (287, 1)
# 标签转换为one-hot编码： (287, 2) 67.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap_mb'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 20)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 1, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1', f1_cv)
print('average f1: {}±{}'.format(np.mean(f1_cv), np.std(f1_cv)))
print('acc', acc_cv)
print('average acc: {}±{}'.format(np.mean(acc_cv), np.std(acc_cv)))
print('auc', auc_cv)
print('average auc: {}±{}'.format(np.mean(auc_cv), np.std(auc_cv)))
# Out:
# Train F1: 0.8564
# 00050: TRAIN| LT=1.207 LP=0.578 LKL=4.498 LPS=0.579 LKLS=0.487 |
# Test F1: 0.8627
# Test ACC: 0.7586
# Test AUC: 0.7760
# Train F1: 0.8691
# 00100: TRAIN| LT=1.139 LP=0.534 LKL=4.321 LPS=0.555 LKLS=0.617 |
# Test F1: 0.8627
# Test ACC: 0.7586
# Test AUC: 0.8409
# Train F1: 0.8663
# 00150: TRAIN| LT=1.116 LP=0.534 LKL=4.340 LPS=0.525 LKLS=1.357 |
# Test F1: 0.8627
# Test ACC: 0.7586
# Test AUC: 0.8506
# Train F1: 0.8657
# 00200: TRAIN| LT=0.990 LP=0.472 LKL=4.823 LPS=0.439 LKLS=3.143 |
# Test F1: 0.8627
# Test ACC: 0.7586
# Test AUC: 0.8393
# Train F1: 0.8958
# 00250: TRAIN| LT=0.855 LP=0.392 LKL=5.713 LPS=0.355 LKLS=5.116 |
# Test F1: 0.8750
# Test ACC: 0.7931
# Test AUC: 0.8490
# Train F1: 0.9201
# 00300: TRAIN| LT=0.773 LP=0.346 LKL=6.282 LPS=0.301 LKLS=6.286 |
# Test F1: 0.8791
# Test ACC: 0.8103
# Test AUC: 0.8782
# Train F1: 0.9392
# 00350: TRAIN| LT=0.637 LP=0.273 LKL=6.742 LPS=0.223 LKLS=7.381 |
# Test F1: 0.8764
# Test ACC: 0.8103
# Test AUC: 0.8880
# Train F1: 0.9638
# 00400: TRAIN| LT=0.424 LP=0.162 LKL=7.229 LPS=0.103 LKLS=8.665 |
# Test F1: 0.8764
# Test ACC: 0.8103
# Test AUC: 0.8945
# Train F1: 0.9775
# 00450: TRAIN| LT=0.398 LP=0.148 LKL=7.398 LPS=0.087 LKLS=8.814 |
# Test F1: 0.8889
# Test ACC: 0.8276
# Test AUC: 0.8896
# Train F1: 0.9803
# 00500: TRAIN| LT=0.336 LP=0.101 LKL=7.581 LPS=0.069 LKLS=9.066 |
# Test F1: 0.8889
# Test ACC: 0.8276
# Test AUC: 0.9010
# Train F1: 0.9859
# 00550: TRAIN| LT=0.309 LP=0.094 LKL=7.567 LPS=0.051 LKLS=8.851 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.8994
# Train F1: 0.9802
# 00600: TRAIN| LT=0.237 LP=0.051 LKL=7.464 LPS=0.027 LKLS=8.458 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.9042
# Train F1: 0.9943
# 00650: TRAIN| LT=0.259 LP=0.059 LKL=7.636 LPS=0.034 LKLS=8.915 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.9042
# Train F1: 0.9830
# 00700: TRAIN| LT=0.239 LP=0.069 LKL=7.451 LPS=0.014 LKLS=8.217 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.9058
# Train F1: 0.9828
# 00750: TRAIN| LT=0.231 LP=0.051 LKL=7.639 LPS=0.018 LKLS=8.576 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.9075
# Train F1: 0.9886
# 00800: TRAIN| LT=0.210 LP=0.035 LKL=7.684 LPS=0.010 LKLS=8.729 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.9075
# Train F1: 0.9886
# 00850: TRAIN| LT=0.244 LP=0.072 LKL=7.678 LPS=0.010 LKLS=8.596 |
# Test F1: 0.9111
# Test ACC: 0.8621
# Test AUC: 0.9107
# Train F1: 0.9943
# 00900: TRAIN| LT=0.207 LP=0.039 LKL=7.657 LPS=0.009 LKLS=8.278 |
# Test F1: 0.9213
# Test ACC: 0.8793
# Test AUC: 0.9107
# Train F1: 1.0000
# 00950: TRAIN| LT=0.243 LP=0.070 LKL=7.710 LPS=0.014 LKLS=8.186 |
# Test F1: 0.9111
# Test ACC: 0.8621
# Test AUC: 0.9123
# Train F1: 0.9830
# 01000: TRAIN| LT=0.229 LP=0.049 LKL=7.677 LPS=0.024 LKLS=7.928 |
# Test F1: 0.9111
# Test ACC: 0.8621
# Test AUC: 0.9140
# Train F1: 0.9886
# 01050: TRAIN| LT=0.201 LP=0.029 LKL=7.605 LPS=0.017 LKLS=7.918 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9123
# Train F1: 0.9915
# 01100: TRAIN| LT=0.202 LP=0.042 LKL=7.428 LPS=0.013 LKLS=7.300 |
# Test F1: 0.9130
# Test ACC: 0.8621
# Test AUC: 0.9140
# Train F1: 0.9972
# 01150: TRAIN| LT=0.220 LP=0.036 LKL=7.649 LPS=0.032 LKLS=7.591 |
# Test F1: 0.9195
# Test ACC: 0.8793
# Test AUC: 0.9123
# Train F1: 0.9972
# 01200: TRAIN| LT=0.212 LP=0.034 LKL=7.603 LPS=0.027 LKLS=7.575 |
# Test F1: 0.9111
# Test ACC: 0.8621
# Test AUC: 0.9123
# Train F1: 0.9943
# 01250: TRAIN| LT=0.199 LP=0.046 LKL=7.455 LPS=0.009 LKLS=6.994 |
# Test F1: 0.9195
# Test ACC: 0.8793
# Test AUC: 0.9140
# Train F1: 0.9830
# 01300: TRAIN| LT=0.213 LP=0.022 LKL=7.230 LPS=0.053 LKLS=6.666 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9140
# Train F1: 0.9915
# 01350: TRAIN| LT=0.201 LP=0.032 LKL=7.267 LPS=0.028 LKLS=6.729 |
# Test F1: 0.9130
# Test ACC: 0.8621
# Test AUC: 0.9123
# Train F1: 0.9885
# 01400: TRAIN| LT=0.197 LP=0.047 LKL=7.276 LPS=0.009 LKLS=6.736 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9140
# Train F1: 0.9857
# 01450: TRAIN| LT=0.199 LP=0.057 LKL=7.239 LPS=0.007 LKLS=6.304 |
# Test F1: 0.9091
# Test ACC: 0.8621
# Test AUC: 0.9140
# Train F1: 0.9915
# 01500: TRAIN| LT=0.184 LP=0.040 LKL=7.268 LPS=0.005 LKLS=6.560 |
# Test F1: 0.9091
# Test ACC: 0.8621
# Test AUC: 0.9107
# Train F1: 0.9915
# 01550: TRAIN| LT=0.168 LP=0.023 LKL=7.155 LPS=0.010 LKLS=6.278 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9123
# Train F1: 1.0000
# 01600: TRAIN| LT=0.181 LP=0.023 LKL=6.926 LPS=0.030 LKLS=5.812 |
# Test F1: 0.9130
# Test ACC: 0.8621
# Test AUC: 0.9075
# Train F1: 0.9943
# 01650: TRAIN| LT=0.167 LP=0.021 LKL=7.255 LPS=0.007 LKLS=6.605 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9075
# Train F1: 0.9972
# 01700: TRAIN| LT=0.166 LP=0.021 LKL=7.399 LPS=0.002 LKLS=6.870 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9075
# Train F1: 0.9943
# 01750: TRAIN| LT=0.199 LP=0.041 LKL=6.901 LPS=0.032 LKLS=5.679 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9075
# Train F1: 0.9943
# 01800: TRAIN| LT=0.187 LP=0.038 LKL=7.092 LPS=0.019 LKLS=5.960 |
# Test F1: 0.9195
# Test ACC: 0.8793
# Test AUC: 0.9075
# Train F1: 0.9943
# 01850: TRAIN| LT=0.160 LP=0.025 LKL=6.930 LPS=0.006 LKLS=5.888 |
# Test F1: 0.9130
# Test ACC: 0.8621
# Test AUC: 0.9075
# Train F1: 0.9915
# 01900: TRAIN| LT=0.189 LP=0.045 LKL=7.080 LPS=0.012 LKLS=6.075 |
# Test F1: 0.9091
# Test ACC: 0.8621
# Test AUC: 0.9091
# Train F1: 0.9914
# 01950: TRAIN| LT=0.177 LP=0.043 LKL=6.936 LPS=0.008 LKLS=5.762 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9091
# Train F1: 0.9943
# 02000: TRAIN| LT=0.151 LP=0.024 LKL=6.782 LPS=0.004 LKLS=5.533 |
# Test F1: 0.9231
# Test ACC: 0.8793
# Test AUC: 0.9095
# f1: 0.9333333333333332
# acc: 0.896551724137931
# auc: 0.913961038961039
# Train F1: 0.8628
# 00050: TRAIN| LT=1.203 LP=0.570 LKL=4.492 LPS=0.579 LKLS=0.908 |
# Test F1: 0.8627
# Test ACC: 0.7586
# Test AUC: 0.6899
# Train F1: 0.8691
# 00100: TRAIN| LT=1.163 LP=0.533 LKL=4.384 LPS=0.578 LKLS=0.883 |
# Test F1: 0.8627
# Test ACC: 0.7586
# Test AUC: 0.8490
# Train F1: 0.8691
# 00150: TRAIN| LT=1.062 LP=0.505 LKL=4.690 LPS=0.484 LKLS=2.616 |
# Test F1: 0.8627
# Test ACC: 0.7586
# Test AUC: 0.8620
# Train F1: 0.8782
# 00200: TRAIN| LT=0.915 LP=0.417 LKL=5.681 LPS=0.389 LKLS=5.260 |
# Test F1: 0.8776
# Test ACC: 0.7931
# Test AUC: 0.8896
# Train F1: 0.8930
# 00250: TRAIN| LT=0.773 LP=0.353 LKL=6.199 LPS=0.294 LKLS=6.356 |
# Test F1: 0.9011
# Test ACC: 0.8448
# Test AUC: 0.9562
# Train F1: 0.9141
# 00300: TRAIN| LT=0.607 LP=0.262 LKL=6.632 LPS=0.201 LKLS=7.757 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9821
# Train F1: 0.9521
# 00350: TRAIN| LT=0.470 LP=0.160 LKL=6.913 LPS=0.160 LKLS=8.144 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9854
# Train F1: 0.9602
# 00400: TRAIN| LT=0.418 LP=0.147 LKL=7.172 LPS=0.110 LKLS=8.912 |
# Test F1: 0.9773
# Test ACC: 0.9655
# Test AUC: 0.9919
# Train F1: 0.9632
# 00450: TRAIN| LT=0.391 LP=0.166 LKL=7.177 LPS=0.066 LKLS=8.688 |
# Test F1: 0.9773
# Test ACC: 0.9655
# Test AUC: 0.9903
# Train F1: 0.9663
# 00500: TRAIN| LT=0.375 LP=0.111 LKL=7.691 LPS=0.086 LKLS=10.153 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9951
# Train F1: 0.9714
# 00550: TRAIN| LT=0.327 LP=0.100 LKL=7.289 LPS=0.066 LKLS=8.818 |
# Test F1: 0.9773
# Test ACC: 0.9655
# Test AUC: 0.9935
# Train F1: 0.9830
# 00600: TRAIN| LT=0.299 LP=0.074 LKL=7.473 LPS=0.059 LKLS=9.091 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9968
# Train F1: 0.9798
# 00650: TRAIN| LT=0.290 LP=0.094 LKL=7.399 LPS=0.035 LKLS=8.682 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9935
# Train F1: 0.9831
# 00700: TRAIN| LT=0.221 LP=0.041 LKL=7.229 LPS=0.025 LKLS=8.291 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9951
# Train F1: 0.9773
# 00750: TRAIN| LT=0.274 LP=0.079 LKL=7.334 LPS=0.038 LKLS=8.433 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9886
# Train F1: 0.9773
# 00800: TRAIN| LT=0.216 LP=0.042 LKL=7.315 LPS=0.020 LKLS=8.127 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9903
# Train F1: 0.9828
# 00850: TRAIN| LT=0.229 LP=0.034 LKL=7.378 LPS=0.037 LKLS=8.457 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9919
# Train F1: 0.9887
# 00900: TRAIN| LT=0.229 LP=0.039 LKL=7.405 LPS=0.034 LKLS=8.186 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9951
# Train F1: 0.9915
# 00950: TRAIN| LT=0.216 LP=0.058 LKL=7.243 LPS=0.009 LKLS=7.733 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9919
# Train F1: 0.9943
# 01000: TRAIN| LT=0.219 LP=0.042 LKL=7.249 LPS=0.028 LKLS=7.560 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9903
# Train F1: 0.9886
# 01050: TRAIN| LT=0.250 LP=0.080 LKL=7.567 LPS=0.015 LKLS=7.957 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9903
# Train F1: 0.9943
# 01100: TRAIN| LT=0.173 LP=0.017 LKL=7.171 LPS=0.011 LKLS=7.223 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9903
# Train F1: 0.9857
# 01150: TRAIN| LT=0.177 LP=0.029 LKL=7.229 LPS=0.004 LKLS=7.251 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9919
# Train F1: 1.0000
# 01200: TRAIN| LT=0.186 LP=0.038 LKL=6.881 LPS=0.014 LKLS=6.492 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9903
# Train F1: 0.9886
# 01250: TRAIN| LT=0.196 LP=0.031 LKL=7.155 LPS=0.024 LKLS=6.880 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9903
# Train F1: 0.9887
# 01300: TRAIN| LT=0.199 LP=0.054 LKL=6.951 LPS=0.010 LKLS=6.548 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9919
# Train F1: 0.9831
# 01350: TRAIN| LT=0.191 LP=0.031 LKL=7.115 LPS=0.020 LKLS=6.880 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9935
# Train F1: 0.9972
# 01400: TRAIN| LT=0.231 LP=0.074 LKL=7.074 LPS=0.019 LKLS=6.659 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9903
# Train F1: 0.9829
# 01450: TRAIN| LT=0.169 LP=0.025 LKL=7.066 LPS=0.006 LKLS=6.644 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9886
# Train F1: 0.9915
# 01500: TRAIN| LT=0.164 LP=0.027 LKL=6.950 LPS=0.005 LKLS=6.356 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9886
# Train F1: 0.9943
# 01550: TRAIN| LT=0.175 LP=0.037 LKL=6.891 LPS=0.008 LKLS=6.102 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9903
# Train F1: 0.9914
# 01600: TRAIN| LT=0.158 LP=0.009 LKL=7.062 LPS=0.015 LKLS=6.384 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9870
# Train F1: 0.9943
# 01650: TRAIN| LT=0.196 LP=0.041 LKL=7.007 LPS=0.024 LKLS=6.134 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9919
# Train F1: 0.9915
# 01700: TRAIN| LT=0.263 LP=0.073 LKL=7.200 LPS=0.052 LKLS=6.597 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9870
# Train F1: 1.0000
# 01750: TRAIN| LT=0.150 LP=0.019 LKL=6.855 LPS=0.003 LKLS=5.955 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9886
# Train F1: 0.9886
# 01800: TRAIN| LT=0.150 LP=0.006 LKL=7.073 LPS=0.010 LKLS=6.347 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9886
# Train F1: 0.9915
# 01850: TRAIN| LT=0.146 LP=0.014 LKL=6.810 LPS=0.005 LKLS=5.847 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9919
# Train F1: 0.9972
# 01900: TRAIN| LT=0.179 LP=0.026 LKL=6.912 LPS=0.023 LKLS=6.055 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9886
# Train F1: 0.9915
# 01950: TRAIN| LT=0.165 LP=0.034 LKL=6.632 LPS=0.011 LKLS=5.408 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9870
# Train F1: 0.9858
# 02000: TRAIN| LT=0.192 LP=0.059 LKL=6.707 LPS=0.012 LKLS=5.456 |
# Test F1: 0.9663
# Test ACC: 0.9483
# Test AUC: 0.9886
# f1: 0.9772727272727273
# acc: 0.9655172413793104
# auc: 0.9935064935064936
# Train F1: 0.8614
# 00050: TRAIN| LT=1.178 LP=0.565 LKL=4.454 LPS=0.564 LKLS=0.527 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.6556
# Train F1: 0.8670
# 00100: TRAIN| LT=1.178 LP=0.555 LKL=4.301 LPS=0.573 LKLS=0.666 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.7657
# Train F1: 0.8670
# 00150: TRAIN| LT=1.111 LP=0.536 LKL=4.393 LPS=0.514 LKLS=1.675 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.8042
# Train F1: 0.8586
# 00200: TRAIN| LT=1.070 LP=0.494 LKL=4.865 LPS=0.495 LKLS=3.130 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.8759
# Train F1: 0.8782
# 00250: TRAIN| LT=0.937 LP=0.442 LKL=5.586 LPS=0.390 LKLS=4.956 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9301
# Train F1: 0.8883
# 00300: TRAIN| LT=0.847 LP=0.402 LKL=5.972 LPS=0.329 LKLS=5.634 |
# Test F1: 0.9318
# Test ACC: 0.8947
# Test AUC: 0.9458
# Train F1: 0.9227
# 00350: TRAIN| LT=0.680 LP=0.285 LKL=6.315 LPS=0.269 LKLS=6.301 |
# Test F1: 0.9535
# Test ACC: 0.9298
# Test AUC: 0.9458
# Train F1: 0.9359
# 00400: TRAIN| LT=0.544 LP=0.212 LKL=6.988 LPS=0.179 LKLS=8.309 |
# Test F1: 0.9302
# Test ACC: 0.8947
# Test AUC: 0.9423
# Train F1: 0.9609
# 00450: TRAIN| LT=0.407 LP=0.156 LKL=7.104 LPS=0.094 LKLS=8.572 |
# Test F1: 0.9302
# Test ACC: 0.8947
# Test AUC: 0.9580
# Train F1: 0.9687
# 00500: TRAIN| LT=0.423 LP=0.134 LKL=7.460 LPS=0.121 LKLS=9.256 |
# Test F1: 0.9412
# Test ACC: 0.9123
# Test AUC: 0.9650
# Train F1: 0.9799
# 00550: TRAIN| LT=0.338 LP=0.092 LKL=7.434 LPS=0.083 LKLS=8.872 |
# Test F1: 0.9412
# Test ACC: 0.9123
# Test AUC: 0.9668
# Train F1: 0.9799
# 00600: TRAIN| LT=0.368 LP=0.111 LKL=7.460 LPS=0.094 LKLS=8.932 |
# Test F1: 0.9412
# Test ACC: 0.9123
# Test AUC: 0.9650
# Train F1: 0.9745
# 00650: TRAIN| LT=0.325 LP=0.106 LKL=7.298 LPS=0.063 LKLS=8.227 |
# Test F1: 0.9412
# Test ACC: 0.9123
# Test AUC: 0.9703
# Train F1: 0.9683
# 00700: TRAIN| LT=0.334 LP=0.119 LKL=7.439 LPS=0.054 LKLS=8.621 |
# Test F1: 0.9412
# Test ACC: 0.9123
# Test AUC: 0.9703
# Train F1: 0.9771
# 00750: TRAIN| LT=0.319 LP=0.086 LKL=7.464 LPS=0.072 LKLS=8.596 |
# Test F1: 0.9412
# Test ACC: 0.9123
# Test AUC: 0.9703
# Train F1: 0.9886
# 00800: TRAIN| LT=0.274 LP=0.071 LKL=7.408 LPS=0.045 LKLS=8.369 |
# Test F1: 0.9412
# Test ACC: 0.9123
# Test AUC: 0.9790
# Train F1: 0.9770
# 00850: TRAIN| LT=0.302 LP=0.085 LKL=7.405 LPS=0.062 LKLS=8.082 |
# Test F1: 0.9412
# Test ACC: 0.9123
# Test AUC: 0.9790
# Train F1: 0.9915
# 00900: TRAIN| LT=0.283 LP=0.051 LKL=7.313 LPS=0.082 LKLS=7.672 |
# Test F1: 0.9412
# Test ACC: 0.9123
# Test AUC: 0.9790
# Train F1: 0.9886
# 00950: TRAIN| LT=0.286 LP=0.099 LKL=7.293 LPS=0.038 LKLS=7.719 |
# Test F1: 0.9535
# Test ACC: 0.9298
# Test AUC: 0.9808
# Train F1: 0.9858
# 01000: TRAIN| LT=0.209 LP=0.037 LKL=7.276 LPS=0.023 LKLS=7.623 |
# Test F1: 0.9535
# Test ACC: 0.9298
# Test AUC: 0.9755
# Train F1: 0.9887
# 01050: TRAIN| LT=0.248 LP=0.071 LKL=7.308 LPS=0.025 LKLS=7.843 |
# Test F1: 0.9535
# Test ACC: 0.9298
# Test AUC: 0.9773
# Train F1: 0.9799
# 01100: TRAIN| LT=0.236 LP=0.060 LKL=7.424 LPS=0.024 LKLS=7.716 |
# Test F1: 0.9535
# Test ACC: 0.9298
# Test AUC: 0.9773
# Train F1: 0.9801
# 01150: TRAIN| LT=0.250 LP=0.067 LKL=7.354 LPS=0.032 LKLS=7.695 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9773
# Train F1: 0.9914
# 01200: TRAIN| LT=0.207 LP=0.037 LKL=7.525 LPS=0.016 LKLS=7.961 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9755
# Train F1: 0.9943
# 01250: TRAIN| LT=0.242 LP=0.071 LKL=7.172 LPS=0.028 LKLS=7.114 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9790
# Train F1: 0.9742
# 01300: TRAIN| LT=0.231 LP=0.067 LKL=7.505 LPS=0.013 LKLS=7.674 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9773
# Train F1: 0.9859
# 01350: TRAIN| LT=0.210 LP=0.039 LKL=7.571 LPS=0.017 LKLS=7.849 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9773
# Train F1: 0.9857
# 01400: TRAIN| LT=0.185 LP=0.033 LKL=7.126 LPS=0.014 LKLS=6.689 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9755
# Train F1: 0.9943
# 01450: TRAIN| LT=0.238 LP=0.061 LKL=7.335 LPS=0.032 LKLS=7.187 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9755
# Train F1: 0.9831
# 01500: TRAIN| LT=0.199 LP=0.037 LKL=7.219 LPS=0.022 LKLS=6.788 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9738
# Train F1: 0.9915
# 01550: TRAIN| LT=0.192 LP=0.047 LKL=7.089 LPS=0.007 LKLS=6.706 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9738
# Train F1: 0.9888
# 01600: TRAIN| LT=0.205 LP=0.061 LKL=7.101 LPS=0.005 LKLS=6.716 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9720
# Train F1: 0.9915
# 01650: TRAIN| LT=0.181 LP=0.035 LKL=7.327 LPS=0.005 LKLS=6.848 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9755
# Train F1: 0.9859
# 01700: TRAIN| LT=0.177 LP=0.020 LKL=7.092 LPS=0.022 LKLS=6.416 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9703
# Train F1: 0.9972
# 01750: TRAIN| LT=0.194 LP=0.038 LKL=7.063 LPS=0.022 LKLS=6.332 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9685
# Train F1: 0.9914
# 01800: TRAIN| LT=0.184 LP=0.039 LKL=7.065 LPS=0.010 LKLS=6.393 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9755
# Train F1: 0.9943
# 01850: TRAIN| LT=0.185 LP=0.038 LKL=7.075 LPS=0.014 LKLS=6.259 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9755
# Train F1: 0.9915
# 01900: TRAIN| LT=0.162 LP=0.015 LKL=7.131 LPS=0.013 LKLS=6.278 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9773
# Train F1: 0.9915
# 01950: TRAIN| LT=0.159 LP=0.018 LKL=7.035 LPS=0.008 LKLS=6.271 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9755
# Train F1: 0.9943
# 02000: TRAIN| LT=0.156 LP=0.021 LKL=7.111 LPS=0.003 LKLS=6.082 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9720
# f1: 0.9772727272727273
# acc: 0.9649122807017544
# auc: 0.9720279720279721
# Train F1: 0.8663
# 00050: TRAIN| LT=1.185 LP=0.579 LKL=4.413 LPS=0.555 LKLS=0.649 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.6783
# Train F1: 0.8670
# 00100: TRAIN| LT=1.176 LP=0.569 LKL=4.279 LPS=0.556 LKLS=0.860 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.7990
# Train F1: 0.8670
# 00150: TRAIN| LT=1.120 LP=0.538 LKL=4.375 LPS=0.525 LKLS=1.369 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.8427
# Train F1: 0.8663
# 00200: TRAIN| LT=1.046 LP=0.504 LKL=4.901 LPS=0.462 LKLS=3.179 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.8497
# Train F1: 0.8889
# 00250: TRAIN| LT=0.913 LP=0.434 LKL=5.699 LPS=0.371 LKLS=5.048 |
# Test F1: 0.8913
# Test ACC: 0.8246
# Test AUC: 0.8671
# Train F1: 0.8847
# 00300: TRAIN| LT=0.760 LP=0.380 LKL=6.145 LPS=0.258 LKLS=6.038 |
# Test F1: 0.9195
# Test ACC: 0.8772
# Test AUC: 0.9021
# Train F1: 0.9363
# 00350: TRAIN| LT=0.594 LP=0.263 LKL=6.576 LPS=0.194 LKLS=7.186 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9423
# Train F1: 0.9551
# 00400: TRAIN| LT=0.520 LP=0.189 LKL=7.234 LPS=0.167 LKLS=9.147 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9615
# Train F1: 0.9577
# 00450: TRAIN| LT=0.457 LP=0.173 LKL=7.043 LPS=0.133 LKLS=8.074 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9615
# Train F1: 0.9632
# 00500: TRAIN| LT=0.426 LP=0.143 LKL=7.550 LPS=0.114 LKLS=9.369 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9685
# Train F1: 0.9858
# 00550: TRAIN| LT=0.355 LP=0.119 LKL=7.315 LPS=0.077 LKLS=8.598 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9738
# Train F1: 0.9744
# 00600: TRAIN| LT=0.344 LP=0.113 LKL=7.335 LPS=0.071 LKLS=8.638 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9755
# Train F1: 0.9628
# 00650: TRAIN| LT=0.300 LP=0.084 LKL=7.425 LPS=0.052 LKLS=8.975 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9773
# Train F1: 0.9802
# 00700: TRAIN| LT=0.312 LP=0.089 LKL=7.284 LPS=0.067 LKLS=8.380 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9790
# Train F1: 0.9661
# 00750: TRAIN| LT=0.280 LP=0.067 LKL=7.389 LPS=0.053 LKLS=8.556 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9773
# Train F1: 0.9718
# 00800: TRAIN| LT=0.310 LP=0.086 LKL=7.309 LPS=0.068 LKLS=8.223 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9773
# Train F1: 0.9831
# 00850: TRAIN| LT=0.291 LP=0.077 LKL=7.270 LPS=0.060 LKLS=8.121 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9790
# Train F1: 0.9831
# 00900: TRAIN| LT=0.296 LP=0.106 LKL=7.269 LPS=0.036 LKLS=8.168 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9790
# Train F1: 0.9713
# 00950: TRAIN| LT=0.257 LP=0.063 LKL=7.433 LPS=0.036 LKLS=8.304 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9808
# Train F1: 0.9886
# 01000: TRAIN| LT=0.259 LP=0.069 LKL=7.247 LPS=0.039 LKLS=7.857 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9790
# Train F1: 0.9972
# 01050: TRAIN| LT=0.225 LP=0.056 LKL=7.225 LPS=0.021 LKLS=7.660 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9790
# Train F1: 0.9886
# 01100: TRAIN| LT=0.282 LP=0.102 LKL=7.373 LPS=0.026 LKLS=8.036 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9790
# Train F1: 0.9886
# 01150: TRAIN| LT=0.256 LP=0.057 LKL=7.471 LPS=0.042 LKLS=8.207 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9755
# Train F1: 0.9887
# 01200: TRAIN| LT=0.237 LP=0.046 LKL=7.231 LPS=0.043 LKLS=7.564 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9773
# Train F1: 0.9943
# 01250: TRAIN| LT=0.199 LP=0.044 LKL=7.236 LPS=0.007 LKLS=7.542 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9738
# Train F1: 0.9830
# 01300: TRAIN| LT=0.220 LP=0.035 LKL=7.301 LPS=0.034 LKLS=7.714 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9773
# Train F1: 0.9739
# 01350: TRAIN| LT=0.173 LP=0.022 LKL=7.210 LPS=0.005 LKLS=7.421 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9773
# Train F1: 0.9887
# 01400: TRAIN| LT=0.237 LP=0.050 LKL=6.979 LPS=0.050 LKLS=6.692 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9738
# Train F1: 0.9915
# 01450: TRAIN| LT=0.234 LP=0.055 LKL=7.005 LPS=0.041 LKLS=6.749 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9755
# Train F1: 0.9830
# 01500: TRAIN| LT=0.207 LP=0.048 LKL=7.107 LPS=0.018 LKLS=7.051 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9738
# Train F1: 0.9915
# 01550: TRAIN| LT=0.194 LP=0.037 LKL=7.163 LPS=0.015 LKLS=6.959 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9738
# Train F1: 0.9914
# 01600: TRAIN| LT=0.175 LP=0.017 LKL=7.150 LPS=0.014 LKLS=7.250 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9755
# Train F1: 0.9943
# 01650: TRAIN| LT=0.211 LP=0.038 LKL=6.984 LPS=0.037 LKLS=6.609 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9738
# Train F1: 0.9943
# 01700: TRAIN| LT=0.175 LP=0.025 LKL=7.009 LPS=0.012 LKLS=6.822 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9703
# Train F1: 0.9972
# 01750: TRAIN| LT=0.173 LP=0.021 LKL=6.904 LPS=0.020 LKLS=6.389 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9738
# Train F1: 0.9799
# 01800: TRAIN| LT=0.159 LP=0.018 LKL=6.930 LPS=0.008 LKLS=6.363 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9738
# Train F1: 0.9887
# 01850: TRAIN| LT=0.189 LP=0.052 LKL=6.841 LPS=0.008 LKLS=6.097 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9668
# Train F1: 0.9858
# 01900: TRAIN| LT=0.160 LP=0.015 LKL=6.764 LPS=0.018 LKLS=5.894 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9738
# Train F1: 0.9915
# 01950: TRAIN| LT=0.173 LP=0.027 LKL=7.020 LPS=0.009 LKLS=6.619 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9738
# Train F1: 0.9943
# 02000: TRAIN| LT=0.215 LP=0.069 LKL=6.944 LPS=0.014 LKLS=6.210 |
# Test F1: 0.9425
# Test ACC: 0.9123
# Test AUC: 0.9720
# f1: 0.9772727272727273
# acc: 0.9649122807017544
# auc: 0.9807692307692308
# Train F1: 0.8657
# 00050: TRAIN| LT=1.212 LP=0.577 LKL=4.509 LPS=0.584 LKLS=0.558 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.6853
# Train F1: 0.8670
# 00100: TRAIN| LT=1.149 LP=0.551 LKL=4.353 LPS=0.547 LKLS=0.700 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.7483
# Train F1: 0.8691
# 00150: TRAIN| LT=1.091 LP=0.535 LKL=4.500 LPS=0.492 LKLS=1.926 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.7797
# Train F1: 0.8788
# 00200: TRAIN| LT=0.974 LP=0.474 LKL=5.296 LPS=0.405 LKLS=4.232 |
# Test F1: 0.8261
# Test ACC: 0.7193
# Test AUC: 0.8164
# Train F1: 0.9149
# 00250: TRAIN| LT=0.820 LP=0.370 LKL=5.869 LPS=0.340 LKLS=5.249 |
# Test F1: 0.8675
# Test ACC: 0.8070
# Test AUC: 0.8392
# Train F1: 0.9205
# 00300: TRAIN| LT=0.783 LP=0.373 LKL=6.192 LPS=0.287 LKLS=6.182 |
# Test F1: 0.8889
# Test ACC: 0.8421
# Test AUC: 0.8619
# Train F1: 0.9162
# 00350: TRAIN| LT=0.601 LP=0.231 LKL=6.485 LPS=0.238 LKLS=6.640 |
# Test F1: 0.9024
# Test ACC: 0.8596
# Test AUC: 0.9318
# Train F1: 0.9716
# 00400: TRAIN| LT=0.501 LP=0.198 LKL=6.759 LPS=0.164 LKLS=7.233 |
# Test F1: 0.9398
# Test ACC: 0.9123
# Test AUC: 0.9528
# Train F1: 0.9602
# 00450: TRAIN| LT=0.456 LP=0.201 LKL=6.842 LPS=0.111 LKLS=7.562 |
# Test F1: 0.9647
# Test ACC: 0.9474
# Test AUC: 0.9738
# Train F1: 0.9625
# 00500: TRAIN| LT=0.488 LP=0.179 LKL=7.297 LPS=0.150 LKLS=8.626 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9755
# Train F1: 0.9538
# 00550: TRAIN| LT=0.431 LP=0.162 LKL=7.473 LPS=0.107 LKLS=8.726 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9773
# Train F1: 0.9685
# 00600: TRAIN| LT=0.353 LP=0.118 LKL=7.371 LPS=0.076 LKLS=8.570 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9808
# Train F1: 0.9801
# 00650: TRAIN| LT=0.368 LP=0.121 LKL=7.521 LPS=0.082 LKLS=8.877 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9930
# Train F1: 0.9801
# 00700: TRAIN| LT=0.308 LP=0.089 LKL=7.436 LPS=0.058 LKLS=8.591 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9774
# 00750: TRAIN| LT=0.300 LP=0.104 LKL=7.521 LPS=0.031 LKLS=9.031 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9983
# Train F1: 0.9802
# 00800: TRAIN| LT=0.318 LP=0.099 LKL=7.598 LPS=0.053 LKLS=8.934 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9831
# 00850: TRAIN| LT=0.246 LP=0.053 LKL=7.521 LPS=0.032 LKLS=8.649 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9965
# Train F1: 0.9830
# 00900: TRAIN| LT=0.247 LP=0.054 LKL=7.552 LPS=0.028 LKLS=8.868 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9803
# 00950: TRAIN| LT=0.244 LP=0.068 LKL=7.506 LPS=0.017 LKLS=8.470 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# Train F1: 0.9859
# 01000: TRAIN| LT=0.229 LP=0.059 LKL=7.510 LPS=0.012 LKLS=8.226 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9858
# 01050: TRAIN| LT=0.262 LP=0.066 LKL=7.364 LPS=0.042 LKLS=8.014 |
# Test F1: 0.9885
# Test ACC: 0.9825
# Test AUC: 0.9965
# Train F1: 0.9771
# 01100: TRAIN| LT=0.278 LP=0.076 LKL=7.577 LPS=0.043 LKLS=8.294 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9944
# 01150: TRAIN| LT=0.195 LP=0.033 LKL=7.356 LPS=0.010 LKLS=7.865 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9930
# Train F1: 0.9745
# 01200: TRAIN| LT=0.206 LP=0.036 LKL=7.301 LPS=0.021 LKLS=7.525 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9930
# Train F1: 0.9831
# 01250: TRAIN| LT=0.223 LP=0.037 LKL=7.416 LPS=0.032 LKLS=7.941 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9913
# Train F1: 0.9886
# 01300: TRAIN| LT=0.232 LP=0.051 LKL=7.499 LPS=0.028 LKLS=7.811 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9913
# Train F1: 0.9915
# 01350: TRAIN| LT=0.182 LP=0.024 LKL=7.140 LPS=0.017 LKLS=7.003 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9930
# Train F1: 0.9972
# 01400: TRAIN| LT=0.179 LP=0.020 LKL=7.228 LPS=0.014 LKLS=7.267 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9930
# Train F1: 0.9943
# 01450: TRAIN| LT=0.179 LP=0.032 LKL=7.102 LPS=0.007 LKLS=6.858 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9895
# Train F1: 0.9943
# 01500: TRAIN| LT=0.204 LP=0.037 LKL=7.313 LPS=0.020 LKLS=7.281 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9895
# Train F1: 0.9887
# 01550: TRAIN| LT=0.192 LP=0.037 LKL=7.257 LPS=0.012 LKLS=7.032 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9930
# Train F1: 0.9885
# 01600: TRAIN| LT=0.167 LP=0.018 LKL=7.262 LPS=0.005 LKLS=7.019 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9895
# Train F1: 0.9943
# 01650: TRAIN| LT=0.180 LP=0.035 LKL=7.003 LPS=0.009 LKLS=6.613 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 0.9886
# 01700: TRAIN| LT=0.180 LP=0.027 LKL=6.950 LPS=0.022 LKLS=6.220 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9913
# Train F1: 1.0000
# 01750: TRAIN| LT=0.190 LP=0.040 LKL=6.804 LPS=0.020 LKLS=6.179 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 0.9944
# 01800: TRAIN| LT=0.178 LP=0.041 LKL=6.849 LPS=0.007 LKLS=6.121 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9913
# Train F1: 0.9886
# 01850: TRAIN| LT=0.175 LP=0.028 LKL=6.908 LPS=0.014 LKLS=6.371 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 0.9943
# 01900: TRAIN| LT=0.157 LP=0.022 LKL=6.851 LPS=0.005 LKLS=6.087 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9878
# Train F1: 0.9944
# 01950: TRAIN| LT=0.155 LP=0.011 LKL=7.139 LPS=0.007 LKLS=6.556 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9895
# Train F1: 0.9831
# 02000: TRAIN| LT=0.184 LP=0.054 LKL=6.660 LPS=0.004 LKLS=5.912 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9948
# f1: 0.9887640449438202
# acc: 0.9824561403508771
# auc: 0.9982517482517483
# f1 [0.9333333333333332, 0.9772727272727273, 0.9772727272727273, 0.9772727272727273, 0.9887640449438202]
# average f1: 0.9707831120190671±0.01924653314691523
# acc [0.896551724137931, 0.9655172413793104, 0.9649122807017544, 0.9649122807017544, 0.9824561403508771]
# average acc: 0.9548699334543255±0.02992348573056114
# auc [0.913961038961039, 0.9935064935064936, 0.9720279720279721, 0.9807692307692308, 0.9982517482517483]
# average auc: 0.9717032967032967±0.030320503208842227
