# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics.csv',index_col=0)
data_class={'nonIBD':0,'CD':2,'UC':1}
meta_data['diagnosis']=meta_data['diagnosis'].map(data_class)

X1=metagenomics
X2=metabolomics
print('输入各组学数据表：',X1.shape,X2.shape,meta_data.shape)

#重构数据表和标签表
index_new = X1.index&X2.index&meta_data[meta_data['diagnosis'] != 2].index
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['diagnosis'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (1638, 578) (546, 596) (2891, 1)
# 集合所有样本重构数据表： (207, 578) (207, 596) (207, 1)
# 标签转换为one-hot编码： (207, 2) 105.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 8, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1',f1_cv)
print('average maxf1',sum(f1_cv)/5)
print('acc',acc_cv)
print('average maxacc',sum(acc_cv)/5)
print('auc',auc_cv)
print('average maxauc',sum(auc_cv)/5)
# Out:
# Train F1: 0.7702
# 00050: TRAIN| LT=1.875 LP=0.556 LKL=11.821 LPS=1.107 LKLS=9.390 |
# Test F1: 0.8500
# Test ACC: 0.8571
# Test AUC: 0.9773
# Train F1: 0.9481
# 00100: TRAIN| LT=1.341 LP=0.243 LKL=12.541 LPS=0.844 LKLS=12.829 |
# Test F1: 0.9268
# Test ACC: 0.9286
# Test AUC: 0.9932
# Train F1: 0.9441
# 00150: TRAIN| LT=1.135 LP=0.134 LKL=13.142 LPS=0.731 LKLS=13.898 |
# Test F1: 0.9524
# Test ACC: 0.9524
# Test AUC: 0.9932
# Train F1: 0.9697
# 00200: TRAIN| LT=1.055 LP=0.106 LKL=13.137 LPS=0.698 LKLS=11.977 |
# Test F1: 0.8889
# Test ACC: 0.8810
# Test AUC: 0.9887
# Train F1: 0.9689
# 00250: TRAIN| LT=0.968 LP=0.085 LKL=13.315 LPS=0.623 LKLS=12.624 |
# Test F1: 0.9524
# Test ACC: 0.9524
# Test AUC: 0.9932
# Train F1: 0.9811
# 00300: TRAIN| LT=0.955 LP=0.089 LKL=13.549 LPS=0.597 LKLS=13.286 |
# Test F1: 0.9756
# Test ACC: 0.9762
# Test AUC: 0.9955
# Train F1: 0.9686
# 00350: TRAIN| LT=0.943 LP=0.065 LKL=13.661 LPS=0.610 LKLS=13.089 |
# Test F1: 0.9302
# Test ACC: 0.9286
# Test AUC: 0.9955
# Train F1: 0.9814
# 00400: TRAIN| LT=0.847 LP=0.084 LKL=13.311 LPS=0.516 LKLS=11.311 |
# Test F1: 0.9302
# Test ACC: 0.9286
# Test AUC: 0.9955
# Train F1: 0.9875
# 00450: TRAIN| LT=0.821 LP=0.038 LKL=13.783 LPS=0.517 LKLS=12.835 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 0.9977
# Train F1: 0.9938
# 00500: TRAIN| LT=0.768 LP=0.024 LKL=13.559 LPS=0.489 LKLS=12.006 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 0.9977
# Train F1: 0.9938
# 00550: TRAIN| LT=0.738 LP=0.061 LKL=13.477 LPS=0.420 LKLS=12.237 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 1.0000
# Train F1: 0.9938
# 00600: TRAIN| LT=0.673 LP=0.019 LKL=13.358 LPS=0.409 LKLS=11.063 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 1.0000
# Train F1: 0.9634
# 00650: TRAIN| LT=0.739 LP=0.033 LKL=13.378 LPS=0.465 LKLS=10.671 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 0.9977
# Train F1: 0.9818
# 00700: TRAIN| LT=0.685 LP=0.022 LKL=13.503 LPS=0.411 LKLS=11.683 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 0.9977
# Train F1: 0.9756
# 00750: TRAIN| LT=0.729 LP=0.031 LKL=13.296 LPS=0.457 LKLS=10.817 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 0.9955
# Train F1: 0.9877
# 00800: TRAIN| LT=0.686 LP=0.016 LKL=13.420 LPS=0.424 LKLS=11.171 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 1.0000
# Train F1: 0.9816
# 00850: TRAIN| LT=0.661 LP=0.016 LKL=13.538 LPS=0.402 LKLS=10.694 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 1.0000
# Train F1: 1.0000
# 00900: TRAIN| LT=0.711 LP=0.028 LKL=13.309 LPS=0.446 LKLS=10.378 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 1.0000
# Train F1: 0.9938
# 00950: TRAIN| LT=0.621 LP=0.010 LKL=13.769 LPS=0.354 LKLS=11.910 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 1.0000
# Train F1: 1.0000
# 01000: TRAIN| LT=0.693 LP=0.020 LKL=13.412 LPS=0.435 LKLS=10.495 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 1.0000
# Train F1: 0.9938
# 01050: TRAIN| LT=0.628 LP=0.030 LKL=13.522 LPS=0.357 LKLS=10.679 |
# Test F1: 0.9302
# Test ACC: 0.9286
# Test AUC: 0.9955
# Train F1: 0.9938
# 01100: TRAIN| LT=0.669 LP=0.007 LKL=13.719 LPS=0.413 LKLS=11.243 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 0.9955
# Train F1: 0.9877
# 01150: TRAIN| LT=0.619 LP=0.013 LKL=13.507 LPS=0.360 LKLS=11.230 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 1.0000
# Train F1: 0.9939
# 01200: TRAIN| LT=0.739 LP=0.033 LKL=13.502 LPS=0.464 LKLS=10.658 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 1.0000
# Train F1: 0.9877
# 01250: TRAIN| LT=0.615 LP=0.031 LKL=13.244 LPS=0.353 LKLS=9.843 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 0.9955
# Train F1: 0.9816
# 01300: TRAIN| LT=0.597 LP=0.007 LKL=13.491 LPS=0.344 LKLS=11.063 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 1.0000
# Train F1: 1.0000
# 01350: TRAIN| LT=0.673 LP=0.004 LKL=13.496 LPS=0.431 LKLS=10.247 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 0.9977
# Train F1: 0.9875
# 01400: TRAIN| LT=0.634 LP=0.004 LKL=13.684 LPS=0.384 LKLS=10.843 |
# Test F1: 0.9333
# Test ACC: 0.9286
# Test AUC: 0.9932
# Train F1: 0.9939
# 01450: TRAIN| LT=0.573 LP=0.014 LKL=13.655 LPS=0.320 LKLS=10.255 |
# Test F1: 0.9333
# Test ACC: 0.9286
# Test AUC: 0.9932
# Train F1: 0.9939
# 01500: TRAIN| LT=0.588 LP=0.015 LKL=13.380 LPS=0.343 LKLS=9.631 |
# Test F1: 0.9333
# Test ACC: 0.9286
# Test AUC: 0.9909
# Train F1: 0.9877
# 01550: TRAIN| LT=0.626 LP=0.004 LKL=13.379 LPS=0.390 LKLS=9.835 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 0.9864
# Train F1: 0.9938
# 01600: TRAIN| LT=0.583 LP=0.013 LKL=13.195 LPS=0.339 LKLS=9.899 |
# Test F1: 0.9333
# Test ACC: 0.9286
# Test AUC: 0.9955
# Train F1: 1.0000
# 01650: TRAIN| LT=0.556 LP=0.020 LKL=13.302 LPS=0.308 LKLS=9.433 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 1.0000
# Train F1: 1.0000
# 01700: TRAIN| LT=0.646 LP=0.022 LKL=13.076 LPS=0.407 LKLS=8.710 |
# Test F1: 0.9333
# Test ACC: 0.9286
# Test AUC: 0.9977
# Train F1: 1.0000
# 01750: TRAIN| LT=0.559 LP=0.018 LKL=13.623 LPS=0.303 LKLS=10.130 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 1.0000
# Train F1: 0.9877
# 01800: TRAIN| LT=0.563 LP=0.004 LKL=13.372 LPS=0.331 LKLS=9.448 |
# Test F1: 0.9545
# Test ACC: 0.9524
# Test AUC: 1.0000
# Train F1: 0.9875
# 01850: TRAIN| LT=0.597 LP=0.002 LKL=13.147 LPS=0.373 LKLS=9.028 |
# Test F1: 0.9302
# Test ACC: 0.9286
# Test AUC: 0.9955
# Train F1: 1.0000
# 01900: TRAIN| LT=0.579 LP=0.008 LKL=13.138 LPS=0.351 LKLS=8.791 |
# Test F1: 0.9333
# Test ACC: 0.9286
# Test AUC: 0.9955
# Train F1: 0.9939
# 01950: TRAIN| LT=0.609 LP=0.002 LKL=13.405 LPS=0.378 LKLS=9.434 |
# Test F1: 0.9333
# Test ACC: 0.9286
# Test AUC: 1.0000
# Train F1: 0.9938
# 02000: TRAIN| LT=0.612 LP=0.017 LKL=13.354 LPS=0.364 LKLS=9.754 |
# Test F1: 0.9767
# Test ACC: 0.9762
# Test AUC: 1.0000
# f1: 0.9767441860465117
# acc: 0.9761904761904762
# auc: 1.0
# Train F1: 0.7950
# 00050: TRAIN| LT=1.851 LP=0.574 LKL=11.410 LPS=1.085 LKLS=7.759 |
# Test F1: 0.9000
# Test ACC: 0.9048
# Test AUC: 0.9365
# Train F1: 0.9500
# 00100: TRAIN| LT=1.275 LP=0.198 LKL=12.744 LPS=0.805 LKLS=14.479 |
# Test F1: 0.9000
# Test ACC: 0.9048
# Test AUC: 0.9819
# Train F1: 0.9560
# 00150: TRAIN| LT=1.072 LP=0.109 LKL=12.974 LPS=0.702 LKLS=13.074 |
# Test F1: 0.9000
# Test ACC: 0.9048
# Test AUC: 0.9841
# Train F1: 0.9500
# 00200: TRAIN| LT=1.110 LP=0.146 LKL=13.065 LPS=0.704 LKLS=12.905 |
# Test F1: 0.9000
# Test ACC: 0.9048
# Test AUC: 0.9796
# Train F1: 0.9308
# 00250: TRAIN| LT=0.935 LP=0.087 LKL=13.020 LPS=0.598 LKLS=12.002 |
# Test F1: 0.9048
# Test ACC: 0.9048
# Test AUC: 0.9705
# Train F1: 0.9877
# 00300: TRAIN| LT=0.889 LP=0.105 LKL=12.993 LPS=0.537 LKLS=11.715 |
# Test F1: 0.9048
# Test ACC: 0.9048
# Test AUC: 0.9773
# Train F1: 0.9697
# 00350: TRAIN| LT=0.873 LP=0.057 LKL=13.247 LPS=0.555 LKLS=12.790 |
# Test F1: 0.9091
# Test ACC: 0.9048
# Test AUC: 0.9705
# Train F1: 0.9693
# 00400: TRAIN| LT=0.912 LP=0.098 LKL=13.108 LPS=0.569 LKLS=11.407 |
# Test F1: 0.9091
# Test ACC: 0.9048
# Test AUC: 0.9773
# Train F1: 0.9697
# 00450: TRAIN| LT=0.881 LP=0.089 LKL=13.233 LPS=0.541 LKLS=11.811 |
# Test F1: 0.8889
# Test ACC: 0.8810
# Test AUC: 0.9637
# Train F1: 0.9875
# 00500: TRAIN| LT=0.775 LP=0.038 LKL=13.445 LPS=0.486 LKLS=11.662 |
# Test F1: 0.8889
# Test ACC: 0.8810
# Test AUC: 0.9683
# Train F1: 0.9630
# 00550: TRAIN| LT=0.783 LP=0.083 LKL=13.306 LPS=0.451 LKLS=11.616 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9637
# Train F1: 0.9753
# 00600: TRAIN| LT=0.821 LP=0.084 LKL=13.274 LPS=0.490 LKLS=11.511 |
# Test F1: 0.8696
# Test ACC: 0.8571
# Test AUC: 0.9524
# Train F1: 0.9877
# 00650: TRAIN| LT=0.714 LP=0.048 LKL=13.507 LPS=0.410 LKLS=12.022 |
# Test F1: 0.8696
# Test ACC: 0.8571
# Test AUC: 0.9569
# Train F1: 0.9877
# 00700: TRAIN| LT=0.722 LP=0.051 LKL=13.748 LPS=0.405 LKLS=12.892 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9569
# Train F1: 0.9938
# 00750: TRAIN| LT=0.708 LP=0.047 LKL=13.210 LPS=0.419 LKLS=10.968 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9524
# Train F1: 0.9938
# 00800: TRAIN| LT=0.669 LP=0.028 LKL=13.420 LPS=0.394 LKLS=11.316 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9524
# Train F1: 0.9877
# 00850: TRAIN| LT=0.686 LP=0.055 LKL=13.593 LPS=0.376 LKLS=11.893 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9524
# Train F1: 0.9814
# 00900: TRAIN| LT=0.681 LP=0.033 LKL=13.603 LPS=0.392 LKLS=11.984 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9456
# Train F1: 1.0000
# 00950: TRAIN| LT=0.632 LP=0.026 LKL=13.741 LPS=0.345 LKLS=12.359 |
# Test F1: 0.8696
# Test ACC: 0.8571
# Test AUC: 0.9388
# Train F1: 1.0000
# 01000: TRAIN| LT=0.716 LP=0.051 LKL=13.708 LPS=0.409 LKLS=11.901 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9410
# Train F1: 0.9747
# 01050: TRAIN| LT=0.749 LP=0.102 LKL=13.208 LPS=0.408 LKLS=10.651 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9433
# Train F1: 0.9747
# 01100: TRAIN| LT=0.750 LP=0.037 LKL=13.831 LPS=0.457 LKLS=11.814 |
# Test F1: 0.8182
# Test ACC: 0.8095
# Test AUC: 0.9478
# Train F1: 0.9878
# 01150: TRAIN| LT=0.756 LP=0.039 LKL=13.677 LPS=0.469 LKLS=11.087 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9456
# Train F1: 1.0000
# 01200: TRAIN| LT=0.641 LP=0.043 LKL=13.787 LPS=0.342 LKLS=11.751 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9433
# Train F1: 0.9875
# 01250: TRAIN| LT=0.622 LP=0.023 LKL=13.606 LPS=0.356 LKLS=10.636 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9433
# Train F1: 0.9877
# 01300: TRAIN| LT=0.674 LP=0.004 LKL=13.669 LPS=0.425 LKLS=10.837 |
# Test F1: 0.8696
# Test ACC: 0.8571
# Test AUC: 0.9365
# Train F1: 1.0000
# 01350: TRAIN| LT=0.642 LP=0.037 LKL=13.820 LPS=0.351 LKLS=11.468 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9297
# Train F1: 0.9877
# 01400: TRAIN| LT=0.603 LP=0.005 LKL=13.796 LPS=0.348 LKLS=11.209 |
# Test F1: 0.8372
# Test ACC: 0.8333
# Test AUC: 0.9410
# Train F1: 0.9877
# 01450: TRAIN| LT=0.634 LP=0.021 LKL=13.644 LPS=0.366 LKLS=11.001 |
# Test F1: 0.8696
# Test ACC: 0.8571
# Test AUC: 0.9433
# Train F1: 0.9878
# 01500: TRAIN| LT=0.612 LP=0.025 LKL=13.347 LPS=0.354 LKLS=9.972 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9342
# Train F1: 0.9875
# 01550: TRAIN| LT=0.634 LP=0.006 LKL=13.581 LPS=0.388 LKLS=10.440 |
# Test F1: 0.8182
# Test ACC: 0.8095
# Test AUC: 0.9365
# Train F1: 0.9753
# 01600: TRAIN| LT=0.626 LP=0.024 LKL=13.500 LPS=0.363 LKLS=10.381 |
# Test F1: 0.8444
# Test ACC: 0.8333
# Test AUC: 0.9365
# Train F1: 1.0000
# 01650: TRAIN| LT=0.564 LP=0.012 LKL=13.665 LPS=0.310 LKLS=10.486 |
# Test F1: 0.8636
# Test ACC: 0.8571
# Test AUC: 0.9456
# Train F1: 0.9875
# 01700: TRAIN| LT=0.600 LP=0.013 LKL=13.303 LPS=0.352 LKLS=10.224 |
# Test F1: 0.8696
# Test ACC: 0.8571
# Test AUC: 0.9365
# Train F1: 1.0000
# 01750: TRAIN| LT=0.617 LP=0.021 LKL=13.504 LPS=0.362 LKLS=9.900 |
# Test F1: 0.8696
# Test ACC: 0.8571
# Test AUC: 0.9320
# Train F1: 0.9753
# 01800: TRAIN| LT=0.584 LP=0.015 LKL=13.491 LPS=0.339 LKLS=9.545 |
# Test F1: 0.8636
# Test ACC: 0.8571
# Test AUC: 0.9433
# Train F1: 1.0000
# 01850: TRAIN| LT=0.568 LP=0.026 LKL=13.496 LPS=0.310 LKLS=9.775 |
# Test F1: 0.8636
# Test ACC: 0.8571
# Test AUC: 0.9410
# Train F1: 0.9939
# 01900: TRAIN| LT=0.611 LP=0.014 LKL=13.466 LPS=0.365 LKLS=9.827 |
# Test F1: 0.8696
# Test ACC: 0.8571
# Test AUC: 0.9342
# Train F1: 1.0000
# 01950: TRAIN| LT=0.587 LP=0.010 LKL=13.740 LPS=0.341 LKLS=9.792 |
# Test F1: 0.8636
# Test ACC: 0.8571
# Test AUC: 0.9365
# Train F1: 1.0000
# 02000: TRAIN| LT=0.562 LP=0.003 LKL=13.431 LPS=0.330 LKLS=9.479 |
# Test F1: 0.8636
# Test ACC: 0.8571
# Test AUC: 0.9365
# f1: 0.909090909090909
# acc: 0.9047619047619048
# auc: 0.9773242630385488
# Train F1: 0.7200
# 00050: TRAIN| LT=1.933 LP=0.594 LKL=11.101 LPS=1.156 LKLS=7.093 |
# Test F1: 0.8421
# Test ACC: 0.8537
# Test AUC: 0.8405
# Train F1: 0.9441
# 00100: TRAIN| LT=1.320 LP=0.245 LKL=13.092 LPS=0.785 LKLS=15.928 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9619
# Train F1: 0.9625
# 00150: TRAIN| LT=1.053 LP=0.126 LKL=13.405 LPS=0.646 LKLS=14.691 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9786
# Train F1: 0.9689
# 00200: TRAIN| LT=1.066 LP=0.122 LKL=13.268 LPS=0.682 LKLS=12.979 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9762
# Train F1: 0.9818
# 00250: TRAIN| LT=0.957 LP=0.055 LKL=13.140 LPS=0.647 LKLS=12.302 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9667
# Train F1: 0.9880
# 00300: TRAIN| LT=0.898 LP=0.067 LKL=13.092 LPS=0.583 LKLS=11.689 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9714
# Train F1: 0.9880
# 00350: TRAIN| LT=0.767 LP=0.032 LKL=13.197 LPS=0.484 LKLS=11.897 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9667
# Train F1: 1.0000
# 00400: TRAIN| LT=0.816 LP=0.057 LKL=13.150 LPS=0.519 LKLS=10.868 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9667
# Train F1: 0.9878
# 00450: TRAIN| LT=0.798 LP=0.016 LKL=13.196 LPS=0.537 LKLS=11.253 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9667
# Train F1: 0.9820
# 00500: TRAIN| LT=0.780 LP=0.026 LKL=13.224 LPS=0.513 LKLS=10.948 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9595
# Train F1: 0.9878
# 00550: TRAIN| LT=0.785 LP=0.046 LKL=13.387 LPS=0.489 LKLS=11.481 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9738
# Train F1: 0.9816
# 00600: TRAIN| LT=0.738 LP=0.012 LKL=13.124 LPS=0.492 LKLS=10.246 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9738
# Train F1: 1.0000
# 00650: TRAIN| LT=0.746 LP=0.011 LKL=13.356 LPS=0.488 LKLS=11.348 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9810
# Train F1: 0.9814
# 00700: TRAIN| LT=0.691 LP=0.018 LKL=12.976 LPS=0.449 LKLS=9.419 |
# Test F1: 0.9189
# Test ACC: 0.9268
# Test AUC: 0.9857
# Train F1: 0.9816
# 00750: TRAIN| LT=0.696 LP=0.016 LKL=13.231 LPS=0.440 LKLS=10.730 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9762
# Train F1: 0.9878
# 00800: TRAIN| LT=0.750 LP=0.045 LKL=13.328 LPS=0.463 LKLS=10.929 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9881
# Train F1: 0.9939
# 00850: TRAIN| LT=0.710 LP=0.022 LKL=13.194 LPS=0.456 LKLS=10.052 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9833
# Train F1: 0.9878
# 00900: TRAIN| LT=0.688 LP=0.033 LKL=13.059 LPS=0.423 LKLS=10.068 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9738
# Train F1: 0.9939
# 00950: TRAIN| LT=0.708 LP=0.054 LKL=13.095 LPS=0.423 LKLS=10.084 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9667
# Train F1: 1.0000
# 01000: TRAIN| LT=0.738 LP=0.009 LKL=13.321 LPS=0.490 LKLS=10.604 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9833
# Train F1: 1.0000
# 01050: TRAIN| LT=0.641 LP=0.024 LKL=12.999 LPS=0.388 LKLS=9.902 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9833
# Train F1: 1.0000
# 01100: TRAIN| LT=0.688 LP=0.010 LKL=13.024 LPS=0.454 LKLS=9.447 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9857
# Train F1: 0.9939
# 01150: TRAIN| LT=0.690 LP=0.021 LKL=13.232 LPS=0.438 LKLS=9.875 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9810
# Train F1: 1.0000
# 01200: TRAIN| LT=0.624 LP=0.006 LKL=13.385 LPS=0.380 LKLS=10.392 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9643
# Train F1: 0.9939
# 01250: TRAIN| LT=0.622 LP=0.006 LKL=13.045 LPS=0.390 LKLS=9.516 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9690
# Train F1: 0.9939
# 01300: TRAIN| LT=0.617 LP=0.008 LKL=13.123 LPS=0.381 LKLS=9.693 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9810
# Train F1: 0.9939
# 01350: TRAIN| LT=0.589 LP=0.015 LKL=13.077 LPS=0.351 LKLS=9.217 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9833
# Train F1: 0.9939
# 01400: TRAIN| LT=0.633 LP=0.008 LKL=13.059 LPS=0.400 LKLS=9.510 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9857
# Train F1: 1.0000
# 01450: TRAIN| LT=0.612 LP=0.014 LKL=13.112 LPS=0.373 LKLS=9.369 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9762
# Train F1: 0.9939
# 01500: TRAIN| LT=0.612 LP=0.007 LKL=13.203 LPS=0.373 LKLS=9.944 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9738
# Train F1: 1.0000
# 01550: TRAIN| LT=0.652 LP=0.006 LKL=13.427 LPS=0.407 LKLS=10.469 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9857
# Train F1: 0.9939
# 01600: TRAIN| LT=0.699 LP=0.037 LKL=13.195 LPS=0.433 LKLS=9.710 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9738
# Train F1: 1.0000
# 01650: TRAIN| LT=0.649 LP=0.003 LKL=12.999 LPS=0.425 LKLS=9.124 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9554
# Train F1: 0.9939
# 01700: TRAIN| LT=0.600 LP=0.006 LKL=12.977 LPS=0.374 LKLS=8.953 |
# Test F1: 0.9189
# Test ACC: 0.9268
# Test AUC: 0.9536
# Train F1: 0.9877
# 01750: TRAIN| LT=0.600 LP=0.001 LKL=13.237 LPS=0.369 LKLS=9.817 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9714
# Train F1: 0.9939
# 01800: TRAIN| LT=0.586 LP=0.015 LKL=12.995 LPS=0.354 LKLS=8.663 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9637
# Train F1: 0.9816
# 01850: TRAIN| LT=0.666 LP=0.034 LKL=12.974 LPS=0.417 LKLS=8.441 |
# Test F1: 0.9189
# Test ACC: 0.9268
# Test AUC: 0.9655
# Train F1: 0.9880
# 01900: TRAIN| LT=0.633 LP=0.007 LKL=13.291 LPS=0.399 LKLS=9.326 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9762
# Train F1: 0.9939
# 01950: TRAIN| LT=0.607 LP=0.016 LKL=13.094 LPS=0.368 LKLS=9.171 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9738
# Train F1: 1.0000
# 02000: TRAIN| LT=0.638 LP=0.022 LKL=12.958 LPS=0.402 LKLS=8.516 |
# Test F1: 0.9474
# Test ACC: 0.9512
# Test AUC: 0.9655
# f1: 0.9473684210526316
# acc: 0.9512195121951219
# auc: 0.9880952380952381
# Train F1: 0.8228
# 00050: TRAIN| LT=1.887 LP=0.617 LKL=11.381 LPS=1.074 LKLS=8.220 |
# Test F1: 0.6111
# Test ACC: 0.6585
# Test AUC: 0.7357
# Train F1: 0.9057
# 00100: TRAIN| LT=1.235 LP=0.192 LKL=13.184 LPS=0.745 LKLS=16.575 |
# Test F1: 0.7879
# Test ACC: 0.8293
# Test AUC: 0.9262
# Train F1: 0.9625
# 00150: TRAIN| LT=0.997 LP=0.128 LKL=13.216 LPS=0.596 LKLS=14.077 |
# Test F1: 0.8235
# Test ACC: 0.8537
# Test AUC: 0.9405
# Train F1: 0.9625
# 00200: TRAIN| LT=1.058 LP=0.165 LKL=13.023 LPS=0.631 LKLS=13.123 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9643
# Train F1: 0.9753
# 00250: TRAIN| LT=0.883 LP=0.088 LKL=13.265 LPS=0.531 LKLS=13.167 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9643
# Train F1: 0.9639
# 00300: TRAIN| LT=0.887 LP=0.069 LKL=13.212 LPS=0.558 LKLS=12.849 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9667
# Train F1: 0.9939
# 00350: TRAIN| LT=0.839 LP=0.058 LKL=13.474 LPS=0.511 LKLS=13.521 |
# Test F1: 0.8000
# Test ACC: 0.8293
# Test AUC: 0.9619
# Train F1: 0.9816
# 00400: TRAIN| LT=0.839 LP=0.079 LKL=13.139 LPS=0.510 LKLS=11.872 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9690
# Train F1: 0.9818
# 00450: TRAIN| LT=0.769 LP=0.048 LKL=13.380 LPS=0.463 LKLS=12.388 |
# Test F1: 0.8649
# Test ACC: 0.8780
# Test AUC: 0.9786
# Train F1: 0.9939
# 00500: TRAIN| LT=0.727 LP=0.050 LKL=13.326 LPS=0.424 LKLS=11.934 |
# Test F1: 0.8000
# Test ACC: 0.8293
# Test AUC: 0.9524
# Train F1: 0.9818
# 00550: TRAIN| LT=0.728 LP=0.046 LKL=13.220 LPS=0.437 LKLS=11.327 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9548
# Train F1: 0.9686
# 00600: TRAIN| LT=0.749 LP=0.027 LKL=13.220 LPS=0.480 LKLS=10.960 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9667
# Train F1: 0.9689
# 00650: TRAIN| LT=0.699 LP=0.037 LKL=13.379 LPS=0.414 LKLS=11.482 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9548
# Train F1: 0.9878
# 00700: TRAIN| LT=0.689 LP=0.033 LKL=13.394 LPS=0.412 LKLS=11.049 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9690
# Train F1: 0.9877
# 00750: TRAIN| LT=0.685 LP=0.028 LKL=13.417 LPS=0.408 LKLS=11.422 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9548
# Train F1: 0.9880
# 00800: TRAIN| LT=0.654 LP=0.045 LKL=13.326 LPS=0.368 LKLS=10.816 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9524
# Train F1: 0.9878
# 00850: TRAIN| LT=0.639 LP=0.042 LKL=13.307 LPS=0.359 LKLS=10.426 |
# Test F1: 0.8571
# Test ACC: 0.8780
# Test AUC: 0.9524
# Train F1: 0.9878
# 00900: TRAIN| LT=0.692 LP=0.071 LKL=13.334 LPS=0.382 LKLS=10.539 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9595
# Train F1: 0.9753
# 00950: TRAIN| LT=0.592 LP=0.039 LKL=13.437 LPS=0.308 LKLS=11.062 |
# Test F1: 0.8000
# Test ACC: 0.8293
# Test AUC: 0.9524
# Train F1: 0.9939
# 01000: TRAIN| LT=0.640 LP=0.035 LKL=13.267 LPS=0.365 LKLS=10.731 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9476
# Train F1: 0.9939
# 01050: TRAIN| LT=0.654 LP=0.042 LKL=13.665 LPS=0.359 LKLS=11.694 |
# Test F1: 0.8333
# Test ACC: 0.8537
# Test AUC: 0.9476
# Train F1: 0.9939
# 01100: TRAIN| LT=0.607 LP=0.047 LKL=13.544 LPS=0.308 LKLS=11.612 |
# Test F1: 0.8947
# Test ACC: 0.9024
# Test AUC: 0.9595
# Train F1: 0.9939
# 01150: TRAIN| LT=0.597 LP=0.004 LKL=13.571 LPS=0.345 LKLS=11.329 |
# Test F1: 0.8947
# Test ACC: 0.9024
# Test AUC: 0.9571
# Train F1: 1.0000
# 01200: TRAIN| LT=0.599 LP=0.009 LKL=13.301 LPS=0.351 LKLS=10.649 |
# Test F1: 0.8889
# Test ACC: 0.9024
# Test AUC: 0.9619
# Train F1: 0.9878
# 01250: TRAIN| LT=0.647 LP=0.035 LKL=13.230 LPS=0.377 LKLS=10.249 |
# Test F1: 0.8571
# Test ACC: 0.8780
# Test AUC: 0.9429
# Train F1: 0.9939
# 01300: TRAIN| LT=0.742 LP=0.078 LKL=13.257 LPS=0.428 LKLS=10.341 |
# Test F1: 0.8889
# Test ACC: 0.9024
# Test AUC: 0.9500
# Train F1: 0.9814
# 01350: TRAIN| LT=0.605 LP=0.015 LKL=13.528 LPS=0.349 LKLS=10.602 |
# Test F1: 0.8571
# Test ACC: 0.8780
# Test AUC: 0.9500
# Train F1: 1.0000
# 01400: TRAIN| LT=0.615 LP=0.011 LKL=13.460 LPS=0.367 LKLS=10.243 |
# Test F1: 0.9189
# Test ACC: 0.9268
# Test AUC: 0.9500
# Train F1: 0.9939
# 01450: TRAIN| LT=0.575 LP=0.034 LKL=13.109 LPS=0.313 LKLS=9.704 |
# Test F1: 0.8649
# Test ACC: 0.8780
# Test AUC: 0.9524
# Train F1: 0.9939
# 01500: TRAIN| LT=0.589 LP=0.011 LKL=13.523 LPS=0.338 LKLS=10.448 |
# Test F1: 0.8649
# Test ACC: 0.8780
# Test AUC: 0.9571
# Train F1: 0.9939
# 01550: TRAIN| LT=0.578 LP=0.016 LKL=13.535 LPS=0.317 LKLS=10.969 |
# Test F1: 0.8947
# Test ACC: 0.9024
# Test AUC: 0.9452
# Train F1: 1.0000
# 01600: TRAIN| LT=0.629 LP=0.051 LKL=13.529 LPS=0.339 LKLS=10.420 |
# Test F1: 0.8649
# Test ACC: 0.8780
# Test AUC: 0.9429
# Train F1: 0.9880
# 01650: TRAIN| LT=0.605 LP=0.024 LKL=13.283 LPS=0.351 LKLS=9.709 |
# Test F1: 0.8889
# Test ACC: 0.9024
# Test AUC: 0.9333
# Train F1: 0.9877
# 01700: TRAIN| LT=0.579 LP=0.005 LKL=13.430 LPS=0.337 LKLS=10.296 |
# Test F1: 0.8889
# Test ACC: 0.9024
# Test AUC: 0.9500
# Train F1: 0.9939
# 01750: TRAIN| LT=0.536 LP=0.007 LKL=13.293 LPS=0.300 LKLS=9.539 |
# Test F1: 0.8889
# Test ACC: 0.9024
# Test AUC: 0.9310
# Train F1: 1.0000
# 01800: TRAIN| LT=0.588 LP=0.019 LKL=13.397 LPS=0.332 LKLS=10.298 |
# Test F1: 0.8889
# Test ACC: 0.9024
# Test AUC: 0.9357
# Train F1: 1.0000
# 01850: TRAIN| LT=0.542 LP=0.007 LKL=13.361 LPS=0.301 LKLS=9.997 |
# Test F1: 0.8889
# Test ACC: 0.9024
# Test AUC: 0.9286
# Train F1: 0.9939
# 01900: TRAIN| LT=0.517 LP=0.009 LKL=13.342 LPS=0.283 LKLS=9.133 |
# Test F1: 0.8889
# Test ACC: 0.9024
# Test AUC: 0.9310
# Train F1: 1.0000
# 01950: TRAIN| LT=0.557 LP=0.008 LKL=13.510 LPS=0.314 LKLS=9.977 |
# Test F1: 0.8889
# Test ACC: 0.9024
# Test AUC: 0.9262
# Train F1: 0.9939
# 02000: TRAIN| LT=0.504 LP=0.012 LKL=13.390 LPS=0.262 LKLS=9.619 |
# Test F1: 0.8889
# Test ACC: 0.9024
# Test AUC: 0.9190
# f1: 0.9189189189189189
# acc: 0.926829268292683
# auc: 0.95
# Train F1: 0.7673
# 00050: TRAIN| LT=1.940 LP=0.619 LKL=11.336 LPS=1.147 LKLS=6.139 |
# Test F1: 0.8947
# Test ACC: 0.9024
# Test AUC: 0.9238
# Train F1: 0.9114
# 00100: TRAIN| LT=1.341 LP=0.249 LKL=12.999 LPS=0.820 LKLS=14.166 |
# Test F1: 0.9231
# Test ACC: 0.9268
# Test AUC: 0.9929
# Train F1: 0.9268
# 00150: TRAIN| LT=1.159 LP=0.156 LKL=13.182 LPS=0.740 LKLS=13.174 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9689
# 00200: TRAIN| LT=1.110 LP=0.155 LKL=13.001 LPS=0.706 LKLS=11.904 |
# Test F1: 0.9524
# Test ACC: 0.9512
# Test AUC: 1.0000
# Train F1: 0.9565
# 00250: TRAIN| LT=1.038 LP=0.152 LKL=13.279 LPS=0.628 LKLS=12.546 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9576
# 00300: TRAIN| LT=1.005 LP=0.147 LKL=13.419 LPS=0.600 LKLS=12.420 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9816
# 00350: TRAIN| LT=0.879 LP=0.082 LKL=13.623 LPS=0.534 LKLS=12.762 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9693
# 00400: TRAIN| LT=0.949 LP=0.095 LKL=13.182 LPS=0.613 LKLS=10.982 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9500
# 00450: TRAIN| LT=0.844 LP=0.077 LKL=13.409 LPS=0.518 LKLS=11.488 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9560
# 00500: TRAIN| LT=0.869 LP=0.121 LKL=13.418 LPS=0.498 LKLS=11.561 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9697
# 00550: TRAIN| LT=0.772 LP=0.049 LKL=13.671 LPS=0.463 LKLS=12.334 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9461
# 00600: TRAIN| LT=0.861 LP=0.112 LKL=13.473 LPS=0.500 LKLS=11.384 |
# Test F1: 0.9302
# Test ACC: 0.9268
# Test AUC: 1.0000
# Train F1: 0.9814
# 00650: TRAIN| LT=0.797 LP=0.077 LKL=13.602 LPS=0.464 LKLS=12.066 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 1.0000
# 00700: TRAIN| LT=0.744 LP=0.041 LKL=13.483 LPS=0.452 LKLS=11.627 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9816
# 00750: TRAIN| LT=0.714 LP=0.033 LKL=13.658 LPS=0.423 LKLS=12.085 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9939
# 00800: TRAIN| LT=0.769 LP=0.039 LKL=13.498 LPS=0.482 LKLS=11.356 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9643
# 00850: TRAIN| LT=0.724 LP=0.041 LKL=13.739 LPS=0.418 LKLS=12.711 |
# Test F1: 0.9302
# Test ACC: 0.9268
# Test AUC: 1.0000
# Train F1: 0.9877
# 00900: TRAIN| LT=0.757 LP=0.074 LKL=13.542 LPS=0.429 LKLS=11.883 |
# Test F1: 0.9524
# Test ACC: 0.9512
# Test AUC: 1.0000
# Train F1: 0.9816
# 00950: TRAIN| LT=0.693 LP=0.023 LKL=13.699 LPS=0.413 LKLS=12.017 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 1.0000
# 01000: TRAIN| LT=0.694 LP=0.048 LKL=13.677 LPS=0.394 LKLS=11.571 |
# Test F1: 0.9524
# Test ACC: 0.9512
# Test AUC: 1.0000
# Train F1: 0.9878
# 01050: TRAIN| LT=0.677 LP=0.026 LKL=13.376 LPS=0.407 LKLS=11.053 |
# Test F1: 0.9524
# Test ACC: 0.9512
# Test AUC: 1.0000
# Train F1: 0.9816
# 01100: TRAIN| LT=0.631 LP=0.024 LKL=13.788 LPS=0.346 LKLS=12.324 |
# Test F1: 0.9524
# Test ACC: 0.9512
# Test AUC: 1.0000
# Train F1: 0.9877
# 01150: TRAIN| LT=0.657 LP=0.040 LKL=13.573 LPS=0.368 LKLS=11.334 |
# Test F1: 0.9302
# Test ACC: 0.9268
# Test AUC: 0.9929
# Train F1: 0.9818
# 01200: TRAIN| LT=0.669 LP=0.046 LKL=13.583 LPS=0.372 LKLS=11.415 |
# Test F1: 0.9524
# Test ACC: 0.9512
# Test AUC: 1.0000
# Train F1: 0.9753
# 01250: TRAIN| LT=0.628 LP=0.035 LKL=13.608 LPS=0.342 LKLS=11.521 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9939
# 01300: TRAIN| LT=0.690 LP=0.051 LKL=13.646 LPS=0.388 LKLS=11.509 |
# Test F1: 0.9524
# Test ACC: 0.9512
# Test AUC: 1.0000
# Train F1: 0.9880
# 01350: TRAIN| LT=0.640 LP=0.047 LKL=13.521 LPS=0.346 LKLS=11.180 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9814
# 01400: TRAIN| LT=0.666 LP=0.026 LKL=13.608 LPS=0.389 LKLS=11.582 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9816
# 01450: TRAIN| LT=0.658 LP=0.021 LKL=13.642 LPS=0.387 LKLS=11.367 |
# Test F1: 0.9302
# Test ACC: 0.9268
# Test AUC: 1.0000
# Train F1: 0.9878
# 01500: TRAIN| LT=0.700 LP=0.036 LKL=13.607 LPS=0.415 LKLS=11.330 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9939
# 01550: TRAIN| LT=0.662 LP=0.049 LKL=13.533 LPS=0.365 LKLS=11.299 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 1.0000
# 01600: TRAIN| LT=0.589 LP=0.025 LKL=13.617 LPS=0.319 LKLS=10.913 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9878
# 01650: TRAIN| LT=0.664 LP=0.046 LKL=13.334 LPS=0.384 LKLS=10.038 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9878
# 01700: TRAIN| LT=0.623 LP=0.039 LKL=13.455 LPS=0.342 LKLS=10.730 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9818
# 01750: TRAIN| LT=0.674 LP=0.023 LKL=13.429 LPS=0.412 LKLS=10.489 |
# Test F1: 0.9524
# Test ACC: 0.9512
# Test AUC: 1.0000
# Train F1: 0.9939
# 01800: TRAIN| LT=0.638 LP=0.018 LKL=13.880 LPS=0.369 LKLS=11.196 |
# Test F1: 0.9524
# Test ACC: 0.9512
# Test AUC: 1.0000
# Train F1: 0.9939
# 01850: TRAIN| LT=0.603 LP=0.007 LKL=13.542 LPS=0.356 LKLS=10.443 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9939
# 01900: TRAIN| LT=0.629 LP=0.076 LKL=13.294 LPS=0.322 LKLS=9.705 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# Train F1: 0.9939
# 01950: TRAIN| LT=0.606 LP=0.038 LKL=13.625 LPS=0.327 LKLS=10.400 |
# Test F1: 0.9756
# Test ACC: 0.9756
# Test AUC: 1.0000
# Train F1: 0.9818
# 02000: TRAIN| LT=0.669 LP=0.063 LKL=13.556 LPS=0.365 LKLS=10.591 |
# Test F1: 1.0000
# Test ACC: 1.0000
# Test AUC: 1.0000
# f1: 1.0
# acc: 1.0
# auc: 1.0
# f1 [0.9767441860465117, 0.909090909090909, 0.9473684210526316, 0.9189189189189189, 1.0]
# average maxf1 0.9504244870217942
# acc [0.9761904761904762, 0.9047619047619048, 0.9512195121951219, 0.926829268292683, 1.0]
# average maxacc 0.951800232288037
# auc [1.0, 0.9773242630385488, 0.9880952380952381, 0.95, 1.0]
# average maxauc 0.9830839002267574
