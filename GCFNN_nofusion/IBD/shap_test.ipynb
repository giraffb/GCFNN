# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics.csv',index_col=0)
data_class={'nonIBD':0,'CD':1,'UC':1}
meta_data['diagnosis']=meta_data['diagnosis'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['diagnosis'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (1638, 578) (546, 596) (2891, 1)
# Index(['PSM7J1BF', 'CSM7KORK', 'HSM7J4HS', 'MSM9VZNL', 'MSMB4LYB', 'MSM6J2PM',
#        'MSMA26ET', 'CSM79HMN', 'CSM67UB1', 'HSM7J4IS',
#        ...
#        'PSM7J134', 'HSM5FZBJ', 'CSM79HK1', 'CSM5MCTZ', 'CSM9X21P', 'CSM5MCXF',
#        'CSM67U9P', 'CSM7KOPQ', 'HSMA33LV', 'MSM5LLFK'],
#       dtype='object', length=1796)
# 数据完整率missing_rate : 0.6080178173719376
# 集合所有样本重构数据表： (1796, 578) (1796, 596) (1796, 1)
# 标签转换为one-hot编码： (1796, 2) 459.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 8, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1', f1_cv)
print('average f1: {}±{}'.format(np.mean(f1_cv), np.std(f1_cv)))
print('acc', acc_cv)
print('average acc: {}±{}'.format(np.mean(acc_cv), np.std(acc_cv)))
print('auc', auc_cv)
print('average auc: {}±{}'.format(np.mean(auc_cv), np.std(auc_cv)))
# Out:
# Train F1: 0.8526
# 00050: TRAIN| LT=1.703 LP=0.528 LKL=6.781 LPS=1.060 LKLS=4.771 |
# Test F1: 0.8535
# Test ACC: 0.7444
# Test AUC: 0.8651
# Train F1: 0.9268
# 00100: TRAIN| LT=1.194 LP=0.285 LKL=8.533 LPS=0.705 LKLS=11.819 |
# Test F1: 0.9612
# Test ACC: 0.9417
# Test AUC: 0.9639
# Train F1: 0.9535
# 00150: TRAIN| LT=0.939 LP=0.152 LKL=8.697 LPS=0.573 LKLS=12.718 |
# Test F1: 0.9719
# Test ACC: 0.9583
# Test AUC: 0.9775
# Train F1: 0.9698
# 00200: TRAIN| LT=0.849 LP=0.124 LKL=8.874 LPS=0.507 LKLS=12.921 |
# Test F1: 0.9740
# Test ACC: 0.9611
# Test AUC: 0.9801
# Train F1: 0.9827
# 00250: TRAIN| LT=0.822 LP=0.120 LKL=8.680 LPS=0.497 LKLS=11.947 |
# Test F1: 0.9759
# Test ACC: 0.9639
# Test AUC: 0.9802
# Train F1: 0.9670
# 00300: TRAIN| LT=0.824 LP=0.123 LKL=8.689 LPS=0.496 LKLS=11.728 |
# Test F1: 0.9760
# Test ACC: 0.9639
# Test AUC: 0.9813
# Train F1: 0.9748
# 00350: TRAIN| LT=0.745 LP=0.108 LKL=8.634 LPS=0.439 LKLS=11.211 |
# Test F1: 0.9741
# Test ACC: 0.9611
# Test AUC: 0.9830
# Train F1: 0.9728
# 00400: TRAIN| LT=0.724 LP=0.097 LKL=8.574 LPS=0.432 LKLS=10.865 |
# Test F1: 0.9723
# Test ACC: 0.9583
# Test AUC: 0.9835
# Train F1: 0.9809
# 00450: TRAIN| LT=0.710 LP=0.102 LKL=8.525 LPS=0.412 LKLS=11.010 |
# Test F1: 0.9742
# Test ACC: 0.9611
# Test AUC: 0.9829
# Train F1: 0.9760
# 00500: TRAIN| LT=0.677 LP=0.089 LKL=8.471 LPS=0.399 LKLS=10.366 |
# Test F1: 0.9683
# Test ACC: 0.9528
# Test AUC: 0.9828
# Train F1: 0.9813
# 00550: TRAIN| LT=0.648 LP=0.082 LKL=8.589 LPS=0.370 LKLS=10.948 |
# Test F1: 0.9683
# Test ACC: 0.9528
# Test AUC: 0.9832
# Train F1: 0.9828
# 00600: TRAIN| LT=0.576 LP=0.071 LKL=8.517 LPS=0.314 LKLS=10.633 |
# Test F1: 0.9682
# Test ACC: 0.9528
# Test AUC: 0.9828
# Train F1: 0.9842
# 00650: TRAIN| LT=0.550 LP=0.068 LKL=8.379 LPS=0.295 LKLS=10.360 |
# Test F1: 0.9625
# Test ACC: 0.9444
# Test AUC: 0.9818
# Train F1: 0.9850
# 00700: TRAIN| LT=0.485 LP=0.046 LKL=8.299 LPS=0.250 LKLS=10.541 |
# Test F1: 0.9682
# Test ACC: 0.9528
# Test AUC: 0.9824
# Train F1: 0.9837
# 00750: TRAIN| LT=0.501 LP=0.067 LKL=8.175 LPS=0.253 LKLS=9.952 |
# Test F1: 0.9682
# Test ACC: 0.9528
# Test AUC: 0.9831
# Train F1: 0.9860
# 00800: TRAIN| LT=0.506 LP=0.064 LKL=8.236 LPS=0.255 LKLS=10.362 |
# Test F1: 0.9682
# Test ACC: 0.9528
# Test AUC: 0.9833
# Train F1: 0.9864
# 00850: TRAIN| LT=0.459 LP=0.061 LKL=8.353 LPS=0.207 LKLS=10.793 |
# Test F1: 0.9644
# Test ACC: 0.9472
# Test AUC: 0.9835
# Train F1: 0.9912
# 00900: TRAIN| LT=0.429 LP=0.047 LKL=8.202 LPS=0.197 LKLS=10.297 |
# Test F1: 0.9645
# Test ACC: 0.9472
# Test AUC: 0.9828
# Train F1: 0.9883
# 00950: TRAIN| LT=0.388 LP=0.050 LKL=8.248 LPS=0.152 LKLS=10.383 |
# Test F1: 0.9605
# Test ACC: 0.9417
# Test AUC: 0.9837
# Train F1: 0.9888
# 01000: TRAIN| LT=0.371 LP=0.043 LKL=8.156 LPS=0.148 LKLS=9.880 |
# Test F1: 0.9663
# Test ACC: 0.9500
# Test AUC: 0.9824
# Train F1: 0.9920
# 01050: TRAIN| LT=0.386 LP=0.040 LKL=8.192 LPS=0.163 LKLS=10.088 |
# Test F1: 0.9624
# Test ACC: 0.9444
# Test AUC: 0.9829
# Train F1: 0.9925
# 01100: TRAIN| LT=0.407 LP=0.050 LKL=8.096 LPS=0.179 LKLS=9.721 |
# Test F1: 0.9624
# Test ACC: 0.9444
# Test AUC: 0.9832
# Train F1: 0.9907
# 01150: TRAIN| LT=0.345 LP=0.041 LKL=8.023 LPS=0.133 LKLS=9.138 |
# Test F1: 0.9644
# Test ACC: 0.9472
# Test AUC: 0.9842
# Train F1: 0.9958
# 01200: TRAIN| LT=0.331 LP=0.043 LKL=8.115 LPS=0.110 LKLS=9.615 |
# Test F1: 0.9624
# Test ACC: 0.9444
# Test AUC: 0.9827
# Train F1: 0.9934
# 01250: TRAIN| LT=0.333 LP=0.031 LKL=8.083 LPS=0.128 LKLS=9.285 |
# Test F1: 0.9682
# Test ACC: 0.9528
# Test AUC: 0.9833
# Train F1: 0.9935
# 01300: TRAIN| LT=0.336 LP=0.044 LKL=7.999 LPS=0.120 LKLS=9.295 |
# Test F1: 0.9682
# Test ACC: 0.9528
# Test AUC: 0.9830
# Train F1: 0.9916
# 01350: TRAIN| LT=0.310 LP=0.029 LKL=7.975 LPS=0.109 LKLS=9.167 |
# Test F1: 0.9721
# Test ACC: 0.9583
# Test AUC: 0.9842
# Train F1: 0.9944
# 01400: TRAIN| LT=0.298 LP=0.037 LKL=7.865 LPS=0.092 LKLS=8.950 |
# Test F1: 0.9665
# Test ACC: 0.9500
# Test AUC: 0.9837
# Train F1: 0.9944
# 01450: TRAIN| LT=0.283 LP=0.022 LKL=7.951 LPS=0.092 LKLS=8.919 |
# Test F1: 0.9664
# Test ACC: 0.9500
# Test AUC: 0.9847
# Train F1: 0.9935
# 01500: TRAIN| LT=0.297 LP=0.025 LKL=7.902 LPS=0.107 LKLS=8.699 |
# Test F1: 0.9664
# Test ACC: 0.9500
# Test AUC: 0.9846
# Train F1: 0.9934
# 01550: TRAIN| LT=0.293 LP=0.025 LKL=7.966 LPS=0.103 LKLS=8.618 |
# Test F1: 0.9624
# Test ACC: 0.9444
# Test AUC: 0.9820
# Train F1: 0.9939
# 01600: TRAIN| LT=0.281 LP=0.026 LKL=7.875 LPS=0.091 LKLS=8.510 |
# Test F1: 0.9646
# Test ACC: 0.9472
# Test AUC: 0.9835
# Train F1: 0.9953
# 01650: TRAIN| LT=0.256 LP=0.023 LKL=7.995 LPS=0.066 LKLS=8.714 |
# Test F1: 0.9645
# Test ACC: 0.9472
# Test AUC: 0.9847
# Train F1: 0.9916
# 01700: TRAIN| LT=0.265 LP=0.033 LKL=7.663 LPS=0.076 LKLS=7.877 |
# Test F1: 0.9665
# Test ACC: 0.9500
# Test AUC: 0.9813
# Train F1: 0.9939
# 01750: TRAIN| LT=0.261 LP=0.021 LKL=7.982 LPS=0.076 LKLS=8.350 |
# Test F1: 0.9682
# Test ACC: 0.9528
# Test AUC: 0.9842
# Train F1: 0.9949
# 01800: TRAIN| LT=0.239 LP=0.020 LKL=7.799 LPS=0.061 LKLS=8.057 |
# Test F1: 0.9663
# Test ACC: 0.9500
# Test AUC: 0.9845
# Train F1: 0.9935
# 01850: TRAIN| LT=0.243 LP=0.024 LKL=7.854 LPS=0.060 LKLS=8.031 |
# Test F1: 0.9625
# Test ACC: 0.9444
# Test AUC: 0.9832
# Train F1: 0.9967
# 01900: TRAIN| LT=0.253 LP=0.019 LKL=7.838 LPS=0.073 LKLS=8.227 |
# Test F1: 0.9625
# Test ACC: 0.9444
# Test AUC: 0.9824
# Train F1: 0.9939
# 01950: TRAIN| LT=0.228 LP=0.019 LKL=7.904 LPS=0.047 LKLS=8.261 |
# Test F1: 0.9644
# Test ACC: 0.9472
# Test AUC: 0.9837
# Train F1: 0.9930
# 02000: TRAIN| LT=0.244 LP=0.018 LKL=7.885 LPS=0.068 LKLS=7.935 |
# Test F1: 0.9663
# Test ACC: 0.9500
# Test AUC: 0.9844
# f1: 0.9759704251386322
# acc: 0.9638888888888889
# auc: 0.9812621674237507
# Train F1: 0.8522
# 00050: TRAIN| LT=1.703 LP=0.546 LKL=6.191 LPS=1.057 LKLS=3.809 |
# Test F1: 0.8549
# Test ACC: 0.7465
# Test AUC: 0.8427
# Train F1: 0.9337
# 00100: TRAIN| LT=1.178 LP=0.276 LKL=8.287 LPS=0.705 LKLS=11.465 |
# Test F1: 0.9462
# Test ACC: 0.9192
# Test AUC: 0.9538
# Train F1: 0.9561
# 00150: TRAIN| LT=0.914 LP=0.144 LKL=8.613 LPS=0.558 LKLS=12.651 |
# Test F1: 0.9630
# Test ACC: 0.9443
# Test AUC: 0.9751
# Train F1: 0.9666
# 00200: TRAIN| LT=0.846 LP=0.136 LKL=8.611 LPS=0.504 LKLS=12.090 |
# Test F1: 0.9668
# Test ACC: 0.9499
# Test AUC: 0.9781
# Train F1: 0.9697
# 00250: TRAIN| LT=0.808 LP=0.122 LKL=8.609 LPS=0.483 LKLS=11.662 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9782
# Train F1: 0.9698
# 00300: TRAIN| LT=0.761 LP=0.111 LKL=8.459 LPS=0.456 LKLS=10.920 |
# Test F1: 0.9667
# Test ACC: 0.9499
# Test AUC: 0.9782
# Train F1: 0.9763
# 00350: TRAIN| LT=0.692 LP=0.081 LKL=8.449 LPS=0.420 LKLS=10.561 |
# Test F1: 0.9630
# Test ACC: 0.9443
# Test AUC: 0.9787
# Train F1: 0.9828
# 00400: TRAIN| LT=0.710 LP=0.104 LKL=8.419 LPS=0.416 LKLS=10.525 |
# Test F1: 0.9683
# Test ACC: 0.9526
# Test AUC: 0.9790
# Train F1: 0.9780
# 00450: TRAIN| LT=0.682 LP=0.101 LKL=8.271 LPS=0.397 LKLS=10.125 |
# Test F1: 0.9630
# Test ACC: 0.9443
# Test AUC: 0.9774
# Train F1: 0.9851
# 00500: TRAIN| LT=0.627 LP=0.094 LKL=8.213 LPS=0.349 LKLS=10.271 |
# Test F1: 0.9612
# Test ACC: 0.9415
# Test AUC: 0.9770
# Train F1: 0.9809
# 00550: TRAIN| LT=0.627 LP=0.078 LKL=8.228 LPS=0.365 LKLS=10.136 |
# Test F1: 0.9593
# Test ACC: 0.9387
# Test AUC: 0.9775
# Train F1: 0.9827
# 00600: TRAIN| LT=0.575 LP=0.080 LKL=8.177 LPS=0.310 LKLS=10.382 |
# Test F1: 0.9554
# Test ACC: 0.9331
# Test AUC: 0.9777
# Train F1: 0.9850
# 00650: TRAIN| LT=0.549 LP=0.076 LKL=8.155 LPS=0.293 LKLS=9.742 |
# Test F1: 0.9607
# Test ACC: 0.9415
# Test AUC: 0.9780
# Train F1: 0.9824
# 00700: TRAIN| LT=0.525 LP=0.067 LKL=8.148 LPS=0.273 LKLS=10.370 |
# Test F1: 0.9573
# Test ACC: 0.9359
# Test AUC: 0.9779
# Train F1: 0.9808
# 00750: TRAIN| LT=0.505 LP=0.064 LKL=8.231 LPS=0.254 LKLS=10.382 |
# Test F1: 0.9572
# Test ACC: 0.9359
# Test AUC: 0.9779
# Train F1: 0.9855
# 00800: TRAIN| LT=0.461 LP=0.056 LKL=8.181 LPS=0.217 LKLS=10.574 |
# Test F1: 0.9538
# Test ACC: 0.9304
# Test AUC: 0.9775
# Train F1: 0.9893
# 00850: TRAIN| LT=0.453 LP=0.050 LKL=8.208 LPS=0.217 LKLS=10.406 |
# Test F1: 0.9572
# Test ACC: 0.9359
# Test AUC: 0.9787
# Train F1: 0.9879
# 00900: TRAIN| LT=0.431 LP=0.059 LKL=8.024 LPS=0.190 LKLS=10.235 |
# Test F1: 0.9572
# Test ACC: 0.9359
# Test AUC: 0.9774
# Train F1: 0.9925
# 00950: TRAIN| LT=0.414 LP=0.041 LKL=8.181 LPS=0.188 LKLS=10.306 |
# Test F1: 0.9591
# Test ACC: 0.9387
# Test AUC: 0.9769
# Train F1: 0.9906
# 01000: TRAIN| LT=0.432 LP=0.056 LKL=8.117 LPS=0.195 LKLS=10.017 |
# Test F1: 0.9606
# Test ACC: 0.9415
# Test AUC: 0.9804
# Train F1: 0.9921
# 01050: TRAIN| LT=0.379 LP=0.038 LKL=8.031 LPS=0.163 LKLS=9.753 |
# Test F1: 0.9572
# Test ACC: 0.9359
# Test AUC: 0.9791
# Train F1: 0.9911
# 01100: TRAIN| LT=0.353 LP=0.040 LKL=8.145 LPS=0.130 LKLS=10.175 |
# Test F1: 0.9591
# Test ACC: 0.9387
# Test AUC: 0.9798
# Train F1: 0.9902
# 01150: TRAIN| LT=0.321 LP=0.038 LKL=7.948 LPS=0.108 LKLS=9.563 |
# Test F1: 0.9572
# Test ACC: 0.9359
# Test AUC: 0.9788
# Train F1: 0.9916
# 01200: TRAIN| LT=0.331 LP=0.035 LKL=7.951 LPS=0.123 LKLS=9.344 |
# Test F1: 0.9591
# Test ACC: 0.9387
# Test AUC: 0.9791
# Train F1: 0.9921
# 01250: TRAIN| LT=0.365 LP=0.033 LKL=7.966 LPS=0.160 LKLS=9.217 |
# Test F1: 0.9573
# Test ACC: 0.9359
# Test AUC: 0.9794
# Train F1: 0.9897
# 01300: TRAIN| LT=0.330 LP=0.034 LKL=8.084 LPS=0.122 LKLS=9.324 |
# Test F1: 0.9591
# Test ACC: 0.9387
# Test AUC: 0.9792
# Train F1: 0.9948
# 01350: TRAIN| LT=0.341 LP=0.034 LKL=8.014 LPS=0.135 LKLS=9.102 |
# Test F1: 0.9573
# Test ACC: 0.9359
# Test AUC: 0.9794
# Train F1: 0.9944
# 01400: TRAIN| LT=0.310 LP=0.046 LKL=7.834 LPS=0.103 LKLS=8.313 |
# Test F1: 0.9591
# Test ACC: 0.9387
# Test AUC: 0.9795
# Train F1: 0.9935
# 01450: TRAIN| LT=0.324 LP=0.037 LKL=8.063 LPS=0.116 LKLS=9.076 |
# Test F1: 0.9573
# Test ACC: 0.9359
# Test AUC: 0.9799
# Train F1: 0.9920
# 01500: TRAIN| LT=0.299 LP=0.036 LKL=8.008 LPS=0.096 LKLS=8.720 |
# Test F1: 0.9609
# Test ACC: 0.9415
# Test AUC: 0.9806
# Train F1: 0.9920
# 01550: TRAIN| LT=0.302 LP=0.031 LKL=8.029 LPS=0.104 LKLS=8.632 |
# Test F1: 0.9591
# Test ACC: 0.9387
# Test AUC: 0.9802
# Train F1: 0.9953
# 01600: TRAIN| LT=0.256 LP=0.020 LKL=7.873 LPS=0.074 LKLS=8.344 |
# Test F1: 0.9573
# Test ACC: 0.9359
# Test AUC: 0.9798
# Train F1: 0.9935
# 01650: TRAIN| LT=0.268 LP=0.032 LKL=7.836 LPS=0.076 LKLS=8.220 |
# Test F1: 0.9591
# Test ACC: 0.9387
# Test AUC: 0.9809
# Train F1: 0.9925
# 01700: TRAIN| LT=0.260 LP=0.030 LKL=7.871 LPS=0.069 LKLS=8.229 |
# Test F1: 0.9554
# Test ACC: 0.9331
# Test AUC: 0.9801
# Train F1: 0.9949
# 01750: TRAIN| LT=0.252 LP=0.025 LKL=7.850 LPS=0.066 LKLS=8.162 |
# Test F1: 0.9573
# Test ACC: 0.9359
# Test AUC: 0.9806
# Train F1: 0.9934
# 01800: TRAIN| LT=0.249 LP=0.014 LKL=7.945 LPS=0.076 LKLS=8.004 |
# Test F1: 0.9568
# Test ACC: 0.9359
# Test AUC: 0.9811
# Train F1: 0.9930
# 01850: TRAIN| LT=0.243 LP=0.022 LKL=7.685 LPS=0.065 LKLS=7.981 |
# Test F1: 0.9591
# Test ACC: 0.9387
# Test AUC: 0.9818
# Train F1: 0.9934
# 01900: TRAIN| LT=0.230 LP=0.029 LKL=7.697 LPS=0.045 LKLS=7.891 |
# Test F1: 0.9590
# Test ACC: 0.9387
# Test AUC: 0.9817
# Train F1: 0.9935
# 01950: TRAIN| LT=0.260 LP=0.022 LKL=7.681 LPS=0.083 LKLS=7.813 |
# Test F1: 0.9593
# Test ACC: 0.9387
# Test AUC: 0.9816
# Train F1: 0.9958
# 02000: TRAIN| LT=0.233 LP=0.022 LKL=7.630 LPS=0.057 LKLS=7.800 |
# Test F1: 0.9552
# Test ACC: 0.9331
# Test AUC: 0.9811
# f1: 0.9685767097966728
# acc: 0.9526462395543176
# auc: 0.9781859931113662
# Train F1: 0.8548
# 00050: TRAIN| LT=1.743 LP=0.544 LKL=6.591 LPS=1.084 LKLS=4.899 |
# Test F1: 0.8530
# Test ACC: 0.7437
# Test AUC: 0.8803
# Train F1: 0.9188
# 00100: TRAIN| LT=1.231 LP=0.297 LKL=8.434 LPS=0.731 LKLS=11.899 |
# Test F1: 0.9610
# Test ACC: 0.9415
# Test AUC: 0.9738
# Train F1: 0.9567
# 00150: TRAIN| LT=0.964 LP=0.161 LKL=8.825 LPS=0.584 LKLS=13.020 |
# Test F1: 0.9665
# Test ACC: 0.9499
# Test AUC: 0.9871
# Train F1: 0.9697
# 00200: TRAIN| LT=0.914 LP=0.133 LKL=8.897 LPS=0.561 LKLS=13.132 |
# Test F1: 0.9665
# Test ACC: 0.9499
# Test AUC: 0.9887
# Train F1: 0.9667
# 00250: TRAIN| LT=0.818 LP=0.114 LKL=8.850 LPS=0.492 LKLS=12.368 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9890
# Train F1: 0.9700
# 00300: TRAIN| LT=0.785 LP=0.109 LKL=8.745 LPS=0.470 LKLS=11.762 |
# Test F1: 0.9663
# Test ACC: 0.9499
# Test AUC: 0.9898
# Train F1: 0.9733
# 00350: TRAIN| LT=0.733 LP=0.089 LKL=8.731 LPS=0.440 LKLS=11.583 |
# Test F1: 0.9687
# Test ACC: 0.9526
# Test AUC: 0.9907
# Train F1: 0.9818
# 00400: TRAIN| LT=0.698 LP=0.084 LKL=8.672 LPS=0.415 LKLS=11.238 |
# Test F1: 0.9650
# Test ACC: 0.9471
# Test AUC: 0.9911
# Train F1: 0.9779
# 00450: TRAIN| LT=0.685 LP=0.086 LKL=8.744 LPS=0.403 LKLS=10.819 |
# Test F1: 0.9682
# Test ACC: 0.9526
# Test AUC: 0.9919
# Train F1: 0.9790
# 00500: TRAIN| LT=0.644 LP=0.081 LKL=8.651 LPS=0.367 LKLS=10.937 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9914
# Train F1: 0.9818
# 00550: TRAIN| LT=0.631 LP=0.080 LKL=8.666 LPS=0.355 LKLS=10.880 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9916
# Train F1: 0.9818
# 00600: TRAIN| LT=0.615 LP=0.070 LKL=8.547 LPS=0.351 LKLS=10.795 |
# Test F1: 0.9687
# Test ACC: 0.9526
# Test AUC: 0.9928
# Train F1: 0.9813
# 00650: TRAIN| LT=0.547 LP=0.055 LKL=8.609 LPS=0.296 LKLS=11.021 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9916
# Train F1: 0.9874
# 00700: TRAIN| LT=0.520 LP=0.061 LKL=8.498 LPS=0.266 LKLS=10.795 |
# Test F1: 0.9687
# Test ACC: 0.9526
# Test AUC: 0.9920
# Train F1: 0.9856
# 00750: TRAIN| LT=0.506 LP=0.052 LKL=8.451 LPS=0.263 LKLS=10.594 |
# Test F1: 0.9669
# Test ACC: 0.9499
# Test AUC: 0.9909
# Train F1: 0.9828
# 00800: TRAIN| LT=0.478 LP=0.063 LKL=8.521 LPS=0.222 LKLS=10.773 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9922
# Train F1: 0.9869
# 00850: TRAIN| LT=0.441 LP=0.058 LKL=8.322 LPS=0.195 LKLS=10.451 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9923
# Train F1: 0.9879
# 00900: TRAIN| LT=0.460 LP=0.063 LKL=8.322 LPS=0.212 LKLS=10.146 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9924
# Train F1: 0.9916
# 00950: TRAIN| LT=0.401 LP=0.044 LKL=8.453 LPS=0.167 LKLS=10.571 |
# Test F1: 0.9704
# Test ACC: 0.9554
# Test AUC: 0.9920
# Train F1: 0.9874
# 01000: TRAIN| LT=0.434 LP=0.051 LKL=8.234 LPS=0.200 LKLS=10.008 |
# Test F1: 0.9706
# Test ACC: 0.9554
# Test AUC: 0.9911
# Train F1: 0.9892
# 01050: TRAIN| LT=0.401 LP=0.039 LKL=8.363 LPS=0.179 LKLS=9.927 |
# Test F1: 0.9722
# Test ACC: 0.9582
# Test AUC: 0.9925
# Train F1: 0.9893
# 01100: TRAIN| LT=0.389 LP=0.036 LKL=8.350 LPS=0.168 LKLS=10.072 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9919
# Train F1: 0.9911
# 01150: TRAIN| LT=0.380 LP=0.033 LKL=8.256 LPS=0.162 LKLS=10.167 |
# Test F1: 0.9760
# Test ACC: 0.9638
# Test AUC: 0.9917
# Train F1: 0.9930
# 01200: TRAIN| LT=0.339 LP=0.030 LKL=8.223 LPS=0.128 LKLS=9.857 |
# Test F1: 0.9741
# Test ACC: 0.9610
# Test AUC: 0.9915
# Train F1: 0.9906
# 01250: TRAIN| LT=0.344 LP=0.032 LKL=8.144 LPS=0.133 LKLS=9.704 |
# Test F1: 0.9741
# Test ACC: 0.9610
# Test AUC: 0.9918
# Train F1: 0.9953
# 01300: TRAIN| LT=0.346 LP=0.038 LKL=8.026 LPS=0.133 LKLS=9.530 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9923
# Train F1: 0.9935
# 01350: TRAIN| LT=0.321 LP=0.027 LKL=8.109 LPS=0.118 LKLS=9.537 |
# Test F1: 0.9741
# Test ACC: 0.9610
# Test AUC: 0.9924
# Train F1: 0.9963
# 01400: TRAIN| LT=0.333 LP=0.029 LKL=8.098 LPS=0.130 LKLS=9.269 |
# Test F1: 0.9761
# Test ACC: 0.9638
# Test AUC: 0.9911
# Train F1: 0.9944
# 01450: TRAIN| LT=0.325 LP=0.031 LKL=7.946 LPS=0.125 LKLS=8.907 |
# Test F1: 0.9743
# Test ACC: 0.9610
# Test AUC: 0.9915
# Train F1: 0.9949
# 01500: TRAIN| LT=0.305 LP=0.031 LKL=8.077 LPS=0.103 LKLS=9.029 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9916
# Train F1: 0.9963
# 01550: TRAIN| LT=0.290 LP=0.026 LKL=8.025 LPS=0.093 LKLS=9.060 |
# Test F1: 0.9704
# Test ACC: 0.9554
# Test AUC: 0.9916
# Train F1: 0.9949
# 01600: TRAIN| LT=0.288 LP=0.024 LKL=7.976 LPS=0.097 LKLS=8.757 |
# Test F1: 0.9722
# Test ACC: 0.9582
# Test AUC: 0.9910
# Train F1: 0.9935
# 01650: TRAIN| LT=0.293 LP=0.021 LKL=8.018 LPS=0.103 LKLS=8.855 |
# Test F1: 0.9759
# Test ACC: 0.9638
# Test AUC: 0.9918
# Train F1: 0.9972
# 01700: TRAIN| LT=0.270 LP=0.020 LKL=7.904 LPS=0.090 LKLS=8.158 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9918
# Train F1: 0.9981
# 01750: TRAIN| LT=0.269 LP=0.021 LKL=8.076 LPS=0.081 LKLS=8.556 |
# Test F1: 0.9703
# Test ACC: 0.9554
# Test AUC: 0.9922
# Train F1: 0.9949
# 01800: TRAIN| LT=0.240 LP=0.025 LKL=7.999 LPS=0.047 LKLS=8.848 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9916
# Train F1: 0.9934
# 01850: TRAIN| LT=0.286 LP=0.021 LKL=7.946 LPS=0.098 LKLS=8.750 |
# Test F1: 0.9683
# Test ACC: 0.9526
# Test AUC: 0.9909
# Train F1: 0.9958
# 01900: TRAIN| LT=0.235 LP=0.015 LKL=7.850 LPS=0.057 LKLS=8.425 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9903
# Train F1: 0.9958
# 01950: TRAIN| LT=0.233 LP=0.016 LKL=7.931 LPS=0.054 LKLS=8.327 |
# Test F1: 0.9721
# Test ACC: 0.9582
# Test AUC: 0.9900
# Train F1: 0.9944
# 02000: TRAIN| LT=0.258 LP=0.018 LKL=7.987 LPS=0.078 LKLS=8.229 |
# Test F1: 0.9703
# Test ACC: 0.9554
# Test AUC: 0.9909
# f1: 0.9760589318600369
# acc: 0.9637883008356546
# auc: 0.9910641589317701
# Train F1: 0.8568
# 00050: TRAIN| LT=1.682 LP=0.527 LKL=6.769 LPS=1.035 LKLS=5.293 |
# Test F1: 0.8530
# Test ACC: 0.7437
# Test AUC: 0.8934
# Train F1: 0.9142
# 00100: TRAIN| LT=1.236 LP=0.296 LKL=8.140 LPS=0.749 LKLS=10.961 |
# Test F1: 0.9616
# Test ACC: 0.9415
# Test AUC: 0.9733
# Train F1: 0.9566
# 00150: TRAIN| LT=0.955 LP=0.163 LKL=8.702 LPS=0.579 LKLS=12.721 |
# Test F1: 0.9742
# Test ACC: 0.9610
# Test AUC: 0.9878
# Train F1: 0.9650
# 00200: TRAIN| LT=0.914 LP=0.147 LKL=8.612 LPS=0.562 LKLS=11.829 |
# Test F1: 0.9778
# Test ACC: 0.9666
# Test AUC: 0.9916
# Train F1: 0.9696
# 00250: TRAIN| LT=0.858 LP=0.123 LKL=8.697 LPS=0.528 LKLS=11.906 |
# Test F1: 0.9760
# Test ACC: 0.9638
# Test AUC: 0.9920
# Train F1: 0.9724
# 00300: TRAIN| LT=0.793 LP=0.107 LKL=8.550 LPS=0.488 LKLS=11.260 |
# Test F1: 0.9779
# Test ACC: 0.9666
# Test AUC: 0.9921
# Train F1: 0.9804
# 00350: TRAIN| LT=0.748 LP=0.091 LKL=8.650 LPS=0.456 LKLS=11.545 |
# Test F1: 0.9760
# Test ACC: 0.9638
# Test AUC: 0.9932
# Train F1: 0.9827
# 00400: TRAIN| LT=0.734 LP=0.111 LKL=8.557 LPS=0.428 LKLS=10.938 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9931
# Train F1: 0.9800
# 00450: TRAIN| LT=0.684 LP=0.099 LKL=8.525 LPS=0.394 LKLS=10.656 |
# Test F1: 0.9669
# Test ACC: 0.9499
# Test AUC: 0.9927
# Train F1: 0.9818
# 00500: TRAIN| LT=0.661 LP=0.088 LKL=8.603 LPS=0.380 LKLS=10.782 |
# Test F1: 0.9704
# Test ACC: 0.9554
# Test AUC: 0.9941
# Train F1: 0.9814
# 00550: TRAIN| LT=0.657 LP=0.087 LKL=8.360 LPS=0.386 LKLS=10.059 |
# Test F1: 0.9686
# Test ACC: 0.9526
# Test AUC: 0.9930
# Train F1: 0.9822
# 00600: TRAIN| LT=0.611 LP=0.065 LKL=8.577 LPS=0.357 LKLS=10.395 |
# Test F1: 0.9704
# Test ACC: 0.9554
# Test AUC: 0.9947
# Train F1: 0.9850
# 00650: TRAIN| LT=0.561 LP=0.072 LKL=8.509 LPS=0.296 LKLS=10.769 |
# Test F1: 0.9707
# Test ACC: 0.9554
# Test AUC: 0.9949
# Train F1: 0.9822
# 00700: TRAIN| LT=0.538 LP=0.070 LKL=8.488 LPS=0.278 LKLS=10.604 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9952
# Train F1: 0.9888
# 00750: TRAIN| LT=0.496 LP=0.051 LKL=8.359 LPS=0.256 LKLS=10.474 |
# Test F1: 0.9707
# Test ACC: 0.9554
# Test AUC: 0.9954
# Train F1: 0.9925
# 00800: TRAIN| LT=0.477 LP=0.063 LKL=8.326 LPS=0.226 LKLS=10.468 |
# Test F1: 0.9672
# Test ACC: 0.9499
# Test AUC: 0.9958
# Train F1: 0.9897
# 00850: TRAIN| LT=0.457 LP=0.064 LKL=8.329 LPS=0.205 LKLS=10.543 |
# Test F1: 0.9669
# Test ACC: 0.9499
# Test AUC: 0.9947
# Train F1: 0.9892
# 00900: TRAIN| LT=0.430 LP=0.048 LKL=8.201 LPS=0.198 LKLS=10.216 |
# Test F1: 0.9670
# Test ACC: 0.9499
# Test AUC: 0.9956
# Train F1: 0.9921
# 00950: TRAIN| LT=0.412 LP=0.046 LKL=8.199 LPS=0.187 LKLS=9.656 |
# Test F1: 0.9672
# Test ACC: 0.9499
# Test AUC: 0.9962
# Train F1: 0.9906
# 01000: TRAIN| LT=0.401 LP=0.055 LKL=8.252 LPS=0.162 LKLS=10.111 |
# Test F1: 0.9708
# Test ACC: 0.9554
# Test AUC: 0.9960
# Train F1: 0.9883
# 01050: TRAIN| LT=0.419 LP=0.049 LKL=8.169 LPS=0.191 LKLS=9.754 |
# Test F1: 0.9723
# Test ACC: 0.9582
# Test AUC: 0.9963
# Train F1: 0.9907
# 01100: TRAIN| LT=0.364 LP=0.038 LKL=8.309 LPS=0.144 LKLS=9.976 |
# Test F1: 0.9706
# Test ACC: 0.9554
# Test AUC: 0.9962
# Train F1: 0.9930
# 01150: TRAIN| LT=0.383 LP=0.057 LKL=8.020 LPS=0.150 LKLS=9.605 |
# Test F1: 0.9707
# Test ACC: 0.9554
# Test AUC: 0.9964
# Train F1: 0.9897
# 01200: TRAIN| LT=0.331 LP=0.027 LKL=8.219 LPS=0.127 LKLS=9.471 |
# Test F1: 0.9669
# Test ACC: 0.9499
# Test AUC: 0.9960
# Train F1: 0.9893
# 01250: TRAIN| LT=0.356 LP=0.039 LKL=8.200 LPS=0.139 LKLS=9.662 |
# Test F1: 0.9689
# Test ACC: 0.9526
# Test AUC: 0.9962
# Train F1: 0.9897
# 01300: TRAIN| LT=0.344 LP=0.050 LKL=8.114 LPS=0.118 LKLS=9.502 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9963
# Train F1: 0.9925
# 01350: TRAIN| LT=0.358 LP=0.037 LKL=8.001 LPS=0.154 LKLS=8.732 |
# Test F1: 0.9689
# Test ACC: 0.9526
# Test AUC: 0.9967
# Train F1: 0.9888
# 01400: TRAIN| LT=0.306 LP=0.036 LKL=8.026 LPS=0.101 LKLS=8.907 |
# Test F1: 0.9743
# Test ACC: 0.9610
# Test AUC: 0.9964
# Train F1: 0.9921
# 01450: TRAIN| LT=0.327 LP=0.036 LKL=7.978 LPS=0.125 LKLS=8.533 |
# Test F1: 0.9670
# Test ACC: 0.9499
# Test AUC: 0.9965
# Train F1: 0.9949
# 01500: TRAIN| LT=0.268 LP=0.024 LKL=8.044 LPS=0.073 LKLS=9.071 |
# Test F1: 0.9744
# Test ACC: 0.9610
# Test AUC: 0.9967
# Train F1: 0.9916
# 01550: TRAIN| LT=0.290 LP=0.021 LKL=8.151 LPS=0.099 LKLS=8.840 |
# Test F1: 0.9724
# Test ACC: 0.9582
# Test AUC: 0.9967
# Train F1: 0.9949
# 01600: TRAIN| LT=0.293 LP=0.026 LKL=8.069 LPS=0.101 LKLS=8.498 |
# Test F1: 0.9744
# Test ACC: 0.9610
# Test AUC: 0.9969
# Train F1: 0.9916
# 01650: TRAIN| LT=0.292 LP=0.036 LKL=7.855 LPS=0.096 LKLS=8.184 |
# Test F1: 0.9761
# Test ACC: 0.9638
# Test AUC: 0.9967
# Train F1: 0.9953
# 01700: TRAIN| LT=0.287 LP=0.025 LKL=7.892 LPS=0.101 LKLS=8.186 |
# Test F1: 0.9744
# Test ACC: 0.9610
# Test AUC: 0.9973
# Train F1: 0.9949
# 01750: TRAIN| LT=0.280 LP=0.039 LKL=7.858 LPS=0.080 LKLS=8.292 |
# Test F1: 0.9761
# Test ACC: 0.9638
# Test AUC: 0.9971
# Train F1: 0.9935
# 01800: TRAIN| LT=0.254 LP=0.026 LKL=7.903 LPS=0.069 LKLS=8.038 |
# Test F1: 0.9725
# Test ACC: 0.9582
# Test AUC: 0.9972
# Train F1: 0.9934
# 01850: TRAIN| LT=0.257 LP=0.014 LKL=8.091 LPS=0.077 LKLS=8.527 |
# Test F1: 0.9705
# Test ACC: 0.9554
# Test AUC: 0.9965
# Train F1: 0.9953
# 01900: TRAIN| LT=0.253 LP=0.019 LKL=7.811 LPS=0.077 LKLS=7.852 |
# Test F1: 0.9725
# Test ACC: 0.9582
# Test AUC: 0.9970
# Train F1: 0.9958
# 01950: TRAIN| LT=0.242 LP=0.019 LKL=7.743 LPS=0.067 LKLS=7.904 |
# Test F1: 0.9724
# Test ACC: 0.9582
# Test AUC: 0.9969
# Train F1: 0.9967
# 02000: TRAIN| LT=0.247 LP=0.019 LKL=7.867 LPS=0.073 LKLS=7.636 |
# Test F1: 0.9725
# Test ACC: 0.9582
# Test AUC: 0.9965
# f1: 0.977859778597786
# acc: 0.9665738161559888
# auc: 0.9921022634750041
# Train F1: 0.8574
# 00050: TRAIN| LT=1.658 LP=0.508 LKL=6.703 LPS=1.031 LKLS=5.213 |
# Test F1: 0.8530
# Test ACC: 0.7437
# Test AUC: 0.8992
# Train F1: 0.9488
# 00100: TRAIN| LT=1.175 LP=0.245 LKL=8.562 LPS=0.721 LKLS=12.259 |
# Test F1: 0.9724
# Test ACC: 0.9582
# Test AUC: 0.9757
# Train F1: 0.9594
# 00150: TRAIN| LT=0.924 LP=0.155 LKL=8.672 LPS=0.558 LKLS=12.454 |
# Test F1: 0.9721
# Test ACC: 0.9582
# Test AUC: 0.9831
# Train F1: 0.9698
# 00200: TRAIN| LT=0.871 LP=0.139 LKL=8.636 LPS=0.525 LKLS=12.131 |
# Test F1: 0.9736
# Test ACC: 0.9610
# Test AUC: 0.9833
# Train F1: 0.9695
# 00250: TRAIN| LT=0.795 LP=0.112 LKL=8.707 LPS=0.477 LKLS=11.923 |
# Test F1: 0.9773
# Test ACC: 0.9666
# Test AUC: 0.9836
# Train F1: 0.9781
# 00300: TRAIN| LT=0.772 LP=0.111 LKL=8.659 LPS=0.459 LKLS=11.598 |
# Test F1: 0.9755
# Test ACC: 0.9638
# Test AUC: 0.9836
# Train F1: 0.9753
# 00350: TRAIN| LT=0.746 LP=0.105 LKL=8.622 LPS=0.441 LKLS=11.370 |
# Test F1: 0.9737
# Test ACC: 0.9610
# Test AUC: 0.9837
# Train F1: 0.9772
# 00400: TRAIN| LT=0.714 LP=0.077 LKL=8.595 LPS=0.439 LKLS=11.249 |
# Test F1: 0.9737
# Test ACC: 0.9610
# Test AUC: 0.9822
# Train F1: 0.9814
# 00450: TRAIN| LT=0.700 LP=0.083 LKL=8.702 LPS=0.417 LKLS=11.296 |
# Test F1: 0.9754
# Test ACC: 0.9638
# Test AUC: 0.9835
# Train F1: 0.9814
# 00500: TRAIN| LT=0.680 LP=0.085 LKL=8.470 LPS=0.402 LKLS=10.794 |
# Test F1: 0.9737
# Test ACC: 0.9610
# Test AUC: 0.9826
# Train F1: 0.9785
# 00550: TRAIN| LT=0.598 LP=0.062 LKL=8.374 LPS=0.345 LKLS=10.702 |
# Test F1: 0.9719
# Test ACC: 0.9582
# Test AUC: 0.9810
# Train F1: 0.9841
# 00600: TRAIN| LT=0.566 LP=0.054 LKL=8.448 LPS=0.320 LKLS=10.751 |
# Test F1: 0.9719
# Test ACC: 0.9582
# Test AUC: 0.9810
# Train F1: 0.9870
# 00650: TRAIN| LT=0.568 LP=0.064 LKL=8.429 LPS=0.310 LKLS=10.981 |
# Test F1: 0.9776
# Test ACC: 0.9666
# Test AUC: 0.9803
# Train F1: 0.9859
# 00700: TRAIN| LT=0.536 LP=0.066 LKL=8.427 LPS=0.278 LKLS=10.706 |
# Test F1: 0.9776
# Test ACC: 0.9666
# Test AUC: 0.9801
# Train F1: 0.9874
# 00750: TRAIN| LT=0.493 LP=0.062 LKL=8.362 LPS=0.241 LKLS=10.602 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9781
# Train F1: 0.9846
# 00800: TRAIN| LT=0.451 LP=0.045 LKL=8.355 LPS=0.216 LKLS=10.742 |
# Test F1: 0.9777
# Test ACC: 0.9666
# Test AUC: 0.9775
# Train F1: 0.9855
# 00850: TRAIN| LT=0.428 LP=0.039 LKL=8.361 LPS=0.200 LKLS=10.537 |
# Test F1: 0.9719
# Test ACC: 0.9582
# Test AUC: 0.9746
# Train F1: 0.9897
# 00900: TRAIN| LT=0.459 LP=0.051 LKL=8.127 LPS=0.225 LKLS=10.178 |
# Test F1: 0.9739
# Test ACC: 0.9610
# Test AUC: 0.9761
# Train F1: 0.9921
# 00950: TRAIN| LT=0.386 LP=0.031 LKL=8.211 LPS=0.170 LKLS=10.329 |
# Test F1: 0.9757
# Test ACC: 0.9638
# Test AUC: 0.9763
# Train F1: 0.9921
# 01000: TRAIN| LT=0.393 LP=0.038 LKL=8.215 LPS=0.173 LKLS=10.066 |
# Test F1: 0.9776
# Test ACC: 0.9666
# Test AUC: 0.9744
# Train F1: 0.9892
# 01050: TRAIN| LT=0.359 LP=0.043 LKL=8.134 LPS=0.134 LKLS=10.062 |
# Test F1: 0.9720
# Test ACC: 0.9582
# Test AUC: 0.9744
# Train F1: 0.9916
# 01100: TRAIN| LT=0.363 LP=0.047 LKL=8.103 LPS=0.139 LKLS=9.647 |
# Test F1: 0.9777
# Test ACC: 0.9666
# Test AUC: 0.9740
# Train F1: 0.9949
# 01150: TRAIN| LT=0.374 LP=0.036 LKL=8.093 LPS=0.163 LKLS=9.482 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9742
# Train F1: 0.9935
# 01200: TRAIN| LT=0.344 LP=0.032 LKL=8.137 LPS=0.137 LKLS=9.354 |
# Test F1: 0.9777
# Test ACC: 0.9666
# Test AUC: 0.9738
# Train F1: 0.9944
# 01250: TRAIN| LT=0.341 LP=0.037 LKL=8.007 LPS=0.132 LKLS=9.109 |
# Test F1: 0.9777
# Test ACC: 0.9666
# Test AUC: 0.9753
# Train F1: 0.9920
# 01300: TRAIN| LT=0.323 LP=0.037 LKL=8.072 LPS=0.109 LKLS=9.602 |
# Test F1: 0.9739
# Test ACC: 0.9610
# Test AUC: 0.9724
# Train F1: 0.9925
# 01350: TRAIN| LT=0.315 LP=0.028 LKL=8.105 LPS=0.115 LKLS=9.108 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9739
# Train F1: 0.9944
# 01400: TRAIN| LT=0.303 LP=0.033 LKL=8.106 LPS=0.100 LKLS=8.929 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9739
# Train F1: 0.9930
# 01450: TRAIN| LT=0.311 LP=0.032 LKL=7.996 LPS=0.112 LKLS=8.765 |
# Test F1: 0.9739
# Test ACC: 0.9610
# Test AUC: 0.9753
# Train F1: 0.9939
# 01500: TRAIN| LT=0.284 LP=0.043 LKL=7.908 LPS=0.076 LKLS=8.644 |
# Test F1: 0.9739
# Test ACC: 0.9610
# Test AUC: 0.9731
# Train F1: 0.9944
# 01550: TRAIN| LT=0.310 LP=0.021 LKL=7.946 LPS=0.125 LKLS=8.394 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9739
# Train F1: 0.9949
# 01600: TRAIN| LT=0.297 LP=0.030 LKL=7.873 LPS=0.107 LKLS=8.203 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9743
# Train F1: 0.9939
# 01650: TRAIN| LT=0.291 LP=0.019 LKL=7.896 LPS=0.110 LKLS=8.265 |
# Test F1: 0.9739
# Test ACC: 0.9610
# Test AUC: 0.9741
# Train F1: 0.9953
# 01700: TRAIN| LT=0.247 LP=0.019 LKL=7.794 LPS=0.070 LKLS=8.106 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9744
# Train F1: 0.9949
# 01750: TRAIN| LT=0.273 LP=0.021 LKL=7.818 LPS=0.094 LKLS=8.001 |
# Test F1: 0.9739
# Test ACC: 0.9610
# Test AUC: 0.9745
# Train F1: 0.9981
# 01800: TRAIN| LT=0.269 LP=0.017 LKL=7.829 LPS=0.093 LKLS=8.046 |
# Test F1: 0.9757
# Test ACC: 0.9638
# Test AUC: 0.9733
# Train F1: 0.9958
# 01850: TRAIN| LT=0.253 LP=0.019 LKL=7.865 LPS=0.076 LKLS=7.984 |
# Test F1: 0.9757
# Test ACC: 0.9638
# Test AUC: 0.9733
# Train F1: 0.9972
# 01900: TRAIN| LT=0.222 LP=0.015 LKL=7.900 LPS=0.044 LKLS=8.402 |
# Test F1: 0.9738
# Test ACC: 0.9610
# Test AUC: 0.9737
# Train F1: 0.9963
# 01950: TRAIN| LT=0.266 LP=0.012 LKL=7.745 LPS=0.097 LKLS=7.901 |
# Test F1: 0.9738
# Test ACC: 0.9610
# Test AUC: 0.9741
# Train F1: 0.9916
# 02000: TRAIN| LT=0.282 LP=0.029 LKL=7.579 LPS=0.103 LKLS=7.368 |
# Test F1: 0.9758
# Test ACC: 0.9638
# Test AUC: 0.9728
# f1: 0.9776951672862454
# acc: 0.9665738161559888
# auc: 0.9774873799055528
# f1 [0.9759704251386322, 0.9685767097966728, 0.9760589318600369, 0.977859778597786, 0.9776951672862454]
# average f1: 0.9752322025358746±0.0034203622296744827
# acc [0.9638888888888889, 0.9526462395543176, 0.9637883008356546, 0.9665738161559888, 0.9665738161559888]
# average acc: 0.9626942123181678±0.00517085467466787
# auc [0.9812621674237507, 0.9781859931113662, 0.9910641589317701, 0.9921022634750041, 0.9774873799055528]
# average auc: 0.9840203925694887±0.006312837069947101
