# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'H':0,'C':1,'D':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (444, 1034) (444, 43) (444, 1)
# Index(['1.T.0', '1.T.1', '1.T.2', '1.T.3', '1.T.4', '1.T.5', '1.T.6', '10.T.0',
#        '10.T.1', '10.T.2',
#        ...
#        '8.T.4', '8.T.5', '8.T.6', '9.T.0', '9.T.1', '9.T.2', '9.T.3', '9.T.4',
#        '9.T.6', '9.T.Flare'],
#       dtype='object', name='Sample', length=444)
# 数据完整率missing_rate : 1.0
# 集合所有样本重构数据表： (444, 1034) (444, 43) (444, 1)
# 标签转换为one-hot编码： (444, 2) 139.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 4, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1', f1_cv)
print('average f1: {}±{}'.format(np.mean(f1_cv), np.std(f1_cv)))
print('acc', acc_cv)
print('average acc: {}±{}'.format(np.mean(acc_cv), np.std(acc_cv)))
print('auc', auc_cv)
print('average auc: {}±{}'.format(np.mean(auc_cv), np.std(auc_cv)))
# Out:
# Train F1: 0.8294
# 00050: TRAIN| LT=1.662 LP=0.497 LKL=11.711 LPS=0.940 LKLS=10.799 |
# Test F1: 0.8133
# Test ACC: 0.6854
# Test AUC: 0.9672
# Train F1: 0.9634
# 00100: TRAIN| LT=1.150 LP=0.170 LKL=12.060 LPS=0.732 LKLS=12.720 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9889
# Train F1: 0.9775
# 00150: TRAIN| LT=1.033 LP=0.112 LKL=11.980 LPS=0.693 LKLS=10.853 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9906
# Train F1: 0.9772
# 00200: TRAIN| LT=1.027 LP=0.109 LKL=11.942 LPS=0.701 LKLS=9.790 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9900
# Train F1: 0.9753
# 00250: TRAIN| LT=0.970 LP=0.070 LKL=11.882 LPS=0.691 LKLS=9.047 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9912
# Train F1: 0.9775
# 00300: TRAIN| LT=0.941 LP=0.064 LKL=11.872 LPS=0.670 LKLS=8.866 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9895
# Train F1: 0.9857
# 00350: TRAIN| LT=0.958 LP=0.076 LKL=11.920 LPS=0.670 LKLS=9.206 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9900
# Train F1: 0.9836
# 00400: TRAIN| LT=0.990 LP=0.089 LKL=12.050 LPS=0.688 LKLS=9.230 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9895
# Train F1: 0.9774
# 00450: TRAIN| LT=0.962 LP=0.094 LKL=11.829 LPS=0.668 LKLS=8.136 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9900
# Train F1: 0.9816
# 00500: TRAIN| LT=0.951 LP=0.064 LKL=11.929 LPS=0.684 LKLS=8.446 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9895
# Train F1: 0.9794
# 00550: TRAIN| LT=0.955 LP=0.100 LKL=11.725 LPS=0.665 LKLS=7.375 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9889
# Train F1: 0.9877
# 00600: TRAIN| LT=0.960 LP=0.094 LKL=11.852 LPS=0.669 LKLS=7.800 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9912
# Train F1: 0.9755
# 00650: TRAIN| LT=0.922 LP=0.067 LKL=11.840 LPS=0.661 LKLS=7.506 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9883
# Train F1: 0.9775
# 00700: TRAIN| LT=0.911 LP=0.048 LKL=11.895 LPS=0.667 LKLS=7.695 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9906
# Train F1: 0.9835
# 00750: TRAIN| LT=0.962 LP=0.098 LKL=11.964 LPS=0.666 LKLS=7.790 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9924
# Train F1: 0.9817
# 00800: TRAIN| LT=0.895 LP=0.039 LKL=11.938 LPS=0.660 LKLS=7.685 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9900
# Train F1: 0.9817
# 00850: TRAIN| LT=0.909 LP=0.050 LKL=11.895 LPS=0.662 LKLS=7.881 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9900
# Train F1: 0.9774
# 00900: TRAIN| LT=0.918 LP=0.055 LKL=12.091 LPS=0.667 LKLS=7.525 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9895
# Train F1: 0.9898
# 00950: TRAIN| LT=0.890 LP=0.049 LKL=11.921 LPS=0.647 LKLS=7.472 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9918
# Train F1: 0.9837
# 01000: TRAIN| LT=0.889 LP=0.053 LKL=11.743 LPS=0.649 LKLS=6.897 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9895
# Train F1: 0.9857
# 01050: TRAIN| LT=0.888 LP=0.037 LKL=11.923 LPS=0.658 LKLS=7.374 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9883
# Train F1: 0.9857
# 01100: TRAIN| LT=0.918 LP=0.053 LKL=12.200 LPS=0.667 LKLS=7.612 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9889
# Train F1: 0.9796
# 01150: TRAIN| LT=0.903 LP=0.062 LKL=11.947 LPS=0.654 LKLS=6.769 |
# Test F1: 0.9412
# Test ACC: 0.9213
# Test AUC: 0.9859
# Train F1: 0.9878
# 01200: TRAIN| LT=0.897 LP=0.040 LKL=11.786 LPS=0.670 LKLS=6.911 |
# Test F1: 0.9587
# Test ACC: 0.9438
# Test AUC: 0.9877
# Train F1: 0.9816
# 01250: TRAIN| LT=0.930 LP=0.055 LKL=11.993 LPS=0.685 LKLS=6.982 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9871
# Train F1: 0.9877
# 01300: TRAIN| LT=0.911 LP=0.069 LKL=11.957 LPS=0.656 LKLS=6.625 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9865
# Train F1: 0.9898
# 01350: TRAIN| LT=0.871 LP=0.030 LKL=12.131 LPS=0.649 LKLS=7.140 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9836
# Train F1: 0.9836
# 01400: TRAIN| LT=0.903 LP=0.055 LKL=11.927 LPS=0.664 LKLS=6.383 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9842
# Train F1: 0.9856
# 01450: TRAIN| LT=0.911 LP=0.071 LKL=12.120 LPS=0.655 LKLS=6.378 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9871
# Train F1: 0.9772
# 01500: TRAIN| LT=0.907 LP=0.062 LKL=11.668 LPS=0.668 LKLS=6.008 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9830
# Train F1: 0.9837
# 01550: TRAIN| LT=0.870 LP=0.042 LKL=11.935 LPS=0.646 LKLS=6.236 |
# Test F1: 0.9580
# Test ACC: 0.9438
# Test AUC: 0.9830
# Train F1: 0.9836
# 01600: TRAIN| LT=0.860 LP=0.040 LKL=11.981 LPS=0.637 LKLS=6.259 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9801
# Train F1: 0.9897
# 01650: TRAIN| LT=0.870 LP=0.039 LKL=12.012 LPS=0.650 LKLS=6.126 |
# Test F1: 0.9492
# Test ACC: 0.9326
# Test AUC: 0.9819
# Train F1: 0.9857
# 01700: TRAIN| LT=0.872 LP=0.035 LKL=12.099 LPS=0.650 LKLS=6.696 |
# Test F1: 0.9587
# Test ACC: 0.9438
# Test AUC: 0.9836
# Train F1: 0.9856
# 01750: TRAIN| LT=0.881 LP=0.042 LKL=12.288 LPS=0.654 LKLS=6.213 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9854
# Train F1: 0.9897
# 01800: TRAIN| LT=0.888 LP=0.054 LKL=12.079 LPS=0.652 LKLS=6.095 |
# Test F1: 0.9587
# Test ACC: 0.9438
# Test AUC: 0.9836
# Train F1: 0.9918
# 01850: TRAIN| LT=0.875 LP=0.055 LKL=11.940 LPS=0.642 LKLS=5.863 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9854
# Train F1: 0.9856
# 01900: TRAIN| LT=0.878 LP=0.028 LKL=11.980 LPS=0.673 LKLS=5.807 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9801
# Train F1: 0.9897
# 01950: TRAIN| LT=0.884 LP=0.040 LKL=11.955 LPS=0.670 LKLS=5.393 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9824
# Train F1: 0.9918
# 02000: TRAIN| LT=0.864 LP=0.045 LKL=11.776 LPS=0.648 LKLS=5.376 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9801
# f1: 0.9586776859504132
# acc: 0.9438202247191011
# auc: 0.9877049180327868
# Train F1: 0.8556
# 00050: TRAIN| LT=1.547 LP=0.419 LKL=12.072 LPS=0.875 LKLS=13.214 |
# Test F1: 0.9606
# Test ACC: 0.9438
# Test AUC: 0.9959
# Train F1: 0.9795
# 00100: TRAIN| LT=1.163 LP=0.170 LKL=12.323 LPS=0.752 LKLS=11.768 |
# Test F1: 0.9833
# Test ACC: 0.9775
# Test AUC: 0.9988
# Train F1: 0.9711
# 00150: TRAIN| LT=1.046 LP=0.112 LKL=12.352 LPS=0.701 LKLS=10.951 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9971
# Train F1: 0.9735
# 00200: TRAIN| LT=1.036 LP=0.108 LKL=12.060 LPS=0.714 LKLS=9.405 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9971
# Train F1: 0.9814
# 00250: TRAIN| LT=1.036 LP=0.110 LKL=12.296 LPS=0.712 LKLS=9.163 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9817
# 00300: TRAIN| LT=0.994 LP=0.082 LKL=12.129 LPS=0.701 LKLS=8.975 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9959
# Train F1: 0.9753
# 00350: TRAIN| LT=1.018 LP=0.120 LKL=11.903 LPS=0.701 LKLS=7.811 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9796
# 00400: TRAIN| LT=0.990 LP=0.112 LKL=11.777 LPS=0.688 LKLS=7.203 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9777
# 00450: TRAIN| LT=0.992 LP=0.104 LKL=11.936 LPS=0.693 LKLS=7.522 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9754
# 00500: TRAIN| LT=0.953 LP=0.051 LKL=12.027 LPS=0.703 LKLS=7.844 |
# Test F1: 0.9917
# Test ACC: 0.9888
# Test AUC: 0.9965
# Train F1: 0.9856
# 00550: TRAIN| LT=0.978 LP=0.091 LKL=11.945 LPS=0.689 LKLS=7.828 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9965
# Train F1: 0.9815
# 00600: TRAIN| LT=0.975 LP=0.114 LKL=12.043 LPS=0.666 LKLS=7.516 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9971
# Train F1: 0.9775
# 00650: TRAIN| LT=0.954 LP=0.080 LKL=11.976 LPS=0.678 LKLS=7.705 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9930
# Train F1: 0.9817
# 00700: TRAIN| LT=0.939 LP=0.077 LKL=11.822 LPS=0.675 LKLS=6.931 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9836
# Train F1: 0.9858
# 00750: TRAIN| LT=0.959 LP=0.077 LKL=12.344 LPS=0.679 LKLS=7.932 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9900
# Train F1: 0.9878
# 00800: TRAIN| LT=0.937 LP=0.067 LKL=12.133 LPS=0.675 LKLS=7.442 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9936
# Train F1: 0.9796
# 00850: TRAIN| LT=0.941 LP=0.068 LKL=12.206 LPS=0.679 LKLS=7.130 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9842
# Train F1: 0.9773
# 00900: TRAIN| LT=0.918 LP=0.086 LKL=11.976 LPS=0.649 LKLS=6.322 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9842
# Train F1: 0.9795
# 00950: TRAIN| LT=0.919 LP=0.055 LKL=12.204 LPS=0.674 LKLS=6.846 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9871
# Train F1: 0.9877
# 01000: TRAIN| LT=0.910 LP=0.039 LKL=12.112 LPS=0.681 LKLS=6.798 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9865
# Train F1: 0.9879
# 01050: TRAIN| LT=0.914 LP=0.069 LKL=11.915 LPS=0.662 LKLS=6.439 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9813
# Train F1: 0.9858
# 01100: TRAIN| LT=0.887 LP=0.045 LKL=11.985 LPS=0.660 LKLS=6.257 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9696
# Train F1: 0.9856
# 01150: TRAIN| LT=0.920 LP=0.076 LKL=12.222 LPS=0.656 LKLS=6.610 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9912
# Train F1: 0.9856
# 01200: TRAIN| LT=0.908 LP=0.050 LKL=12.217 LPS=0.671 LKLS=6.469 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9737
# Train F1: 0.9856
# 01250: TRAIN| LT=0.924 LP=0.079 LKL=12.157 LPS=0.666 LKLS=5.700 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9813
# Train F1: 0.9837
# 01300: TRAIN| LT=0.864 LP=0.046 LKL=12.059 LPS=0.641 LKLS=5.655 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9918
# Train F1: 0.9817
# 01350: TRAIN| LT=0.881 LP=0.042 LKL=11.795 LPS=0.669 LKLS=5.204 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9778
# Train F1: 0.9918
# 01400: TRAIN| LT=0.878 LP=0.047 LKL=11.901 LPS=0.659 LKLS=5.361 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9836
# Train F1: 0.9877
# 01450: TRAIN| LT=0.869 LP=0.040 LKL=11.746 LPS=0.659 LKLS=5.234 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9865
# Train F1: 0.9878
# 01500: TRAIN| LT=0.893 LP=0.045 LKL=11.763 LPS=0.679 LKLS=5.117 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9830
# Train F1: 0.9857
# 01550: TRAIN| LT=0.876 LP=0.054 LKL=11.490 LPS=0.657 LKLS=5.061 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9813
# Train F1: 0.9919
# 01600: TRAIN| LT=0.873 LP=0.049 LKL=11.596 LPS=0.656 LKLS=5.096 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9865
# Train F1: 0.9918
# 01650: TRAIN| LT=0.856 LP=0.037 LKL=11.729 LPS=0.655 LKLS=4.615 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9842
# Train F1: 0.9858
# 01700: TRAIN| LT=0.872 LP=0.052 LKL=11.628 LPS=0.658 LKLS=4.572 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9883
# Train F1: 0.9898
# 01750: TRAIN| LT=0.871 LP=0.052 LKL=11.836 LPS=0.656 LKLS=4.449 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9824
# Train F1: 0.9857
# 01800: TRAIN| LT=0.847 LP=0.039 LKL=11.517 LPS=0.651 LKLS=4.195 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9742
# Train F1: 0.9939
# 01850: TRAIN| LT=0.856 LP=0.036 LKL=11.574 LPS=0.662 LKLS=4.268 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9719
# Train F1: 0.9919
# 01900: TRAIN| LT=0.869 LP=0.052 LKL=11.610 LPS=0.659 LKLS=4.190 |
# Test F1: 0.9600
# Test ACC: 0.9438
# Test AUC: 0.9760
# Train F1: 0.9877
# 01950: TRAIN| LT=0.841 LP=0.037 LKL=11.452 LPS=0.649 LKLS=4.094 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9819
# Train F1: 0.9857
# 02000: TRAIN| LT=0.846 LP=0.034 LKL=11.427 LPS=0.656 LKLS=4.078 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9760
# f1: 0.9917355371900827
# acc: 0.9887640449438202
# auc: 0.9970725995316159
# Train F1: 0.8768
# 00050: TRAIN| LT=1.552 LP=0.435 LKL=12.082 LPS=0.867 LKLS=12.930 |
# Test F1: 0.9077
# Test ACC: 0.8652
# Test AUC: 0.9233
# Train F1: 0.9754
# 00100: TRAIN| LT=1.081 LP=0.120 LKL=12.343 LPS=0.703 LKLS=13.435 |
# Test F1: 0.9500
# Test ACC: 0.9326
# Test AUC: 0.9432
# Train F1: 0.9753
# 00150: TRAIN| LT=0.986 LP=0.088 LKL=12.018 LPS=0.669 LKLS=10.778 |
# Test F1: 0.9421
# Test ACC: 0.9213
# Test AUC: 0.9520
# Train F1: 0.9817
# 00200: TRAIN| LT=0.958 LP=0.060 LKL=11.907 LPS=0.686 LKLS=9.317 |
# Test F1: 0.9587
# Test ACC: 0.9438
# Test AUC: 0.9532
# Train F1: 0.9773
# 00250: TRAIN| LT=0.943 LP=0.064 LKL=11.827 LPS=0.671 LKLS=8.925 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9479
# Train F1: 0.9835
# 00300: TRAIN| LT=0.914 LP=0.048 LKL=12.088 LPS=0.652 LKLS=9.305 |
# Test F1: 0.9421
# Test ACC: 0.9213
# Test AUC: 0.9508
# Train F1: 0.9816
# 00350: TRAIN| LT=0.918 LP=0.062 LKL=11.764 LPS=0.658 LKLS=7.968 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9491
# Train F1: 0.9696
# 00400: TRAIN| LT=0.923 LP=0.054 LKL=11.856 LPS=0.667 LKLS=8.362 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9473
# Train F1: 0.9897
# 00450: TRAIN| LT=0.921 LP=0.059 LKL=11.817 LPS=0.669 LKLS=7.460 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9496
# Train F1: 0.9857
# 00500: TRAIN| LT=0.919 LP=0.062 LKL=11.930 LPS=0.656 LKLS=8.224 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9508
# Train F1: 0.9857
# 00550: TRAIN| LT=0.945 LP=0.094 LKL=11.799 LPS=0.662 LKLS=7.091 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9491
# Train F1: 0.9816
# 00600: TRAIN| LT=0.917 LP=0.049 LKL=11.862 LPS=0.677 LKLS=7.283 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9555
# Train F1: 0.9857
# 00650: TRAIN| LT=0.928 LP=0.056 LKL=11.789 LPS=0.681 LKLS=7.261 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9461
# Train F1: 0.9796
# 00700: TRAIN| LT=0.917 LP=0.055 LKL=11.830 LPS=0.670 LKLS=7.373 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9479
# Train F1: 0.9816
# 00750: TRAIN| LT=0.912 LP=0.059 LKL=11.867 LPS=0.660 LKLS=7.405 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9502
# Train F1: 0.9857
# 00800: TRAIN| LT=0.908 LP=0.049 LKL=11.870 LPS=0.669 LKLS=7.161 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9526
# Train F1: 0.9897
# 00850: TRAIN| LT=0.912 LP=0.074 LKL=11.831 LPS=0.654 LKLS=6.630 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9537
# Train F1: 0.9856
# 00900: TRAIN| LT=0.916 LP=0.067 LKL=12.063 LPS=0.655 LKLS=7.283 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9555
# Train F1: 0.9835
# 00950: TRAIN| LT=0.892 LP=0.051 LKL=11.813 LPS=0.655 LKLS=6.894 |
# Test F1: 0.9677
# Test ACC: 0.9551
# Test AUC: 0.9561
# Train F1: 0.9854
# 01000: TRAIN| LT=0.909 LP=0.067 LKL=11.845 LPS=0.660 LKLS=6.281 |
# Test F1: 0.9421
# Test ACC: 0.9213
# Test AUC: 0.9555
# Train F1: 0.9836
# 01050: TRAIN| LT=0.899 LP=0.043 LKL=12.081 LPS=0.667 LKLS=6.884 |
# Test F1: 0.9421
# Test ACC: 0.9213
# Test AUC: 0.9567
# Train F1: 0.9877
# 01100: TRAIN| LT=0.898 LP=0.042 LKL=12.132 LPS=0.667 LKLS=6.737 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9514
# Train F1: 0.9877
# 01150: TRAIN| LT=0.891 LP=0.053 LKL=11.991 LPS=0.653 LKLS=6.484 |
# Test F1: 0.9593
# Test ACC: 0.9438
# Test AUC: 0.9537
# Train F1: 0.9918
# 01200: TRAIN| LT=0.902 LP=0.056 LKL=12.006 LPS=0.665 LKLS=6.069 |
# Test F1: 0.9421
# Test ACC: 0.9213
# Test AUC: 0.9573
# Train F1: 0.9897
# 01250: TRAIN| LT=0.887 LP=0.036 LKL=12.061 LPS=0.670 LKLS=6.093 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9520
# Train F1: 0.9878
# 01300: TRAIN| LT=0.878 LP=0.035 LKL=11.797 LPS=0.668 LKLS=5.620 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9508
# Train F1: 0.9877
# 01350: TRAIN| LT=0.873 LP=0.053 LKL=11.774 LPS=0.648 LKLS=5.500 |
# Test F1: 0.9421
# Test ACC: 0.9213
# Test AUC: 0.9508
# Train F1: 0.9938
# 01400: TRAIN| LT=0.878 LP=0.050 LKL=11.715 LPS=0.661 LKLS=5.004 |
# Test F1: 0.9421
# Test ACC: 0.9213
# Test AUC: 0.9631
# Train F1: 0.9898
# 01450: TRAIN| LT=0.877 LP=0.031 LKL=12.237 LPS=0.665 LKLS=5.829 |
# Test F1: 0.9421
# Test ACC: 0.9213
# Test AUC: 0.9514
# Train F1: 0.9918
# 01500: TRAIN| LT=0.848 LP=0.035 LKL=11.738 LPS=0.644 LKLS=5.151 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9514
# Train F1: 0.9897
# 01550: TRAIN| LT=0.864 LP=0.039 LKL=11.737 LPS=0.657 LKLS=4.993 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9567
# Train F1: 0.9897
# 01600: TRAIN| LT=0.840 LP=0.027 LKL=11.732 LPS=0.645 LKLS=5.021 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9608
# Train F1: 0.9918
# 01650: TRAIN| LT=0.858 LP=0.027 LKL=11.696 LPS=0.663 LKLS=5.001 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9584
# Train F1: 0.9918
# 01700: TRAIN| LT=0.862 LP=0.038 LKL=11.728 LPS=0.661 LKLS=4.531 |
# Test F1: 0.9421
# Test ACC: 0.9213
# Test AUC: 0.9578
# Train F1: 0.9897
# 01750: TRAIN| LT=0.862 LP=0.038 LKL=11.771 LPS=0.659 LKLS=4.723 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9567
# Train F1: 0.9857
# 01800: TRAIN| LT=0.832 LP=0.028 LKL=11.613 LPS=0.644 LKLS=4.362 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9555
# Train F1: 0.9877
# 01850: TRAIN| LT=0.849 LP=0.035 LKL=11.293 LPS=0.659 LKLS=4.161 |
# Test F1: 0.9421
# Test ACC: 0.9213
# Test AUC: 0.9584
# Train F1: 0.9836
# 01900: TRAIN| LT=0.830 LP=0.028 LKL=11.698 LPS=0.639 LKLS=4.606 |
# Test F1: 0.9431
# Test ACC: 0.9213
# Test AUC: 0.9567
# Train F1: 0.9959
# 01950: TRAIN| LT=0.843 LP=0.029 LKL=11.360 LPS=0.660 LKLS=4.032 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9573
# Train F1: 0.9857
# 02000: TRAIN| LT=0.838 LP=0.038 LKL=11.329 LPS=0.647 LKLS=3.869 |
# Test F1: 0.9508
# Test ACC: 0.9326
# Test AUC: 0.9514
# f1: 0.9677419354838709
# acc: 0.9550561797752809
# auc: 0.9560889929742389
# Train F1: 0.8393
# 00050: TRAIN| LT=1.699 LP=0.500 LKL=11.764 LPS=0.985 LKLS=9.640 |
# Test F1: 0.8592
# Test ACC: 0.7753
# Test AUC: 0.9877
# Train F1: 0.9695
# 00100: TRAIN| LT=1.167 LP=0.151 LKL=12.940 LPS=0.742 LKLS=14.390 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9631
# Train F1: 0.9696
# 00150: TRAIN| LT=1.012 LP=0.093 LKL=12.312 LPS=0.687 LKLS=10.944 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9625
# Train F1: 0.9718
# 00200: TRAIN| LT=1.004 LP=0.096 LKL=12.223 LPS=0.677 LKLS=10.839 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9333
# Train F1: 0.9776
# 00250: TRAIN| LT=0.964 LP=0.069 LKL=12.018 LPS=0.681 LKLS=9.309 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9297
# Train F1: 0.9816
# 00300: TRAIN| LT=0.953 LP=0.083 LKL=12.001 LPS=0.655 LKLS=9.488 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9309
# Train F1: 0.9645
# 00350: TRAIN| LT=0.954 LP=0.086 LKL=11.873 LPS=0.669 LKLS=8.059 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9280
# Train F1: 0.9796
# 00400: TRAIN| LT=0.913 LP=0.051 LKL=12.013 LPS=0.654 LKLS=8.812 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9292
# Train F1: 0.9836
# 00450: TRAIN| LT=0.942 LP=0.082 LKL=11.896 LPS=0.662 LKLS=8.017 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9262
# Train F1: 0.9834
# 00500: TRAIN| LT=0.895 LP=0.047 LKL=12.019 LPS=0.644 LKLS=8.385 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9239
# Train F1: 0.9817
# 00550: TRAIN| LT=0.884 LP=0.037 LKL=12.083 LPS=0.641 LKLS=8.489 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9240
# Train F1: 0.9918
# 00600: TRAIN| LT=0.898 LP=0.049 LKL=11.919 LPS=0.654 LKLS=7.648 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9221
# Train F1: 0.9877
# 00650: TRAIN| LT=0.883 LP=0.043 LKL=11.852 LPS=0.650 LKLS=7.168 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9210
# Train F1: 0.9857
# 00700: TRAIN| LT=0.878 LP=0.033 LKL=12.104 LPS=0.643 LKLS=8.088 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9233
# Train F1: 0.9918
# 00750: TRAIN| LT=0.870 LP=0.036 LKL=12.066 LPS=0.638 LKLS=7.533 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9198
# Train F1: 0.9878
# 00800: TRAIN| LT=0.882 LP=0.044 LKL=12.107 LPS=0.643 LKLS=7.403 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9251
# Train F1: 0.9837
# 00850: TRAIN| LT=0.895 LP=0.046 LKL=12.210 LPS=0.647 LKLS=7.955 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9186
# Train F1: 0.9898
# 00900: TRAIN| LT=0.880 LP=0.044 LKL=12.163 LPS=0.642 LKLS=7.354 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9204
# Train F1: 0.9876
# 00950: TRAIN| LT=0.895 LP=0.041 LKL=12.309 LPS=0.659 LKLS=7.217 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9215
# Train F1: 0.9878
# 01000: TRAIN| LT=0.872 LP=0.037 LKL=12.268 LPS=0.640 LKLS=7.216 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9246
# Train F1: 0.9877
# 01050: TRAIN| LT=0.886 LP=0.061 LKL=12.031 LPS=0.638 LKLS=6.636 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9227
# Train F1: 0.9898
# 01100: TRAIN| LT=0.876 LP=0.039 LKL=12.126 LPS=0.646 LKLS=7.026 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9262
# Train F1: 0.9918
# 01150: TRAIN| LT=0.880 LP=0.047 LKL=12.066 LPS=0.647 LKLS=6.534 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9217
# Train F1: 0.9939
# 01200: TRAIN| LT=0.906 LP=0.051 LKL=12.096 LPS=0.671 LKLS=6.297 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9204
# Train F1: 0.9959
# 01250: TRAIN| LT=0.862 LP=0.019 LKL=12.608 LPS=0.646 LKLS=7.173 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9239
# Train F1: 0.9959
# 01300: TRAIN| LT=0.856 LP=0.029 LKL=12.066 LPS=0.648 LKLS=5.958 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9211
# Train F1: 0.9878
# 01350: TRAIN| LT=0.846 LP=0.026 LKL=12.027 LPS=0.643 LKLS=5.735 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9202
# Train F1: 0.9938
# 01400: TRAIN| LT=0.845 LP=0.023 LKL=12.100 LPS=0.642 LKLS=5.902 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9207
# Train F1: 0.9959
# 01450: TRAIN| LT=0.826 LP=0.020 LKL=11.871 LPS=0.635 LKLS=5.111 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9174
# Train F1: 0.9939
# 01500: TRAIN| LT=0.855 LP=0.024 LKL=11.982 LPS=0.658 LKLS=5.347 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9243
# Train F1: 0.9938
# 01550: TRAIN| LT=0.842 LP=0.027 LKL=11.914 LPS=0.645 LKLS=5.115 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9233
# Train F1: 0.9959
# 01600: TRAIN| LT=0.830 LP=0.025 LKL=12.031 LPS=0.633 LKLS=5.146 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9211
# Train F1: 0.9959
# 01650: TRAIN| LT=0.823 LP=0.016 LKL=12.075 LPS=0.634 LKLS=5.215 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9213
# Train F1: 0.9918
# 01700: TRAIN| LT=0.831 LP=0.028 LKL=12.137 LPS=0.631 LKLS=4.993 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9195
# Train F1: 0.9959
# 01750: TRAIN| LT=0.847 LP=0.021 LKL=12.314 LPS=0.652 LKLS=5.115 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9201
# Train F1: 0.9918
# 01800: TRAIN| LT=0.828 LP=0.027 LKL=11.935 LPS=0.634 LKLS=4.732 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9210
# Train F1: 0.9898
# 01850: TRAIN| LT=0.827 LP=0.029 LKL=11.918 LPS=0.632 LKLS=4.665 |
# Test F1: 0.9756
# Test ACC: 0.9663
# Test AUC: 0.9213
# Train F1: 0.9938
# 01900: TRAIN| LT=0.849 LP=0.042 LKL=11.854 LPS=0.643 LKLS=4.563 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9218
# Train F1: 0.9979
# 01950: TRAIN| LT=0.841 LP=0.016 LKL=11.564 LPS=0.669 LKLS=4.003 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9191
# Train F1: 0.9939
# 02000: TRAIN| LT=0.813 LP=0.022 LKL=11.595 LPS=0.635 LKLS=3.994 |
# Test F1: 0.9672
# Test ACC: 0.9551
# Test AUC: 0.9233
# f1: 0.975609756097561
# acc: 0.9662921348314607
# auc: 0.9631147540983607
# Train F1: 0.8885
# 00050: TRAIN| LT=1.559 LP=0.442 LKL=12.221 LPS=0.866 LKLS=12.904 |
# Test F1: 0.9440
# Test ACC: 0.9205
# Test AUC: 0.9794
# Train F1: 0.9714
# 00100: TRAIN| LT=1.111 LP=0.139 LKL=12.386 LPS=0.723 LKLS=12.494 |
# Test F1: 0.9508
# Test ACC: 0.9318
# Test AUC: 0.9897
# Train F1: 0.9611
# 00150: TRAIN| LT=1.072 LP=0.129 LKL=11.898 LPS=0.727 LKLS=9.711 |
# Test F1: 0.9508
# Test ACC: 0.9318
# Test AUC: 0.9897
# Train F1: 0.9756
# 00200: TRAIN| LT=1.000 LP=0.094 LKL=11.899 LPS=0.694 LKLS=9.368 |
# Test F1: 0.9587
# Test ACC: 0.9432
# Test AUC: 0.9915
# Train F1: 0.9794
# 00250: TRAIN| LT=1.013 LP=0.089 LKL=12.046 LPS=0.709 LKLS=9.464 |
# Test F1: 0.9587
# Test ACC: 0.9432
# Test AUC: 0.9933
# Train F1: 0.9773
# 00300: TRAIN| LT=1.006 LP=0.114 LKL=11.816 LPS=0.689 LKLS=8.480 |
# Test F1: 0.9587
# Test ACC: 0.9432
# Test AUC: 0.9939
# Train F1: 0.9774
# 00350: TRAIN| LT=0.963 LP=0.090 LKL=11.944 LPS=0.667 LKLS=8.607 |
# Test F1: 0.9587
# Test ACC: 0.9432
# Test AUC: 0.9945
# Train F1: 0.9857
# 00400: TRAIN| LT=0.948 LP=0.077 LKL=11.911 LPS=0.667 LKLS=8.530 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9891
# Train F1: 0.9797
# 00450: TRAIN| LT=0.973 LP=0.096 LKL=11.916 LPS=0.678 LKLS=8.049 |
# Test F1: 0.9593
# Test ACC: 0.9432
# Test AUC: 0.9921
# Train F1: 0.9897
# 00500: TRAIN| LT=0.964 LP=0.078 LKL=11.913 LPS=0.687 LKLS=7.964 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9945
# Train F1: 0.9756
# 00550: TRAIN| LT=0.981 LP=0.088 LKL=12.045 LPS=0.689 LKLS=8.369 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9927
# Train F1: 0.9816
# 00600: TRAIN| LT=0.953 LP=0.081 LKL=11.858 LPS=0.679 LKLS=7.385 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9933
# Train F1: 0.9837
# 00650: TRAIN| LT=0.906 LP=0.057 LKL=11.797 LPS=0.659 LKLS=7.258 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9915
# Train F1: 0.9773
# 00700: TRAIN| LT=0.938 LP=0.071 LKL=11.875 LPS=0.678 LKLS=7.098 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9927
# Train F1: 0.9776
# 00750: TRAIN| LT=0.935 LP=0.076 LKL=11.853 LPS=0.670 LKLS=7.052 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9909
# Train F1: 0.9837
# 00800: TRAIN| LT=0.912 LP=0.059 LKL=11.689 LPS=0.670 LKLS=6.563 |
# Test F1: 0.9600
# Test ACC: 0.9432
# Test AUC: 0.9927
# Train F1: 0.9898
# 00850: TRAIN| LT=0.951 LP=0.093 LKL=11.907 LPS=0.667 LKLS=7.267 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9927
# Train F1: 0.9754
# 00900: TRAIN| LT=0.900 LP=0.055 LKL=11.894 LPS=0.652 LKLS=7.322 |
# Test F1: 0.9600
# Test ACC: 0.9432
# Test AUC: 0.9921
# Train F1: 0.9856
# 00950: TRAIN| LT=0.959 LP=0.085 LKL=12.012 LPS=0.680 LKLS=7.390 |
# Test F1: 0.9593
# Test ACC: 0.9432
# Test AUC: 0.9933
# Train F1: 0.9856
# 01000: TRAIN| LT=0.906 LP=0.073 LKL=11.936 LPS=0.645 LKLS=6.809 |
# Test F1: 0.9593
# Test ACC: 0.9432
# Test AUC: 0.9909
# Train F1: 0.9918
# 01050: TRAIN| LT=0.897 LP=0.042 LKL=11.968 LPS=0.666 LKLS=6.894 |
# Test F1: 0.9677
# Test ACC: 0.9545
# Test AUC: 0.9909
# Train F1: 0.9856
# 01100: TRAIN| LT=0.891 LP=0.055 LKL=11.949 LPS=0.651 LKLS=6.627 |
# Test F1: 0.9593
# Test ACC: 0.9432
# Test AUC: 0.9909
# Train F1: 0.9794
# 01150: TRAIN| LT=0.944 LP=0.071 LKL=11.993 LPS=0.692 LKLS=6.096 |
# Test F1: 0.9593
# Test ACC: 0.9432
# Test AUC: 0.9860
# Train F1: 0.9837
# 01200: TRAIN| LT=0.874 LP=0.032 LKL=11.785 LPS=0.660 LKLS=6.408 |
# Test F1: 0.9600
# Test ACC: 0.9432
# Test AUC: 0.9897
# Train F1: 0.9857
# 01250: TRAIN| LT=0.897 LP=0.068 LKL=11.760 LPS=0.652 LKLS=6.005 |
# Test F1: 0.9516
# Test ACC: 0.9318
# Test AUC: 0.9891
# Train F1: 0.9815
# 01300: TRAIN| LT=0.899 LP=0.064 LKL=11.988 LPS=0.655 LKLS=5.957 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9854
# Train F1: 0.9857
# 01350: TRAIN| LT=0.900 LP=0.050 LKL=11.824 LPS=0.671 LKLS=6.039 |
# Test F1: 0.9593
# Test ACC: 0.9432
# Test AUC: 0.9866
# Train F1: 0.9856
# 01400: TRAIN| LT=0.862 LP=0.031 LKL=11.842 LPS=0.652 LKLS=5.951 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9860
# Train F1: 0.9836
# 01450: TRAIN| LT=0.864 LP=0.028 LKL=11.804 LPS=0.664 LKLS=5.432 |
# Test F1: 0.9672
# Test ACC: 0.9545
# Test AUC: 0.9872
# Train F1: 0.9878
# 01500: TRAIN| LT=0.877 LP=0.040 LKL=11.983 LPS=0.657 LKLS=6.081 |
# Test F1: 0.9516
# Test ACC: 0.9318
# Test AUC: 0.9879
# Train F1: 0.9877
# 01550: TRAIN| LT=0.878 LP=0.047 LKL=11.825 LPS=0.657 LKLS=5.669 |
# Test F1: 0.9593
# Test ACC: 0.9432
# Test AUC: 0.9879
# Train F1: 0.9836
# 01600: TRAIN| LT=0.884 LP=0.044 LKL=11.628 LPS=0.668 LKLS=5.606 |
# Test F1: 0.9600
# Test ACC: 0.9432
# Test AUC: 0.9848
# Train F1: 0.9878
# 01650: TRAIN| LT=0.873 LP=0.052 LKL=11.499 LPS=0.655 LKLS=5.101 |
# Test F1: 0.9600
# Test ACC: 0.9432
# Test AUC: 0.9854
# Train F1: 0.9756
# 01700: TRAIN| LT=0.899 LP=0.059 LKL=11.654 LPS=0.669 LKLS=5.417 |
# Test F1: 0.9516
# Test ACC: 0.9318
# Test AUC: 0.9885
# Train F1: 0.9897
# 01750: TRAIN| LT=0.887 LP=0.055 LKL=11.650 LPS=0.664 LKLS=5.053 |
# Test F1: 0.9752
# Test ACC: 0.9659
# Test AUC: 0.9872
# Train F1: 0.9939
# 01800: TRAIN| LT=0.867 LP=0.037 LKL=11.596 LPS=0.660 LKLS=5.372 |
# Test F1: 0.9600
# Test ACC: 0.9432
# Test AUC: 0.9872
# Train F1: 0.9878
# 01850: TRAIN| LT=0.877 LP=0.055 LKL=11.605 LPS=0.656 LKLS=5.066 |
# Test F1: 0.9600
# Test ACC: 0.9432
# Test AUC: 0.9872
# Train F1: 0.9898
# 01900: TRAIN| LT=0.858 LP=0.039 LKL=11.818 LPS=0.649 LKLS=5.269 |
# Test F1: 0.9600
# Test ACC: 0.9432
# Test AUC: 0.9860
# Train F1: 0.9859
# 01950: TRAIN| LT=0.891 LP=0.051 LKL=11.406 LPS=0.677 LKLS=4.983 |
# Test F1: 0.9600
# Test ACC: 0.9432
# Test AUC: 0.9836
# Train F1: 0.9836
# 02000: TRAIN| LT=0.886 LP=0.043 LKL=11.507 LPS=0.679 LKLS=4.975 |
# Test F1: 0.9593
# Test ACC: 0.9432
# Test AUC: 0.9848
# f1: 0.9752066115702478
# acc: 0.9659090909090909
# auc: 0.9872495446265939
# f1 [0.9586776859504132, 0.9917355371900827, 0.9677419354838709, 0.975609756097561, 0.9752066115702478]
# average f1: 0.9737943052584352±0.010884131874288888
# acc [0.9438202247191011, 0.9887640449438202, 0.9550561797752809, 0.9662921348314607, 0.9659090909090909]
# average acc: 0.9639683350357509±0.014895413182682674
# auc [0.9877049180327868, 0.9970725995316159, 0.9560889929742389, 0.9631147540983607, 0.9872495446265939]
# average auc: 0.9782461618527192±0.01577886788627377
