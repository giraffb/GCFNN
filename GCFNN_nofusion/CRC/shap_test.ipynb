# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'Healthy':0,'Stage_0':1, 'Stage_I_II':1, 'Stage_III_IV':1, 'HS':1, 'MP':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (347, 851) (347, 450) (347, 1)
# Int64Index([10021, 10023, 10025, 10029, 10031, 10033, 10034, 10036, 10037,
#             10038,
#             ...
#             10818, 10825, 10827, 10829, 10835, 10838, 10839, 10847, 10850,
#             10853],
#            dtype='int64', name='Sample', length=347)
# 数据完整率missing_rate : 1.0
# 集合所有样本重构数据表： (347, 851) (347, 450) (347, 1)
# 标签转换为one-hot编码： (347, 2) 127.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 50)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 4, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1', f1_cv)
print('average f1: {}±{}'.format(np.mean(f1_cv), np.std(f1_cv)))
print('acc', acc_cv)
print('average acc: {}±{}'.format(np.mean(acc_cv), np.std(acc_cv)))
print('auc', auc_cv)
print('average auc: {}±{}'.format(np.mean(auc_cv), np.std(auc_cv)))
# Out:
# Train F1: 0.7664
# 00050: TRAIN| LT=2.114 LP=0.670 LKL=10.428 LPS=1.326 LKLS=1.410 |
# Test F1: 0.7719
# Test ACC: 0.6286
# Test AUC: 0.6346
# Train F1: 0.8030
# 00100: TRAIN| LT=1.883 LP=0.570 LKL=10.985 LPS=1.139 LKLS=6.340 |
# Test F1: 0.6818
# Test ACC: 0.6000
# Test AUC: 0.6617
# Train F1: 0.8378
# 00150: TRAIN| LT=1.637 LP=0.412 LKL=11.443 LPS=1.023 LKLS=8.780 |
# Test F1: 0.6098
# Test ACC: 0.5429
# Test AUC: 0.6914
# Train F1: 0.8515
# 00200: TRAIN| LT=1.622 LP=0.382 LKL=11.844 LPS=1.028 LKLS=9.408 |
# Test F1: 0.7253
# Test ACC: 0.6429
# Test AUC: 0.7264
# Train F1: 0.8678
# 00250: TRAIN| LT=1.525 LP=0.322 LKL=12.090 LPS=0.982 LKLS=10.008 |
# Test F1: 0.7059
# Test ACC: 0.6429
# Test AUC: 0.7439
# Train F1: 0.8901
# 00300: TRAIN| LT=1.503 LP=0.335 LKL=12.093 LPS=0.952 LKLS=9.511 |
# Test F1: 0.7579
# Test ACC: 0.6714
# Test AUC: 0.7649
# Train F1: 0.8934
# 00350: TRAIN| LT=1.392 LP=0.262 LKL=12.274 LPS=0.909 LKLS=9.765 |
# Test F1: 0.7416
# Test ACC: 0.6714
# Test AUC: 0.7675
# Train F1: 0.9192
# 00400: TRAIN| LT=1.383 LP=0.244 LKL=12.520 LPS=0.916 LKLS=9.919 |
# Test F1: 0.7872
# Test ACC: 0.7143
# Test AUC: 0.7858
# Train F1: 0.9239
# 00450: TRAIN| LT=1.391 LP=0.267 LKL=12.410 LPS=0.905 LKLS=9.474 |
# Test F1: 0.7789
# Test ACC: 0.7000
# Test AUC: 0.7552
# Train F1: 0.9280
# 00500: TRAIN| LT=1.276 LP=0.206 LKL=12.987 LPS=0.829 LKLS=11.074 |
# Test F1: 0.7556
# Test ACC: 0.6857
# Test AUC: 0.7386
# Train F1: 0.9258
# 00550: TRAIN| LT=1.239 LP=0.184 LKL=13.203 LPS=0.814 LKLS=10.787 |
# Test F1: 0.7073
# Test ACC: 0.6571
# Test AUC: 0.7247
# Train F1: 0.9573
# 00600: TRAIN| LT=1.275 LP=0.229 LKL=13.309 LPS=0.804 LKLS=10.901 |
# Test F1: 0.7317
# Test ACC: 0.6857
# Test AUC: 0.7229
# Train F1: 0.9344
# 00650: TRAIN| LT=1.176 LP=0.140 LKL=13.450 LPS=0.785 LKLS=11.694 |
# Test F1: 0.7609
# Test ACC: 0.6857
# Test AUC: 0.7247
# Train F1: 0.9521
# 00700: TRAIN| LT=1.125 LP=0.123 LKL=13.567 LPS=0.749 LKLS=11.707 |
# Test F1: 0.7692
# Test ACC: 0.7000
# Test AUC: 0.7220
# Train F1: 0.9607
# 00750: TRAIN| LT=1.089 LP=0.144 LKL=13.419 LPS=0.698 LKLS=11.302 |
# Test F1: 0.7692
# Test ACC: 0.7000
# Test AUC: 0.7115
# Train F1: 0.9615
# 00800: TRAIN| LT=1.155 LP=0.160 LKL=13.606 LPS=0.739 LKLS=11.915 |
# Test F1: 0.7692
# Test ACC: 0.7000
# Test AUC: 0.7107
# Train F1: 0.9580
# 00850: TRAIN| LT=1.080 LP=0.163 LKL=13.514 LPS=0.671 LKLS=11.087 |
# Test F1: 0.7609
# Test ACC: 0.6857
# Test AUC: 0.7177
# Train F1: 0.9605
# 00900: TRAIN| LT=1.047 LP=0.155 LKL=13.409 LPS=0.646 LKLS=11.089 |
# Test F1: 0.7556
# Test ACC: 0.6857
# Test AUC: 0.7098
# Train F1: 0.9655
# 00950: TRAIN| LT=1.032 LP=0.127 LKL=13.628 LPS=0.653 LKLS=11.632 |
# Test F1: 0.7333
# Test ACC: 0.6571
# Test AUC: 0.7089
# Train F1: 0.9605
# 01000: TRAIN| LT=1.023 LP=0.123 LKL=13.616 LPS=0.647 LKLS=11.618 |
# Test F1: 0.7556
# Test ACC: 0.6857
# Test AUC: 0.7142
# Train F1: 0.9605
# 01050: TRAIN| LT=1.026 LP=0.132 LKL=13.554 LPS=0.644 LKLS=11.405 |
# Test F1: 0.7586
# Test ACC: 0.7000
# Test AUC: 0.7238
# Train F1: 0.9887
# 01100: TRAIN| LT=0.980 LP=0.123 LKL=13.799 LPS=0.600 LKLS=11.831 |
# Test F1: 0.7529
# Test ACC: 0.7000
# Test AUC: 0.7281
# Train F1: 0.9667
# 01150: TRAIN| LT=1.057 LP=0.159 LKL=13.665 LPS=0.647 LKLS=11.436 |
# Test F1: 0.7742
# Test ACC: 0.7000
# Test AUC: 0.7080
# Train F1: 0.9607
# 01200: TRAIN| LT=0.987 LP=0.109 LKL=13.617 LPS=0.628 LKLS=11.446 |
# Test F1: 0.7556
# Test ACC: 0.6857
# Test AUC: 0.7168
# Train F1: 0.9741
# 01250: TRAIN| LT=1.036 LP=0.134 LKL=14.022 LPS=0.643 LKLS=11.878 |
# Test F1: 0.7381
# Test ACC: 0.6857
# Test AUC: 0.7244
# Train F1: 0.9661
# 01300: TRAIN| LT=0.948 LP=0.096 LKL=13.258 LPS=0.618 LKLS=10.190 |
# Test F1: 0.7778
# Test ACC: 0.7143
# Test AUC: 0.7229
# Train F1: 0.9611
# 01350: TRAIN| LT=0.907 LP=0.085 LKL=13.612 LPS=0.572 LKLS=11.471 |
# Test F1: 0.7556
# Test ACC: 0.6857
# Test AUC: 0.7212
# Train F1: 0.9625
# 01400: TRAIN| LT=0.935 LP=0.078 LKL=13.883 LPS=0.601 LKLS=11.702 |
# Test F1: 0.7586
# Test ACC: 0.7000
# Test AUC: 0.7277
# Train F1: 0.9642
# 01450: TRAIN| LT=0.920 LP=0.080 LKL=13.428 LPS=0.600 LKLS=10.566 |
# Test F1: 0.7865
# Test ACC: 0.7286
# Test AUC: 0.7290
# Train F1: 0.9595
# 01500: TRAIN| LT=0.943 LP=0.090 LKL=14.022 LPS=0.592 LKLS=12.002 |
# Test F1: 0.7674
# Test ACC: 0.7143
# Test AUC: 0.7303
# Train F1: 0.9742
# 01550: TRAIN| LT=0.940 LP=0.109 LKL=13.819 LPS=0.589 LKLS=10.351 |
# Test F1: 0.7674
# Test ACC: 0.7143
# Test AUC: 0.7399
# Train F1: 0.9745
# 01600: TRAIN| LT=0.934 LP=0.099 LKL=14.019 LPS=0.584 LKLS=11.122 |
# Test F1: 0.7674
# Test ACC: 0.7143
# Test AUC: 0.7356
# Train F1: 0.9521
# 01650: TRAIN| LT=0.905 LP=0.073 LKL=13.837 LPS=0.584 LKLS=11.015 |
# Test F1: 0.7640
# Test ACC: 0.7000
# Test AUC: 0.7345
# Train F1: 0.9573
# 01700: TRAIN| LT=0.941 LP=0.131 LKL=13.859 LPS=0.561 LKLS=11.017 |
# Test F1: 0.7619
# Test ACC: 0.7143
# Test AUC: 0.7365
# Train F1: 0.9663
# 01750: TRAIN| LT=0.872 LP=0.066 LKL=13.792 LPS=0.558 LKLS=10.975 |
# Test F1: 0.7640
# Test ACC: 0.7000
# Test AUC: 0.7321
# Train F1: 0.9663
# 01800: TRAIN| LT=0.886 LP=0.102 LKL=13.441 LPS=0.553 LKLS=9.729 |
# Test F1: 0.7765
# Test ACC: 0.7286
# Test AUC: 0.7434
# Train F1: 0.9829
# 01850: TRAIN| LT=0.903 LP=0.093 LKL=13.705 LPS=0.567 LKLS=10.543 |
# Test F1: 0.7727
# Test ACC: 0.7143
# Test AUC: 0.7312
# Train F1: 0.9669
# 01900: TRAIN| LT=0.911 LP=0.137 LKL=13.869 LPS=0.526 LKLS=10.921 |
# Test F1: 0.7674
# Test ACC: 0.7143
# Test AUC: 0.7382
# Train F1: 0.9744
# 01950: TRAIN| LT=0.819 LP=0.077 LKL=13.679 LPS=0.502 LKLS=10.232 |
# Test F1: 0.7711
# Test ACC: 0.7286
# Test AUC: 0.7369
# Train F1: 0.9719
# 02000: TRAIN| LT=0.847 LP=0.090 LKL=13.722 LPS=0.517 LKLS=10.272 |
# Test F1: 0.7356
# Test ACC: 0.6714
# Test AUC: 0.7251
# f1: 0.7872340425531915
# acc: 0.7142857142857143
# auc: 0.7858391608391608
# Train F1: 0.7692
# 00050: TRAIN| LT=2.060 LP=0.635 LKL=10.487 LPS=1.298 LKLS=2.170 |
# Test F1: 0.7719
# Test ACC: 0.6286
# Test AUC: 0.6163
# Train F1: 0.7961
# 00100: TRAIN| LT=1.917 LP=0.563 LKL=11.012 LPS=1.178 LKLS=6.561 |
# Test F1: 0.7706
# Test ACC: 0.6429
# Test AUC: 0.5900
# Train F1: 0.8261
# 00150: TRAIN| LT=1.754 LP=0.471 LKL=11.469 LPS=1.085 LKLS=8.355 |
# Test F1: 0.7500
# Test ACC: 0.6571
# Test AUC: 0.6425
# Train F1: 0.8656
# 00200: TRAIN| LT=1.659 LP=0.417 LKL=11.814 LPS=1.029 LKLS=9.495 |
# Test F1: 0.7600
# Test ACC: 0.6571
# Test AUC: 0.6285
# Train F1: 0.8504
# 00250: TRAIN| LT=1.608 LP=0.378 LKL=11.747 LPS=1.027 LKLS=8.561 |
# Test F1: 0.7097
# Test ACC: 0.6143
# Test AUC: 0.6136
# Train F1: 0.8649
# 00300: TRAIN| LT=1.551 LP=0.365 LKL=11.918 LPS=0.974 LKLS=9.237 |
# Test F1: 0.7423
# Test ACC: 0.6429
# Test AUC: 0.6224
# Train F1: 0.8644
# 00350: TRAIN| LT=1.542 LP=0.355 LKL=11.960 LPS=0.982 LKLS=8.538 |
# Test F1: 0.7234
# Test ACC: 0.6286
# Test AUC: 0.6276
# Train F1: 0.8977
# 00400: TRAIN| LT=1.496 LP=0.302 LKL=12.256 LPS=0.975 LKLS=9.708 |
# Test F1: 0.7174
# Test ACC: 0.6286
# Test AUC: 0.6189
# Train F1: 0.8815
# 00450: TRAIN| LT=1.408 LP=0.295 LKL=12.229 LPS=0.900 LKLS=9.121 |
# Test F1: 0.7234
# Test ACC: 0.6286
# Test AUC: 0.6329
# Train F1: 0.9132
# 00500: TRAIN| LT=1.340 LP=0.244 LKL=12.565 LPS=0.864 LKLS=10.595 |
# Test F1: 0.7021
# Test ACC: 0.6000
# Test AUC: 0.6407
# Train F1: 0.9300
# 00550: TRAIN| LT=1.315 LP=0.246 LKL=12.959 LPS=0.834 LKLS=10.551 |
# Test F1: 0.6739
# Test ACC: 0.5714
# Test AUC: 0.6381
# Train F1: 0.9288
# 00600: TRAIN| LT=1.248 LP=0.235 LKL=12.808 LPS=0.784 LKLS=10.179 |
# Test F1: 0.6517
# Test ACC: 0.5571
# Test AUC: 0.6294
# Train F1: 0.9227
# 00650: TRAIN| LT=1.235 LP=0.188 LKL=13.329 LPS=0.790 LKLS=12.373 |
# Test F1: 0.7312
# Test ACC: 0.6429
# Test AUC: 0.6206
# Train F1: 0.9375
# 00700: TRAIN| LT=1.202 LP=0.149 LKL=13.405 LPS=0.796 LKLS=12.235 |
# Test F1: 0.7234
# Test ACC: 0.6286
# Test AUC: 0.6355
# Train F1: 0.9526
# 00750: TRAIN| LT=1.229 LP=0.191 LKL=13.337 LPS=0.786 LKLS=11.978 |
# Test F1: 0.7292
# Test ACC: 0.6286
# Test AUC: 0.6329
# Train F1: 0.9486
# 00800: TRAIN| LT=1.222 LP=0.192 LKL=13.294 LPS=0.782 LKLS=11.530 |
# Test F1: 0.6742
# Test ACC: 0.5857
# Test AUC: 0.6311
# Train F1: 0.9398
# 00850: TRAIN| LT=1.132 LP=0.148 LKL=13.265 LPS=0.736 LKLS=11.539 |
# Test F1: 0.6591
# Test ACC: 0.5714
# Test AUC: 0.6075
# Train F1: 0.9580
# 00900: TRAIN| LT=1.121 LP=0.177 LKL=13.281 LPS=0.694 LKLS=11.651 |
# Test F1: 0.7097
# Test ACC: 0.6143
# Test AUC: 0.6049
# Train F1: 0.9553
# 00950: TRAIN| LT=1.045 LP=0.117 LKL=13.383 LPS=0.680 LKLS=11.467 |
# Test F1: 0.7292
# Test ACC: 0.6286
# Test AUC: 0.6215
# Train F1: 0.9510
# 01000: TRAIN| LT=1.077 LP=0.141 LKL=13.161 LPS=0.695 LKLS=11.012 |
# Test F1: 0.6882
# Test ACC: 0.5857
# Test AUC: 0.6163
# Train F1: 0.9545
# 01050: TRAIN| LT=1.094 LP=0.173 LKL=13.386 LPS=0.679 LKLS=10.815 |
# Test F1: 0.6742
# Test ACC: 0.5857
# Test AUC: 0.6066
# Train F1: 0.9551
# 01100: TRAIN| LT=1.016 LP=0.107 LKL=13.241 LPS=0.668 LKLS=10.821 |
# Test F1: 0.7500
# Test ACC: 0.6571
# Test AUC: 0.6180
# Train F1: 0.9657
# 01150: TRAIN| LT=1.021 LP=0.116 LKL=13.493 LPS=0.650 LKLS=12.044 |
# Test F1: 0.7579
# Test ACC: 0.6714
# Test AUC: 0.6224
# Train F1: 0.9573
# 01200: TRAIN| LT=0.986 LP=0.112 LKL=13.448 LPS=0.625 LKLS=11.423 |
# Test F1: 0.7500
# Test ACC: 0.6571
# Test AUC: 0.6187
# Train F1: 0.9718
# 01250: TRAIN| LT=1.073 LP=0.154 LKL=13.888 LPS=0.656 LKLS=12.389 |
# Test F1: 0.7253
# Test ACC: 0.6429
# Test AUC: 0.6101
# Train F1: 0.9802
# 01300: TRAIN| LT=0.903 LP=0.062 LKL=13.722 LPS=0.582 LKLS=12.240 |
# Test F1: 0.7660
# Test ACC: 0.6857
# Test AUC: 0.6171
# Train F1: 0.9605
# 01350: TRAIN| LT=0.939 LP=0.105 LKL=13.507 LPS=0.583 LKLS=11.576 |
# Test F1: 0.7527
# Test ACC: 0.6714
# Test AUC: 0.6163
# Train F1: 0.9827
# 01400: TRAIN| LT=0.965 LP=0.106 LKL=13.822 LPS=0.602 LKLS=11.918 |
# Test F1: 0.7391
# Test ACC: 0.6571
# Test AUC: 0.6171
# Train F1: 0.9446
# 01450: TRAIN| LT=0.971 LP=0.126 LKL=13.604 LPS=0.595 LKLS=11.394 |
# Test F1: 0.7126
# Test ACC: 0.6429
# Test AUC: 0.6219
# Train F1: 0.9775
# 01500: TRAIN| LT=0.918 LP=0.079 LKL=13.830 LPS=0.582 LKLS=11.945 |
# Test F1: 0.7660
# Test ACC: 0.6857
# Test AUC: 0.6226
# Train F1: 0.9518
# 01550: TRAIN| LT=0.921 LP=0.071 LKL=13.616 LPS=0.599 LKLS=11.439 |
# Test F1: 0.7660
# Test ACC: 0.6857
# Test AUC: 0.6206
# Train F1: 0.9540
# 01600: TRAIN| LT=0.956 LP=0.100 LKL=13.594 LPS=0.610 LKLS=10.948 |
# Test F1: 0.7253
# Test ACC: 0.6429
# Test AUC: 0.6176
# Train F1: 0.9831
# 01650: TRAIN| LT=0.996 LP=0.116 LKL=13.877 LPS=0.625 LKLS=11.562 |
# Test F1: 0.7391
# Test ACC: 0.6571
# Test AUC: 0.6108
# Train F1: 0.9744
# 01700: TRAIN| LT=0.909 LP=0.086 LKL=13.807 LPS=0.568 LKLS=11.683 |
# Test F1: 0.7527
# Test ACC: 0.6714
# Test AUC: 0.6112
# Train F1: 0.9741
# 01750: TRAIN| LT=0.920 LP=0.080 LKL=13.903 LPS=0.580 LKLS=12.134 |
# Test F1: 0.7660
# Test ACC: 0.6857
# Test AUC: 0.6152
# Train F1: 0.9718
# 01800: TRAIN| LT=0.947 LP=0.086 LKL=13.807 LPS=0.608 LKLS=11.570 |
# Test F1: 0.7527
# Test ACC: 0.6714
# Test AUC: 0.6125
# Train F1: 0.9745
# 01850: TRAIN| LT=0.864 LP=0.074 LKL=14.185 LPS=0.524 LKLS=12.472 |
# Test F1: 0.7111
# Test ACC: 0.6286
# Test AUC: 0.6042
# Train F1: 0.9858
# 01900: TRAIN| LT=0.870 LP=0.067 LKL=13.798 LPS=0.548 LKLS=11.603 |
# Test F1: 0.7111
# Test ACC: 0.6286
# Test AUC: 0.6060
# Train F1: 0.9774
# 01950: TRAIN| LT=0.955 LP=0.092 LKL=13.720 LPS=0.618 LKLS=10.759 |
# Test F1: 0.7527
# Test ACC: 0.6714
# Test AUC: 0.6060
# Train F1: 0.9659
# 02000: TRAIN| LT=0.878 LP=0.090 LKL=13.547 LPS=0.545 LKLS=10.702 |
# Test F1: 0.7391
# Test ACC: 0.6571
# Test AUC: 0.6176
# f1: 0.7719298245614035
# acc: 0.6285714285714286
# auc: 0.6162587412587412
# Train F1: 0.7723
# 00050: TRAIN| LT=2.077 LP=0.651 LKL=10.546 LPS=1.300 LKLS=1.986 |
# Test F1: 0.7788
# Test ACC: 0.6377
# Test AUC: 0.5309
# Train F1: 0.8000
# 00100: TRAIN| LT=1.802 LP=0.512 LKL=11.230 LPS=1.105 LKLS=7.201 |
# Test F1: 0.7400
# Test ACC: 0.6232
# Test AUC: 0.5464
# Train F1: 0.8415
# 00150: TRAIN| LT=1.667 LP=0.386 LKL=11.749 LPS=1.066 LKLS=9.728 |
# Test F1: 0.6098
# Test ACC: 0.5362
# Test AUC: 0.5373
# Train F1: 0.8705
# 00200: TRAIN| LT=1.552 LP=0.365 LKL=11.692 LPS=0.976 LKLS=9.377 |
# Test F1: 0.6341
# Test ACC: 0.5652
# Test AUC: 0.5273
# Train F1: 0.8649
# 00250: TRAIN| LT=1.564 LP=0.377 LKL=11.768 LPS=0.972 LKLS=9.703 |
# Test F1: 0.6591
# Test ACC: 0.5652
# Test AUC: 0.5445
# Train F1: 0.8743
# 00300: TRAIN| LT=1.520 LP=0.334 LKL=12.141 LPS=0.965 LKLS=10.001 |
# Test F1: 0.6512
# Test ACC: 0.5652
# Test AUC: 0.5336
# Train F1: 0.8953
# 00350: TRAIN| LT=1.439 LP=0.297 LKL=12.164 LPS=0.920 LKLS=9.943 |
# Test F1: 0.6341
# Test ACC: 0.5652
# Test AUC: 0.5600
# Train F1: 0.8975
# 00400: TRAIN| LT=1.438 LP=0.279 LKL=12.022 LPS=0.947 LKLS=9.126 |
# Test F1: 0.6667
# Test ACC: 0.5652
# Test AUC: 0.5427
# Train F1: 0.8944
# 00450: TRAIN| LT=1.444 LP=0.274 LKL=12.378 LPS=0.950 LKLS=9.613 |
# Test F1: 0.6889
# Test ACC: 0.5942
# Test AUC: 0.5682
# Train F1: 0.9178
# 00500: TRAIN| LT=1.356 LP=0.240 LKL=12.729 LPS=0.882 LKLS=10.605 |
# Test F1: 0.7253
# Test ACC: 0.6377
# Test AUC: 0.5873
# Train F1: 0.9270
# 00550: TRAIN| LT=1.354 LP=0.223 LKL=12.846 LPS=0.899 LKLS=10.371 |
# Test F1: 0.7253
# Test ACC: 0.6377
# Test AUC: 0.5800
# Train F1: 0.9258
# 00600: TRAIN| LT=1.287 LP=0.241 LKL=13.108 LPS=0.808 LKLS=10.580 |
# Test F1: 0.7586
# Test ACC: 0.6957
# Test AUC: 0.5982
# Train F1: 0.9379
# 00650: TRAIN| LT=1.242 LP=0.212 LKL=13.056 LPS=0.793 LKLS=10.515 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5773
# Train F1: 0.9205
# 00700: TRAIN| LT=1.213 LP=0.193 LKL=13.201 LPS=0.770 LKLS=11.843 |
# Test F1: 0.7391
# Test ACC: 0.6522
# Test AUC: 0.5800
# Train F1: 0.9655
# 00750: TRAIN| LT=1.182 LP=0.169 LKL=13.216 LPS=0.770 LKLS=11.089 |
# Test F1: 0.7391
# Test ACC: 0.6522
# Test AUC: 0.5700
# Train F1: 0.9492
# 00800: TRAIN| LT=1.159 LP=0.175 LKL=13.143 LPS=0.742 LKLS=11.102 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5764
# Train F1: 0.9456
# 00850: TRAIN| LT=1.144 LP=0.147 LKL=13.532 LPS=0.749 LKLS=11.346 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5509
# Train F1: 0.9545
# 00900: TRAIN| LT=1.121 LP=0.156 LKL=13.630 LPS=0.708 LKLS=12.091 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5664
# Train F1: 0.9492
# 00950: TRAIN| LT=1.070 LP=0.099 LKL=13.341 LPS=0.727 LKLS=11.129 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5800
# Train F1: 0.9630
# 01000: TRAIN| LT=1.098 LP=0.135 LKL=13.761 LPS=0.701 LKLS=12.391 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5827
# Train F1: 0.9657
# 01050: TRAIN| LT=1.070 LP=0.109 LKL=13.508 LPS=0.710 LKLS=11.650 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5691
# Train F1: 0.9805
# 01100: TRAIN| LT=1.051 LP=0.141 LKL=13.501 LPS=0.663 LKLS=11.216 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5736
# Train F1: 0.9625
# 01150: TRAIN| LT=1.032 LP=0.116 LKL=13.513 LPS=0.670 LKLS=11.059 |
# Test F1: 0.7273
# Test ACC: 0.6522
# Test AUC: 0.5709
# Train F1: 0.9494
# 01200: TRAIN| LT=1.000 LP=0.114 LKL=13.637 LPS=0.632 LKLS=11.858 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5736
# Train F1: 0.9655
# 01250: TRAIN| LT=0.981 LP=0.117 LKL=13.792 LPS=0.614 LKLS=11.245 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.5773
# Train F1: 0.9607
# 01300: TRAIN| LT=0.998 LP=0.112 LKL=13.713 LPS=0.633 LKLS=11.583 |
# Test F1: 0.7391
# Test ACC: 0.6522
# Test AUC: 0.5700
# Train F1: 0.9636
# 01350: TRAIN| LT=0.960 LP=0.096 LKL=13.399 LPS=0.623 LKLS=10.713 |
# Test F1: 0.7527
# Test ACC: 0.6667
# Test AUC: 0.5807
# Train F1: 0.9692
# 01400: TRAIN| LT=0.953 LP=0.061 LKL=13.872 LPS=0.635 LKLS=11.861 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5755
# Train F1: 0.9718
# 01450: TRAIN| LT=0.862 LP=0.056 LKL=13.837 LPS=0.554 LKLS=11.321 |
# Test F1: 0.7333
# Test ACC: 0.6522
# Test AUC: 0.5727
# Train F1: 0.9745
# 01500: TRAIN| LT=0.911 LP=0.080 LKL=13.637 LPS=0.585 LKLS=10.883 |
# Test F1: 0.7527
# Test ACC: 0.6667
# Test AUC: 0.5764
# Train F1: 0.9775
# 01550: TRAIN| LT=0.893 LP=0.058 LKL=14.021 LPS=0.578 LKLS=11.708 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5745
# Train F1: 0.9830
# 01600: TRAIN| LT=0.886 LP=0.077 LKL=13.641 LPS=0.564 LKLS=10.882 |
# Test F1: 0.7473
# Test ACC: 0.6667
# Test AUC: 0.5725
# Train F1: 0.9745
# 01650: TRAIN| LT=0.820 LP=0.048 LKL=14.142 LPS=0.515 LKLS=11.512 |
# Test F1: 0.7660
# Test ACC: 0.6812
# Test AUC: 0.5739
# Train F1: 0.9801
# 01700: TRAIN| LT=0.848 LP=0.073 LKL=13.678 LPS=0.535 LKLS=10.286 |
# Test F1: 0.7556
# Test ACC: 0.6812
# Test AUC: 0.5748
# Train F1: 0.9887
# 01750: TRAIN| LT=0.907 LP=0.075 LKL=13.931 LPS=0.581 LKLS=11.183 |
# Test F1: 0.7527
# Test ACC: 0.6667
# Test AUC: 0.5730
# Train F1: 0.9858
# 01800: TRAIN| LT=0.871 LP=0.105 LKL=13.880 LPS=0.520 LKLS=10.714 |
# Test F1: 0.7416
# Test ACC: 0.6667
# Test AUC: 0.5648
# Train F1: 0.9802
# 01850: TRAIN| LT=0.877 LP=0.079 LKL=13.473 LPS=0.565 LKLS=9.870 |
# Test F1: 0.7556
# Test ACC: 0.6812
# Test AUC: 0.5820
# Train F1: 0.9914
# 01900: TRAIN| LT=0.905 LP=0.085 LKL=13.776 LPS=0.579 LKLS=10.271 |
# Test F1: 0.7527
# Test ACC: 0.6667
# Test AUC: 0.5673
# Train F1: 0.9858
# 01950: TRAIN| LT=0.814 LP=0.044 LKL=13.956 LPS=0.522 LKLS=10.807 |
# Test F1: 0.7045
# Test ACC: 0.6232
# Test AUC: 0.5586
# Train F1: 0.9804
# 02000: TRAIN| LT=0.858 LP=0.062 LKL=13.943 LPS=0.551 LKLS=10.516 |
# Test F1: 0.7234
# Test ACC: 0.6232
# Test AUC: 0.5680
# f1: 0.7787610619469026
# acc: 0.6376811594202898
# auc: 0.5309090909090909
# Train F1: 0.7534
# 00050: TRAIN| LT=2.108 LP=0.657 LKL=10.547 LPS=1.333 LKLS=1.303 |
# Test F1: 0.7788
# Test ACC: 0.6377
# Test AUC: 0.7191
# Train F1: 0.7793
# 00100: TRAIN| LT=1.894 LP=0.577 LKL=10.939 LPS=1.146 LKLS=6.144 |
# Test F1: 0.7850
# Test ACC: 0.6667
# Test AUC: 0.6855
# Train F1: 0.8532
# 00150: TRAIN| LT=1.641 LP=0.392 LKL=11.528 LPS=1.028 LKLS=10.477 |
# Test F1: 0.6824
# Test ACC: 0.6087
# Test AUC: 0.5864
# Train F1: 0.8676
# 00200: TRAIN| LT=1.553 LP=0.356 LKL=11.684 LPS=0.978 LKLS=10.240 |
# Test F1: 0.6824
# Test ACC: 0.6087
# Test AUC: 0.5900
# Train F1: 0.8500
# 00250: TRAIN| LT=1.549 LP=0.346 LKL=11.669 LPS=0.992 LKLS=9.433 |
# Test F1: 0.7045
# Test ACC: 0.6232
# Test AUC: 0.5782
# Train F1: 0.8809
# 00300: TRAIN| LT=1.548 LP=0.360 LKL=11.908 LPS=0.969 LKLS=9.992 |
# Test F1: 0.7045
# Test ACC: 0.6232
# Test AUC: 0.5773
# Train F1: 0.8539
# 00350: TRAIN| LT=1.510 LP=0.338 LKL=11.933 LPS=0.960 LKLS=9.300 |
# Test F1: 0.6966
# Test ACC: 0.6087
# Test AUC: 0.5964
# Train F1: 0.8941
# 00400: TRAIN| LT=1.449 LP=0.285 LKL=12.085 LPS=0.953 LKLS=9.015 |
# Test F1: 0.6744
# Test ACC: 0.5942
# Test AUC: 0.5855
# Train F1: 0.8991
# 00450: TRAIN| LT=1.432 LP=0.284 LKL=12.163 LPS=0.932 LKLS=9.426 |
# Test F1: 0.7253
# Test ACC: 0.6377
# Test AUC: 0.5973
# Train F1: 0.8977
# 00500: TRAIN| LT=1.332 LP=0.250 LKL=12.383 LPS=0.860 LKLS=9.763 |
# Test F1: 0.6889
# Test ACC: 0.5942
# Test AUC: 0.6027
# Train F1: 0.9017
# 00550: TRAIN| LT=1.363 LP=0.262 LKL=12.462 LPS=0.884 LKLS=9.232 |
# Test F1: 0.6667
# Test ACC: 0.5797
# Test AUC: 0.6064
# Train F1: 0.9192
# 00600: TRAIN| LT=1.316 LP=0.240 LKL=12.568 LPS=0.852 LKLS=9.756 |
# Test F1: 0.6813
# Test ACC: 0.5797
# Test AUC: 0.5973
# Train F1: 0.9239
# 00650: TRAIN| LT=1.250 LP=0.227 LKL=12.838 LPS=0.792 LKLS=10.375 |
# Test F1: 0.6889
# Test ACC: 0.5942
# Test AUC: 0.6082
# Train F1: 0.9197
# 00700: TRAIN| LT=1.248 LP=0.237 LKL=12.891 LPS=0.777 LKLS=10.510 |
# Test F1: 0.6591
# Test ACC: 0.5652
# Test AUC: 0.6091
# Train F1: 0.9256
# 00750: TRAIN| LT=1.222 LP=0.218 LKL=13.048 LPS=0.763 LKLS=11.029 |
# Test F1: 0.6667
# Test ACC: 0.5652
# Test AUC: 0.6064
# Train F1: 0.9189
# 00800: TRAIN| LT=1.182 LP=0.180 LKL=13.192 LPS=0.753 LKLS=11.695 |
# Test F1: 0.6047
# Test ACC: 0.5072
# Test AUC: 0.5964
# Train F1: 0.9507
# 00850: TRAIN| LT=1.131 LP=0.156 LKL=13.397 LPS=0.724 LKLS=11.629 |
# Test F1: 0.6173
# Test ACC: 0.5507
# Test AUC: 0.6118
# Train F1: 0.9382
# 00900: TRAIN| LT=1.102 LP=0.179 LKL=13.327 LPS=0.677 LKLS=11.298 |
# Test F1: 0.6173
# Test ACC: 0.5507
# Test AUC: 0.6009
# Train F1: 0.9359
# 00950: TRAIN| LT=1.159 LP=0.228 LKL=13.208 LPS=0.686 LKLS=11.284 |
# Test F1: 0.6591
# Test ACC: 0.5652
# Test AUC: 0.5973
# Train F1: 0.9438
# 01000: TRAIN| LT=1.047 LP=0.162 LKL=13.581 LPS=0.627 LKLS=12.261 |
# Test F1: 0.6265
# Test ACC: 0.5507
# Test AUC: 0.5964
# Train F1: 0.9582
# 01050: TRAIN| LT=1.129 LP=0.194 LKL=13.459 LPS=0.683 LKLS=11.718 |
# Test F1: 0.6118
# Test ACC: 0.5217
# Test AUC: 0.5855
# Train F1: 0.9379
# 01100: TRAIN| LT=1.054 LP=0.137 LKL=13.435 LPS=0.665 LKLS=11.765 |
# Test F1: 0.6173
# Test ACC: 0.5507
# Test AUC: 0.5882
# Train F1: 0.9366
# 01150: TRAIN| LT=1.022 LP=0.133 LKL=13.557 LPS=0.636 LKLS=11.794 |
# Test F1: 0.6024
# Test ACC: 0.5217
# Test AUC: 0.5836
# Train F1: 0.9659
# 01200: TRAIN| LT=1.000 LP=0.137 LKL=13.378 LPS=0.615 LKLS=11.403 |
# Test F1: 0.6429
# Test ACC: 0.5652
# Test AUC: 0.5909
# Train F1: 0.9595
# 01250: TRAIN| LT=1.058 LP=0.129 LKL=13.715 LPS=0.671 LKLS=12.054 |
# Test F1: 0.6429
# Test ACC: 0.5652
# Test AUC: 0.5964
# Train F1: 0.9412
# 01300: TRAIN| LT=1.025 LP=0.151 LKL=13.891 LPS=0.609 LKLS=12.624 |
# Test F1: 0.6250
# Test ACC: 0.5652
# Test AUC: 0.6191
# Train F1: 0.9421
# 01350: TRAIN| LT=1.024 LP=0.153 LKL=13.659 LPS=0.613 LKLS=12.203 |
# Test F1: 0.6744
# Test ACC: 0.5942
# Test AUC: 0.6136
# Train F1: 0.9415
# 01400: TRAIN| LT=0.989 LP=0.124 LKL=13.584 LPS=0.613 LKLS=11.551 |
# Test F1: 0.6250
# Test ACC: 0.5652
# Test AUC: 0.6073
# Train F1: 0.9379
# 01450: TRAIN| LT=0.964 LP=0.139 LKL=13.502 LPS=0.575 LKLS=11.446 |
# Test F1: 0.6429
# Test ACC: 0.5652
# Test AUC: 0.6118
# Train F1: 0.9568
# 01500: TRAIN| LT=0.948 LP=0.109 LKL=13.804 LPS=0.576 LKLS=12.434 |
# Test F1: 0.6173
# Test ACC: 0.5507
# Test AUC: 0.6173
# Train F1: 0.9580
# 01550: TRAIN| LT=0.954 LP=0.093 LKL=13.977 LPS=0.593 LKLS=12.830 |
# Test F1: 0.6588
# Test ACC: 0.5797
# Test AUC: 0.6145
# Train F1: 0.9628
# 01600: TRAIN| LT=1.020 LP=0.128 LKL=13.763 LPS=0.631 LKLS=12.276 |
# Test F1: 0.6588
# Test ACC: 0.5797
# Test AUC: 0.6184
# Train F1: 0.9690
# 01650: TRAIN| LT=0.920 LP=0.097 LKL=13.671 LPS=0.572 LKLS=11.414 |
# Test F1: 0.6588
# Test ACC: 0.5797
# Test AUC: 0.6155
# Train F1: 0.9628
# 01700: TRAIN| LT=0.956 LP=0.124 LKL=13.713 LPS=0.578 LKLS=11.674 |
# Test F1: 0.6588
# Test ACC: 0.5797
# Test AUC: 0.6134
# Train F1: 0.9489
# 01750: TRAIN| LT=0.969 LP=0.137 LKL=13.878 LPS=0.572 LKLS=12.115 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.6164
# Train F1: 0.9655
# 01800: TRAIN| LT=0.916 LP=0.099 LKL=13.505 LPS=0.571 LKLS=11.131 |
# Test F1: 0.6585
# Test ACC: 0.5942
# Test AUC: 0.6227
# Train F1: 0.9688
# 01850: TRAIN| LT=0.957 LP=0.123 LKL=13.815 LPS=0.580 LKLS=11.715 |
# Test F1: 0.6588
# Test ACC: 0.5797
# Test AUC: 0.6200
# Train F1: 0.9685
# 01900: TRAIN| LT=0.918 LP=0.106 LKL=13.813 LPS=0.555 LKLS=11.840 |
# Test F1: 0.6585
# Test ACC: 0.5942
# Test AUC: 0.6173
# Train F1: 0.9607
# 01950: TRAIN| LT=0.904 LP=0.110 LKL=13.815 LPS=0.539 LKLS=11.629 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.6245
# Train F1: 0.9663
# 02000: TRAIN| LT=0.896 LP=0.069 LKL=13.670 LPS=0.574 LKLS=11.665 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.6284
# f1: 0.7850467289719627
# acc: 0.6666666666666666
# auc: 0.6854545454545454
# Train F1: 0.7710
# 00050: TRAIN| LT=2.111 LP=0.661 LKL=10.509 LPS=1.330 LKLS=1.495 |
# Test F1: 0.7788
# Test ACC: 0.6377
# Test AUC: 0.5555
# Train F1: 0.7751
# 00100: TRAIN| LT=1.939 LP=0.571 LKL=10.983 LPS=1.184 LKLS=7.502 |
# Test F1: 0.7748
# Test ACC: 0.6377
# Test AUC: 0.6009
# Train F1: 0.8435
# 00150: TRAIN| LT=1.677 LP=0.433 LKL=11.380 LPS=1.040 LKLS=9.031 |
# Test F1: 0.6341
# Test ACC: 0.5652
# Test AUC: 0.6209
# Train F1: 0.8451
# 00200: TRAIN| LT=1.632 LP=0.379 LKL=11.859 LPS=1.034 LKLS=10.015 |
# Test F1: 0.6250
# Test ACC: 0.5652
# Test AUC: 0.6064
# Train F1: 0.8783
# 00250: TRAIN| LT=1.550 LP=0.352 LKL=11.677 LPS=0.992 LKLS=8.979 |
# Test F1: 0.6591
# Test ACC: 0.5652
# Test AUC: 0.6018
# Train F1: 0.8746
# 00300: TRAIN| LT=1.567 LP=0.389 LKL=11.888 LPS=0.971 LKLS=8.863 |
# Test F1: 0.6250
# Test ACC: 0.5652
# Test AUC: 0.5855
# Train F1: 0.8736
# 00350: TRAIN| LT=1.553 LP=0.338 LKL=12.049 LPS=1.000 LKLS=9.503 |
# Test F1: 0.6265
# Test ACC: 0.5507
# Test AUC: 0.5782
# Train F1: 0.8937
# 00400: TRAIN| LT=1.419 LP=0.278 LKL=12.499 LPS=0.907 LKLS=10.955 |
# Test F1: 0.6889
# Test ACC: 0.5942
# Test AUC: 0.5773
# Train F1: 0.8889
# 00450: TRAIN| LT=1.403 LP=0.259 LKL=12.697 LPS=0.916 LKLS=10.122 |
# Test F1: 0.6747
# Test ACC: 0.6087
# Test AUC: 0.5800
# Train F1: 0.9015
# 00500: TRAIN| LT=1.394 LP=0.258 LKL=12.775 LPS=0.903 LKLS=10.473 |
# Test F1: 0.6667
# Test ACC: 0.6087
# Test AUC: 0.5836
# Train F1: 0.9178
# 00550: TRAIN| LT=1.298 LP=0.207 LKL=13.312 LPS=0.838 LKLS=11.963 |
# Test F1: 0.7045
# Test ACC: 0.6232
# Test AUC: 0.5645
# Train F1: 0.9191
# 00600: TRAIN| LT=1.291 LP=0.257 LKL=12.887 LPS=0.799 LKLS=10.536 |
# Test F1: 0.6265
# Test ACC: 0.5507
# Test AUC: 0.5609
# Train F1: 0.9118
# 00650: TRAIN| LT=1.267 LP=0.243 LKL=13.257 LPS=0.782 LKLS=10.921 |
# Test F1: 0.6506
# Test ACC: 0.5797
# Test AUC: 0.5800
# Train F1: 0.9438
# 00700: TRAIN| LT=1.238 LP=0.206 LKL=13.183 LPS=0.788 LKLS=11.201 |
# Test F1: 0.6429
# Test ACC: 0.5652
# Test AUC: 0.5709
# Train F1: 0.9310
# 00750: TRAIN| LT=1.151 LP=0.208 LKL=13.419 LPS=0.692 LKLS=11.738 |
# Test F1: 0.6588
# Test ACC: 0.5797
# Test AUC: 0.5691
# Train F1: 0.9248
# 00800: TRAIN| LT=1.178 LP=0.183 LKL=13.255 LPS=0.742 LKLS=11.956 |
# Test F1: 0.6813
# Test ACC: 0.5797
# Test AUC: 0.5564
# Train F1: 0.9449
# 00850: TRAIN| LT=1.138 LP=0.172 LKL=13.415 LPS=0.717 LKLS=11.416 |
# Test F1: 0.6190
# Test ACC: 0.5362
# Test AUC: 0.5500
# Train F1: 0.9516
# 00900: TRAIN| LT=1.070 LP=0.158 LKL=13.495 LPS=0.659 LKLS=11.836 |
# Test F1: 0.6437
# Test ACC: 0.5507
# Test AUC: 0.5609
# Train F1: 0.9459
# 00950: TRAIN| LT=1.096 LP=0.169 LKL=13.346 LPS=0.682 LKLS=11.080 |
# Test F1: 0.6512
# Test ACC: 0.5652
# Test AUC: 0.5600
# Train F1: 0.9602
# 01000: TRAIN| LT=0.995 LP=0.130 LKL=13.660 LPS=0.609 LKLS=12.048 |
# Test F1: 0.6591
# Test ACC: 0.5652
# Test AUC: 0.5573
# Train F1: 0.9521
# 01050: TRAIN| LT=1.050 LP=0.150 LKL=13.345 LPS=0.653 LKLS=11.346 |
# Test F1: 0.6742
# Test ACC: 0.5797
# Test AUC: 0.5591
# Train F1: 0.9294
# 01100: TRAIN| LT=1.014 LP=0.128 LKL=13.777 LPS=0.629 LKLS=11.950 |
# Test F1: 0.6667
# Test ACC: 0.5942
# Test AUC: 0.5664
# Train F1: 0.9628
# 01150: TRAIN| LT=0.977 LP=0.138 LKL=13.547 LPS=0.585 LKLS=11.851 |
# Test F1: 0.6818
# Test ACC: 0.5942
# Test AUC: 0.5618
# Train F1: 0.9687
# 01200: TRAIN| LT=0.951 LP=0.114 LKL=13.651 LPS=0.582 LKLS=11.944 |
# Test F1: 0.6591
# Test ACC: 0.5652
# Test AUC: 0.5618
# Train F1: 0.9688
# 01250: TRAIN| LT=1.015 LP=0.154 LKL=13.744 LPS=0.605 LKLS=11.893 |
# Test F1: 0.6818
# Test ACC: 0.5942
# Test AUC: 0.5627
# Train F1: 0.9573
# 01300: TRAIN| LT=0.979 LP=0.122 LKL=13.664 LPS=0.601 LKLS=11.978 |
# Test F1: 0.6667
# Test ACC: 0.5652
# Test AUC: 0.5509
# Train F1: 0.9657
# 01350: TRAIN| LT=0.949 LP=0.111 LKL=13.770 LPS=0.578 LKLS=12.253 |
# Test F1: 0.6742
# Test ACC: 0.5797
# Test AUC: 0.5773
# Train F1: 0.9653
# 01400: TRAIN| LT=0.905 LP=0.121 LKL=13.669 LPS=0.530 LKLS=11.781 |
# Test F1: 0.6824
# Test ACC: 0.6087
# Test AUC: 0.5600
# Train F1: 0.9630
# 01450: TRAIN| LT=0.944 LP=0.126 LKL=13.405 LPS=0.574 LKLS=10.949 |
# Test F1: 0.6742
# Test ACC: 0.5797
# Test AUC: 0.5664
# Train F1: 0.9524
# 01500: TRAIN| LT=0.899 LP=0.115 LKL=13.739 LPS=0.528 LKLS=11.796 |
# Test F1: 0.6818
# Test ACC: 0.5942
# Test AUC: 0.5745
# Train F1: 0.9580
# 01550: TRAIN| LT=0.983 LP=0.156 LKL=13.530 LPS=0.578 LKLS=11.311 |
# Test F1: 0.6742
# Test ACC: 0.5797
# Test AUC: 0.5764
# Train F1: 0.9630
# 01600: TRAIN| LT=0.922 LP=0.114 LKL=13.887 LPS=0.550 LKLS=11.959 |
# Test F1: 0.6667
# Test ACC: 0.5652
# Test AUC: 0.5745
# Train F1: 0.9714
# 01650: TRAIN| LT=0.959 LP=0.114 LKL=13.574 LPS=0.597 LKLS=11.329 |
# Test F1: 0.6667
# Test ACC: 0.5652
# Test AUC: 0.5818
# Train F1: 0.9667
# 01700: TRAIN| LT=0.879 LP=0.108 LKL=13.955 LPS=0.512 LKLS=11.949 |
# Test F1: 0.6739
# Test ACC: 0.5652
# Test AUC: 0.5727
# Train F1: 0.9711
# 01750: TRAIN| LT=0.908 LP=0.096 LKL=13.968 LPS=0.555 LKLS=11.828 |
# Test F1: 0.6818
# Test ACC: 0.5942
# Test AUC: 0.5818
# Train F1: 0.9745
# 01800: TRAIN| LT=0.874 LP=0.096 LKL=13.891 LPS=0.524 LKLS=11.489 |
# Test F1: 0.6813
# Test ACC: 0.5797
# Test AUC: 0.5800
# Train F1: 0.9773
# 01850: TRAIN| LT=0.846 LP=0.075 LKL=14.176 LPS=0.505 LKLS=12.381 |
# Test F1: 0.6897
# Test ACC: 0.6087
# Test AUC: 0.5845
# Train F1: 0.9801
# 01900: TRAIN| LT=0.822 LP=0.091 LKL=13.731 LPS=0.479 LKLS=11.369 |
# Test F1: 0.6739
# Test ACC: 0.5652
# Test AUC: 0.5718
# Train F1: 0.9714
# 01950: TRAIN| LT=0.913 LP=0.119 LKL=13.589 LPS=0.550 LKLS=10.752 |
# Test F1: 0.6667
# Test ACC: 0.5797
# Test AUC: 0.5745
# Train F1: 0.9661
# 02000: TRAIN| LT=0.873 LP=0.102 LKL=13.902 LPS=0.517 LKLS=11.484 |
# Test F1: 0.6517
# Test ACC: 0.5507
# Test AUC: 0.5818
# f1: 0.7787610619469026
# acc: 0.6376811594202898
# auc: 0.5554545454545454
# f1 [0.7872340425531915, 0.7719298245614035, 0.7787610619469026, 0.7850467289719627, 0.7787610619469026]
# average f1: 0.7803465439960726±0.005392551304907829
# acc [0.7142857142857143, 0.6285714285714286, 0.6376811594202898, 0.6666666666666666, 0.6376811594202898]
# average acc: 0.6569772256728779±0.031399725439809054
# auc [0.7858391608391608, 0.6162587412587412, 0.5309090909090909, 0.6854545454545454, 0.5554545454545454]
# average auc: 0.6347832167832168±0.09253270783705977
