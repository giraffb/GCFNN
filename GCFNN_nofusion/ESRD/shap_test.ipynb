# %%
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import numpy as np
import pandas as pd
import sys, os
import torch
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from GCFNN import GCFNN
import torch.nn.functional as F
from numpy.random import randint

# %%
def concatenated_tensor(X_set, M):
    concatenated_tensor_list = []
    # 遍历索引范围为 0 到 M-1 的值
    for i in range(M.shape[1]):
        # 拼接 X_set[i]
        concatenated_tensor_list.append(X_set[i])
        ## 将 adj_list[i] 转换为密集张量并拼接
        #adj_dense_tensor = adj_list[i].to_dense()
        #concatenated_tensor_list.append(adj_dense_tensor)
        
    # 将 tr_M 转换为张量并拼接
    M_tensor = torch.from_numpy(M)
    concatenated_tensor_list.append(M_tensor)
    # 沿着 dim=1 拼接所有张量
    concatenated_tensor = torch.cat(concatenated_tensor_list, dim=1)
    return concatenated_tensor

# %%
# read data
meta_data=pd.read_csv('meta.csv',index_col=0)
metabolomics=pd.read_csv('metabolomics.csv',index_col=0).fillna(0)
metagenomics=pd.read_csv('metagenomics_species.csv',index_col=0)
data_class={'Control':0,'ESRD':1}
meta_data['Study.Group']=meta_data['Study.Group'].map(data_class)

x1=metagenomics
x2=metabolomics
print('输入各组学数据表：',x1.shape,x2.shape,meta_data.shape)

#重构数据表和标签表
X1=pd.concat([x1,x2],axis=1).iloc[:,:x1.shape[1]]
X2=pd.concat([x1,x2],axis=1).iloc[:,x1.shape[1]:x1.shape[1]+x2.shape[1]]
index_new=X1.index
print(index_new)
missing_rate=(len(x1)+len(x2))/(len(index_new)*2)
print('数据完整率missing_rate :',missing_rate)
                                        
meta_data=meta_data.reindex(index_new)
X1=array(X1.reindex(index_new))
X2=array(X2.reindex(index_new))
print('集合所有样本重构数据表：',X1.shape,X2.shape,meta_data.shape)
X_set=[X1,X2]
M        = len(X_set)
Mask     = np.ones([np.shape(X_set[0])[0], M])
#生成表示组学缺失情况的掩码矩阵，将缺失组学部分填补为0
for m_idx in range(M):
    Mask[np.isnan(X_set[m_idx]).all(axis=1), m_idx] = 0
    #X_set[m_idx][Mask[:, m_idx] == 0] = np.mean(X_set[m_idx][Mask[:, m_idx] == 1], axis=0)
    X_set[m_idx][Mask[:, m_idx] == 0] = 0
    
#对宏基因组数据预处理
def log(base,x):
    return np.log(x)/np.log(base)
X_set[0]=log(2,2*X_set[0]+0.00001)

#print(Mask)
#print(X_set)
Y = meta_data['Study.Group'].tolist()
Y = np.array(Y)
Y_onehot = np.zeros((Y.shape[0], 2))
Y_onehot[np.arange(Y.shape[0]), Y] = 1
print('标签转换为one-hot编码：', Y_onehot.shape, np.sum(Y_onehot[:, 0]))
# Out:
# 输入各组学数据表： (287, 780) (287, 276) (287, 1)
# Index(['CON-001', 'CON-002', 'CON-003', 'CON-004', 'CON-005', 'CON-006',
#        'CON-007', 'CON-008', 'CON-009', 'CON-010',
#        ...
#        'KD-214', 'KD-215', 'KD-216', 'KD-217', 'KD-218', 'KD-219', 'KD-220',
#        'KD-221', 'KD-222', 'KD-223'],
#       dtype='object', name='Sample', length=287)
# 数据完整率missing_rate : 1.0
# 集合所有样本重构数据表： (287, 780) (287, 276) (287, 1)
# 标签转换为one-hot编码： (287, 2) 67.0

# %%
# 指定保存模型的文件夹路径
folder_path = 'model_shap'
# 创建文件夹
os.makedirs(folder_path, exist_ok=True)

cv = StratifiedKFold(n_splits=5,shuffle = True,random_state = 20)
auc_cv = []
acc_cv = []
f1_cv = []
for i,(train_index, test_index) in enumerate(cv.split(X_set[0],np.argmax(Y_onehot,axis=1))):
    tr_X_set, te_X_set, va_X_set = {}, {}, {}
    for m in range(len(X_set)):
        tr_X_set[m],tr_Y_onehot,tr_M = X_set[m][train_index],Y_onehot[train_index],Mask[train_index]
        te_X_set[m],te_Y_onehot,te_M = X_set[m][test_index],Y_onehot[test_index],Mask[test_index]
        #归一化
        #print(te_Y_onehot)
    def Normalize(data):
        """
        :param data:Input data
        :return:normalized data
        """
        mean = np.mean(data)
        mx = np.max(data)
        mn = np.min(data)
        return mean, mx, mn
    
    for m in range(M):
        mean, mx, mn = Normalize(tr_X_set[m])
        tr_X_set[m] = (tr_X_set[m] - mean) / (mx - mn)
        te_X_set[m] = (te_X_set[m] - mean) / (mx - mn)
    
    x_dim_set    = [tr_X_set[m].shape[1] for m in range(len(tr_X_set))]
    y_dim        = np.shape(tr_Y_onehot)[1]
    
    input_dims = {
        'x_dim_set': x_dim_set,
        'y_dim': y_dim,
        'z_dim': 50,
        #'steps_per_batch': steps_per_batch
    }
    network_settings = {
        'dim_enc': 100,
        'num_layers_enc': 3,   #view-specific
        'dim_specificpre': 100,
        'num_layers_specificpre': 2,  #multi-view
        'dim_joint_pre': 100,
        'num_layers_jointpre': 2,
        'dropout': 0.5,
        'edge_per_node': 1, 
        'ITERATION': 2000
    }
    
    for m in range(M):
        tr_X_set[m] = torch.from_numpy(tr_X_set[m])
        te_X_set[m] = torch.from_numpy(te_X_set[m])
    tr_Y_onehot = torch.from_numpy(tr_Y_onehot)
    te_Y_onehot = torch.from_numpy(te_Y_onehot)
    #tansform
    tr_input = concatenated_tensor(tr_X_set, tr_M)
    te_input = concatenated_tensor(te_X_set, te_M)
    GPU_use = True
    model = GCFNN(input_dims, network_settings, cuda = GPU_use)
    if GPU_use: 
        model = model.cuda()
        tr_input = tr_input.cuda()
        te_input = te_input.cuda()
        tr_Y_onehot = tr_Y_onehot.cuda()
        te_Y_onehot = te_Y_onehot.cuda()
    model_save, maxf1, maxacc, maxauc = model.train_model(train_input = tr_input, test_input = te_input, alpha = 1.0, beta = 0.01, l_rate = 0.0005, tr_Y_onehot = tr_Y_onehot, te_Y_onehot = te_Y_onehot)
    model_path = os.path.join(folder_path, 'model_'+str(i)+'.pth')
    torch.save(model_save, model_path)
    f1_cv.append(maxf1)
    acc_cv.append(maxacc)
    auc_cv.append(maxauc)
print('f1', f1_cv)
print('average f1: {}±{}'.format(np.mean(f1_cv), np.std(f1_cv)))
print('acc', acc_cv)
print('average acc: {}±{}'.format(np.mean(acc_cv), np.std(acc_cv)))
print('auc', auc_cv)
print('average auc: {}±{}'.format(np.mean(auc_cv), np.std(auc_cv)))
# Out:
# Train F1: 0.8883
# 00050: TRAIN| LT=1.590 LP=0.465 LKL=11.270 LPS=0.918 LKLS=9.434 |
# Test F1: 0.8627
# Test ACC: 0.7586
# Test AUC: 0.9610
# Train F1: 0.9613
# 00100: TRAIN| LT=1.075 LP=0.186 LKL=12.359 LPS=0.610 LKLS=15.621 |
# Test F1: 0.9670
# Test ACC: 0.9483
# Test AUC: 0.9756
# Train F1: 0.9887
# 00150: TRAIN| LT=0.886 LP=0.081 LKL=11.990 LPS=0.553 LKLS=13.206 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9821
# Train F1: 0.9914
# 00200: TRAIN| LT=0.807 LP=0.047 LKL=11.998 LPS=0.518 LKLS=12.245 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9789
# Train F1: 0.9887
# 00250: TRAIN| LT=0.752 LP=0.043 LKL=11.979 LPS=0.477 LKLS=11.297 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9740
# Train F1: 0.9858
# 00300: TRAIN| LT=0.691 LP=0.046 LKL=12.399 LPS=0.406 LKLS=11.591 |
# Test F1: 0.9451
# Test ACC: 0.9138
# Test AUC: 0.9838
# Train F1: 0.9915
# 00350: TRAIN| LT=0.586 LP=0.023 LKL=12.445 LPS=0.322 LKLS=11.639 |
# Test F1: 0.9348
# Test ACC: 0.8966
# Test AUC: 0.9821
# Train F1: 0.9972
# 00400: TRAIN| LT=0.463 LP=0.008 LKL=12.503 LPS=0.214 LKLS=11.561 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9854
# Train F1: 0.9915
# 00450: TRAIN| LT=0.414 LP=0.013 LKL=12.778 LPS=0.147 LKLS=12.731 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9838
# Train F1: 0.9972
# 00500: TRAIN| LT=0.402 LP=0.013 LKL=12.667 LPS=0.137 LKLS=12.504 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9821
# Train F1: 1.0000
# 00550: TRAIN| LT=0.349 LP=0.010 LKL=12.730 LPS=0.093 LKLS=11.896 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9805
# Train F1: 1.0000
# 00600: TRAIN| LT=0.358 LP=0.011 LKL=12.804 LPS=0.093 LKLS=12.606 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9805
# Train F1: 1.0000
# 00650: TRAIN| LT=0.326 LP=0.010 LKL=12.610 LPS=0.076 LKLS=11.444 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9789
# Train F1: 1.0000
# 00700: TRAIN| LT=0.356 LP=0.018 LKL=12.515 LPS=0.102 LKLS=11.060 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9805
# Train F1: 0.9943
# 00750: TRAIN| LT=0.299 LP=0.005 LKL=12.696 LPS=0.051 LKLS=11.621 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9805
# Train F1: 0.9915
# 00800: TRAIN| LT=0.313 LP=0.013 LKL=12.599 LPS=0.060 LKLS=11.484 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9789
# Train F1: 1.0000
# 00850: TRAIN| LT=0.297 LP=0.006 LKL=12.514 LPS=0.056 LKLS=11.024 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9773
# Train F1: 0.9972
# 00900: TRAIN| LT=0.292 LP=0.005 LKL=12.563 LPS=0.052 LKLS=10.950 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9773
# Train F1: 1.0000
# 00950: TRAIN| LT=0.262 LP=0.002 LKL=12.482 LPS=0.023 LKLS=11.262 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9773
# Train F1: 0.9943
# 01000: TRAIN| LT=0.271 LP=0.003 LKL=12.434 LPS=0.041 LKLS=10.307 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9773
# Train F1: 1.0000
# 01050: TRAIN| LT=0.277 LP=0.011 LKL=12.490 LPS=0.031 LKLS=10.919 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9805
# Train F1: 1.0000
# 01100: TRAIN| LT=0.292 LP=0.008 LKL=12.307 LPS=0.063 LKLS=9.771 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9805
# Train F1: 1.0000
# 01150: TRAIN| LT=0.260 LP=0.013 LKL=12.373 LPS=0.024 LKLS=9.914 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9773
# Train F1: 0.9943
# 01200: TRAIN| LT=0.302 LP=0.012 LKL=12.344 LPS=0.066 LKLS=10.046 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9773
# Train F1: 1.0000
# 01250: TRAIN| LT=0.273 LP=0.010 LKL=12.209 LPS=0.044 LKLS=9.689 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9789
# Train F1: 0.9972
# 01300: TRAIN| LT=0.265 LP=0.002 LKL=12.421 LPS=0.037 LKLS=10.273 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9821
# Train F1: 1.0000
# 01350: TRAIN| LT=0.265 LP=0.004 LKL=12.173 LPS=0.045 LKLS=9.467 |
# Test F1: 0.9333
# Test ACC: 0.8966
# Test AUC: 0.9805
# Train F1: 0.9972
# 01400: TRAIN| LT=0.277 LP=0.001 LKL=12.210 LPS=0.058 LKLS=9.615 |
# Test F1: 0.9556
# Test ACC: 0.9310
# Test AUC: 0.9838
# Train F1: 0.9943
# 01450: TRAIN| LT=0.336 LP=0.025 LKL=12.330 LPS=0.090 LKLS=9.751 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9821
# Train F1: 1.0000
# 01500: TRAIN| LT=0.261 LP=0.002 LKL=12.279 LPS=0.039 LKLS=9.778 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9838
# Train F1: 0.9972
# 01550: TRAIN| LT=0.229 LP=0.003 LKL=12.132 LPS=0.014 LKLS=9.160 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9854
# Train F1: 1.0000
# 01600: TRAIN| LT=0.248 LP=0.003 LKL=12.226 LPS=0.029 LKLS=9.396 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9821
# Train F1: 0.9944
# 01650: TRAIN| LT=0.255 LP=0.007 LKL=12.232 LPS=0.029 LKLS=9.678 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9805
# Train F1: 1.0000
# 01700: TRAIN| LT=0.255 LP=0.008 LKL=12.096 LPS=0.037 LKLS=8.937 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9789
# Train F1: 0.9972
# 01750: TRAIN| LT=0.236 LP=0.006 LKL=12.007 LPS=0.024 LKLS=8.645 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9838
# Train F1: 1.0000
# 01800: TRAIN| LT=0.254 LP=0.020 LKL=12.162 LPS=0.022 LKLS=9.034 |
# Test F1: 0.9655
# Test ACC: 0.9483
# Test AUC: 0.9821
# Train F1: 0.9972
# 01850: TRAIN| LT=0.248 LP=0.004 LKL=12.056 LPS=0.033 LKLS=8.991 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9821
# Train F1: 1.0000
# 01900: TRAIN| LT=0.228 LP=0.000 LKL=11.914 LPS=0.024 LKLS=8.506 |
# Test F1: 0.9438
# Test ACC: 0.9138
# Test AUC: 0.9838
# Train F1: 0.9972
# 01950: TRAIN| LT=0.236 LP=0.008 LKL=11.967 LPS=0.020 LKLS=8.810 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9854
# Train F1: 1.0000
# 02000: TRAIN| LT=0.242 LP=0.001 LKL=11.918 LPS=0.040 LKLS=8.159 |
# Test F1: 0.9545
# Test ACC: 0.9310
# Test AUC: 0.9854
# f1: 0.967032967032967
# acc: 0.9482758620689655
# auc: 0.9756493506493507
# Train F1: 0.8691
# 00050: TRAIN| LT=1.592 LP=0.470 LKL=11.336 LPS=0.917 LKLS=9.144 |
# Test F1: 0.8627
# Test ACC: 0.7586
# Test AUC: 0.8864
# Train F1: 0.9563
# 00100: TRAIN| LT=1.126 LP=0.190 LKL=12.582 LPS=0.650 LKLS=15.998 |
# Test F1: 0.9302
# Test ACC: 0.8966
# Test AUC: 0.9513
# Train F1: 0.9972
# 00150: TRAIN| LT=0.888 LP=0.085 LKL=12.331 LPS=0.547 LKLS=13.290 |
# Test F1: 0.9524
# Test ACC: 0.9310
# Test AUC: 0.9692
# Train F1: 0.9915
# 00200: TRAIN| LT=0.763 LP=0.046 LKL=12.343 LPS=0.461 LKLS=13.227 |
# Test F1: 0.9655
# Test ACC: 0.9483
# Test AUC: 0.9773
# Train F1: 0.9886
# 00250: TRAIN| LT=0.724 LP=0.046 LKL=12.499 LPS=0.430 LKLS=12.267 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9724
# Train F1: 1.0000
# 00300: TRAIN| LT=0.607 LP=0.025 LKL=12.649 LPS=0.330 LKLS=12.521 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9838
# Train F1: 0.9972
# 00350: TRAIN| LT=0.518 LP=0.017 LKL=12.589 LPS=0.256 LKLS=11.966 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9919
# Train F1: 0.9943
# 00400: TRAIN| LT=0.451 LP=0.013 LKL=12.753 LPS=0.180 LKLS=13.040 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9903
# Train F1: 0.9915
# 00450: TRAIN| LT=0.407 LP=0.012 LKL=12.835 LPS=0.134 LKLS=13.165 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9919
# Train F1: 0.9972
# 00500: TRAIN| LT=0.439 LP=0.037 LKL=12.496 LPS=0.164 LKLS=11.326 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 1.0000
# 00550: TRAIN| LT=0.400 LP=0.008 LKL=12.649 LPS=0.142 LKLS=12.386 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 1.0000
# 00600: TRAIN| LT=0.349 LP=0.011 LKL=12.670 LPS=0.089 LKLS=12.148 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 0.9972
# 00650: TRAIN| LT=0.345 LP=0.005 LKL=12.622 LPS=0.095 LKLS=11.892 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 0.9972
# 00700: TRAIN| LT=0.333 LP=0.021 LKL=12.410 LPS=0.079 LKLS=10.929 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 0.9972
# 00750: TRAIN| LT=0.327 LP=0.017 LKL=12.547 LPS=0.069 LKLS=11.472 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9984
# Train F1: 1.0000
# 00800: TRAIN| LT=0.314 LP=0.010 LKL=12.346 LPS=0.076 LKLS=10.471 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 0.9972
# 00850: TRAIN| LT=0.285 LP=0.004 LKL=12.466 LPS=0.045 LKLS=11.249 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9968
# Train F1: 0.9972
# 00900: TRAIN| LT=0.285 LP=0.009 LKL=12.283 LPS=0.053 LKLS=10.042 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 1.0000
# 00950: TRAIN| LT=0.293 LP=0.005 LKL=12.437 LPS=0.052 LKLS=11.083 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# Train F1: 1.0000
# 01000: TRAIN| LT=0.286 LP=0.021 LKL=12.369 LPS=0.039 LKLS=10.249 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# Train F1: 0.9972
# 01050: TRAIN| LT=0.269 LP=0.011 LKL=12.190 LPS=0.037 LKLS=9.855 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# Train F1: 1.0000
# 01100: TRAIN| LT=0.261 LP=0.004 LKL=12.249 LPS=0.032 LKLS=10.318 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# Train F1: 0.9943
# 01150: TRAIN| LT=0.278 LP=0.004 LKL=12.265 LPS=0.048 LKLS=10.271 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# Train F1: 0.9972
# 01200: TRAIN| LT=0.263 LP=0.014 LKL=12.190 LPS=0.026 LKLS=10.022 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 1.0000
# Train F1: 0.9972
# 01250: TRAIN| LT=0.275 LP=0.002 LKL=12.340 LPS=0.044 LKLS=10.537 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9984
# Train F1: 0.9972
# 01300: TRAIN| LT=0.260 LP=0.008 LKL=12.189 LPS=0.033 LKLS=9.633 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9984
# Train F1: 0.9972
# 01350: TRAIN| LT=0.255 LP=0.011 LKL=12.135 LPS=0.029 LKLS=9.371 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# Train F1: 1.0000
# 01400: TRAIN| LT=0.258 LP=0.008 LKL=12.170 LPS=0.030 LKLS=9.845 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# Train F1: 0.9972
# 01450: TRAIN| LT=0.249 LP=0.001 LKL=12.207 LPS=0.028 LKLS=9.795 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9984
# Train F1: 1.0000
# 01500: TRAIN| LT=0.262 LP=0.008 LKL=12.008 LPS=0.043 LKLS=9.137 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9968
# Train F1: 1.0000
# 01550: TRAIN| LT=0.281 LP=0.007 LKL=12.094 LPS=0.064 LKLS=8.961 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# Train F1: 1.0000
# 01600: TRAIN| LT=0.274 LP=0.042 LKL=11.999 LPS=0.022 LKLS=8.952 |
# Test F1: 0.9767
# Test ACC: 0.9655
# Test AUC: 0.9984
# Train F1: 1.0000
# 01650: TRAIN| LT=0.242 LP=0.001 LKL=12.000 LPS=0.029 LKLS=9.230 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# Train F1: 1.0000
# 01700: TRAIN| LT=0.288 LP=0.008 LKL=11.944 LPS=0.074 LKLS=8.697 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# Train F1: 1.0000
# 01750: TRAIN| LT=0.257 LP=0.003 LKL=11.943 LPS=0.048 LKLS=8.696 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9951
# Train F1: 1.0000
# 01800: TRAIN| LT=0.240 LP=0.003 LKL=11.985 LPS=0.027 LKLS=9.069 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9984
# Train F1: 1.0000
# 01850: TRAIN| LT=0.280 LP=0.038 LKL=11.851 LPS=0.042 LKLS=8.147 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9968
# Train F1: 0.9972
# 01900: TRAIN| LT=0.256 LP=0.018 LKL=11.909 LPS=0.036 LKLS=8.261 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9968
# Train F1: 1.0000
# 01950: TRAIN| LT=0.222 LP=0.003 LKL=11.743 LPS=0.020 LKLS=8.041 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 0.9968
# Train F1: 1.0000
# 02000: TRAIN| LT=0.244 LP=0.004 LKL=11.860 LPS=0.036 LKLS=8.538 |
# Test F1: 0.9647
# Test ACC: 0.9483
# Test AUC: 1.0000
# f1: 0.9767441860465117
# acc: 0.9655172413793104
# auc: 1.0
# Train F1: 0.8691
# 00050: TRAIN| LT=1.590 LP=0.488 LKL=11.061 LPS=0.909 LKLS=8.226 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.9003
# Train F1: 0.9591
# 00100: TRAIN| LT=1.130 LP=0.189 LKL=12.314 LPS=0.668 LKLS=15.018 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9528
# Train F1: 0.9857
# 00150: TRAIN| LT=0.910 LP=0.086 LKL=12.212 LPS=0.572 LKLS=12.947 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9563
# Train F1: 1.0000
# 00200: TRAIN| LT=0.777 LP=0.042 LKL=12.211 LPS=0.487 LKLS=12.657 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9476
# Train F1: 0.9972
# 00250: TRAIN| LT=0.752 LP=0.041 LKL=12.346 LPS=0.466 LKLS=12.100 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9528
# Train F1: 0.9972
# 00300: TRAIN| LT=0.706 LP=0.022 LKL=12.509 LPS=0.436 LKLS=12.235 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9703
# Train F1: 0.9943
# 00350: TRAIN| LT=0.642 LP=0.015 LKL=12.496 LPS=0.385 LKLS=11.767 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9790
# Train F1: 0.9943
# 00400: TRAIN| LT=0.545 LP=0.049 LKL=12.491 LPS=0.255 LKLS=11.549 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9843
# Train F1: 0.9972
# 00450: TRAIN| LT=0.467 LP=0.009 LKL=12.766 LPS=0.204 LKLS=12.594 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9860
# Train F1: 0.9972
# 00500: TRAIN| LT=0.414 LP=0.020 LKL=12.573 LPS=0.150 LKLS=11.808 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9913
# Train F1: 0.9943
# 00550: TRAIN| LT=0.390 LP=0.009 LKL=12.681 LPS=0.135 LKLS=11.913 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9895
# Train F1: 1.0000
# 00600: TRAIN| LT=0.359 LP=0.009 LKL=12.664 LPS=0.102 LKLS=12.273 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9965
# Train F1: 1.0000
# 00650: TRAIN| LT=0.352 LP=0.033 LKL=12.599 LPS=0.077 LKLS=11.523 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9895
# Train F1: 1.0000
# 00700: TRAIN| LT=0.343 LP=0.004 LKL=12.500 LPS=0.102 LKLS=11.114 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9930
# Train F1: 0.9972
# 00750: TRAIN| LT=0.345 LP=0.004 LKL=12.584 LPS=0.101 LKLS=11.405 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9948
# Train F1: 0.9972
# 00800: TRAIN| LT=0.337 LP=0.018 LKL=12.405 LPS=0.087 LKLS=10.774 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9972
# 00850: TRAIN| LT=0.358 LP=0.031 LKL=12.375 LPS=0.097 LKLS=10.677 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9948
# Train F1: 0.9972
# 00900: TRAIN| LT=0.324 LP=0.007 LKL=12.376 LPS=0.084 LKLS=10.940 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9972
# 00950: TRAIN| LT=0.331 LP=0.006 LKL=12.402 LPS=0.094 LKLS=10.704 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9972
# 01000: TRAIN| LT=0.331 LP=0.014 LKL=12.259 LPS=0.093 LKLS=10.179 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9930
# Train F1: 1.0000
# 01050: TRAIN| LT=0.287 LP=0.007 LKL=12.313 LPS=0.053 LKLS=10.335 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9965
# Train F1: 0.9972
# 01100: TRAIN| LT=0.305 LP=0.005 LKL=12.311 LPS=0.071 LKLS=10.525 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9930
# Train F1: 1.0000
# 01150: TRAIN| LT=0.275 LP=0.010 LKL=12.363 LPS=0.036 LKLS=10.634 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 1.0000
# 01200: TRAIN| LT=0.321 LP=0.028 LKL=12.326 LPS=0.065 LKLS=10.464 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 0.9972
# 01250: TRAIN| LT=0.263 LP=0.006 LKL=12.187 LPS=0.039 LKLS=9.605 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9972
# 01300: TRAIN| LT=0.274 LP=0.020 LKL=12.180 LPS=0.035 LKLS=9.687 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9930
# Train F1: 0.9972
# 01350: TRAIN| LT=0.284 LP=0.002 LKL=12.306 LPS=0.052 LKLS=10.668 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9965
# Train F1: 1.0000
# 01400: TRAIN| LT=0.254 LP=0.005 LKL=12.229 LPS=0.027 LKLS=9.950 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 0.9972
# 01450: TRAIN| LT=0.285 LP=0.016 LKL=12.166 LPS=0.051 LKLS=9.627 |
# Test F1: 0.9767
# Test ACC: 0.9649
# Test AUC: 1.0000
# Train F1: 1.0000
# 01500: TRAIN| LT=0.282 LP=0.016 LKL=12.297 LPS=0.042 LKLS=10.154 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 1.0000
# 01550: TRAIN| LT=0.258 LP=0.005 LKL=12.018 LPS=0.041 LKLS=9.113 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9948
# Train F1: 1.0000
# 01600: TRAIN| LT=0.245 LP=0.004 LKL=12.076 LPS=0.026 LKLS=9.470 |
# Test F1: 0.9655
# Test ACC: 0.9474
# Test AUC: 0.9965
# Train F1: 0.9972
# 01650: TRAIN| LT=0.272 LP=0.007 LKL=12.011 LPS=0.052 LKLS=9.239 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9965
# Train F1: 1.0000
# 01700: TRAIN| LT=0.266 LP=0.002 LKL=12.046 LPS=0.049 LKLS=9.471 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 1.0000
# Train F1: 1.0000
# 01750: TRAIN| LT=0.272 LP=0.005 LKL=11.922 LPS=0.058 LKLS=8.954 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 1.0000
# Train F1: 0.9972
# 01800: TRAIN| LT=0.277 LP=0.004 LKL=12.026 LPS=0.065 LKLS=8.809 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9983
# Train F1: 1.0000
# 01850: TRAIN| LT=0.277 LP=0.009 LKL=11.952 LPS=0.057 LKLS=9.176 |
# Test F1: 0.9778
# Test ACC: 0.9649
# Test AUC: 0.9983
# Train F1: 0.9972
# 01900: TRAIN| LT=0.261 LP=0.009 LKL=11.960 LPS=0.047 LKLS=8.626 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9983
# Train F1: 0.9972
# 01950: TRAIN| LT=0.247 LP=0.012 LKL=11.940 LPS=0.029 LKLS=8.554 |
# Test F1: 0.9773
# Test ACC: 0.9649
# Test AUC: 0.9983
# Train F1: 1.0000
# 02000: TRAIN| LT=0.237 LP=0.003 LKL=11.879 LPS=0.029 LKLS=8.720 |
# Test F1: 0.9888
# Test ACC: 0.9825
# Test AUC: 0.9983
# f1: 0.9887640449438202
# acc: 0.9824561403508771
# auc: 1.0
# Train F1: 0.8678
# 00050: TRAIN| LT=1.651 LP=0.466 LKL=11.273 LPS=0.981 LKLS=9.037 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.8934
# Train F1: 0.9804
# 00100: TRAIN| LT=1.102 LP=0.199 LKL=12.263 LPS=0.634 LKLS=14.601 |
# Test F1: 0.9231
# Test ACC: 0.8772
# Test AUC: 0.9196
# Train F1: 0.9858
# 00150: TRAIN| LT=0.921 LP=0.087 LKL=12.089 LPS=0.590 LKLS=12.317 |
# Test F1: 0.9231
# Test ACC: 0.8772
# Test AUC: 0.9196
# Train F1: 0.9831
# 00200: TRAIN| LT=0.861 LP=0.109 LKL=11.956 LPS=0.521 LKLS=11.114 |
# Test F1: 0.9231
# Test ACC: 0.8772
# Test AUC: 0.9178
# Train F1: 0.9887
# 00250: TRAIN| LT=0.754 LP=0.062 LKL=12.119 LPS=0.458 LKLS=11.255 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9353
# Train F1: 0.9944
# 00300: TRAIN| LT=0.655 LP=0.028 LKL=12.442 LPS=0.387 LKLS=11.633 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9458
# Train F1: 0.9972
# 00350: TRAIN| LT=0.626 LP=0.039 LKL=12.438 LPS=0.347 LKLS=11.529 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9545
# Train F1: 0.9972
# 00400: TRAIN| LT=0.540 LP=0.017 LKL=12.510 LPS=0.283 LKLS=11.517 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9668
# Train F1: 0.9915
# 00450: TRAIN| LT=0.542 LP=0.042 LKL=12.557 LPS=0.253 LKLS=12.098 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9738
# Train F1: 0.9943
# 00500: TRAIN| LT=0.479 LP=0.032 LKL=12.759 LPS=0.199 LKLS=12.045 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9790
# Train F1: 1.0000
# 00550: TRAIN| LT=0.403 LP=0.012 LKL=12.698 LPS=0.140 LKLS=12.364 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9860
# Train F1: 0.9944
# 00600: TRAIN| LT=0.382 LP=0.010 LKL=12.583 LPS=0.135 LKLS=11.115 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9878
# Train F1: 0.9944
# 00650: TRAIN| LT=0.415 LP=0.035 LKL=12.607 LPS=0.131 LKLS=12.310 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9930
# Train F1: 0.9944
# 00700: TRAIN| LT=0.372 LP=0.007 LKL=12.593 LPS=0.126 LKLS=11.316 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9878
# Train F1: 1.0000
# 00750: TRAIN| LT=0.365 LP=0.022 LKL=12.584 LPS=0.101 LKLS=11.577 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9913
# Train F1: 0.9972
# 00800: TRAIN| LT=0.362 LP=0.008 LKL=12.444 LPS=0.121 LKLS=10.861 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9895
# Train F1: 1.0000
# 00850: TRAIN| LT=0.341 LP=0.004 LKL=12.686 LPS=0.092 LKLS=11.786 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9930
# Train F1: 0.9972
# 00900: TRAIN| LT=0.384 LP=0.020 LKL=12.601 LPS=0.124 LKLS=11.429 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9948
# Train F1: 1.0000
# 00950: TRAIN| LT=0.361 LP=0.025 LKL=12.588 LPS=0.094 LKLS=11.609 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9930
# Train F1: 0.9972
# 01000: TRAIN| LT=0.377 LP=0.009 LKL=12.530 LPS=0.129 LKLS=11.345 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9965
# Train F1: 0.9972
# 01050: TRAIN| LT=0.353 LP=0.017 LKL=12.400 LPS=0.106 LKLS=10.615 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 0.9943
# 01100: TRAIN| LT=0.298 LP=0.012 LKL=12.362 LPS=0.058 LKLS=10.490 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 0.9972
# 01150: TRAIN| LT=0.305 LP=0.006 LKL=12.403 LPS=0.069 LKLS=10.577 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 0.9943
# 01200: TRAIN| LT=0.354 LP=0.002 LKL=12.458 LPS=0.121 LKLS=10.653 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 0.9972
# 01250: TRAIN| LT=0.324 LP=0.012 LKL=12.440 LPS=0.079 LKLS=10.869 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9965
# Train F1: 1.0000
# 01300: TRAIN| LT=0.337 LP=0.007 LKL=12.420 LPS=0.098 LKLS=10.813 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 0.9972
# 01350: TRAIN| LT=0.382 LP=0.039 LKL=12.494 LPS=0.108 LKLS=11.085 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 1.0000
# 01400: TRAIN| LT=0.300 LP=0.009 LKL=12.417 LPS=0.057 LKLS=11.013 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 1.0000
# 01450: TRAIN| LT=0.288 LP=0.005 LKL=12.240 LPS=0.063 LKLS=9.748 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 0.9972
# 01500: TRAIN| LT=0.273 LP=0.006 LKL=12.356 LPS=0.040 LKLS=10.322 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 0.9915
# 01550: TRAIN| LT=0.291 LP=0.004 LKL=12.154 LPS=0.072 LKLS=9.351 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 0.9943
# 01600: TRAIN| LT=0.291 LP=0.011 LKL=12.369 LPS=0.052 LKLS=10.463 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 0.9943
# 01650: TRAIN| LT=0.318 LP=0.002 LKL=12.336 LPS=0.095 LKLS=9.718 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 0.9972
# 01700: TRAIN| LT=0.288 LP=0.002 LKL=12.261 LPS=0.068 LKLS=9.623 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 0.9943
# 01750: TRAIN| LT=0.294 LP=0.003 LKL=12.338 LPS=0.067 LKLS=10.104 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9930
# Train F1: 0.9943
# 01800: TRAIN| LT=0.287 LP=0.025 LKL=12.376 LPS=0.037 LKLS=10.231 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# Train F1: 1.0000
# 01850: TRAIN| LT=0.268 LP=0.002 LKL=12.259 LPS=0.041 LKLS=10.207 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 1.0000
# 01900: TRAIN| LT=0.318 LP=0.008 LKL=12.354 LPS=0.089 LKLS=9.779 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 1.0000
# 01950: TRAIN| LT=0.276 LP=0.001 LKL=12.107 LPS=0.061 LKLS=9.251 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9948
# Train F1: 1.0000
# 02000: TRAIN| LT=0.310 LP=0.002 LKL=12.073 LPS=0.096 LKLS=9.010 |
# Test F1: 0.9670
# Test ACC: 0.9474
# Test AUC: 0.9948
# f1: 0.967032967032967
# acc: 0.9473684210526315
# auc: 0.9965034965034965
# Train F1: 0.8670
# 00050: TRAIN| LT=1.629 LP=0.465 LKL=11.482 LPS=0.951 LKLS=9.773 |
# Test F1: 0.8713
# Test ACC: 0.7719
# Test AUC: 0.9021
# Train F1: 0.9565
# 00100: TRAIN| LT=1.128 LP=0.211 LKL=12.391 LPS=0.638 LKLS=15.530 |
# Test F1: 0.9231
# Test ACC: 0.8772
# Test AUC: 0.9231
# Train F1: 0.9943
# 00150: TRAIN| LT=0.902 LP=0.096 LKL=12.115 LPS=0.549 LKLS=13.466 |
# Test F1: 0.9130
# Test ACC: 0.8596
# Test AUC: 0.9073
# Train F1: 0.9915
# 00200: TRAIN| LT=0.809 LP=0.054 LKL=12.114 LPS=0.515 LKLS=11.837 |
# Test F1: 0.8889
# Test ACC: 0.8246
# Test AUC: 0.8934
# Train F1: 0.9887
# 00250: TRAIN| LT=0.735 LP=0.039 LKL=12.409 LPS=0.446 LKLS=12.530 |
# Test F1: 0.8889
# Test ACC: 0.8246
# Test AUC: 0.8899
# Train F1: 0.9886
# 00300: TRAIN| LT=0.648 LP=0.062 LKL=12.552 LPS=0.343 LKLS=11.781 |
# Test F1: 0.8966
# Test ACC: 0.8421
# Test AUC: 0.8986
# Train F1: 0.9943
# 00350: TRAIN| LT=0.590 LP=0.021 LKL=12.748 LPS=0.320 LKLS=12.099 |
# Test F1: 0.9195
# Test ACC: 0.8772
# Test AUC: 0.9248
# Train F1: 1.0000
# 00400: TRAIN| LT=0.539 LP=0.030 LKL=12.801 LPS=0.259 LKLS=12.193 |
# Test F1: 0.9195
# Test ACC: 0.8772
# Test AUC: 0.9388
# Train F1: 1.0000
# 00450: TRAIN| LT=0.439 LP=0.010 LKL=12.788 LPS=0.181 LKLS=11.889 |
# Test F1: 0.9438
# Test ACC: 0.9123
# Test AUC: 0.9528
# Train F1: 1.0000
# 00500: TRAIN| LT=0.435 LP=0.012 LKL=12.822 LPS=0.173 LKLS=12.208 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9685
# Train F1: 1.0000
# 00550: TRAIN| LT=0.387 LP=0.007 LKL=12.794 LPS=0.134 LKLS=11.789 |
# Test F1: 0.9545
# Test ACC: 0.9298
# Test AUC: 0.9738
# Train F1: 0.9972
# 00600: TRAIN| LT=0.418 LP=0.014 LKL=12.720 LPS=0.159 LKLS=11.775 |
# Test F1: 0.9438
# Test ACC: 0.9123
# Test AUC: 0.9773
# Train F1: 0.9972
# 00650: TRAIN| LT=0.366 LP=0.007 LKL=12.613 LPS=0.124 LKLS=10.969 |
# Test F1: 0.9438
# Test ACC: 0.9123
# Test AUC: 0.9808
# Train F1: 0.9972
# 00700: TRAIN| LT=0.351 LP=0.005 LKL=12.624 LPS=0.106 LKLS=11.378 |
# Test F1: 0.9333
# Test ACC: 0.8947
# Test AUC: 0.9808
# Train F1: 0.9972
# 00750: TRAIN| LT=0.365 LP=0.012 LKL=12.604 LPS=0.115 LKLS=11.232 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9878
# Train F1: 0.9972
# 00800: TRAIN| LT=0.387 LP=0.005 LKL=12.699 LPS=0.137 LKLS=11.819 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9860
# Train F1: 1.0000
# 00850: TRAIN| LT=0.315 LP=0.009 LKL=12.662 LPS=0.066 LKLS=11.234 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9895
# Train F1: 0.9972
# 00900: TRAIN| LT=0.321 LP=0.015 LKL=12.704 LPS=0.064 LKLS=11.498 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9860
# Train F1: 0.9972
# 00950: TRAIN| LT=0.353 LP=0.014 LKL=12.517 LPS=0.105 LKLS=10.832 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9843
# Train F1: 0.9972
# 01000: TRAIN| LT=0.287 LP=0.013 LKL=12.413 LPS=0.045 LKLS=10.451 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9825
# Train F1: 1.0000
# 01050: TRAIN| LT=0.293 LP=0.014 LKL=12.388 LPS=0.053 LKLS=10.155 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9860
# Train F1: 1.0000
# 01100: TRAIN| LT=0.310 LP=0.001 LKL=12.306 LPS=0.083 LKLS=10.205 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9843
# Train F1: 1.0000
# 01150: TRAIN| LT=0.290 LP=0.013 LKL=12.504 LPS=0.040 LKLS=11.079 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9808
# Train F1: 1.0000
# 01200: TRAIN| LT=0.266 LP=0.005 LKL=12.440 LPS=0.028 LKLS=10.807 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9860
# Train F1: 0.9972
# 01250: TRAIN| LT=0.311 LP=0.013 LKL=12.452 LPS=0.064 LKLS=10.891 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9860
# Train F1: 0.9943
# 01300: TRAIN| LT=0.301 LP=0.003 LKL=12.258 LPS=0.077 LKLS=9.916 |
# Test F1: 0.9348
# Test ACC: 0.8947
# Test AUC: 0.9843
# Train F1: 1.0000
# 01350: TRAIN| LT=0.293 LP=0.002 LKL=12.388 LPS=0.064 LKLS=10.310 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9825
# Train F1: 1.0000
# 01400: TRAIN| LT=0.288 LP=0.010 LKL=12.315 LPS=0.055 LKLS=9.994 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9825
# Train F1: 1.0000
# 01450: TRAIN| LT=0.257 LP=0.008 LKL=12.285 LPS=0.024 LKLS=10.199 |
# Test F1: 0.9462
# Test ACC: 0.9123
# Test AUC: 0.9825
# Train F1: 1.0000
# 01500: TRAIN| LT=0.268 LP=0.004 LKL=12.217 LPS=0.045 LKLS=9.619 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9843
# Train F1: 1.0000
# 01550: TRAIN| LT=0.277 LP=0.008 LKL=12.199 LPS=0.050 LKLS=9.640 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9825
# Train F1: 0.9943
# 01600: TRAIN| LT=0.251 LP=0.002 LKL=12.197 LPS=0.032 LKLS=9.500 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9825
# Train F1: 0.9972
# 01650: TRAIN| LT=0.245 LP=0.002 LKL=12.035 LPS=0.033 LKLS=8.942 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9860
# Train F1: 1.0000
# 01700: TRAIN| LT=0.293 LP=0.004 LKL=12.081 LPS=0.079 LKLS=8.948 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9878
# Train F1: 0.9972
# 01750: TRAIN| LT=0.253 LP=0.006 LKL=12.041 LPS=0.038 LKLS=8.829 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9860
# Train F1: 1.0000
# 01800: TRAIN| LT=0.265 LP=0.004 LKL=12.105 LPS=0.046 LKLS=9.409 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9825
# Train F1: 0.9972
# 01850: TRAIN| LT=0.248 LP=0.002 LKL=12.119 LPS=0.036 LKLS=8.872 |
# Test F1: 0.9663
# Test ACC: 0.9474
# Test AUC: 0.9825
# Train F1: 1.0000
# 01900: TRAIN| LT=0.269 LP=0.005 LKL=12.004 LPS=0.055 LKLS=8.932 |
# Test F1: 0.9556
# Test ACC: 0.9298
# Test AUC: 0.9878
# Train F1: 1.0000
# 01950: TRAIN| LT=0.250 LP=0.010 LKL=12.013 LPS=0.030 LKLS=9.006 |
# Test F1: 0.9565
# Test ACC: 0.9298
# Test AUC: 0.9860
# Train F1: 0.9943
# 02000: TRAIN| LT=0.256 LP=0.003 LKL=11.944 LPS=0.044 LKLS=8.881 |
# Test F1: 0.9451
# Test ACC: 0.9123
# Test AUC: 0.9860
# f1: 0.9662921348314608
# acc: 0.9473684210526315
# auc: 0.9877622377622378
# f1 [0.967032967032967, 0.9767441860465117, 0.9887640449438202, 0.967032967032967, 0.9662921348314608]
# average f1: 0.9731732599775453±0.008701498342483306
# acc [0.9482758620689655, 0.9655172413793104, 0.9824561403508771, 0.9473684210526315, 0.9473684210526315]
# average acc: 0.9581972171808832±0.013964505333626967
# auc [0.9756493506493507, 1.0, 1.0, 0.9965034965034965, 0.9877622377622378]
# average auc: 0.9919830169830168±0.009312168400693455
